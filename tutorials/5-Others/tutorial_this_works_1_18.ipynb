# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL/blob/master/tutorials/tutorial_this_works_1_18.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading
#
# Tutorials to use OpenAI DRL to trade multiple stocks in one Jupyter Notebook | Presented at NeurIPS 2020: Deep RL Workshop
#
# * This blog is based on our paper: FinRL: A Deep Reinforcement Learning Library for Automated Stock Trading in Quantitative Finance, presented at NeurIPS 2020: Deep RL Workshop.
# * Check out medium blog for detailed explanations: https://towardsdatascience.com/finrl-for-quantitative-finance-tutorial-for-multiple-stock-trading-7b00763b7530
# * Please report any issues to our Github: https://github.com/AI4Finance-LLC/FinRL-Library/issues
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- ASSUMES USING DOCKER, see readme for instructions

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Add FinRL to your path. You can of course install it as a pipy package, but this is for development purposes.

# %%
import sys

sys.path.append("..")

# %%
import pandas as pd
print(pd.__version__)
# Out:
# 1.1.5

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl import config
from finrl.neo_finrl.preprocessor.yahoodownloader import YahooDownloader
from finrl.neo_finrl.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.neo_finrl.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline

from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools
# Out:
# /opt/conda/lib/python3.6/site-packages/pyfolio/pos.py:27: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   'Module "zipline.assets" not found; multipliers will not be applied'

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
# from config.py start_date is a string
config.START_DATE
# Out:
# '2009-01-01'

# %%
# from config.py end_date is a string
config.END_DATE
# Out:
# '2020-12-01'

# %%
print(config.DOW_30_TICKER)
# Out:
# ['AAPL', 'MSFT', 'JPM', 'V', 'RTX', 'PG', 'GS', 'NKE', 'DIS', 'AXP', 'HD', 'INTC', 'WMT', 'IBM', 'MRK', 'UNH', 'KO', 'CAT', 'TRV', 'JNJ', 'CVX', 'MCD', 'VZ', 'CSCO', 'XOM', 'BA', 'MMM', 'PFE', 'WBA', 'DD']

# %%
df = YahooDownloader(start_date = '2009-01-01',
                     end_date = '2021-01-01',
                     ticker_list = config.DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (90630, 8)

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = config.INDICATORS,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators
# Successfully added turbulence index

# %%
processed['log_volume'] = np.log(processed.volume*processed.close)
processed['change'] = (processed.close-processed.open)/processed.close
processed['daily_variance'] = (processed.high-processed.low)/processed.close
processed.head()
# Out:
#          date       open       high        low      close       volume   tic  \
# 0  2009-01-02   3.067143   3.251429   3.041429   2.795913  746015200.0  AAPL
# 1  2009-01-02  18.570000  19.520000  18.400000  15.745411   10955700.0   AXP
# 2  2009-01-02  42.799999  45.560001  42.779999  33.680935    7010200.0    BA
# 3  2009-01-02  44.910000  46.980000  44.709999  32.514400    7117200.0   CAT
# 4  2009-01-02  16.410000  17.000000  16.250000  12.683227   40980600.0  CSCO
#
#    day  macd  rsi_30     cci_30  dx_30  turbulence  log_volume    change  \
# 0    4   0.0   100.0  66.666667  100.0         0.0   21.458415 -0.097009
# 1    4   0.0   100.0  66.666667  100.0         0.0   18.965919 -0.179391
# 2    4   0.0   100.0  66.666667  100.0         0.0   19.279809 -0.270749
# 3    4   0.0   100.0  66.666667  100.0         0.0   19.259708 -0.381234
# 4    4   0.0   100.0  66.666667  100.0         0.0   20.068890 -0.293835
#
#    daily_variance
# 0        0.075110
# 1        0.071132
# 2        0.082539
# 3        0.069815
# 4        0.059133

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %% [markdown]
# ## Training data split: 2009-01-01 to 2018-12-31
# ## Trade data split: 2019-01-01 to 2020-09-30

# %%
train = data_split(processed, '2009-01-01','2019-01-01')
trade = data_split(processed, '2019-01-01','2021-01-01')
print(len(train))
print(len(trade))
# Out:
# 75480
# 15150

# %%
import numpy as np
import pandas as pd
from gym.utils import seeding
import gym
from gym import spaces
import matplotlib
from copy import deepcopy

matplotlib.use("Agg")
import matplotlib.pyplot as plt
import pickle
from stable_baselines3.common.vec_env import DummyVecEnv
import numpy as np
import pandas as pd
from gym.utils import seeding
import gym
from gym import spaces
import matplotlib
import random

matplotlib.use("Agg")
import matplotlib.pyplot as plt
import pickle
from stable_baselines3.common.vec_env import DummyVecEnv, SubprocVecEnv
from stable_baselines3.common import logger
import time


class StockTradingEnvV2(gym.Env):

    """
    A stock trading environment for OpenAI gym
    Parameters:
    state space: {start_cash, <owned_shares>, for s in stocks{<stock.values>}, }
        df (pandas.DataFrame): Dataframe containing data
        transaction_cost (float): cost for buying or selling shares
        hmax (int): max number of share purchases allowed per asset
        turbulence_threshold (float): Maximum turbulence allowed in market for purchases to occur. If exceeded, positions are liquidated
        print_verbosity(int): When iterating (step), how often to print stats about state of env
        reward_scaling (float): Scaling value to multiply reward by at each step.
        initial_amount: (int, float): Amount of cash initially available
        daily_information_columns (list(str)): Columns to use when building state space from the dataframe.
        out_of_cash_penalty (int, float): Penalty to apply if the algorithm runs out of cash

    action space: <share_dollar_purchases>

    TODO:
        make cash penalty proportional to total assets


    tests:
        after reset, static strategy should result in same metrics

        buy zero should result in no costs, no assets purchased
        given no change in prices, no change in asset values
    """

    metadata = {"render.modes": ["human"]}

    def __init__(
        self,
        df,
        transaction_cost_pct=3e-3,
        date_col_name="date",
        hmax=10,
        turbulence_threshold=None,
        print_verbosity=10,
        reward_scaling=1e-4,
        initial_amount=1e6,
        daily_information_cols=["open", "close", "high", "low", "volume"],
        out_of_cash_penalty=None,
        cache_indicator_data=True,
        daily_reward=None,
        cash_penalty_proportion=0.1,
        random_start=True,
    ):
        self.df = df
        self.stock_col = "tic"
        self.assets = df[self.stock_col].unique()
        self.dates = df[date_col_name].sort_values().unique()
        self.random_start = random_start

        self.df = self.df.set_index(date_col_name)
        self.hmax = hmax
        self.initial_amount = initial_amount
        if out_of_cash_penalty is None:
            out_of_cash_penalty = -initial_amount * 0.5
        self.out_of_cash_penalty = out_of_cash_penalty
        self.print_verbosity = print_verbosity
        self.transaction_cost_pct = transaction_cost_pct
        self.reward_scaling = reward_scaling
        self.daily_information_cols = daily_information_cols
        self.state_space = (
            1 + len(self.assets) + len(self.assets) * len(self.daily_information_cols)
        )
        self.action_space = spaces.Box(low=-1, high=1, shape=(len(self.assets),))
        self.observation_space = spaces.Box(
            low=-np.inf, high=np.inf, shape=(self.state_space,)
        )
        self.episode = -1  # initialize so we can call reset
        self.episode_history = []
        self.printed_header = False
        self.daily_reward = daily_reward
        self.cache_indicator_data = cache_indicator_data
        self.cached_data = None
        self.cash_penalty_proportion = cash_penalty_proportion
        if self.cache_indicator_data:
            print("caching data")
            self.cached_data = [
                self.get_date_vector(i) for i, _ in enumerate(self.dates)
            ]
            print("data cached!")

    def seed(self, seed=None):
        if seed is None:
            seed = int(round(time.time() * 1000))
        random.seed(seed)

    @property
    def current_step(self):
        return self.date_index - self.starting_point

    def reset(self):
        self.seed()
        self.sum_trades = 0
        if self.random_start:
            starting_point = random.choice(range(int(len(self.dates) * 0.5)))
            self.starting_point = starting_point
        else:
            self.starting_point = 0
        self.date_index = self.starting_point
        self.episode += 1
        self.actions_memory = []
        self.transaction_memory = []
        self.state_memory = []
        self.account_information = {
            "cash": [],
            "asset_value": [],
            "total_assets": [],
            "reward": [],
        }
        init_state = np.array(
            [self.initial_amount]
            + [0] * len(self.assets)
            + self.get_date_vector(self.date_index)
        )
        self.state_memory.append(init_state)
        return init_state

    def get_date_vector(self, date, cols=None):
        if (cols is None) and (self.cached_data is not None):
            return self.cached_data[date]
        else:
            date = self.dates[date]
            if cols is None:
                cols = self.daily_information_cols
            trunc_df = self.df.loc[date]
            v = []
            for a in self.assets:
                subset = trunc_df[trunc_df[self.stock_col] == a]
                v += subset.loc[date, cols].tolist()
            assert len(v) == len(self.assets) * len(cols)
            return v

    def return_terminal(self, reason="Last Date", reward=0):

        state = self.state_memory[-1]
        self.log_step(reason=reason, terminal_reward=reward)
        reward = reward * self.reward_scaling
        # Add outputs to logger interface
        reward_pct = self.account_information["total_assets"][-1] / self.initial_amount
        logger.record("environment/total_reward_pct", (reward_pct - 1) * 100)
        logger.record(
            "environment/daily_trades",
            self.sum_trades / (self.current_step) / len(self.assets),
        )
        logger.record("environment/completed_steps", self.current_step)
        logger.record(
            "environment/sum_rewards", np.sum(self.account_information["reward"])
        )
        logger.record(
            "environment/cash_proportion",
            self.account_information["cash"][-1]
            / self.account_information["total_assets"][-1],
        )
        return state, reward, True, {}

    def log_step(self, reason, terminal_reward=None):
        if terminal_reward is None:
            terminal_reward = self.account_information["reward"][-1]
        cash_pct = (
            self.account_information["cash"][-1]
            / self.account_information["total_assets"][-1]
        )
        rec = [
            self.episode,
            self.date_index - self.starting_point,
            reason,
            f"${int(self.account_information['total_assets'][-1])}",
            f"{terminal_reward*100:0.5f}%",
            f"{cash_pct*100:0.2f}%",
        ]

        self.episode_history.append(rec)
        print(self.template.format(*rec))

    def log_header(self):
        self.template = "{0:4}|{1:4}|{2:15}|{3:10}|{4:10}|{5:10}"  # column widths: 8, 10, 15, 7, 10
        print(
            self.template.format(
                "EPISODE",
                "STEPS",
                "TERMINAL_REASON",
                "TOT_ASSETS",
                "TERMINAL_REWARD_unsc",
                "CASH_PCT",
            )
        )
        self.printed_header = True
        
    def get_reward(self):
        if self.current_step==0:
            return 0
        else:
            assets = self.account_information['total_assets'][-1]
            cash = self.account_information['cash'][-1]
            cash_penalty = max(0, (assets*self.cash_penalty_proportion-cash))
            assets -= cash_penalty
            reward = (assets/self.initial_amount)-1
            reward/=self.current_step
            return reward

    def step(self, actions):
        # let's just log what we're doing in terms of max actions at each step.
        self.sum_trades += np.sum(np.abs(actions))

        # print header only first time
        if self.printed_header is False:
            self.log_header()

        # print if it's time.
        if (self.current_step + 1) % self.print_verbosity == 0:
            self.log_step(reason="update")

        # if we're at the end
        if self.date_index == len(self.dates) - 1:
            # if we hit the end, set reward to total gains (or losses)
            return self.return_terminal(reward=self.get_reward())
        else:
            # compute value of cash + assets
            begin_cash = self.state_memory[-1][0]
            holdings = self.state_memory[-1][1 : len(self.assets) + 1]
            assert min(holdings) >= 0
            closings = np.array(self.get_date_vector(self.date_index, cols=["close"]))
            asset_value = np.dot(holdings, closings)

            # reward is (cash + assets) - (cash_last_step + assets_last_step)
            reward = self.get_reward()

            # log the values of cash, assets, and total assets
            self.account_information["cash"].append(begin_cash)
            self.account_information["asset_value"].append(asset_value)
            self.account_information["total_assets"].append(begin_cash + asset_value)
            self.account_information["reward"].append(reward)

            # multiply action values by our scalar multiplier and save
            actions = actions * self.hmax
            self.actions_memory.append(actions)

            # scale cash purchases to asset # changes
            actions = actions / closings
            self.transaction_memory.append(actions)

            # clip actions so we can't sell more assets than we hold
            actions = np.maximum(actions, -np.array(holdings))

            # compute our proceeds from sales, and add to cash
            sells = -np.clip(actions, -np.inf, 0)
            proceeds = np.dot(sells, closings)
            costs = proceeds * self.transaction_cost_pct
            coh = begin_cash + proceeds

            # compute the cost of our buys
            buys = np.clip(actions, 0, np.inf)
            spend = np.dot(buys, closings)
            costs += spend * self.transaction_cost_pct

            # if we run out of cash, end the cycle and penalize
            if (spend + costs) > coh:
                return self.return_terminal(
                    reason="CASH SHORTAGE",
                    reward=self.get_reward()
                )

            # verify we didn't do anything impossible here
            assert (spend + costs) <= coh

            # update our holdings
            coh = coh - spend - costs
            holdings_updated = holdings + actions
            self.date_index += 1
            state = (
                [coh] + list(holdings_updated) + self.get_date_vector(self.date_index)
            )
            self.state_memory.append(state)
            reward = reward * self.reward_scaling
            return state, reward, False, {}

    def get_sb_env(self):
        def get_self():
            return deepcopy(self)

        e = DummyVecEnv([get_self])
        obs = e.reset()
        return e, obs

    def get_multiproc_env(self, n=10):
        def get_self():
            return deepcopy(self)

        e = SubprocVecEnv([get_self for _ in range(n)], start_method="fork")
        obs = e.reset()
        return e, obs

    def save_asset_memory(self):
        if self.current_step == 0:
            return None
        else:
            self.account_information["date"] = self.dates[
                -len(self.account_information["cash"]) :
            ]
            return pd.DataFrame(self.account_information)

    def save_action_memory(self):
        if self.current_step == 0:
            return None
        else:
            return pd.DataFrame(
                {
                    "date": self.dates[-len(self.account_information["cash"]) :],
                    "actions": self.actions_memory,
                    "transactions": self.transaction_memory,
                }
            )

# %%
print(StockTradingEnvV2.__doc__)
# Out:
#     A stock trading environment for OpenAI gym
#     Parameters:
#     state space: {start_cash, <owned_shares>, for s in stocks{<stock.values>}, }
#         df (pandas.DataFrame): Dataframe containing data
#         transaction_cost (float): cost for buying or selling shares
#         hmax (int): max number of share purchases allowed per asset
#         turbulence_threshold (float): Maximum turbulence allowed in market for purchases to occur. If exceeded, positions are liquidated
#         print_verbosity(int): When iterating (step), how often to print stats about state of env
#         reward_scaling (float): Scaling value to multiply reward by at each step.
#         initial_amount: (int, float): Amount of cash initially available
#         daily_information_columns (list(str)): Columns to use when building state space from the dataframe.
#         out_of_cash_penalty (int, float): Penalty to apply if the algorithm runs out of cash
#
#     action space: <share_dollar_purchases>
#
#     TODO:
#         make cash penalty proportional to total assets
#
#
#     tests:
#         after reset, static strategy should result in same metrics
#
#         buy zero should result in no costs, no assets purchased
#         given no change in prices, no change in asset values

# %% [markdown]
# #### state space
# The state space of the observation is as follows
#
# `start_cash, <owned_shares_of_n_assets>, <<indicator_i_for_asset_j> for j in assets>`
#
# indicators are any daily measurement you can achieve. Common ones are 'volume', 'open' 'close' 'high', 'low'.
# However, you can add these as needed,
# The feature engineer adds indicators, and you can add your own as well.

# %%
processed.head()
# Out:
#          date       open       high        low      close       volume   tic  \
# 0  2009-01-02   3.067143   3.251429   3.041429   2.795913  746015200.0  AAPL
# 1  2009-01-02  18.570000  19.520000  18.400000  15.745411   10955700.0   AXP
# 2  2009-01-02  42.799999  45.560001  42.779999  33.680935    7010200.0    BA
# 3  2009-01-02  44.910000  46.980000  44.709999  32.514400    7117200.0   CAT
# 4  2009-01-02  16.410000  17.000000  16.250000  12.683227   40980600.0  CSCO
#
#    day  macd  rsi_30     cci_30  dx_30  turbulence  log_volume    change  \
# 0    4   0.0   100.0  66.666667  100.0         0.0   21.458415 -0.097009
# 1    4   0.0   100.0  66.666667  100.0         0.0   18.965919 -0.179391
# 2    4   0.0   100.0  66.666667  100.0         0.0   19.279809 -0.270749
# 3    4   0.0   100.0  66.666667  100.0         0.0   19.259708 -0.381234
# 4    4   0.0   100.0  66.666667  100.0         0.0   20.068890 -0.293835
#
#    daily_variance
# 0        0.075110
# 1        0.071132
# 2        0.082539
# 3        0.069815
# 4        0.059133

# %%
information_cols = ['daily_variance', 'change', 'log_volume', 'close','day', 
                    'macd', 'rsi_30', 'cci_30', 'dx_30', 'turbulence']

e_train_gym = StockTradingEnvV2(df = train,initial_amount = 1e6,hmax = 5000, 
                                out_of_cash_penalty = 0, 
                                cache_indicator_data=True,
                                cash_penalty_proportion=0.2, 
                                reward_scaling=1,
                                daily_information_cols = information_cols, 
                                print_verbosity = 500, random_start = True)


trade = data_split(processed, '2019-01-01','2021-01-01')


e_trade_gym = StockTradingEnvV2(df = trade,initial_amount = 1e6,hmax = 5000, 
                                out_of_cash_penalty = 0, 
                                cash_penalty_proportion=0.2,
                                reward_scaling = 1, 
                                cache_indicator_data=True,
                                daily_information_cols = information_cols, 
                                print_verbosity = 500, random_start = False)
# Out:
# caching data
# data cached!
# caching data
# data cached!

# %% [markdown]
# ## Environment for Training
# There are two available environments. The multiprocessing and the single processing env.
# Some models won't work with multiprocessing.
#
# ```python
# # single processing
# env_train, _ = e_train_gym.get_sb_env()
#
#
# #multiprocessing
# env_train, _ = e_train_gym.get_multiproc_env(n = <n_cores>)
# ```

# %%
# for this example, let's do multiprocessing with n_cores-2

import multiprocessing

n_cores = multiprocessing.cpu_count() - 2
n_cores = 24
print(f"using {n_cores} cores")

#this is our training env. It allows multiprocessing
env_train, _ = e_train_gym.get_multiproc_env(n = n_cores)
# env_train, _ = e_train_gym.get_sb_env()


#this is our observation environment. It allows full diagnostics
env_trade, _ = e_trade_gym.get_sb_env()
# Out:
# using 24 cores
# EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT  EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT  EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT  EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT  EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT  EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT  EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT  EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT
# EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT  EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT  EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT  EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT
# EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT  EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT  EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT  EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT
# EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT  EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT  EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT
#
#
#
# EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT    47|1164|CASH SHORTAGE  |$1258678  |0.00189%  |1.20%
#   50|1972|CASH SHORTAGE  |$1651301  |0.01659%  |0.36%
#   50| 999|update         |$1248120  |0.01671%  |13.01%
#   50| 499|update         |$1217370  |0.02287%  |11.05%
#   52|1750|CASH SHORTAGE  |$1990771  |0.03515%  |1.13%
#   46|1499|update         |$1412770  |0.01635%  |6.60%
#   50| 999|update         |$1217826  |0.00329%  |6.14%
#   49| 499|update         |$1147229  |0.00852%  |12.02%
#   50| 499|update         |$1260071  |0.02766%  |8.22%
#   49| 711|CASH SHORTAGE  |$1098277  |-0.01512% |1.26%
#   49|1439|CASH SHORTAGE  |$1784172  |0.03015%  |0.37%
#   50|1079|CASH SHORTAGE  |$1256115  |0.00128%  |0.71%
#   48| 499|update         |$1143076  |0.01829%  |18.03%
#   50|1198|CASH SHORTAGE  |$1429800  |0.01268%  |0.56%
#   48| 499|update         |$1164773  |0.00058%  |4.68%
#   50| 499|update         |$1082494  |0.00249%  |15.96%
#   49| 648|CASH SHORTAGE  |$1307075  |0.00740%  |0.18%
#   50| 999|update         |$1260451  |0.01278%  |9.26%
#   50| 499|update         |$1033080  |0.00667%  |25.38%
#   47| 499|update         |$1132838  |0.01072%  |11.16%
#   52| 499|update         |$1023724  |0.00400%  |18.36%
#   52| 499|update         |$1060835  |-0.00152% |14.79%
#   50| 499|update         |$1057956  |0.00053%  |11.24%      51| 499|update         |$1204667  |0.01238%  |9.81%
#
#   50| 691|CASH SHORTAGE  |$1352230  |0.01334%  |0.77%
#   50|1083|CASH SHORTAGE  |$1289438  |0.00320%  |0.24%
#   51| 499|update         |$976351   |-0.01386% |15.09%
#   46|1815|CASH SHORTAGE  |$1525997  |0.01285%  |0.82%
#   51|1468|CASH SHORTAGE  |$1221860  |-0.00142% |0.14%
#   50| 499|update         |$1146605  |-0.00120% |5.13%
#   48| 499|update         |$1046713  |-0.00936% |10.10%
#   50| 329|CASH SHORTAGE  |$971039   |-0.06664% |0.40%
#   51| 499|update         |$1023483  |-0.00857% |10.92%
#   50| 999|update         |$1231466  |0.01636%  |11.56%
#   53| 499|update         |$940579   |-0.03147% |11.58%
#   52| 799|CASH SHORTAGE  |$1284222  |0.00509%  |1.03%
#   50| 499|update         |$1212968  |0.03472%  |14.69%
#   52| 856|CASH SHORTAGE  |$1292441  |0.00635%  |1.58%
#   51| 499|update         |$1034363  |-0.01722% |7.73%
#   48| 999|update         |$1210991  |0.01049%  |9.71%
#   47| 911|CASH SHORTAGE  |$1450900  |0.01897%  |0.83%
#   51| 499|update         |$1162425  |0.01354%  |10.92%
#   51| 547|CASH SHORTAGE  |$1086819  |-0.02363% |0.12%
#   48| 999|update         |$1368478  |0.02122%  |10.45%
#   50| 999|update         |$1387522  |0.02662%  |11.36%
#   50| 499|update         |$1014915  |-0.01404% |12.55%
#   48|1039|CASH SHORTAGE  |$1366842  |0.00983%  |0.64%
#   48| 784|CASH SHORTAGE  |$1192786  |-0.00070% |3.38%
#   50| 999|update         |$1315322  |0.01840%  |8.77%
#   53| 734|CASH SHORTAGE  |$1009564  |-0.02053% |4.13%
#   50| 967|CASH SHORTAGE  |$1278456  |0.00265%  |0.23%
#   51| 999|update         |$1347733  |0.01770%  |5.56%
#   51| 499|update         |$1138487  |0.00983%  |10.79%
#   51| 499|update         |$1044896  |-0.01394% |11.03%
#   51| 999|update         |$1215475  |0.00864%  |6.82%
#   50| 951|CASH SHORTAGE  |$1223676  |-0.00139% |0.64%
#   47| 489|CASH SHORTAGE  |$960161   |-0.03967% |3.95%
#   51| 999|update         |$1437637  |0.02357%  |5.13%
#   51|1770|CASH SHORTAGE  |$1636984  |0.01779%  |0.32%
#   49| 499|update         |$1221222  |0.03400%  |17.37%
#   53|1148|CASH SHORTAGE  |$1276124  |0.00184%  |0.02%
#   53| 598|CASH SHORTAGE  |$1115240  |-0.01655% |0.79%
#   51| 971|CASH SHORTAGE  |$1248077  |0.00110%  |0.98%
#   52| 499|update         |$1017130  |0.00208%  |21.91%
#   51|1499|update         |$1491669  |0.01953%  |7.96%
#   48| 999|update         |$1411643  |0.03197%  |11.11%
#   55| 499|update         |$1082088  |-0.00525% |9.21%
#   52| 499|update         |$1056091  |-0.01074% |13.18%
#   53|1331|CASH SHORTAGE  |$1412426  |0.01008%  |0.30%
#   50|2196|CASH SHORTAGE  |$1756746  |0.01883%  |0.47%
#   52| 499|update         |$1190529  |0.03552%  |17.85%
#   52| 499|update         |$1168096  |0.01144%  |10.56%
#   51| 499|update         |$965430   |-0.01406% |17.75%
#   49|1258|CASH SHORTAGE  |$1470185  |0.01528%  |1.10%
#   51|1877|Last Date      |$1518359  |0.01472%  |4.06%
#   51| 570|CASH SHORTAGE  |$1062547  |-0.02177% |2.44%
#   51| 905|CASH SHORTAGE  |$1290108  |0.00356%  |0.01%
#   51|1788|CASH SHORTAGE  |$1854243  |0.02747%  |0.42%
#   52| 499|update         |$1171118  |0.02966%  |17.92%
#   52| 799|CASH SHORTAGE  |$1216077  |-0.00093% |1.62%
#   52|1499|update         |$1808295  |0.03585%  |5.57%
#   49| 499|update         |$1000626  |-0.00024% |22.24%
#   51| 987|CASH SHORTAGE  |$1318171  |0.00564%  |0.08%
#   50| 499|update         |$1191945  |0.00995%  |6.62%
#   51|1499|update         |$1600732  |0.02532%  |5.62%
#   52| 499|update         |$1153277  |-0.00320% |6.69%
#   49| 999|update         |$1286331  |0.01834%  |10.82%
#   54| 499|update         |$1214731  |0.00833%  |6.25%
#   52|1580|CASH SHORTAGE  |$1735761  |0.02517%  |0.53%
#   54| 504|CASH SHORTAGE  |$1246255  |0.00235%  |1.19%
#   54| 499|update         |$1206082  |0.02292%  |9.86%
#   52| 499|update         |$1234893  |0.02017%  |8.58%
#   52| 999|update         |$1421167  |0.03169%  |13.94%
#   48|1499|update         |$1814075  |0.03946%  |7.53%
#   51|1586|Last Date      |$1463782  |0.01460%  |4.14%
#   52| 594|CASH SHORTAGE  |$1137740  |-0.01473% |0.20%
#   52| 898|CASH SHORTAGE  |$1128951  |-0.00887% |1.52%
#   55| 999|update         |$1325754  |0.01605%  |6.77%
#   54| 499|update         |$1181038  |0.01584%  |10.16%
#   51| 499|update         |$1123235  |0.00770%  |13.57%
#   52| 999|update         |$1282303  |0.01683%  |11.85%
#   52| 851|CASH SHORTAGE  |$1427035  |0.01771%  |0.63%
#   50| 499|update         |$1186363  |0.01338%  |9.72%
#   52| 499|update         |$1236961  |0.02560%  |9.50%
#   52| 499|update         |$1077843  |0.00274%  |12.47%
#   52| 499|update         |$1062785  |-0.00200% |15.74%
#   52| 499|update         |$1204779  |0.01761%  |12.77%
#   49| 903|CASH SHORTAGE  |$1329328  |0.00837%  |0.91%
#   52| 833|CASH SHORTAGE  |$1197050  |-0.00271% |1.65%
#   53| 499|update         |$1041599  |-0.01093% |13.05%
#   54| 816|CASH SHORTAGE  |$1155552  |-0.00908% |0.12%
#   52| 499|update         |$1033337  |-0.01966% |10.11%
#   50| 999|update         |$1348241  |0.02085%  |10.14%
#   49|1499|update         |$1868325  |0.04199%  |6.88%
#   53| 499|update         |$1026836  |-0.01428% |11.65%
#   55| 499|update         |$1004349  |-0.02187% |7.37%
#   54| 999|update         |$1205296  |-0.00010% |4.67%
#   52|1499|update         |$1502141  |0.01728%  |4.05%
#   52|1505|CASH SHORTAGE  |$1510878  |0.01387%  |0.01%
#   48|1999|update         |$1962249  |0.03390%  |4.94%
#   52|1353|CASH SHORTAGE  |$1550732  |0.01860%  |0.72%
#   52| 499|update         |$975041   |-0.02063% |15.09%
#   53| 499|update         |$1171556  |0.00641%  |9.40%
#   54|1067|CASH SHORTAGE  |$1303823  |0.00619%  |1.77%
#   55| 592|CASH SHORTAGE  |$1126320  |-0.01669% |0.01%
#   53| 499|update         |$1228800  |0.02762%  |11.78%
#   52| 797|CASH SHORTAGE  |$1279188  |0.00310%  |0.11%
#   55|1499|update         |$1512612  |0.02177%  |6.76%
#   55|1511|CASH SHORTAGE  |$1476784  |0.01216%  |0.16%
#   50| 932|CASH SHORTAGE  |$1199393  |-0.00096% |2.63%
#   51| 999|update         |$1337613  |0.01713%  |7.19%
#   50|1209|CASH SHORTAGE  |$1443747  |0.01325%  |0.36%
#   53| 499|update         |$1041267  |-0.00360% |13.22%
#   52| 999|update         |$1338033  |0.01633%  |7.37%
#   52| 999|update         |$1294801  |0.02051%  |11.73%
#   52| 841|CASH SHORTAGE  |$1344274  |0.00994%  |0.61%
#   52| 999|update         |$1434641  |0.02498%  |7.70%
#   50| 499|update         |$1224930  |0.02518%  |9.99%
#   53| 499|update         |$1009523  |-0.01194% |12.75%
#   55| 459|CASH SHORTAGE  |$1193035  |-0.00913% |0.31%
#   53| 999|update         |$1450808  |0.02227%  |5.31%
#   53| 387|CASH SHORTAGE  |$939080   |-0.05901% |2.17%
#   56| 344|CASH SHORTAGE  |$1070427  |-0.03961% |0.69%
#   53| 601|CASH SHORTAGE  |$953137   |-0.03917% |0.22%
#   49|1989|CASH SHORTAGE  |$2072483  |0.03456%  |1.42%
#   56| 371|CASH SHORTAGE  |$1129984  |-0.02015% |1.88%
#   53| 999|update         |$1294771  |0.02080%  |10.92%
#   53| 231|CASH SHORTAGE  |$1048112  |-0.05177% |4.00%
#   48|2482|Last Date      |$2129634  |0.03421%  |6.83%
#   53| 499|update         |$1162822  |0.01883%  |11.47%
#   52| 999|update         |$1353641  |0.02206%  |10.41%
#   53| 999|update         |$1461338  |0.02800%  |6.86%
#   55| 499|update         |$1194524  |0.01027%  |8.74%
#   53| 999|update         |$1363796  |0.02315%  |8.42%
#   53| 499|update         |$1137980  |0.00145%  |7.48%
#   55| 543|CASH SHORTAGE  |$1159851  |-0.01109% |1.03%
#   51| 499|update         |$1196468  |0.01416%  |10.05%
#   51|1499|update         |$1669884  |0.03454%  |11.67%
#   51| 499|update         |$1164253  |0.00781%  |8.78%
#   52|1149|CASH SHORTAGE  |$1518341  |0.01986%  |0.89%       53|1212|CASH SHORTAGE  |$1420273  |0.01159%  |0.30%
#
#   53| 999|update         |$1441840  |0.03267%  |11.13%
#   52|1499|update         |$1600940  |0.02613%  |6.73%
#   52|1499|update         |$1546153  |0.02367%  |10.41%
#   53| 744|CASH SHORTAGE  |$1033698  |-0.02256% |0.51%
#   53|1400|CASH SHORTAGE  |$1356562  |0.00795%  |1.92%
#   52|1499|update         |$1805146  |0.03538%  |6.40%
#   50| 999|update         |$1323756  |0.01603%  |8.11%
#   56| 499|update         |$1229961  |0.02289%  |13.29%
#   53|1313|CASH SHORTAGE  |$1734898  |0.02981%  |0.20%
#   54| 499|update         |$1140601  |0.00378%  |9.06%
#   53|1220|CASH SHORTAGE  |$1511513  |0.01774%  |0.48%
#   57| 499|update         |$1156081  |0.00195%  |8.58%
#   54| 499|update         |$1104330  |0.01161%  |14.89%
#   52|1672|Last Date      |$1423536  |0.01359%  |6.21%
#   52|1668|CASH SHORTAGE  |$1622589  |0.01977%  |1.95%
#   50| 499|update         |$1093157  |0.00436%  |12.78%
#   57| 499|update         |$994146   |-0.01363% |12.31%
#   51|1853|CASH SHORTAGE  |$1584698  |0.01514%  |0.80%
#   54| 499|update         |$1094922  |-0.00281% |10.59%
#   49| 499|update         |$1179904  |0.00708%  |6.27%
#   51| 875|CASH SHORTAGE  |$1447927  |0.01838%  |0.17%
#   53|1499|update         |$1768539  |0.03389%  |5.57%
#   51| 933|CASH SHORTAGE  |$1268646  |0.00337%  |1.30%
#   53| 999|update         |$1473476  |0.02433%  |2.02%
#   56| 499|update         |$1230725  |0.02633%  |13.42%
#   50| 710|CASH SHORTAGE  |$1257723  |0.00109%  |0.12%
#   52|1873|CASH SHORTAGE  |$1836857  |0.02567%  |0.62%
#   54| 499|update         |$1279381  |0.03011%  |9.72%
#   53| 499|update         |$1215095  |0.01244%  |5.98%
#   53| 253|CASH SHORTAGE  |$940709   |-0.09143% |1.71%
#   53| 508|CASH SHORTAGE  |$1216739  |-0.00311% |0.89%
#   49| 750|CASH SHORTAGE  |$1081745  |-0.01650% |1.00%
#   54| 499|update         |$1014571  |-0.02136% |9.80%
#   54| 499|update         |$1030537  |-0.02106% |7.08%
#   50|1499|update         |$1856200  |0.03898%  |6.54%
#   56| 999|update         |$1485945  |0.03367%  |9.86%
#   54| 499|update         |$955530   |-0.03559% |5.91%
#   54| 999|update         |$1240084  |0.01296%  |9.73%
#   53|1861|CASH SHORTAGE  |$1854706  |0.02601%  |0.01%
#   54| 499|update         |$1021548  |-0.01103% |13.28%
#   57| 999|update         |$1263730  |0.00388%  |2.86%
#   54| 627|CASH SHORTAGE  |$1098819  |-0.01750% |1.02%
#   54| 999|update         |$1328554  |0.02520%  |11.09%
#   53| 499|update         |$975275   |-0.03210% |9.50%
#   57| 999|update         |$1247736  |0.01422%  |10.08%
#   52| 499|update         |$1040298  |-0.01389% |11.49%
#   54| 999|update         |$1453778  |0.02870%  |9.00%
#   52| 499|update         |$956073   |-0.02585% |10.88%
#   53| 631|CASH SHORTAGE  |$986551   |-0.03069% |1.73%
#   52| 499|update         |$1143805  |-0.00705% |4.79%
#   53|1499|update         |$1698897  |0.03327%  |7.06%
#   56| 999|update         |$1397039  |0.02699%  |12.53%
#   52| 602|CASH SHORTAGE  |$1063823  |-0.02319% |0.88%
#   52| 593|CASH SHORTAGE  |$988847   |-0.03441% |0.49%
#   51| 499|update         |$1192001  |0.00642%  |5.60%
#   52| 586|CASH SHORTAGE  |$1112401  |-0.01565% |1.65%
#   53| 499|update         |$1094164  |0.01195%  |14.48%
#   54| 999|update         |$1379928  |0.02497%  |12.22%
#   54| 499|update         |$1173101  |0.00595%  |5.04%
#   54| 499|update         |$1215960  |0.02476%  |13.71%
#   54| 547|CASH SHORTAGE  |$1121915  |-0.01605% |1.31%
#   50| 499|update         |$1136927  |0.01442%  |15.90%
#   54| 999|update         |$1422844  |0.03313%  |15.33%
#   53|1717|CASH SHORTAGE  |$2141104  |0.04235%  |0.66%
#   50|1999|update         |$2067662  |0.04201%  |9.83%
#   56|1499|update         |$1750574  |0.03348%  |7.59%
#   54| 999|update         |$1299156  |0.01901%  |11.17%
#   54|1499|update         |$1527278  |0.02686%  |11.71%
#   54| 499|update         |$1045298  |-0.00739% |11.62%
#   54| 999|update         |$1355437  |0.02221%  |7.33%
#   57|1499|update         |$1534273  |0.02206%  |5.69%
#   55| 499|update         |$1187182  |0.02260%  |14.58%
#   54|1499|update         |$1447889  |0.02205%  |13.73%
#   57|1499|update         |$1402557  |0.02522%  |16.01%
#   57|1554|Last Date      |$1394912  |0.01374%  |7.00%
#   54|1499|update         |$1633194  |0.02722%  |6.44%
#   54| 499|update         |$1154933  |0.00417%  |7.87%
#   54|1183|CASH SHORTAGE  |$1233963  |-0.00034% |0.71%
#   56|1499|update         |$1756150  |0.03440%  |8.22%
#   53| 499|update         |$995294   |0.00237%  |25.20%
#   53| 499|update         |$1093921  |0.00438%  |12.42%
#   51| 999|update         |$1404474  |0.02371%  |7.66%
#   53| 499|update         |$1052360  |-0.01045% |12.99%
#   53| 999|update         |$1337845  |0.02102%  |11.37%
#   54|1499|update         |$1641048  |0.02936%  |8.07%
#   54| 999|update         |$1322583  |0.02466%  |11.57%
#   55| 784|CASH SHORTAGE  |$1178545  |-0.00564% |1.10%
#   55| 482|CASH SHORTAGE  |$1112754  |-0.01956% |1.39%
#   53|1042|CASH SHORTAGE  |$1337314  |0.00863%  |1.50%
#   50| 999|update         |$1511881  |0.03393%  |11.40%
#   54|1499|update         |$1483290  |0.02155%  |9.95%
#   56|1899|Last Date      |$1699502  |0.02495%  |6.72%
#   50|2470|Last Date      |$2171339  |0.03355%  |4.21%
#   54|1604|CASH SHORTAGE  |$1616964  |0.01886%  |0.55%
#   54| 499|update         |$1024029  |0.00154%  |15.59%
#   54|1410|CASH SHORTAGE  |$1368189  |0.00819%  |1.53%
#   53| 787|CASH SHORTAGE  |$1188062  |-0.00558% |0.48%
#   54|1999|update         |$1777471  |0.02722%  |6.47%
#   54| 999|update         |$1364463  |0.02204%  |10.30%
#   54|1640|CASH SHORTAGE  |$1671156  |0.02260%  |2.02%
#   54|1999|update         |$2217566  |0.04402%  |4.06%
#   50|1204|CASH SHORTAGE  |$1453989  |0.01388%  |0.27%
#   57|1999|update         |$1778356  |0.02552%  |6.80%
#   58| 499|update         |$1069211  |0.00132%  |14.78%
#   54|1971|Last Date      |$1693305  |0.02346%  |6.36%
#   56|1887|CASH SHORTAGE  |$1895606  |0.02908%  |1.70%
#   54| 952|CASH SHORTAGE  |$1373408  |0.01090%  |0.37%
#   54|1332|CASH SHORTAGE  |$1663949  |0.02688%  |1.62%
#   55| 499|update         |$1042003  |-0.00270% |15.09%
#   53| 995|CASH SHORTAGE  |$1345260  |0.00870%  |0.77%
#   51|1499|update         |$1683670  |0.02919%  |7.98%
#   54|2234|Last Date      |$1782467  |0.02386%  |6.01%
#   53| 999|update         |$1296011  |0.02212%  |14.33%
#   54|1263|CASH SHORTAGE  |$1509906  |0.01744%  |0.82%
#   56| 499|update         |$1134513  |0.02738%  |19.26%
#   56| 499|update         |$1126636  |0.01322%  |15.54%
#   54| 499|update         |$1069707  |-0.00740% |10.48%
#   54|2333|CASH SHORTAGE  |$1978616  |0.02587%  |1.05%
#   57|2306|CASH SHORTAGE  |$1810485  |0.01966%  |0.27%
#   57| 499|update         |$1136022  |-0.00313% |6.55%
#   51| 499|update         |$955018   |-0.03014% |12.02%
#   54| 561|CASH SHORTAGE  |$988358   |-0.03696% |0.20%
#   55| 499|update         |$1134431  |0.00832%  |14.02%
#   54| 999|update         |$1280029  |0.01399%  |9.52%
#   55| 499|update         |$969370   |-0.02609% |10.11%
#   54| 499|update         |$1044920  |-0.01254% |10.15%
#   55| 416|CASH SHORTAGE  |$1154003  |-0.01739% |0.38%
#   55| 499|update         |$1168942  |0.02248%  |15.89%
#   51| 499|update         |$982228   |-0.02245% |12.41%
#   58| 999|update         |$1361073  |0.02066%  |10.95%
#   57| 499|update         |$1043701  |-0.00653% |15.14%
#   55| 499|update         |$1179095  |0.01780%  |15.03%
#   55| 499|update         |$1000187  |-0.01192% |15.01%
#   56| 805|CASH SHORTAGE  |$1354179  |0.01252%  |1.29%
#   51| 752|CASH SHORTAGE  |$1086978  |-0.01572% |1.12%
#   51|1886|Last Date      |$1577635  |0.01766%  |4.50%
#   56| 840|CASH SHORTAGE  |$1142137  |-0.01025% |0.02%
#   57| 567|CASH SHORTAGE  |$1042091  |-0.02783% |0.82%
#   55| 999|update         |$1383014  |0.02788%  |12.58%
#   54| 475|CASH SHORTAGE  |$1015208  |-0.03591% |1.70%
#   55| 800|CASH SHORTAGE  |$1148594  |-0.00855% |1.11%
#   55| 421|CASH SHORTAGE  |$1145912  |-0.01824% |0.57%
#   54| 710|CASH SHORTAGE  |$1106319  |-0.01527% |0.59%
#   51| 658|CASH SHORTAGE  |$1164083  |-0.00915% |0.73%
#   55| 615|CASH SHORTAGE  |$1207103  |-0.00538% |0.10%
#   55|1079|CASH SHORTAGE  |$1470381  |0.01726%  |0.68%
#   58|1187|CASH SHORTAGE  |$1485886  |0.01622%  |0.26%
#   55| 499|update         |$1221464  |0.01007%  |6.87%
#   53|1499|update         |$1394859  |0.01622%  |6.37%
#   53|1507|CASH SHORTAGE  |$1440710  |0.01238%  |2.36%
#   55| 499|update         |$1101076  |0.00739%  |10.24%
#   58| 461|CASH SHORTAGE  |$1051538  |-0.03144% |1.31%
#   55| 471|CASH SHORTAGE  |$1146678  |-0.01648% |0.44%
#   57| 999|update         |$1214994  |0.00485%  |6.48%
#   57|1003|CASH SHORTAGE  |$1208894  |-0.00111% |1.80%
#   54|1499|update         |$1424471  |0.01651%  |8.87%
#   55| 583|CASH SHORTAGE  |$1165534  |-0.00723% |2.18%
#   55| 999|update         |$1230446  |0.00921%  |7.37%
#   56| 499|update         |$1067044  |-0.01138% |8.86%
#   55| 999|update         |$1288002  |0.01652%  |11.75%
#   55| 774|CASH SHORTAGE  |$1327870  |0.00898%  |0.55%
#   58| 391|CASH SHORTAGE  |$1014128  |-0.04480% |1.33%
#   55| 412|CASH SHORTAGE  |$947274   |-0.05786% |0.40%
#   55| 999|update         |$1345454  |0.02326%  |12.04%
#   56| 626|CASH SHORTAGE  |$1081164  |-0.02098% |0.34%
#   57| 499|update         |$1053798  |-0.00336% |14.83%
#   52| 499|update         |$1078420  |-0.00450% |7.45%
#   52| 499|update         |$1163334  |0.00937%  |8.09%
#   57| 499|update         |$1207100  |0.01922%  |9.53%
#   54|1763|CASH SHORTAGE  |$1627667  |0.01837%  |1.34%
#   52| 531|CASH SHORTAGE  |$1062108  |-0.02356% |2.37%
#   56| 499|update         |$1070127  |-0.00751% |6.32%
#   56| 499|update         |$1133279  |-0.00570% |5.81%
#   56| 504|CASH SHORTAGE  |$994236   |-0.03996% |0.32%
#   55| 499|update         |$1071809  |-0.01329% |4.94%
#   56| 512|CASH SHORTAGE  |$1161622  |-0.00788% |2.61%
#   56| 465|CASH SHORTAGE  |$1221490  |0.00122%  |2.33%
#   52| 499|update         |$1029529  |-0.02115% |8.34%
#   56| 499|update         |$1020462  |-0.00761% |12.40%
#   59| 499|update         |$1003645  |-0.02291% |7.22%
#   54| 499|update         |$1121667  |-0.00471% |6.11%
#   57| 654|CASH SHORTAGE  |$1166819  |-0.00996% |0.12%
#   54| 520|CASH SHORTAGE  |$1243053  |0.00333%  |1.84%
#   59| 546|CASH SHORTAGE  |$1014693  |-0.03345% |0.55%
#   52| 597|CASH SHORTAGE  |$1127543  |-0.01168% |2.51%
#   59| 499|update         |$1077124  |-0.01075% |6.98%
#   56| 499|update         |$996731   |-0.00741% |17.00%
#   52| 721|CASH SHORTAGE  |$1311434  |0.00687%  |0.03%
#   58| 499|update         |$1241468  |0.01941%  |9.96%
#   56| 535|CASH SHORTAGE  |$1023540  |-0.03282% |0.54%
#   57| 756|CASH SHORTAGE  |$1250205  |0.00221%  |1.33%
#   56| 499|update         |$1049792  |-0.01344% |9.23%
#   55|1499|update         |$1411803  |0.01359%  |5.07%
#   58| 544|CASH SHORTAGE  |$1272156  |0.00592%  |1.14%
#   55|1499|update         |$1747137  |0.03935%  |7.51%
#   56| 499|update         |$1019084  |-0.01087% |15.18%
#   59| 499|update         |$948264   |-0.02979% |9.42%
#   55|1463|CASH SHORTAGE  |$1670978  |0.02481%  |1.57%
#   56| 499|update         |$1039695  |-0.01924% |8.05%
#   56| 680|CASH SHORTAGE  |$1166857  |-0.00957% |0.13%
#   55|1688|CASH SHORTAGE  |$1599998  |0.01806%  |1.55%
#   57| 499|update         |$1228116  |0.03669%  |17.14%
#   60| 328|CASH SHORTAGE  |$1031568  |-0.04388% |2.99%
#   55| 499|update         |$1245171  |0.02948%  |10.53%
#   53| 302|CASH SHORTAGE  |$1114685  |-0.03298% |0.78%
#   53| 499|update         |$1179680  |0.01855%  |12.62%
#   57| 499|update         |$1019778  |-0.01434% |11.12%
#   55| 999|update         |$1487152  |0.03042%  |7.95%
#   57| 499|update         |$1197262  |0.02369%  |13.15%
#   57| 499|update         |$1212332  |0.00718%  |9.92%
#   59| 683|CASH SHORTAGE  |$1094389  |-0.01772% |0.32%
#   59| 899|CASH SHORTAGE  |$1181216  |-0.00592% |0.15%
#   56| 999|update         |$1341937  |0.01502%  |5.77%
#   58| 499|update         |$1016084  |-0.01164% |12.13%
#   55| 499|update         |$1166360  |0.00510%  |7.12%
#   55|1096|CASH SHORTAGE  |$1386095  |0.00996%  |0.02%
#   59| 377|CASH SHORTAGE  |$943994   |-0.05712% |3.12%
#   53| 499|update         |$1192429  |0.02022%  |12.23%
#   53| 660|CASH SHORTAGE  |$1064533  |-0.01992% |1.59%
#   57| 499|update         |$966182   |-0.01556% |14.44%
#   58| 499|update         |$910932   |-0.04129% |7.76%
#   56|1219|CASH SHORTAGE  |$1379793  |0.00963%  |0.98%
#   55|1999|update         |$1956387  |0.03189%  |3.76%
#   56| 972|CASH SHORTAGE  |$1291809  |0.00409%  |0.49%
#   56| 465|CASH SHORTAGE  |$1153409  |-0.01525% |0.55%
#   55|2061|CASH SHORTAGE  |$2082902  |0.03282%  |0.49%
#   56| 999|update         |$1328822  |0.01464%  |5.47%
#   57| 499|update         |$1186947  |0.01835%  |10.30%
#   56| 499|update         |$1005498  |-0.02042% |9.26%
#   57| 999|update         |$1233731  |0.01453%  |11.46%
#   61| 499|update         |$1184569  |0.02658%  |17.06%
#   55| 999|update         |$1387482  |0.02333%  |7.65%
#   54| 499|update         |$1134532  |-0.01184% |3.80%
#   56| 557|CASH SHORTAGE  |$1063955  |-0.02628% |0.23%
#   54| 507|CASH SHORTAGE  |$1130114  |-0.01509% |1.72%
#   57| 999|update         |$1273962  |0.00638%  |4.78%
#   54| 368|CASH SHORTAGE  |$1102612  |-0.03047% |0.53%
#   57| 999|update         |$1325207  |0.01634%  |7.82%
#   57| 999|update         |$1601795  |0.03817%  |7.85%
#   56|1123|CASH SHORTAGE  |$1438320  |0.01425%  |0.65%
#   57|1027|CASH SHORTAGE  |$1299198  |0.00423%  |0.32%
#   60| 499|update         |$1175795  |0.01053%  |10.73%
#   60| 499|update         |$1035860  |-0.00708% |15.73%
#   60| 513|CASH SHORTAGE  |$1200780  |-0.00629% |0.59%
#   53| 943|CASH SHORTAGE  |$1404826  |0.01362%  |0.32%
#   58| 999|update         |$1361018  |0.02634%  |12.96%
#   55| 999|update         |$1326059  |0.02277%  |12.81%
#   56| 499|update         |$1092085  |-0.02029% |4.07%
#   60| 499|update         |$1235228  |0.01205%  |9.24%
#   57|1107|CASH SHORTAGE  |$1394398  |0.01225%  |1.44%
#   57|1195|CASH SHORTAGE  |$1419464  |0.01247%  |0.95%
#   58| 934|CASH SHORTAGE  |$1272316  |0.00321%  |0.95%
#   60| 535|CASH SHORTAGE  |$1280752  |0.00850%  |1.63%
#   57| 950|CASH SHORTAGE  |$1249343  |0.00021%  |0.20%
#   57| 758|CASH SHORTAGE  |$1131843  |-0.01222% |0.17%
#   55|1079|CASH SHORTAGE  |$1434530  |0.01390%  |0.16%
#   57|1222|CASH SHORTAGE  |$1542644  |0.01964%  |0.38%
#   57| 499|update         |$1058180  |0.00304%  |15.39%
#   60| 774|CASH SHORTAGE  |$1158984  |-0.00889% |0.35%
#   57| 499|update         |$1130259  |0.00251%  |8.21%
#   56| 467|CASH SHORTAGE  |$1232341  |0.00051%  |1.34%
#   57| 499|update         |$1043708  |-0.00763% |9.54%
#   56| 763|CASH SHORTAGE  |$1129612  |-0.01085% |1.20%
#   58| 257|CASH SHORTAGE  |$1117207  |-0.03916% |0.50%
#   55| 383|CASH SHORTAGE  |$1116744  |-0.02741% |0.14%
#   61| 999|update         |$1484292  |0.03207%  |9.94%
#   57| 671|CASH SHORTAGE  |$1221067  |-0.00207% |0.76%
#   55|1499|update         |$1573243  |0.02354%  |5.63%
#   57| 499|update         |$992982   |-0.01160% |15.06%
#   55| 499|update         |$1233650  |0.01099%  |6.99%
#   56| 307|CASH SHORTAGE  |$1098540  |-0.02949% |2.79%
#   57| 499|update         |$1279550  |0.01988%  |7.77%
#   58| 499|update         |$1277531  |0.04656%  |16.72%
#   61| 499|update         |$1037116  |0.00148%  |16.62%
#   54| 499|update         |$1208502  |0.00959%  |4.80%
#   58|1499|update         |$1585219  |0.02655%  |7.02%
#   58| 465|CASH SHORTAGE  |$1220491  |-0.00282% |0.86%
#   55|1668|Last Date      |$1534953  |0.01902%  |5.82%
#   59| 499|update         |$1041818  |-0.01425% |6.01%
#   61|1203|CASH SHORTAGE  |$1481956  |0.01715%  |1.40%
#   61| 499|update         |$1298339  |0.03601%  |10.15%
#   58| 499|update         |$1034048  |-0.00206% |18.98%
#   58| 499|update         |$1089096  |0.00002%  |14.00%
#   58|1611|CASH SHORTAGE  |$1666890  |0.02095%  |0.24%
#   58| 499|update         |$1303355  |0.05350%  |17.16%
#   58| 711|CASH SHORTAGE  |$1371790  |0.01411%  |0.21%
#   57| 727|CASH SHORTAGE  |$1445696  |0.02326%  |0.87%
#   59| 396|CASH SHORTAGE  |$1276874  |0.01121%  |1.79%
#   61| 499|update         |$1014721  |-0.02661% |3.52%
#   57| 999|update         |$1376167  |0.01757%  |4.54%
#   57| 499|update         |$1181071  |0.01248%  |12.00%
#   57| 999|update         |$1422400  |0.02492%  |7.09%
#   57| 499|update         |$1287192  |0.02091%  |5.39%
#   58| 713|CASH SHORTAGE  |$1188331  |-0.00672% |0.12%
#   56| 499|update         |$1142546  |0.00565%  |10.58%
#   55| 924|CASH SHORTAGE  |$1363905  |0.01406%  |2.84%
#   57| 950|CASH SHORTAGE  |$1406337  |0.01389%  |0.49%
#   59| 343|CASH SHORTAGE  |$982343   |-0.05747% |1.73%
#   58| 499|update         |$1263036  |0.03213%  |13.16%
#   61| 898|CASH SHORTAGE  |$1378580  |0.01169%  |0.15%
#   57| 466|CASH SHORTAGE  |$1208283  |-0.00553% |0.63%
#   57|1108|CASH SHORTAGE  |$1588254  |0.02595%  |1.07%
#   61| 650|CASH SHORTAGE  |$1216935  |-0.00010% |2.12%
#   57| 600|CASH SHORTAGE  |$1260178  |0.00169%  |0.16%
#   58| 833|CASH SHORTAGE  |$1116173  |-0.01089% |1.47%
#   58| 573|CASH SHORTAGE  |$1277082  |0.00610%  |1.04%
#   56| 631|CASH SHORTAGE  |$1125930  |-0.01420% |0.86%
#   54| 986|CASH SHORTAGE  |$1446382  |0.01595%  |0.01%
#   61| 940|CASH SHORTAGE  |$1394671  |0.01380%  |1.00%
#   62| 461|CASH SHORTAGE  |$1067020  |-0.02362% |3.51%
#   59| 430|CASH SHORTAGE  |$969481   |-0.05198% |0.09%
#   56| 499|update         |$1041257  |-0.01974% |8.83%
#   59| 999|update         |$1337118  |0.02312%  |8.99%
#   59| 430|CASH SHORTAGE  |$1011188  |-0.04201% |1.03%
#   56| 311|CASH SHORTAGE  |$1122467  |-0.02883% |1.10%
#   60| 445|CASH SHORTAGE  |$978817   |-0.04366% |2.31%
#   58| 999|update         |$1388953  |0.02895%  |13.50%
#   58| 499|update         |$1020539  |-0.01870% |9.70%
#   59|1110|CASH SHORTAGE  |$1538670  |0.02244%  |1.18%
#   58| 524|CASH SHORTAGE  |$1023044  |-0.03386% |0.40%
#   57|1499|update         |$1759755  |0.03354%  |6.62%
#   57| 991|CASH SHORTAGE  |$1541906  |0.02379%  |0.15%
#   56| 702|CASH SHORTAGE  |$1229267  |-0.00077% |0.91%
#   60| 427|CASH SHORTAGE  |$1212651  |-0.00322% |1.33%
#   62| 399|CASH SHORTAGE  |$1147719  |-0.01923% |0.44%
#   59| 499|update         |$1038581  |-0.01640% |8.43%
#   58| 499|update         |$1183508  |0.01747%  |10.75%
#   58|1200|CASH SHORTAGE  |$1699408  |0.03086%  |0.63%
#   59| 559|CASH SHORTAGE  |$1143919  |-0.01448% |0.34%
#   57|1627|CASH SHORTAGE  |$1662610  |0.02048%  |0.19%
#   62| 499|update         |$1183875  |0.01984%  |14.67%
#   58| 499|update         |$997641   |-0.02185% |10.73%
#   58| 499|update         |$1182141  |0.01297%  |9.50%
#   58| 499|update         |$1246536  |0.03280%  |12.55%
#   59| 499|update         |$1071477  |-0.00829% |9.45%
#   58| 529|CASH SHORTAGE  |$1061013  |-0.02712% |0.73%
#   62| 565|CASH SHORTAGE  |$1205528  |-0.00438% |0.90%
#   59| 531|CASH SHORTAGE  |$1111802  |-0.01710% |1.78%
#   59| 499|update         |$1234894  |0.02044%  |9.71%
#   57| 499|update         |$1238510  |0.01563%  |10.36%
#   60| 396|CASH SHORTAGE  |$1152439  |-0.01610% |1.24%
#   55| 499|update         |$966560   |-0.01056% |16.14%
#   62| 499|update         |$1057283  |-0.00614% |13.30%
#   61| 370|CASH SHORTAGE  |$1127960  |-0.02591% |0.16%
#   63| 499|update         |$1135541  |0.00993%  |12.44%
#   58| 665|CASH SHORTAGE  |$1383571  |0.01621%  |0.07%
#   60| 499|update         |$1301602  |0.03938%  |10.65%
#   57| 499|update         |$963634   |-0.00296% |19.36%
#   57| 399|CASH SHORTAGE  |$1020630  |-0.04479% |0.47%
#   58| 302|CASH SHORTAGE  |$1061956  |-0.04336% |1.84%
#   60| 499|update         |$1078202  |-0.00384% |10.15%
#   59| 744|CASH SHORTAGE  |$1462668  |0.02507%  |1.12%
#   59| 499|update         |$1021483  |-0.00937% |12.55%
#   59| 544|CASH SHORTAGE  |$994980   |-0.03354% |2.16%
#   58| 861|CASH SHORTAGE  |$1256074  |0.00109%  |0.36%
#   58| 499|update         |$1018995  |-0.01266% |11.11%
#   61| 483|CASH SHORTAGE  |$1214560  |-0.00201% |1.54%
#   63| 499|update         |$1201283  |0.02457%  |13.75%
#   57| 677|CASH SHORTAGE  |$996924   |-0.02936% |0.37%
#   60| 470|CASH SHORTAGE  |$1098974  |-0.01709% |3.69%
#   58| 999|update         |$1292917  |0.01250%  |6.83%
#   60| 410|CASH SHORTAGE  |$1016700  |-0.04197% |1.43%
#   59| 499|update         |$1191488  |0.00525%  |7.96%
#   55| 900|CASH SHORTAGE  |$1246202  |0.00224%  |1.86%
#   57| 935|CASH SHORTAGE  |$1217137  |-0.00263% |0.14%
#   63| 865|CASH SHORTAGE  |$1390843  |0.01539%  |1.47%
#   59| 499|update         |$979854   |-0.02151% |8.11%
#   60| 839|CASH SHORTAGE  |$1247378  |0.00303%  |2.20%
#   63| 499|update         |$1195757  |0.00507%  |9.57%
#   59| 386|CASH SHORTAGE  |$975486   |-0.05479% |0.83%
#   60| 771|CASH SHORTAGE  |$1352872  |0.01150%  |0.47%
#   61| 499|update         |$945462   |-0.02520% |10.34%
#   63| 668|CASH SHORTAGE  |$1107484  |-0.01612% |0.57%
#   59| 606|CASH SHORTAGE  |$1086973  |-0.02085% |0.38%
#   59| 561|CASH SHORTAGE  |$1109749  |-0.01813% |0.95%
#   62| 973|CASH SHORTAGE  |$1435377  |0.01549%  |0.17%
#   62| 499|update         |$1333892  |0.02969%  |8.02%
#   61| 592|CASH SHORTAGE  |$1002047  |-0.03315% |0.21%
#   58| 797|CASH SHORTAGE  |$1149494  |-0.00990% |0.13%
#   60| 450|CASH SHORTAGE  |$991381   |-0.04550% |0.22%
#   58| 499|update         |$981056   |-0.02356% |12.33%
#   62| 646|CASH SHORTAGE  |$1459991  |0.02711%  |0.49%
#   59| 499|update         |$998532   |-0.01978% |12.32%
#   63| 796|CASH SHORTAGE  |$1209415  |-0.00276% |0.87%
#   60| 499|update         |$1270500  |0.04955%  |18.17%
#   58| 421|CASH SHORTAGE  |$995298   |-0.04586% |1.07%
#   59| 499|update         |$987410   |-0.00508% |17.89%
#   62| 499|update         |$1308025  |0.02484%  |6.60%
#   60| 576|CASH SHORTAGE  |$1201582  |-0.00228% |2.13%
#   58|1465|CASH SHORTAGE  |$1802647  |0.03138%  |0.97%
#   61| 499|update         |$1051538  |0.00186%  |13.68%
#   61| 499|update         |$1239311  |0.01625%  |5.81%
#   64| 480|CASH SHORTAGE  |$1088893  |-0.02545% |0.62%
#   56| 499|update         |$1260712  |0.03729%  |15.00%
#   58| 499|update         |$1067339  |-0.00515% |10.16%
#   58| 734|CASH SHORTAGE  |$1031235  |-0.02378% |0.04%
#   61| 549|CASH SHORTAGE  |$1326753  |0.01146%  |0.11%
#   64| 453|CASH SHORTAGE  |$1205513  |-0.00709% |0.29%
#   61| 499|update         |$1259103  |0.02120%  |7.44%
#   60| 499|update         |$966970   |-0.03125% |7.46%
#   61| 499|update         |$980372   |-0.03386% |5.47%
#   61| 499|CASH SHORTAGE  |$984904   |-0.04120% |0.66%
#   60| 499|update         |$1285706  |0.04047%  |14.26%
#   59| 794|CASH SHORTAGE  |$1270117  |0.00339%  |0.85%
#   59| 410|CASH SHORTAGE  |$1104050  |-0.02628% |0.81%
#   60| 499|update         |$1095418  |-0.00354% |12.19%
#   63| 499|update         |$1306551  |0.04732%  |13.79%
#   60| 518|CASH SHORTAGE  |$1087048  |-0.02355% |0.77%
#   61| 584|CASH SHORTAGE  |$1223840  |-0.00183% |0.84%
#   62| 488|CASH SHORTAGE  |$1284002  |0.01271%  |2.71%       60| 593|CASH SHORTAGE  |$1006271  |-0.02867% |2.48%
#
#   60| 593|CASH SHORTAGE  |$1328228  |0.01147%  |0.41%
#   62| 823|CASH SHORTAGE  |$1558736  |0.03118%  |0.62%
#   61| 499|update         |$1159783  |0.00793%  |10.30%
#   63| 499|update         |$973952   |-0.02590% |11.37%
#   59| 436|CASH SHORTAGE  |$1015479  |-0.03956% |1.49%
#   61| 543|CASH SHORTAGE  |$1258238  |0.00317%  |0.84%
#   59| 388|CASH SHORTAGE  |$1073240  |-0.02895% |2.71%
#   62| 331|CASH SHORTAGE  |$1097125  |-0.03577% |0.36%
#   61| 899|CASH SHORTAGE  |$1338398  |0.00900%  |0.76%
#   64| 499|update         |$1245327  |0.02492%  |11.58%
#   63| 757|CASH SHORTAGE  |$1358153  |0.01202%  |0.33%
#   59| 999|update         |$1420443  |0.02719%  |12.17%
#   58| 924|CASH SHORTAGE  |$1295927  |0.00829%  |3.08%
#   61| 499|update         |$1102591  |-0.00871% |7.84%
#   63| 664|CASH SHORTAGE  |$1081569  |-0.01596% |2.66%
#   61| 525|CASH SHORTAGE  |$1064336  |-0.02746% |0.41%
#   64| 611|CASH SHORTAGE  |$1330277  |0.01115%  |0.29%
#   65| 499|update         |$1025498  |-0.01489% |10.58%
#   56| 999|update         |$1340260  |0.02042%  |11.22%
#   59| 499|update         |$915626   |-0.03092% |14.09%
#   65| 499|update         |$1142699  |0.00708%  |12.29%
#   56|1042|CASH SHORTAGE  |$1371590  |0.00959%  |0.20%
#   62| 499|update         |$1156944  |0.01581%  |15.05%
#   61| 414|CASH SHORTAGE  |$1134399  |-0.01994% |0.87%
#   60| 499|update         |$1027344  |-0.01230% |11.87%
#   63| 433|CASH SHORTAGE  |$1136059  |-0.01509% |2.27%
#   60| 499|update         |$1234395  |0.03171%  |13.36%
#   65| 561|CASH SHORTAGE  |$1222580  |-0.00168% |1.02%
#   61| 499|update         |$1039200  |-0.01822% |6.74%
#   65| 644|CASH SHORTAGE  |$1130397  |-0.01357% |0.73%
#   62| 499|update         |$1175492  |-0.00268% |4.01%
#   59| 631|CASH SHORTAGE  |$996017   |-0.02898% |2.04%
#   62| 368|CASH SHORTAGE  |$937529   |-0.06187% |2.38%
#   61| 499|update         |$1007955  |-0.01322% |14.41%
#   63| 476|CASH SHORTAGE  |$1002003  |-0.04097% |0.34%
#   61| 527|CASH SHORTAGE  |$934226   |-0.04710% |0.47%
#   59|1345|CASH SHORTAGE  |$1390588  |0.00922%  |0.83%
#   62| 696|CASH SHORTAGE  |$1358697  |0.01262%  |0.06%
#   60| 499|update         |$943601   |-0.03153% |7.44%
#   60| 499|update         |$1206141  |0.02285%  |9.28%
#   62| 499|update         |$1222395  |0.01563%  |8.49%
#   63| 499|update         |$1175145  |0.01286%  |12.59%
#   64| 499|update         |$991489   |-0.02088% |10.85%
#   64| 458|CASH SHORTAGE  |$1264124  |0.00354%  |0.39%
#   62| 773|CASH SHORTAGE  |$1155719  |-0.00926% |0.33%
#   59| 499|update         |$979572   |-0.02617% |7.31%
#   62| 598|CASH SHORTAGE  |$1204376  |-0.00459% |0.75%
#   62| 499|update         |$1024882  |-0.00659% |13.05%
#   63| 611|CASH SHORTAGE  |$1305417  |0.01140%  |1.94%
#   65| 499|update         |$1123789  |0.01935%  |19.23%
#   60| 880|CASH SHORTAGE  |$1265585  |0.00230%  |0.61%
#   59| 552|CASH SHORTAGE  |$1027361  |-0.03104% |0.66%
#   60| 918|CASH SHORTAGE  |$1391095  |0.01352%  |0.81%
#   62| 573|CASH SHORTAGE  |$1033911  |-0.02807% |1.16%
#   60| 713|CASH SHORTAGE  |$1018320  |-0.02200% |2.80%
#   57| 499|update         |$888613   |-0.04151% |7.98%
#   57| 503|CASH SHORTAGE  |$938488   |-0.04631% |1.74%
#   62| 499|update         |$1061156  |-0.01346% |11.18%
#   64| 499|update         |$1233295  |0.04676%  |26.62%
#   66| 499|update         |$1130530  |0.01400%  |13.51%
#   66| 467|CASH SHORTAGE  |$1124761  |-0.01683% |1.92%
#   64| 747|CASH SHORTAGE  |$1035000  |-0.01942% |2.60%
#   61| 999|update         |$1367870  |0.02537%  |13.00%
#   64| 456|CASH SHORTAGE  |$1261276  |0.00470%  |0.99%
#   60| 499|update         |$1039638  |0.00498%  |19.54%
#   63| 487|CASH SHORTAGE  |$989522   |-0.03988% |1.43%
#   66| 592|CASH SHORTAGE  |$1221361  |-0.00314% |0.35%
#   62| 620|CASH SHORTAGE  |$1056043  |-0.02500% |0.02%
#   62| 499|update         |$1119590  |0.02220%  |20.13%
#   60| 499|update         |$1023430  |-0.00706% |10.31%
#   63| 499|update         |$997166   |-0.01240% |13.08%
#   60| 556|CASH SHORTAGE  |$1048335  |-0.02784% |0.63%
#   60| 999|update         |$1331744  |0.02472%  |13.38%
#   62| 621|CASH SHORTAGE  |$995869   |-0.03202% |0.45%
#   61|1218|CASH SHORTAGE  |$1366715  |0.00827%  |0.54%
#   65| 499|update         |$1150744  |0.02149%  |13.26%
#   63| 499|update         |$1126003  |-0.00690% |7.15%
#   63| 499|update         |$1263262  |0.04215%  |14.33%
#   64| 499|update         |$1298968  |0.05668%  |17.92%
#   65| 999|update         |$1284550  |0.01687%  |11.31%
#   61| 499|update         |$918053   |-0.01856% |21.06%
#   60| 499|update         |$1020489  |0.00085%  |17.45%
#   61| 499|update         |$891591   |-0.02863% |17.88%
#   65| 623|CASH SHORTAGE  |$1264156  |0.00234%  |0.25%
#   63| 499|update         |$1122690  |0.01033%  |12.22%
#   61| 499|update         |$1048337  |0.00631%  |18.73%
#   58| 499|update         |$942630   |-0.02113% |13.14%
#   63| 616|CASH SHORTAGE  |$1312942  |0.00861%  |0.21%
#   64| 999|update         |$1331785  |0.02769%  |14.93%
#   61| 593|CASH SHORTAGE  |$990253   |-0.03350% |0.92%
#   67| 499|update         |$1148322  |0.02369%  |16.31%
#   65|1139|CASH SHORTAGE  |$1410384  |0.01341%  |1.73%
#   65| 499|update         |$1211537  |0.01830%  |11.33%
#   65| 499|update         |$1019118  |-0.00775% |12.83%
#   60| 999|update         |$1357894  |0.01734%  |9.89%
#   64| 499|update         |$1045543  |-0.01278% |11.55%
#   67| 499|update         |$1185750  |0.02705%  |15.93%
#   63| 499|update         |$1115666  |0.00369%  |11.05%
#   63| 999|update         |$1413328  |0.03253%  |14.18%
#   61| 499|update         |$1199966  |0.02788%  |15.02%
#   60|1499|update         |$1424547  |0.01975%  |10.65%
#   63| 790|CASH SHORTAGE  |$1410454  |0.01769%  |0.81%
#   63| 499|update         |$1184646  |0.01527%  |11.23%
#   62| 499|update         |$963707   |-0.01202% |16.70%
#   58| 842|CASH SHORTAGE  |$1150232  |-0.00790% |1.16%
#   60| 930|CASH SHORTAGE  |$1207346  |-0.00095% |2.10%
#   63| 999|update         |$1306741  |0.01350%  |5.73%
#   64|1333|CASH SHORTAGE  |$1694105  |0.02700%  |0.27%
#   65| 792|CASH SHORTAGE  |$1162713  |-0.00863% |0.13%
#   61| 926|CASH SHORTAGE  |$1375512  |0.01241%  |1.06%
#   64| 999|update         |$1365045  |0.02929%  |15.51%
#   65| 859|CASH SHORTAGE  |$1247613  |0.00072%  |0.65%
#   61| 999|update         |$1308551  |0.02113%  |13.22%
#   66| 499|update         |$1192937  |0.03384%  |18.10%
#   64| 499|update         |$982102   |-0.02045% |9.86%
#   64| 516|CASH SHORTAGE  |$924958   |-0.04779% |1.45%
#   63| 764|CASH SHORTAGE  |$1190368  |-0.00554% |0.45%
#   62| 499|update         |$1173630  |0.02525%  |13.26%
#   63|1191|CASH SHORTAGE  |$1598661  |0.02487%  |1.08%
#   67| 999|update         |$1311913  |0.01624%  |9.81%       66| 499|update         |$1239329  |0.03381%  |16.39%
#
#   60|1499|update         |$1505364  |0.01935%  |5.12%
#   64| 999|update         |$1464707  |0.02937%  |8.52%
#   60|1512|CASH SHORTAGE  |$1511899  |0.01445%  |0.59%
#   67| 999|update         |$1232427  |0.01426%  |11.78%
#   67|1081|CASH SHORTAGE  |$1338952  |0.00876%  |1.76%
#   63| 999|update         |$1292169  |0.01355%  |8.68%
#   63|1499|update         |$1612839  |0.02333%  |5.54%
#   61| 999|update         |$1359414  |0.02548%  |11.67%
#   60|1999|update         |$2042302  |0.04097%  |9.11%
#   64| 499|update         |$1002458  |-0.00408% |17.18%
#   62| 999|update         |$1292476  |0.02267%  |14.24%
#   63|1592|CASH SHORTAGE  |$1538255  |0.01493%  |0.46%
#   59| 499|update         |$1266929  |0.03943%  |12.86%
#   61| 499|update         |$1285176  |0.03162%  |11.38%
#   65| 499|update         |$1079892  |0.01663%  |19.36%
#   66| 499|update         |$1320879  |0.04418%  |13.73%
#   62| 499|update         |$1003246  |0.00037%  |20.27%
#   64|1499|update         |$2006696  |0.05765%  |11.73%
#   66| 499|update         |$1018128  |-0.01187% |11.27%
#   61|1499|update         |$1445299  |0.02440%  |10.99%
#   66| 999|update         |$1325951  |0.01487%  |10.36%
#   65| 499|update         |$992048   |-0.00855% |17.22%
#   63|1397|Last Date      |$1215886  |0.00125%  |3.69%
#   64| 499|update         |$1087845  |0.00830%  |15.22%
#   62| 999|update         |$1319935  |0.01911%  |10.44%
#   64| 499|update         |$1228000  |0.02519%  |8.94%
#   66| 999|update         |$1336233  |0.02878%  |18.63%
#   60|2318|Last Date      |$1871875  |0.02925%  |9.64%
#   64|1499|update         |$1474109  |0.01610%  |6.29%
#   61| 499|update         |$1193947  |0.01977%  |10.30%
#   62|1334|CASH SHORTAGE  |$1616785  |0.02454%  |2.10%
#   67|1499|update         |$1807520  |0.04225%  |9.23%       68| 499|update         |$997781   |-0.00048% |25.68%
#
#   66| 757|CASH SHORTAGE  |$1521310  |0.03020%  |0.76%
#   62|1160|CASH SHORTAGE  |$1456024  |0.01506%  |0.68%
#   61|1499|update         |$1821085  |0.03897%  |7.81%
#   64| 999|update         |$1337847  |0.02308%  |13.05%
#   64| 499|update         |$1029949  |0.00517%  |18.64%
#   61|1605|CASH SHORTAGE  |$1639709  |0.01996%  |0.52%
#   59| 999|update         |$1326830  |0.02082%  |10.98%
#   61| 999|update         |$1370530  |0.03668%  |19.24%
#   64| 825|CASH SHORTAGE  |$1189605  |-0.00551% |0.24%
#   65| 999|update         |$1463332  |0.02509%  |7.34%
#   62| 999|update         |$1302839  |0.02530%  |15.89%
#   64|1999|update         |$2108594  |0.04378%  |9.62%
#   66| 998|CASH SHORTAGE  |$1431496  |0.01537%  |0.57%
#   61|1999|update         |$2028732  |0.03779%  |5.57%
#   66|1499|update         |$1498732  |0.02103%  |8.85%
#   61| 464|CASH SHORTAGE  |$927077   |-0.05520% |0.24%
#   65| 999|update         |$1356418  |0.02370%  |11.53%
#   64| 499|update         |$926635   |-0.01409% |19.54%
#   64| 999|update         |$1265706  |0.00644%  |5.52%
#   66|1499|update         |$1999509  |0.05026%  |8.66%
#   64|1999|update         |$2359970  |0.05541%  |7.61%
#   61| 999|update         |$1215674  |0.00682%  |6.21%
#   63| 499|update         |$1063956  |0.00445%  |15.62%      66|1632|Last Date      |$1430521  |0.01841%  |10.91%
#
#   67|1999|update         |$1981252  |0.03643%  |8.73%
#   68| 999|update         |$1309251  |0.02185%  |11.36%
#   67| 499|update         |$1154477  |0.03059%  |21.32%
#   61|1076|CASH SHORTAGE  |$1369336  |0.00979%  |0.72%
#   63| 499|update         |$1218058  |0.03165%  |13.42%
#   61|2324|Last Date      |$1891045  |0.02964%  |9.30%
#   64|1499|update         |$1552601  |0.02926%  |10.52%
#   63| 564|CASH SHORTAGE  |$1265103  |0.00593%  |1.69%
#   64| 999|update         |$1342889  |0.02505%  |14.92%
#   62| 499|update         |$1224544  |0.04601%  |22.10%
#   59|1499|update         |$1959999  |0.04788%  |6.38%
#   64|2243|Last Date      |$1930983  |0.03251%  |9.55%
#   61|1499|update         |$1970750  |0.05691%  |13.81%
#   65| 499|update         |$942215   |-0.01689% |15.12%
#   65|1499|update         |$1736618  |0.04056%  |13.29%
#   64|2477|Last Date      |$2286362  |0.03894%  |5.92%
#   62|1499|update         |$1410455  |0.01964%  |10.61%
#   67| 499|update         |$1109450  |0.01464%  |18.71%
#   62| 499|update         |$1209093  |0.03766%  |16.27%
#   65|1499|update         |$1570262  |0.01948%  |4.28%
#   64| 999|update         |$1371282  |0.02746%  |13.15%
#   64|1499|update         |$1456029  |0.02065%  |7.91%
#   66|1999|update         |$2133961  |0.04528%  |10.78%
#   64|1531|Last Date      |$1372597  |0.01198%  |6.22%
#   59|1761|Last Date      |$1624213  |0.02327%  |6.80%
#   67| 499|update         |$1029287  |0.00839%  |31.12%      63| 999|update         |$1438338  |0.03069%  |11.59%
#
#   67|2499|update         |$2015237  |0.03580%  |11.30%      68|1499|update         |$1429114  |0.01618%  |10.30%
#
#   67| 721|CASH SHORTAGE  |$1150406  |-0.00796% |1.94%
#   67|2502|Last Date      |$2122262  |0.03613%  |9.71%
#   67| 999|update         |$1286152  |0.01970%  |14.37%
#   62| 499|update         |$1176734  |0.03142%  |19.25%
#   62| 499|update         |$1088046  |0.01872%  |16.99%
#   64|1999|update         |$2196436  |0.04661%  |8.18%
#   64| 499|update         |$1128962  |0.02893%  |28.33%
#   64|1499|update         |$1567530  |0.02686%  |8.12%
#   62| 999|update         |$1292100  |0.02860%  |20.31%
# ...
#  236| 999|update         |$1292741  |0.01571%  |8.14%
#  237|1999|update         |$2847530  |0.07048%  |6.36%
#  234| 999|update         |$1777196  |0.06008%  |9.80%
#  241|1999|update         |$3186402  |0.08989%  |6.56%
#  238| 999|update         |$1907788  |0.07744%  |15.30%
#  234| 499|update         |$1362607  |0.03870%  |8.97%
#  240|1499|update         |$2400817  |0.06888%  |3.51%
#  234| 499|update         |$1522275  |0.07547%  |10.04%
#  235| 499|update         |$1456701  |0.07246%  |15.40%
#  238|1499|update         |$1859383  |0.04223%  |7.70%
#  241|2105|Last Date      |$3046327  |0.07797%  |6.70%
#  235|1999|update         |$2958786  |0.08066%  |8.23%
#  240| 499|update         |$1092816  |0.00323%  |15.49%
#  240|1563|Last Date      |$2116626  |0.05166%  |5.39%
#  237|2228|Last Date      |$3015953  |0.07063%  |5.34%
#  229| 999|update         |$1766897  |0.06316%  |10.16%
#  235| 999|update         |$1830063  |0.06588%  |10.86%
#  235|1499|update         |$2663283  |0.08409%  |5.86%
#  242|1499|update         |$2573781  |0.08446%  |5.92%
#  241|1499|update         |$2196206  |0.05812%  |4.94%
#  236|1329|Last Date      |$1679738  |0.03522%  |7.40%
#  240|1999|update         |$2845421  |0.07562%  |8.24%
#  238|1468|Last Date      |$1905301  |0.04391%  |6.31%
#  235| 499|update         |$1267749  |0.05317%  |17.94%
#  231| 999|update         |$1488239  |0.03130%  |5.74%
#  236| 999|update         |$1767827  |0.06235%  |11.16%
#  241|1659|Last Date      |$2343857  |0.06284%  |7.14%
#  235|1499|update         |$2451205  |0.07979%  |7.72%
#  232| 999|update         |$1368206  |0.01626%  |7.43%
#  238|1828|Last Date      |$2475384  |0.06390%  |7.58%
#  234|1499|update         |$2522447  |0.08212%  |7.93%
#  235|2348|Last Date      |$3550871  |0.08689%  |5.62%
#  238|1499|update         |$2798941  |0.09861%  |8.40%
#  234| 999|update         |$1504392  |0.03110%  |5.47%
#  234| 999|update         |$1542120  |0.03843%  |8.82%
#  235| 999|update         |$1929419  |0.06255%  |7.56%
#  242| 499|update         |$1359576  |0.03566%  |7.25%
#  240| 999|update         |$1784243  |0.06368%  |12.61%
#  241| 499|update         |$1100731  |0.01350%  |16.52%
#  238| 499|update         |$1246097  |0.05524%  |17.72%
#  229|1499|update         |$1923703  |0.04662%  |7.61%
#  240|2364|Last Date      |$3544329  |0.08811%  |6.98%
#  235|1499|update         |$2373839  |0.06650%  |5.45%
#  235|1999|update         |$2848803  |0.07356%  |7.07%
#  242|1999|update         |$2922006  |0.07300%  |5.63%
#  237| 499|update         |$1299046  |0.06006%  |23.61%
#  232|1371|Last Date      |$1637324  |0.03265%  |8.42%
#  231|1452|Last Date      |$1827590  |0.03712%  |4.21%
#  235|1643|Last Date      |$2348442  |0.06247%  |6.28%
#  239| 499|update         |$1177389  |0.02408%  |14.52%
#  235| 999|update         |$1750864  |0.05881%  |12.04%
#  236|1499|update         |$2443209  |0.07561%  |8.24%
#  242|2185|Last Date      |$3091963  |0.07372%  |4.44%
#  242| 499|update         |$1103484  |0.01295%  |13.57%
#  234|1318|CASH SHORTAGE  |$1860389  |0.03906%  |1.42%
#  235|1999|update         |$3019392  |0.08222%  |6.33%
#  235|2232|Last Date      |$3033939  |0.07176%  |5.75%
#  239| 499|update         |$1525179  |0.09500%  |17.52%
#  234|1999|update         |$3275542  |0.09040%  |5.37%
#  236| 499|update         |$1222931  |0.04538%  |20.57%
#  238|1999|update         |$3080557  |0.08688%  |8.18%
#  235|2154|Last Date      |$3100983  |0.07824%  |6.59%
#  234|1499|update         |$2233213  |0.06050%  |5.35%
#  234|2117|Last Date      |$3112211  |0.07931%  |6.08%
#  234|1532|Last Date      |$2110761  |0.05142%  |4.70%
#  235|1499|update         |$2411441  |0.07112%  |5.00%
#  242| 999|update         |$1346517  |0.01744%  |7.74%
#  240|1499|update         |$1899127  |0.04623%  |9.40%
#  241| 999|update         |$1746758  |0.06160%  |13.45%
#  238| 999|update         |$1649980  |0.05884%  |12.63%
#  229|1999|update         |$2676117  |0.06590%  |5.73%
#  229|2014|Last Date      |$2594243  |0.05881%  |4.20%
#  241| 499|update         |$1490141  |0.06612%  |7.54%
#  237| 999|update         |$1866574  |0.07691%  |14.66%
#  235|1628|Last Date      |$2426423  |0.06505%  |4.86%
#  233| 499|update         |$1317700  |0.03708%  |9.47%
#  232| 499|update         |$1181843  |0.03157%  |19.49%
#  236| 499|update         |$1448233  |0.06550%  |9.93%
#  239| 999|update         |$1655499  |0.05492%  |13.06%
#  235|1499|update         |$2414063  |0.07480%  |7.00%
#  236|1999|update         |$3010321  |0.07968%  |6.19%
#  243| 499|update         |$1133167  |0.01996%  |17.31%
#  242| 999|update         |$1618697  |0.04396%  |10.97%
#  235| 499|update         |$1419128  |0.05002%  |7.66%
#  242|1282|Last Date      |$1649873  |0.03460%  |7.50%
#  236| 499|update         |$1292463  |0.04278%  |10.22%
#  239| 999|update         |$1899424  |0.08127%  |15.65%
#  238|2423|Last Date      |$3950134  |0.10016%  |6.75%
#  236| 999|update         |$1836669  |0.06579%  |12.02%
#  236|2152|Last Date      |$3068508  |0.07690%  |6.52%
#  236| 499|update         |$1138602  |0.02233%  |17.51%
#  235| 499|update         |$1416943  |0.04610%  |8.20%
#  235| 499|update         |$1274922  |0.04478%  |16.52%
#  240|1999|update         |$2383270  |0.05718%  |7.34%
#  241|1499|update         |$2054321  |0.05217%  |7.15%
#  240|2005|Last Date      |$2512266  |0.05787%  |5.99%
#  238|1499|update         |$2531127  |0.07838%  |7.27%
#  230| 499|update         |$1163634  |0.02851%  |17.09%
#  241| 999|update         |$1502390  |0.02991%  |8.50%
#  237|1499|update         |$2916855  |0.10432%  |8.09%
#  236| 499|update         |$1324009  |0.06400%  |22.68%
#  233| 999|update         |$1338422  |0.01722%  |6.46%
#  232| 999|update         |$1759509  |0.06277%  |10.05%
#  236| 999|update         |$2075584  |0.07767%  |6.14%
#  239|1499|update         |$2264723  |0.06486%  |6.85%
#  235|1999|update         |$2985856  |0.07941%  |7.25%
#  243| 999|update         |$1707272  |0.05999%  |11.60%
#  242|1499|update         |$2221976  |0.06278%  |6.19%
#  235| 999|update         |$2149161  |0.08827%  |7.87%
#  243| 499|update         |$1311473  |0.04559%  |14.11%
#  236| 999|update         |$1773183  |0.05570%  |5.95%
#  239|1499|update         |$3209679  |0.12339%  |8.66%
#  239| 499|update         |$1163737  |0.02429%  |16.49%
#  236|1499|update         |$2900294  |0.10114%  |7.78%
#  235|2152|Last Date      |$3053848  |0.07740%  |7.29%
#  237| 499|update         |$1088887  |0.01524%  |15.27%
#  236| 999|update         |$1782697  |0.05927%  |8.50%
#  235| 999|update         |$1476365  |0.03426%  |8.94%
#  235| 999|update         |$1999371  |0.07614%  |8.52%
#  241|1999|update         |$3089684  |0.08494%  |5.33%
#  241| 499|update         |$1244296  |0.02886%  |11.00%
#  238|1999|update         |$2717380  |0.06805%  |7.98%
#  230| 999|update         |$1901704  |0.07309%  |9.08%
#  233|1395|Last Date      |$1689554  |0.03237%  |5.92%
#  241|1499|update         |$1975955  |0.04779%  |6.19%
#  241|2059|Last Date      |$2756492  |0.06597%  |5.55%      241|1520|Last Date      |$2003314  |0.04770%  |6.11%
#
#  237|1999|update         |$3275236  |0.09429%  |7.76%
#  236| 999|update         |$1787409  |0.06807%  |13.74%
#  232|1499|update         |$2817041  |0.09628%  |7.68%
#  236|1499|update         |$2282139  |0.06139%  |7.62%
#  239|1999|update         |$3006753  |0.07945%  |5.46%
#  238|2201|Last Date      |$2935915  |0.06857%  |5.47%
#  243|1499|update         |$2351912  |0.07261%  |8.42%
#  242|1999|update         |$3040876  |0.07768%  |5.06%
#  235|1499|update         |$2162406  |0.05429%  |5.75%
#  243| 999|update         |$2092044  |0.08124%  |4.65%
#  236|1499|update         |$2461995  |0.07134%  |4.38%
#  239|1999|update         |$3440085  |0.10204%  |8.42%
#  239| 999|update         |$1854320  |0.05876%  |6.70%
#  239|2138|Last Date      |$2951117  |0.07230%  |6.27%      236|1999|update         |$2453385  |0.05975%  |8.78%
#
#  242|2106|Last Date      |$2857829  |0.06778%  |4.94%
#  236| 499|update         |$1175841  |0.01874%  |10.03%
#  237| 999|update         |$1917213  |0.07496%  |9.52%
#  236|1603|Last Date      |$2355132  |0.06313%  |5.43%
#  236|1718|Last Date      |$2426538  |0.06382%  |6.40%
#  236|1499|update         |$2064568  |0.05312%  |7.66%
#  235|1499|update         |$1996535  |0.04771%  |7.20%
#  235|1510|Last Date      |$1961931  |0.04563%  |6.09%
#  235|1499|update         |$2040095  |0.05116%  |7.00%
#  241| 999|update         |$1826627  |0.05996%  |7.29%
#  235|1760|Last Date      |$2394075  |0.06011%  |5.96%
#  230|1499|update         |$2001435  |0.05377%  |10.68%
#  234| 499|update         |$1336026  |0.02806%  |6.16%
#  237|2440|Last Date      |$4145263  |0.10682%  |7.00%
#  242| 499|update         |$1367176  |0.04596%  |10.92%
#  242| 499|update         |$1394171  |0.07553%  |19.82%
#  236|1499|update         |$2859754  |0.10188%  |8.69%
#  236|2310|Last Date      |$3342503  |0.08101%  |5.90%
#  232|1999|update         |$2622283  |0.06317%  |6.05%
#  239| 499|update         |$1105295  |0.01380%  |17.99%
#  243|1999|update         |$3107423  |0.08017%  |3.86%
#  243|1499|update         |$2231440  |0.06431%  |6.49%
#  239|2499|update         |$4371213  |0.11414%  |6.41%
#  239|1499|update         |$1939665  |0.04976%  |9.58%
#  239|2504|Last Date      |$4708977  |0.12144%  |5.81%
#  240| 499|update         |$1569158  |0.06915%  |7.88%
#  243|2110|Last Date      |$2966801  |0.07255%  |5.30%
#  243| 499|update         |$1431445  |0.08807%  |20.82%
#  236| 999|update         |$1739952  |0.05352%  |8.22%
#  235|1890|Last Date      |$2665526  |0.06910%  |6.51%
#  236|1971|Last Date      |$2607088  |0.06132%  |4.71%
#  237|1499|update         |$1980468  |0.05094%  |8.29%
#  237| 499|update         |$1351555  |0.02843%  |5.61%
#  237| 499|update         |$1395891  |0.04986%  |10.47%
#  240| 571|CASH SHORTAGE  |$1384352  |0.02090%  |0.86%
#  232|2269|Last Date      |$3091881  |0.07191%  |5.12%
#  236| 499|update         |$1422931  |0.06381%  |12.02%
#  241|1499|update         |$1951098  |0.04522%  |6.45%
#  236| 499|update         |$1279470  |0.05174%  |19.35%
#  237| 363|CASH SHORTAGE  |$1300181  |0.01664%  |1.56%
#  230|1999|update         |$2508703  |0.05941%  |6.17%
#  230|2004|Last Date      |$2704429  |0.06562%  |5.60%      234| 999|update         |$1365397  |0.02290%  |9.18%
#
#  238| 499|update         |$1096343  |0.01369%  |14.50%
#  242| 999|update         |$1948531  |0.06635%  |5.16%      242| 999|update         |$1965845  |0.08410%  |12.55%
#
#  236|1999|update         |$3113265  |0.09434%  |8.25%
#  243|1849|Last Date      |$2665104  |0.07016%  |6.19%
#  239| 999|update         |$1781059  |0.06191%  |9.26%
#  234|1271|CASH SHORTAGE  |$1769975  |0.03343%  |0.51%
#  240| 499|update         |$1545357  |0.10149%  |17.69%     239|1999|update         |$2663417  |0.06281%  |5.13%
#
#  239|2000|Last Date      |$2652301  |0.06147%  |4.06%
#  244| 499|update         |$1367319  |0.04844%  |9.96%
#  243| 999|update         |$2060653  |0.09526%  |13.25%
#  236|1499|update         |$2458274  |0.07899%  |7.47%
#  236| 499|update         |$1263500  |0.02432%  |8.52%
#  237| 499|update         |$1174378  |0.02703%  |15.99%
#  244| 532|CASH SHORTAGE  |$1366942  |0.02238%  |1.87%
#  237|1999|update         |$2782503  |0.06847%  |3.75%
#  237| 999|update         |$1379313  |0.01939%  |6.56%
#  237| 999|update         |$1818711  |0.05273%  |6.89%
#  241| 499|update         |$1341409  |0.05567%  |14.13%
#  237|2028|Last Date      |$2714677  |0.06705%  |6.93%
#  241|1920|Last Date      |$2478132  |0.05783%  |5.16%
#  233| 499|update         |$1482410  |0.09124%  |18.80%
#  236| 999|update         |$1933151  |0.06972%  |9.10%
#  236| 999|update         |$1771927  |0.06552%  |12.78%
#  238| 499|update         |$1157740  |0.01555%  |12.99%
#  231| 499|update         |$1378072  |0.04655%  |10.41%
#  238| 999|update         |$1809528  |0.06665%  |8.31%
#  236|2445|Last Date      |$4134686  |0.10297%  |5.08%
#  242|1499|update         |$3077701  |0.11396%  |7.93%      242|1499|update         |$2119974  |0.05661%  |7.52%
#
#  244| 499|update         |$1349270  |0.05536%  |13.19%
#  239|1499|update         |$2141662  |0.06061%  |8.49%
#  245| 381|CASH SHORTAGE  |$1195363  |-0.00865% |0.90%
#  242|1719|Last Date      |$2306287  |0.05640%  |5.40%
#  237|1398|Last Date      |$1742481  |0.03319%  |4.02%
#  235| 499|update         |$1381984  |0.04080%  |8.92%
#  240| 999|update         |$1953010  |0.08169%  |13.68%
#  240| 499|update         |$1093150  |0.00110%  |14.08%
#  243|1499|update         |$3228689  |0.12314%  |8.41%
#  236|1999|update         |$3489884  |0.09716%  |4.48%
#  236| 999|update         |$1954121  |0.07619%  |8.88%
#  237| 999|update         |$1940328  |0.07599%  |10.32%
#  237|1499|update         |$2279639  |0.06554%  |6.57%
#  241| 999|update         |$2048468  |0.07504%  |4.20%
#  238| 499|update         |$1257387  |0.03671%  |12.89%
#  242| 499|update         |$1542832  |0.07464%  |9.67%
#  233| 999|update         |$1905683  |0.07546%  |12.80%
#  236|2088|Last Date      |$3137874  |0.08070%  |5.57%
#  236|1499|update         |$2454831  |0.07164%  |5.68%
#  236|1499|update         |$2917213  |0.10231%  |6.07%
#  238| 999|update         |$1897811  |0.05995%  |5.24%
#  231| 999|update         |$1901525  |0.06498%  |6.59%
#  238|1499|update         |$2053448  |0.05308%  |7.81%
#  237|1628|Last Date      |$2296731  |0.05934%  |5.61%
#  237| 499|update         |$1232559  |0.03561%  |14.91%
#  242|1999|update         |$3354056  |0.09726%  |8.04%
#  236|1648|Last Date      |$2470174  |0.06864%  |6.28%
#  244| 999|update         |$2214474  |0.09348%  |7.63%
#  239|1999|update         |$3153310  |0.08082%  |3.71%
#  246| 499|update         |$1362876  |0.05408%  |10.37%
#  239|2067|Last Date      |$2733562  |0.06550%  |6.11%
#  243| 499|update         |$1443067  |0.05210%  |7.13%
#  238| 499|update         |$1164374  |0.01395%  |12.41%
#  235| 999|update         |$1784863  |0.05498%  |8.81%
#  240|1499|update         |$3294189  |0.12887%  |8.04%
#  240| 999|update         |$1914767  |0.06855%  |5.94%
#  243|1999|update         |$3730583  |0.10893%  |6.95%
#  236|1499|update         |$1901079  |0.04314%  |8.91%
#  237|1499|update         |$2327525  |0.07136%  |8.41%
#  241|1499|update         |$2008897  |0.05519%  |10.04%
#  238| 999|update         |$1889738  |0.07335%  |12.69%
#  242| 999|update         |$2414167  |0.10734%  |5.97%
#  233|1499|update         |$3141293  |0.11123%  |6.75%
#  237| 499|update         |$1598108  |0.12166%  |22.90%
#  242|2434|Last Date      |$4342990  |0.11203%  |5.81%
#  236|1999|update         |$3089395  |0.08258%  |7.05%
#  238|1499|update         |$2120051  |0.05753%  |7.59%
#  231|1499|update         |$2702150  |0.08378%  |4.46%
#  238|1999|update         |$2890002  |0.06922%  |4.05%
#  238| 499|update         |$1523458  |0.09670%  |17.08%
#  238|2011|Last Date      |$2829352  |0.06989%  |5.02%
#  237| 999|update         |$1872365  |0.07147%  |12.88%
#  237| 499|update         |$1512814  |0.06568%  |8.62%
#  231|1595|Last Date      |$2470544  |0.07011%  |5.74%
#  244|1499|update         |$2234925  |0.06186%  |5.88%

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
agent = DRLAgent(env = env_train)

# %% [markdown]
# ### Model PPO

# %%
# from torch.nn import Softsign, ReLU
ppo_params ={'n_steps': 256, 
             'ent_coef': 0.01, 
             'learning_rate': 0.00009, 
             'batch_size': 1024, 
            'gamma': 0.99}

policy_kwargs = {
#     "activation_fn": ReLU,
    "net_arch": [1024, 1024,1024, 1024,  1024], 
#     "squash_output": True
}

model = agent.get_model("ppo",  
                        model_kwargs = ppo_params, 
                        policy_kwargs = policy_kwargs, verbose = 0)

# model = model.load("scaling_reward.model", env = env_train)
# Out:
# {'n_steps': 256, 'ent_coef': 0.01, 'learning_rate': 9e-05, 'batch_size': 1024, 'gamma': 0.99}

# %%
model.learn(total_timesteps = 5000000, 
            eval_env = env_trade, 
            eval_freq = 250,
            log_interval = 1, 
            tb_log_name = '1_18_lastrun',
            n_eval_episodes = 1)
# Out:
#  229| 499|update         |$1102705  |-0.00996% |5.51%
#  229| 504|Last Date      |$1103753  |-0.01117% |5.50%
# Eval num_timesteps=690000, episode_reward=-0.10 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  231| 499|update         |$1117999  |-0.00580% |6.16%
#  231| 504|Last Date      |$1119692  |-0.00700% |6.16%
# Eval num_timesteps=696000, episode_reward=-0.10 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  233| 499|update         |$1162088  |0.00262%  |6.54%
#  233| 504|Last Date      |$1164556  |0.00141%  |6.48%
# Eval num_timesteps=702000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  243| 499|update         |$1133324  |-0.00175% |6.78%
#  243| 504|Last Date      |$1137277  |-0.00294% |6.63%
# Eval num_timesteps=732000, episode_reward=-0.10 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  245| 499|update         |$1102113  |-0.00918% |5.98%
#  245| 504|Last Date      |$1103001  |-0.01059% |5.82%
# Eval num_timesteps=738000, episode_reward=-0.12 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  247| 499|update         |$1137770  |-0.00294% |6.22%
#  247| 504|Last Date      |$1135751  |-0.00424% |6.17%
# Eval num_timesteps=744000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  249| 499|update         |$1139270  |-0.00189% |6.45%
#  249| 504|Last Date      |$1137629  |-0.00324% |6.47%
# Eval num_timesteps=750000, episode_reward=-0.10 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  251| 499|update         |$1104737  |-0.00601% |7.19%
#  251| 504|Last Date      |$1106365  |-0.00730% |7.06%
# Eval num_timesteps=756000, episode_reward=-0.13 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  253| 499|update         |$1097652  |-0.00934% |6.30%
#  253| 504|Last Date      |$1096615  |-0.01027% |6.47%
# Eval num_timesteps=762000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  255| 499|update         |$1097652  |-0.00934% |6.30%
#  255| 504|Last Date      |$1096615  |-0.01027% |6.47%
# Eval num_timesteps=768000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  257| 499|update         |$1106968  |-0.00702% |6.58%
#  257| 504|Last Date      |$1109646  |-0.00783% |6.56%
# Eval num_timesteps=774000, episode_reward=-0.13 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  259| 499|update         |$1061966  |-0.01350% |7.16%
#  259| 504|Last Date      |$1066890  |-0.01432% |6.97%
# Eval num_timesteps=780000, episode_reward=-0.15 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  261| 499|update         |$999751   |-0.02489% |6.74%
#  261| 504|Last Date      |$1006175  |-0.02564% |6.54%
# Eval num_timesteps=786000, episode_reward=-0.20 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  263| 499|update         |$1054732  |-0.01464% |7.21%
#  263| 504|Last Date      |$1059881  |-0.01543% |7.01%
# Eval num_timesteps=792000, episode_reward=-0.16 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  265| 499|update         |$1098572  |-0.00590% |7.71%
#  265| 504|Last Date      |$1104012  |-0.00684% |7.46%
# Eval num_timesteps=798000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  267| 499|update         |$1097753  |-0.00570% |7.90%
#  267| 504|Last Date      |$1104279  |-0.00629% |7.69%
# Eval num_timesteps=804000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  269| 499|update         |$1114050  |-0.00388% |7.38%
#  269| 504|Last Date      |$1118410  |-0.00481% |7.25%
# Eval num_timesteps=810000, episode_reward=-0.10 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  271| 499|update         |$1102774  |-0.00478% |7.82%
#  271| 504|Last Date      |$1107944  |-0.00569% |7.67%
# Eval num_timesteps=816000, episode_reward=-0.12 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  273| 499|update         |$1110105  |-0.00570% |6.92%
#  273| 504|Last Date      |$1112199  |-0.00633% |7.04%
# Eval num_timesteps=822000, episode_reward=-0.12 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  275| 499|update         |$1063808  |-0.01846% |4.84%
#  275| 504|Last Date      |$1058812  |-0.02056% |4.66%
# Eval num_timesteps=828000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  277| 499|update         |$1046918  |-0.01834% |6.45%
#  277| 504|Last Date      |$1045260  |-0.01953% |6.25%
# Eval num_timesteps=834000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  279| 499|update         |$1041917  |-0.01840% |6.80%
#  279| 504|Last Date      |$1037700  |-0.01984% |6.73%
# Eval num_timesteps=840000, episode_reward=-0.15 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  281| 499|update         |$1041980  |-0.01832% |6.82%
#  281| 504|Last Date      |$1037860  |-0.01973% |6.77%
# Eval num_timesteps=846000, episode_reward=-0.17 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  283| 499|update         |$1056941  |-0.01612% |6.59%
#  283| 504|Last Date      |$1052680  |-0.01745% |6.64%
# Eval num_timesteps=852000, episode_reward=-0.17 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  285| 499|update         |$1049588  |-0.01565% |7.38%
#  285| 504|Last Date      |$1046822  |-0.01704% |7.32%
# Eval num_timesteps=858000, episode_reward=-0.17 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  287| 499|update         |$1062604  |-0.01328% |7.41%
#  287| 504|Last Date      |$1062786  |-0.01438% |7.27%
# Eval num_timesteps=864000, episode_reward=-0.17 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  289| 499|update         |$1041794  |-0.01700% |7.50%
#  289| 504|Last Date      |$1039057  |-0.01785% |7.58%
# Eval num_timesteps=870000, episode_reward=-0.20 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  291| 499|update         |$1045042  |-0.01806% |6.64%
#  291| 504|Last Date      |$1040235  |-0.01972% |6.58%
# Eval num_timesteps=876000, episode_reward=-0.20 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  293| 499|update         |$1039082  |-0.01934% |6.54%
#  293| 504|Last Date      |$1034323  |-0.02102% |6.44%
# Eval num_timesteps=882000, episode_reward=-0.19 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  295| 499|update         |$1037805  |-0.02011% |6.23%
#  295| 504|Last Date      |$1033720  |-0.02194% |6.04%
# Eval num_timesteps=888000, episode_reward=-0.19 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  297| 499|update         |$1051081  |-0.01776% |6.18%
#  297| 504|Last Date      |$1050172  |-0.01893% |6.14%
# Eval num_timesteps=894000, episode_reward=-0.19 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  299| 499|update         |$1047322  |-0.01729% |6.86%
#  299| 504|Last Date      |$1043798  |-0.01836% |6.94%
# Eval num_timesteps=900000, episode_reward=-0.16 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  301| 499|update         |$1035091  |-0.01749% |7.76%
#  301| 504|Last Date      |$1033553  |-0.01873% |7.62%
# Eval num_timesteps=906000, episode_reward=-0.16 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  303| 499|update         |$1029528  |-0.01897% |7.51%
#  303| 504|Last Date      |$1029172  |-0.02000% |7.37%
# Eval num_timesteps=912000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  305| 499|update         |$1021639  |-0.02030% |7.54%
#  305| 504|Last Date      |$1018971  |-0.02184% |7.34%
# Eval num_timesteps=918000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  307| 499|update         |$1024149  |-0.02318% |5.95%
#  307| 504|Last Date      |$1023349  |-0.02405% |5.88%
# Eval num_timesteps=924000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  309| 499|update         |$1031870  |-0.01919% |7.22%
#  309| 504|Last Date      |$1030236  |-0.02029% |7.14%
# Eval num_timesteps=930000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  311| 499|update         |$1036688  |-0.01942% |6.66%
#  311| 504|Last Date      |$1033195  |-0.02108% |6.50%
# Eval num_timesteps=936000, episode_reward=-0.13 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  313| 499|update         |$1029948  |-0.02061% |6.70%
#  313| 504|Last Date      |$1027668  |-0.02166% |6.68%
# Eval num_timesteps=942000, episode_reward=-0.13 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  315| 499|update         |$1044240  |-0.01857% |6.47%
#  315| 504|Last Date      |$1039706  |-0.02026% |6.36%
# Eval num_timesteps=948000, episode_reward=-0.12 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  317| 499|update         |$1022013  |-0.02198% |6.76%
#  317| 504|Last Date      |$1017751  |-0.02293% |6.90%
# Eval num_timesteps=954000, episode_reward=-0.15 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  319| 499|update         |$999837   |-0.02286% |8.22%
#  319| 504|Last Date      |$996140   |-0.02415% |8.17%
# Eval num_timesteps=960000, episode_reward=-0.15 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  321| 499|update         |$1019110  |-0.02005% |7.97%
#  321| 504|Last Date      |$1015147  |-0.02115% |8.01%
# Eval num_timesteps=966000, episode_reward=-0.13 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  323| 499|update         |$1000422  |-0.02293% |8.14%
#  323| 504|Last Date      |$996728   |-0.02432% |8.03%
# Eval num_timesteps=972000, episode_reward=-0.16 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  325| 499|update         |$968251   |-0.02484% |10.11%
#  325| 504|Last Date      |$964946   |-0.02605% |10.02%
# Eval num_timesteps=978000, episode_reward=-0.16 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  327| 499|update         |$1014224  |-0.01980% |8.49%
#  327| 504|Last Date      |$1010662  |-0.02108% |8.43%
# Eval num_timesteps=984000, episode_reward=-0.13 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  329| 499|update         |$1024719  |-0.01807% |8.40%
#  329| 504|Last Date      |$1021113  |-0.01958% |8.27%
# Eval num_timesteps=990000, episode_reward=-0.13 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  331| 499|update         |$1064357  |-0.01076% |8.54%
#  331| 504|Last Date      |$1060619  |-0.01228% |8.45%
# Eval num_timesteps=996000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  333| 499|update         |$1069500  |-0.00270% |11.84%
#  333| 504|Last Date      |$1065873  |-0.00467% |11.61%
# Eval num_timesteps=1002000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  335| 499|update         |$1069852  |-0.00392% |11.23%
#  335| 504|Last Date      |$1066212  |-0.00608% |10.92%
# Eval num_timesteps=1008000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  337| 499|update         |$1068234  |-0.00380% |11.44%
#  337| 504|Last Date      |$1064598  |-0.00563% |11.27%
# Eval num_timesteps=1014000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  339| 499|update         |$1067125  |-0.00001% |13.34%
#  339| 504|Last Date      |$1063575  |-0.00157% |13.28%
# Eval num_timesteps=1020000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  341| 499|update         |$1067125  |-0.00001% |13.34%
#  341| 504|Last Date      |$1063575  |-0.00157% |13.28%
# Eval num_timesteps=1026000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  343| 499|update         |$1067217  |-0.00179% |12.47%
#  343| 504|Last Date      |$1062759  |-0.00356% |12.41%
# Eval num_timesteps=1032000, episode_reward=-0.05 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  345| 499|update         |$1061162  |0.00752%  |17.34%
#  345| 504|Last Date      |$1057779  |0.00505%  |16.95%
# Eval num_timesteps=1038000, episode_reward=-0.04 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  347| 499|update         |$1056321  |0.01212%  |23.69%
#  347| 504|Last Date      |$1053220  |0.01056%  |23.53%
# Eval num_timesteps=1044000, episode_reward=-0.04 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  349| 499|update         |$1043012  |0.00926%  |41.31%
#  349| 504|Last Date      |$1040649  |0.00807%  |41.05%
# Eval num_timesteps=1050000, episode_reward=-0.03 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  351| 499|update         |$1049209  |0.01066%  |32.74%
#  351| 504|Last Date      |$1045486  |0.00903%  |32.42%
# Eval num_timesteps=1056000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  353| 499|update         |$1047024  |0.01019%  |34.93%
#  353| 504|Last Date      |$1043483  |0.00863%  |34.44%
# Eval num_timesteps=1062000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  355| 499|update         |$1065776  |-0.01254% |7.56%
#  355| 504|Last Date      |$1063079  |-0.01354% |7.65%
# Eval num_timesteps=1068000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  357| 499|update         |$1048092  |-0.01259% |8.99%
#  357| 504|Last Date      |$1043794  |-0.01399% |9.05%
# Eval num_timesteps=1074000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  359| 499|update         |$1041640  |-0.00911% |11.16%
#  359| 504|Last Date      |$1035909  |-0.01112% |11.12%
# Eval num_timesteps=1080000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  361| 499|update         |$1048432  |-0.00875% |10.62%
#  361| 504|Last Date      |$1043440  |-0.01074% |10.65%
# Eval num_timesteps=1086000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  363| 499|update         |$1050247  |-0.00964% |10.24%
#  363| 504|Last Date      |$1046848  |-0.01145% |10.01%
# Eval num_timesteps=1092000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  365| 499|update         |$1056876  |-0.01010% |9.46%
#  365| 504|Last Date      |$1057638  |-0.01069% |9.46%
# Eval num_timesteps=1098000, episode_reward=-0.13 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  367| 499|update         |$1044575  |-0.01151% |9.85%
#  367| 504|Last Date      |$1042951  |-0.01259% |9.80%
# Eval num_timesteps=1104000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  369| 499|update         |$1039610  |-0.01071% |10.74%
#  369| 504|Last Date      |$1035659  |-0.01254% |10.45%
# Eval num_timesteps=1110000, episode_reward=-0.13 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  371| 499|update         |$1045527  |-0.01086% |10.10%
#  371| 504|Last Date      |$1043551  |-0.01219% |9.94%
# Eval num_timesteps=1116000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  373| 499|update         |$1048124  |-0.00935% |10.62%
#  373| 504|Last Date      |$1046208  |-0.01044% |10.55%
# Eval num_timesteps=1122000, episode_reward=-0.13 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  375| 499|update         |$1042190  |-0.00999% |10.72%
#  375| 504|Last Date      |$1039202  |-0.01166% |10.57%
# Eval num_timesteps=1128000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  377| 499|update         |$1043253  |-0.00714% |11.89%
#  377| 504|Last Date      |$1037710  |-0.00958% |11.71%
# Eval num_timesteps=1134000, episode_reward=-0.13 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  379| 499|update         |$1048588  |-0.00721% |11.45%
#  379| 504|Last Date      |$1043975  |-0.00910% |11.39%
# Eval num_timesteps=1140000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  381| 499|update         |$1044511  |-0.00690% |11.97%
#  381| 504|Last Date      |$1038256  |-0.00906% |11.92%
# Eval num_timesteps=1146000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  383| 499|update         |$1048186  |-0.00614% |11.96%
#  383| 504|Last Date      |$1043064  |-0.00842% |11.80%
# Eval num_timesteps=1152000, episode_reward=-0.10 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  385| 499|update         |$1051388  |-0.00572% |11.87%
#  385| 504|Last Date      |$1046777  |-0.00788% |11.74%
# Eval num_timesteps=1158000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  387| 499|update         |$1046782  |-0.00551% |12.46%
#  387| 504|Last Date      |$1039238  |-0.00797% |12.36%
# Eval num_timesteps=1164000, episode_reward=-0.10 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  389| 499|update         |$1046637  |-0.00609% |12.17%
#  389| 504|Last Date      |$1037895  |-0.00847% |12.23%
# Eval num_timesteps=1170000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  391| 499|update         |$1049898  |-0.00466% |12.55%
#  391| 504|Last Date      |$1040534  |-0.00677% |12.82%
# Eval num_timesteps=1176000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  393| 499|update         |$1047498  |-0.00471% |12.71%
#  393| 504|Last Date      |$1037558  |-0.00732% |12.82%
# Eval num_timesteps=1182000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  395| 499|update         |$1042685  |-0.00414% |13.42%
#  395| 504|Last Date      |$1032714  |-0.00689% |13.47%
# Eval num_timesteps=1188000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  397| 499|update         |$1043940  |-0.00935% |10.77%
#  397| 504|Last Date      |$1033907  |-0.01227% |10.74%
# Eval num_timesteps=1194000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  399| 499|update         |$1042428  |-0.00930% |10.93%
#  399| 504|Last Date      |$1031926  |-0.01189% |11.10%
# Eval num_timesteps=1200000, episode_reward=-0.10 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  401| 499|update         |$1041933  |-0.00168% |14.61%
#  401| 504|Last Date      |$1030734  |-0.00479% |14.68%
# Eval num_timesteps=1206000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  403| 499|update         |$1048610  |-0.00338% |13.16%
#  403| 504|Last Date      |$1038066  |-0.00676% |13.05%
# Eval num_timesteps=1212000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  405| 499|update         |$1048908  |-0.00263% |13.53%
#  405| 504|Last Date      |$1037917  |-0.00658% |13.15%
# Eval num_timesteps=1218000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  407| 499|update         |$1043804  |0.00196%  |16.19%
#  407| 504|Last Date      |$1032515  |-0.00116% |16.28%
# Eval num_timesteps=1224000, episode_reward=-0.04 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  409| 499|update         |$1051737  |0.00409%  |16.50%
#  409| 504|Last Date      |$1040931  |0.00081%  |16.46%
# Eval num_timesteps=1230000, episode_reward=-0.04 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  411| 499|update         |$1048668  |0.00436%  |16.86%
#  411| 504|Last Date      |$1036799  |0.00098%  |16.93%
# Eval num_timesteps=1236000, episode_reward=-0.00 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  413| 499|update         |$1045818  |0.00370%  |16.87%
#  413| 504|Last Date      |$1034584  |0.00031%  |16.81%
# Eval num_timesteps=1242000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  415| 499|update         |$1050857  |0.00289%  |16.07%
#  415| 504|Last Date      |$1041194  |-0.00014% |15.98%
# Eval num_timesteps=1248000, episode_reward=-0.04 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  417| 280|CASH SHORTAGE  |$1020020  |-0.06495% |0.21%
# Eval num_timesteps=1254000, episode_reward=-0.03 +/- 0.00
# Episode length: 281.00 +/- 0.00
#  419| 207|CASH SHORTAGE  |$1006498  |-0.09123% |0.59%
# Eval num_timesteps=1260000, episode_reward=-0.02 +/- 0.00
# Episode length: 208.00 +/- 0.00
#  421| 204|CASH SHORTAGE  |$1019755  |-0.08823% |0.41%
# Eval num_timesteps=1266000, episode_reward=-0.02 +/- 0.00
# Episode length: 205.00 +/- 0.00
#  423| 181|CASH SHORTAGE  |$1012794  |-0.10412% |0.13%
# Eval num_timesteps=1272000, episode_reward=-0.02 +/- 0.00
# Episode length: 182.00 +/- 0.00
#  425| 155|CASH SHORTAGE  |$969527   |-0.14381% |0.15%
# Eval num_timesteps=1278000, episode_reward=-0.03 +/- 0.00
# Episode length: 156.00 +/- 0.00
#  427| 155|CASH SHORTAGE  |$969527   |-0.14381% |0.15%
# Eval num_timesteps=1284000, episode_reward=-0.03 +/- 0.00
# Episode length: 156.00 +/- 0.00
#  429| 168|CASH SHORTAGE  |$995625   |-0.11970% |0.24%
# Eval num_timesteps=1290000, episode_reward=-0.04 +/- 0.00
# Episode length: 169.00 +/- 0.00
#  431| 158|CASH SHORTAGE  |$994218   |-0.12902% |0.08%
# Eval num_timesteps=1296000, episode_reward=-0.03 +/- 0.00
# Episode length: 159.00 +/- 0.00
#  659| 499|update         |$1004877  |0.00105%  |93.17%
#  659| 504|Last Date      |$1004611  |0.00092%  |93.13%
# Eval num_timesteps=1980000, episode_reward=-0.00 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  661| 499|update         |$1007147  |0.00154%  |90.02%
#  661| 504|Last Date      |$1006757  |0.00134%  |89.96%
# Eval num_timesteps=1986000, episode_reward=-0.00 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  663| 499|update         |$1011615  |0.00250%  |83.85%
#  663| 504|Last Date      |$1010982  |0.00218%  |83.75%
# Eval num_timesteps=1992000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  665| 499|update         |$1017164  |0.00369%  |76.27%
#  665| 504|Last Date      |$1016229  |0.00322%  |76.12%
# Eval num_timesteps=1998000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  667| 499|update         |$1024844  |0.00534%  |65.91%
#  667| 504|Last Date      |$1023490  |0.00466%  |65.68%
# Eval num_timesteps=2004000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  669| 499|update         |$1018856  |0.00405%  |73.97%
#  669| 504|Last Date      |$1017828  |0.00354%  |73.80%
# Eval num_timesteps=2010000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  671| 499|update         |$1042789  |0.00920%  |42.29%
#  671| 504|Last Date      |$1040457  |0.00803%  |41.85%
# Eval num_timesteps=2016000, episode_reward=-0.03 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  673| 499|update         |$1048486  |0.01058%  |31.18%
#  673| 504|Last Date      |$1043860  |0.00870%  |30.67%
# Eval num_timesteps=2022000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  675| 499|update         |$1041619  |0.00908%  |40.58%
#  675| 504|Last Date      |$1037672  |0.00747%  |40.18%
# Eval num_timesteps=2028000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  677| 499|update         |$1031079  |0.00669%  |57.34%
#  677| 504|Last Date      |$1029248  |0.00580%  |57.05%
# Eval num_timesteps=2034000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  679| 499|update         |$1023641  |0.00508%  |67.52%
#  679| 504|Last Date      |$1022353  |0.00444%  |67.30%
# Eval num_timesteps=2040000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  681| 499|update         |$1028557  |0.00614%  |60.95%
#  681| 504|Last Date      |$1027000  |0.00536%  |60.68%
# Eval num_timesteps=2046000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  683| 499|update         |$1028557  |0.00614%  |60.95%
#  683| 504|Last Date      |$1027000  |0.00536%  |60.68%
# Eval num_timesteps=2052000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  685| 499|update         |$1019501  |0.00419%  |73.10%
#  685| 504|Last Date      |$1018439  |0.00366%  |72.92%
# Eval num_timesteps=2058000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  687| 499|update         |$1024386  |0.00524%  |66.52%
#  687| 504|Last Date      |$1023057  |0.00457%  |66.29%
# Eval num_timesteps=2064000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  689| 499|update         |$1022724  |0.00489%  |68.75%
#  689| 504|Last Date      |$1021485  |0.00426%  |68.54%
# Eval num_timesteps=2070000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  691| 499|update         |$1057000  |0.01214%  |49.04%
#  691| 504|Last Date      |$1053775  |0.01067%  |48.73%
# Eval num_timesteps=2076000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  693| 499|update         |$1145206  |0.01723%  |14.16%
#  693| 504|Last Date      |$1139040  |0.01286%  |13.48%
# Eval num_timesteps=2082000, episode_reward=0.00 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  695| 422|CASH SHORTAGE  |$1101653  |-0.02609% |0.78%
# Eval num_timesteps=2088000, episode_reward=-0.04 +/- 0.00
# Episode length: 423.00 +/- 0.00
#  697| 355|CASH SHORTAGE  |$1012377  |-0.05083% |0.95%
# Eval num_timesteps=2094000, episode_reward=-0.04 +/- 0.00
# Episode length: 356.00 +/- 0.00
#  699| 361|CASH SHORTAGE  |$1057758  |-0.04071% |0.64%
# Eval num_timesteps=2100000, episode_reward=-0.07 +/- 0.00
# Episode length: 362.00 +/- 0.00
#  701| 499|update         |$1268338  |0.01114%  |2.58%
#  701| 504|Last Date      |$1262147  |0.00830%  |2.54%
# Eval num_timesteps=2106000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  703| 499|update         |$1251728  |0.00861%  |2.65%
#  703| 504|Last Date      |$1245654  |0.00535%  |2.45%
# Eval num_timesteps=2112000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  705| 499|update         |$1224044  |0.00714%  |3.99%
#  705| 504|Last Date      |$1218475  |0.00424%  |3.82%
# Eval num_timesteps=2118000, episode_reward=-0.05 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  707| 499|update         |$1210749  |0.01061%  |6.41%
#  707| 504|Last Date      |$1205281  |0.00791%  |6.28%
# Eval num_timesteps=2124000, episode_reward=-0.03 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  709| 499|update         |$1228559  |0.00976%  |4.73%
#  709| 504|Last Date      |$1222939  |0.00667%  |4.52%
# Eval num_timesteps=2130000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  711| 499|update         |$1227698  |0.01199%  |5.76%
#  711| 504|Last Date      |$1222212  |0.00922%  |5.62%
# Eval num_timesteps=2136000, episode_reward=-0.04 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  713| 499|update         |$1132097  |-0.00010% |7.72%
#  713| 504|Last Date      |$1126795  |-0.00304% |7.39%
# Eval num_timesteps=2142000, episode_reward=-0.03 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  715| 499|update         |$1137613  |0.00130%  |7.99%
#  715| 504|Last Date      |$1131895  |-0.00144% |7.71%
# Eval num_timesteps=2148000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  717| 499|update         |$1129335  |0.01120%  |12.89%
#  717| 504|Last Date      |$1123345  |0.00766%  |12.46%
# Eval num_timesteps=2154000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  719| 499|update         |$1118245  |0.00056%  |9.27%
#  719| 504|Last Date      |$1113328  |-0.00172% |9.04%
# Eval num_timesteps=2160000, episode_reward=-0.04 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  721| 499|update         |$1077547  |0.00304%  |13.71%
#  721| 504|Last Date      |$1072542  |0.00011%  |13.29%
# Eval num_timesteps=2166000, episode_reward=-0.03 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  723| 499|update         |$1070925  |0.01507%  |22.79%
#  723| 504|Last Date      |$1067472  |0.01339%  |22.22%
# Eval num_timesteps=2172000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  725| 499|update         |$1048227  |0.01038%  |34.04%
#  725| 504|Last Date      |$1045550  |0.00904%  |33.56%
# Eval num_timesteps=2178000, episode_reward=-0.03 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  727| 499|update         |$1029084  |0.00625%  |60.25%
#  727| 504|Last Date      |$1027499  |0.00546%  |59.97%
# Eval num_timesteps=2184000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  729| 499|update         |$1030518  |0.00656%  |58.46%
#  729| 504|Last Date      |$1028860  |0.00573%  |58.18%
# Eval num_timesteps=2190000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  731| 499|update         |$1032117  |0.00691%  |56.24%
#  731| 504|Last Date      |$1030366  |0.00603%  |55.92%
# Eval num_timesteps=2196000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  733| 499|update         |$1028429  |0.00611%  |61.12%
#  733| 504|Last Date      |$1026880  |0.00533%  |60.85%
# Eval num_timesteps=2202000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  735| 499|update         |$1024300  |0.00523%  |66.64%
#  735| 504|Last Date      |$1022976  |0.00456%  |66.41%
# Eval num_timesteps=2208000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  737| 499|update         |$1042693  |0.00918%  |42.42%
#  737| 504|Last Date      |$1040366  |0.00801%  |41.97%
# Eval num_timesteps=2214000, episode_reward=-0.03 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  739| 499|update         |$1047211  |0.01015%  |36.60%
#  739| 504|Last Date      |$1044638  |0.00886%  |36.09%
# Eval num_timesteps=2220000, episode_reward=-0.03 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  741| 499|update         |$1041380  |0.00890%  |44.12%
#  741| 504|Last Date      |$1039125  |0.00776%  |43.69%
# Eval num_timesteps=2226000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  743| 499|update         |$1057449  |0.01235%  |23.59%
#  743| 504|Last Date      |$1054318  |0.01078%  |22.95%
# Eval num_timesteps=2232000, episode_reward=-0.03 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  745| 499|update         |$1045175  |0.00971%  |39.21%
#  745| 504|Last Date      |$1042713  |0.00847%  |38.74%
# Eval num_timesteps=2238000, episode_reward=-0.03 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  747| 499|update         |$1025009  |0.00538%  |65.69%
#  747| 504|Last Date      |$1023646  |0.00469%  |65.45%
# Eval num_timesteps=2244000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  749| 499|update         |$1008901  |0.00191%  |87.59%
#  749| 504|Last Date      |$1008416  |0.00167%  |87.52%
# Eval num_timesteps=2250000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  751| 499|update         |$1009971  |0.00214%  |86.11%
#  751| 504|Last Date      |$1009428  |0.00187%  |86.03%
# Eval num_timesteps=2256000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  753| 499|update         |$1023972  |0.00515%  |67.08%
#  753| 504|Last Date      |$1022665  |0.00450%  |66.85%
# Eval num_timesteps=2262000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  755| 499|update         |$1033715  |0.00725%  |54.13%
#  755| 504|Last Date      |$1031877  |0.00632%  |53.80%
# Eval num_timesteps=2268000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  757| 499|update         |$1043041  |0.00936%  |39.39%
#  757| 504|Last Date      |$1039355  |0.00781%  |38.96%
# Eval num_timesteps=2274000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  759| 499|update         |$1038144  |0.00835%  |44.86%
#  759| 504|Last Date      |$1034269  |0.00680%  |44.51%
# Eval num_timesteps=2280000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  761| 499|update         |$1045636  |0.01002%  |33.70%
#  761| 504|Last Date      |$1040580  |0.00805%  |33.24%
# Eval num_timesteps=2286000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  763| 499|update         |$1051289  |0.01139%  |22.78%
#  763| 504|Last Date      |$1043986  |0.00873%  |22.22%
# Eval num_timesteps=2292000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  765| 499|update         |$1050125  |0.01116%  |23.84%
#  765| 504|Last Date      |$1042660  |0.00846%  |23.29%
# Eval num_timesteps=2298000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  767| 499|update         |$1050125  |0.01116%  |23.84%
#  767| 504|Last Date      |$1042660  |0.00846%  |23.29%
# Eval num_timesteps=2304000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  769| 499|update         |$1036424  |0.00801%  |46.22%
#  769| 504|Last Date      |$1032181  |0.00639%  |45.90%
# Eval num_timesteps=2310000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  771| 499|update         |$1051759  |0.01121%  |27.52%
#  771| 504|Last Date      |$1045818  |0.00909%  |27.08%
# Eval num_timesteps=2316000, episode_reward=-0.00 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  773| 499|update         |$1062446  |0.00192%  |14.54%
#  773| 504|Last Date      |$1056141  |-0.00126% |14.08%
# Eval num_timesteps=2322000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  775| 499|update         |$1070297  |0.00517%  |15.54%
#  775| 504|Last Date      |$1063196  |0.00254%  |15.26%
# Eval num_timesteps=2328000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  777| 499|update         |$1066508  |-0.00542% |10.94%
#  777| 504|Last Date      |$1059362  |-0.00888% |10.17%
# Eval num_timesteps=2334000, episode_reward=-0.05 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  779| 499|update         |$1068220  |-0.00503% |10.92%
#  779| 504|Last Date      |$1060670  |-0.00834% |10.32%
# Eval num_timesteps=2340000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  781| 499|update         |$1089092  |-0.00878% |7.31%
#  781| 504|Last Date      |$1080531  |-0.01122% |7.32%
# Eval num_timesteps=2346000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  783| 499|update         |$1121984  |-0.00257% |7.42%
#  783| 504|Last Date      |$1112619  |-0.00539% |7.44%
# Eval num_timesteps=2352000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  785| 499|update         |$1166534  |0.00378%  |6.76%
#  785| 504|Last Date      |$1157470  |0.00083%  |6.76%
# Eval num_timesteps=2358000, episode_reward=-0.10 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  787| 499|update         |$1164146  |0.00500%  |7.50%
#  787| 504|Last Date      |$1155921  |0.00181%  |7.30%
# Eval num_timesteps=2364000, episode_reward=-0.10 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  789| 499|update         |$1145109  |0.00640%  |9.48%
#  789| 504|Last Date      |$1138053  |0.00295%  |9.18%
# Eval num_timesteps=2370000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  791| 499|update         |$1149095  |0.00891%  |10.44%
#  791| 504|Last Date      |$1143281  |0.00540%  |9.85%
# Eval num_timesteps=2376000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  793| 499|update         |$1245762  |0.02028%  |7.90%
#  793| 504|Last Date      |$1239950  |0.01709%  |7.59%
# Eval num_timesteps=2382000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  795| 499|update         |$1294626  |0.02428%  |6.05%
#  795| 504|Last Date      |$1288423  |0.02147%  |6.01%
# Eval num_timesteps=2388000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  797| 499|update         |$1271240  |0.02537%  |8.09%
#  797| 504|Last Date      |$1265393  |0.02140%  |7.55%
# Eval num_timesteps=2394000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  799| 499|update         |$1266215  |0.02490%  |8.16%
#  799| 504|Last Date      |$1260213  |0.02122%  |7.84%
# Eval num_timesteps=2400000, episode_reward=-0.10 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  801| 499|update         |$1253916  |0.02217%  |8.02%
#  801| 504|Last Date      |$1248257  |0.01820%  |7.46%
# Eval num_timesteps=2406000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  803| 499|update         |$1221752  |0.01806%  |8.74%
#  803| 504|Last Date      |$1216226  |0.01432%  |8.15%
# Eval num_timesteps=2412000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  805| 499|update         |$1195418  |0.01417%  |9.30%
#  805| 504|Last Date      |$1189230  |0.01081%  |8.67%
# Eval num_timesteps=2418000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  807| 499|update         |$1200199  |0.01569%  |9.46%
#  807| 504|Last Date      |$1193548  |0.01151%  |8.65%
# Eval num_timesteps=2424000, episode_reward=-0.12 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  809| 499|update         |$1211042  |0.01846%  |9.34%
#  809| 504|Last Date      |$1203930  |0.01409%  |8.96%
# Eval num_timesteps=2430000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  811| 499|update         |$1195254  |0.01542%  |9.74%
#  811| 504|Last Date      |$1187661  |0.01149%  |9.07%
# Eval num_timesteps=2436000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  813| 499|update         |$1226604  |0.02037%  |8.97%
#  813| 504|Last Date      |$1219449  |0.01537%  |8.36%
# Eval num_timesteps=2442000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  815| 499|update         |$1195714  |0.01591%  |9.48%
#  815| 504|Last Date      |$1188406  |0.01134%  |8.95%
# Eval num_timesteps=2448000, episode_reward=-0.12 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  817| 499|update         |$1193238  |0.01472%  |9.36%
#  817| 504|Last Date      |$1186242  |0.01150%  |9.18%
# Eval num_timesteps=2454000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  819| 499|update         |$1269854  |0.02521%  |7.89%
#  819| 504|Last Date      |$1262737  |0.02114%  |7.63%
# Eval num_timesteps=2460000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  821| 499|update         |$1279526  |0.02729%  |8.01%
#  821| 504|Last Date      |$1273424  |0.02394%  |8.01%
# Eval num_timesteps=2466000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  823| 499|update         |$1309167  |0.02864%  |6.57%
#  823| 504|Last Date      |$1302844  |0.02548%  |6.61%
# Eval num_timesteps=2472000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  825| 499|update         |$1333478  |0.03173%  |6.35%
#  825| 504|Last Date      |$1326886  |0.02846%  |6.18%
# Eval num_timesteps=2478000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  827| 499|update         |$1315884  |0.02933%  |6.58%
#  827| 504|Last Date      |$1309469  |0.02596%  |6.36%
# Eval num_timesteps=2484000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  829| 499|update         |$1320172  |0.02870%  |6.03%
#  829| 504|Last Date      |$1313644  |0.02507%  |5.74%
# Eval num_timesteps=2490000, episode_reward=-0.17 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  831| 499|update         |$1303429  |0.02613%  |6.17%
#  831| 504|Last Date      |$1297047  |0.02247%  |5.83%
# Eval num_timesteps=2496000, episode_reward=-0.18 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  833| 499|update         |$1291973  |0.02565%  |6.62%
#  833| 504|Last Date      |$1285798  |0.02214%  |6.45%
# Eval num_timesteps=2502000, episode_reward=-0.16 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  835| 499|update         |$1329501  |0.03295%  |6.85%
#  835| 504|Last Date      |$1322975  |0.02947%  |6.82%
# Eval num_timesteps=2508000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  837| 499|update         |$1301064  |0.03025%  |7.74%
#  837| 504|Last Date      |$1294833  |0.02623%  |7.44%
# Eval num_timesteps=2514000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  839| 499|update         |$1345165  |0.03632%  |7.06%
#  839| 504|Last Date      |$1338393  |0.03263%  |7.01%
# Eval num_timesteps=2520000, episode_reward=-0.13 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  841| 499|update         |$1362441  |0.03941%  |7.10%
#  841| 504|Last Date      |$1355501  |0.03589%  |7.12%
# Eval num_timesteps=2526000, episode_reward=-0.10 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  843| 499|update         |$1389652  |0.04589%  |7.72%
#  843| 504|Last Date      |$1382423  |0.04069%  |7.17%
# Eval num_timesteps=2532000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  845| 499|update         |$1396350  |0.04819%  |8.20%
#  845| 504|Last Date      |$1388750  |0.04297%  |7.60%
# Eval num_timesteps=2538000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  847| 499|update         |$1383686  |0.04597%  |8.25%
#  847| 504|Last Date      |$1376241  |0.04167%  |7.92%
# Eval num_timesteps=2544000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  849| 499|update         |$1425850  |0.05475%  |8.51%
#  849| 504|Last Date      |$1418288  |0.04991%  |8.24%
# Eval num_timesteps=2550000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  851| 499|update         |$1398392  |0.04967%  |8.50%
#  851| 504|Last Date      |$1390868  |0.04442%  |7.99%
# Eval num_timesteps=2556000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  853| 499|update         |$1398392  |0.04967%  |8.50%
#  853| 504|Last Date      |$1390868  |0.04442%  |7.99%
# Eval num_timesteps=2562000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  855| 499|update         |$1453605  |0.05770%  |7.74%
#  855| 504|Last Date      |$1445788  |0.05329%  |7.74%
# Eval num_timesteps=2568000, episode_reward=-0.04 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  857| 499|update         |$1460913  |0.05832%  |7.66%
#  857| 504|Last Date      |$1452359  |0.05291%  |7.21%
# Eval num_timesteps=2574000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  859| 499|update         |$1480050  |0.06272%  |7.75%
#  859| 504|Last Date      |$1471270  |0.05797%  |7.83%
# Eval num_timesteps=2580000, episode_reward=-0.03 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  861| 499|update         |$1480488  |0.06165%  |7.48%
#  861| 504|Last Date      |$1471451  |0.05683%  |7.42%
# Eval num_timesteps=2586000, episode_reward=-0.04 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  863| 499|update         |$1505845  |0.06276%  |6.35%
#  863| 504|Last Date      |$1497177  |0.05799%  |6.31%
# Eval num_timesteps=2592000, episode_reward=-0.05 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  865| 499|update         |$1485888  |0.05868%  |6.16%
#  865| 504|Last Date      |$1477002  |0.05381%  |6.07%
# Eval num_timesteps=2598000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  867| 499|update         |$1506170  |0.06164%  |5.92%
#  867| 504|Last Date      |$1497493  |0.05610%  |5.66%
# Eval num_timesteps=2604000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  869| 499|update         |$1411998  |0.04080%  |4.49%
#  869| 504|Last Date      |$1404333  |0.03670%  |4.38%
# Eval num_timesteps=2610000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  871| 499|update         |$1447140  |0.04547%  |4.02%
#  871| 504|Last Date      |$1439075  |0.04132%  |3.96%
# Eval num_timesteps=2616000, episode_reward=-0.15 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  873| 499|update         |$1501369  |0.05500%  |4.02%
#  873| 504|Last Date      |$1492714  |0.05050%  |4.04%
# Eval num_timesteps=2622000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  875| 499|update         |$1458508  |0.05037%  |4.92%
#  875| 504|Last Date      |$1450319  |0.04592%  |4.91%
# Eval num_timesteps=2628000, episode_reward=-0.15 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  877| 499|update         |$1478119  |0.05760%  |6.27%
#  877| 504|Last Date      |$1469718  |0.05184%  |5.82%
# Eval num_timesteps=2634000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  879| 499|update         |$1521474  |0.06420%  |5.92%
#  879| 504|Last Date      |$1512718  |0.05911%  |5.80%
# Eval num_timesteps=2640000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  881| 499|update         |$1568148  |0.07000%  |5.15%
#  881| 504|Last Date      |$1559061  |0.06507%  |5.18%
# Eval num_timesteps=2646000, episode_reward=-0.04 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  883| 499|update         |$1586308  |0.07261%  |5.01%
#  883| 504|Last Date      |$1577105  |0.06778%  |5.07%
# Eval num_timesteps=2652000, episode_reward=-0.03 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  885| 499|update         |$1569472  |0.07020%  |5.14%
#  885| 504|Last Date      |$1560374  |0.06511%  |5.12%
# Eval num_timesteps=2658000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  887| 499|update         |$1587664  |0.07251%  |4.88%
#  887| 504|Last Date      |$1578440  |0.06753%  |4.92%
# Eval num_timesteps=2664000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  889| 499|update         |$1556497  |0.06692%  |4.82%
#  889| 504|Last Date      |$1547447  |0.06202%  |4.82%
# Eval num_timesteps=2670000, episode_reward=-0.04 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  891| 499|update         |$1577449  |0.06696%  |3.68%
#  891| 504|Last Date      |$1568169  |0.06203%  |3.70%
# Eval num_timesteps=2676000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  893| 499|update         |$1564202  |0.06456%  |3.63%
#  893| 504|Last Date      |$1554993  |0.05963%  |3.63%
# Eval num_timesteps=2682000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  895| 499|update         |$1537910  |0.06356%  |4.77%
#  895| 504|Last Date      |$1528963  |0.05885%  |4.80%
# Eval num_timesteps=2688000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  897| 499|update         |$1577228  |0.07051%  |4.83%
#  897| 504|Last Date      |$1568060  |0.06567%  |4.88%
# Eval num_timesteps=2694000, episode_reward=-0.05 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  899| 499|update         |$1576692  |0.07240%  |5.47%
#  899| 504|Last Date      |$1567588  |0.06754%  |5.51%
# Eval num_timesteps=2700000, episode_reward=-0.03 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  901| 499|update         |$1575379  |0.06981%  |4.72%
#  901| 504|Last Date      |$1566211  |0.06497%  |4.76%
# Eval num_timesteps=2706000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  903| 499|update         |$1554787  |0.06544%  |4.47%
#  903| 504|Last Date      |$1545713  |0.06068%  |4.48%
# Eval num_timesteps=2712000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  905| 499|update         |$1547781  |0.06413%  |4.43%
#  905| 504|Last Date      |$1538741  |0.05924%  |4.39%
# Eval num_timesteps=2718000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  907| 499|update         |$1539587  |0.06311%  |4.55%
#  907| 504|Last Date      |$1530604  |0.05820%  |4.50%
# Eval num_timesteps=2724000, episode_reward=-0.12 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  909| 499|update         |$1587384  |0.07070%  |4.35%
#  909| 504|Last Date      |$1578108  |0.06579%  |4.38%
# Eval num_timesteps=2730000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  911| 499|update         |$1595261  |0.07392%  |4.93%
#  911| 504|Last Date      |$1585998  |0.06907%  |5.00%
# Eval num_timesteps=2736000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  913| 499|update         |$1580359  |0.07093%  |4.76%
#  913| 504|Last Date      |$1571168  |0.06619%  |4.88%
# Eval num_timesteps=2742000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  915| 499|update         |$1582101  |0.07109%  |4.74%
#  915| 504|Last Date      |$1572894  |0.06619%  |4.79%
# Eval num_timesteps=2748000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  917| 499|update         |$1591822  |0.07253%  |4.67%
#  917| 504|Last Date      |$1582552  |0.06746%  |4.67%
# Eval num_timesteps=2754000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  919| 499|update         |$1586585  |0.07248%  |4.96%
#  919| 504|Last Date      |$1577367  |0.06767%  |5.02%
# Eval num_timesteps=2760000, episode_reward=-0.12 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  921| 499|update         |$1585183  |0.07243%  |5.02%
#  921| 504|Last Date      |$1575987  |0.06767%  |5.09%
# Eval num_timesteps=2766000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  923| 499|update         |$1588896  |0.07283%  |4.93%
#  923| 504|Last Date      |$1579670  |0.06791%  |4.97%
# Eval num_timesteps=2772000, episode_reward=-0.13 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  925| 499|update         |$1580380  |0.07125%  |4.91%
#  925| 504|Last Date      |$1571199  |0.06628%  |4.91%
# Eval num_timesteps=2778000, episode_reward=-0.15 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  927| 499|update         |$1557742  |0.06865%  |5.33%
#  927| 504|Last Date      |$1548732  |0.06367%  |5.29%
# Eval num_timesteps=2784000, episode_reward=-0.13 +/- 0.00
# Episode length: 505.00 +/- 0.00
#  929| 499|update         |$1547589  |0.06721%  |5.41%
#  929| 504|Last Date      |$1538648  |0.06243%  |5.44%
# Eval num_timesteps=2790000, episode_reward=-0.14 +/- 0.00
# Episode length: 505.00 +/- 0.00
# ...
# 1513| 504|Last Date      |$1739603  |0.08871%  |3.19%
# Eval num_timesteps=4542000, episode_reward=0.03 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1515| 499|update         |$1726007  |0.08977%  |3.17%
# 1515| 504|Last Date      |$1727286  |0.08612%  |3.02%
# Eval num_timesteps=4548000, episode_reward=0.05 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1517| 499|update         |$1730434  |0.09143%  |3.31%
# 1517| 504|Last Date      |$1730597  |0.08786%  |3.37%
# Eval num_timesteps=4554000, episode_reward=0.04 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1519| 499|update         |$1714641  |0.08816%  |3.11%
# 1519| 504|Last Date      |$1716337  |0.08476%  |3.15%
# Eval num_timesteps=4560000, episode_reward=0.03 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1521| 499|update         |$1694146  |0.08502%  |3.27%
# 1521| 504|Last Date      |$1696373  |0.08184%  |3.26%
# Eval num_timesteps=4566000, episode_reward=0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1523| 499|update         |$1665330  |0.07941%  |3.00%
# 1523| 504|Last Date      |$1670991  |0.07659%  |2.94%
# Eval num_timesteps=4572000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1525| 499|update         |$1653757  |0.07691%  |2.97%
# 1525| 504|Last Date      |$1660511  |0.07474%  |2.91%
# Eval num_timesteps=4578000, episode_reward=-0.03 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1527| 499|update         |$1662854  |0.07946%  |3.21%
# 1527| 504|Last Date      |$1666309  |0.07687%  |3.26%
# Eval num_timesteps=4584000, episode_reward=-0.04 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1529| 499|update         |$1631596  |0.07469%  |3.40%
# 1529| 504|Last Date      |$1634837  |0.07198%  |3.36%
# Eval num_timesteps=4590000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1531| 499|update         |$1580031  |0.06296%  |2.57%
# 1531| 504|Last Date      |$1592270  |0.06191%  |2.40%
# Eval num_timesteps=4596000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1533| 499|update         |$1618698  |0.07141%  |3.10%
# 1533| 504|Last Date      |$1624119  |0.06909%  |3.01%
# Eval num_timesteps=4602000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1535| 499|update         |$1618698  |0.07141%  |3.10%
# 1535| 504|Last Date      |$1624119  |0.06909%  |3.01%
# Eval num_timesteps=4608000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1537| 499|update         |$1634950  |0.07657%  |3.77%
# 1537| 504|Last Date      |$1635618  |0.07344%  |3.77%
# Eval num_timesteps=4614000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1539| 499|update         |$1667786  |0.08409%  |4.27%
# 1539| 504|Last Date      |$1661438  |0.07957%  |4.33%
# Eval num_timesteps=4620000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1541| 499|update         |$1598727  |0.06860%  |3.27%
# 1541| 504|Last Date      |$1603031  |0.06632%  |3.23%
# Eval num_timesteps=4626000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1543| 499|update         |$1623486  |0.07373%  |3.42%
# 1543| 504|Last Date      |$1621489  |0.07020%  |3.49%
# Eval num_timesteps=4632000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1545| 499|update         |$1649611  |0.07867%  |3.58%
# 1545| 504|Last Date      |$1645273  |0.07492%  |3.73%
# Eval num_timesteps=4638000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1547| 499|update         |$1673518  |0.08463%  |4.05%
# 1547| 504|Last Date      |$1663699  |0.07927%  |4.12%
# Eval num_timesteps=4644000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1549| 499|update         |$1671288  |0.08423%  |4.03%
# 1549| 504|Last Date      |$1661470  |0.07883%  |4.10%
# Eval num_timesteps=4650000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1551| 499|update         |$1663324  |0.08254%  |3.99%
# 1551| 504|Last Date      |$1653567  |0.07740%  |4.07%
# Eval num_timesteps=4656000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1553| 499|update         |$1666251  |0.08298%  |3.94%
# 1553| 504|Last Date      |$1656465  |0.07782%  |4.05%
# Eval num_timesteps=4662000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1555| 499|update         |$1686265  |0.08634%  |3.94%
# 1555| 504|Last Date      |$1676362  |0.08114%  |4.05%
# Eval num_timesteps=4668000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1557| 499|update         |$1675473  |0.08476%  |3.98%
# 1557| 504|Last Date      |$1665645  |0.07944%  |4.07%
# Eval num_timesteps=4674000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1559| 499|update         |$1682745  |0.08644%  |4.07%
# 1559| 504|Last Date      |$1672886  |0.08119%  |4.24%
# Eval num_timesteps=4680000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1561| 499|update         |$1687759  |0.08751%  |4.14%
# 1561| 504|Last Date      |$1677878  |0.08188%  |4.19%
# Eval num_timesteps=4686000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1563| 499|update         |$1672150  |0.08424%  |4.05%
# 1563| 504|Last Date      |$1662351  |0.07886%  |4.07%
# Eval num_timesteps=4692000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1565| 499|update         |$1665287  |0.08355%  |4.12%
# 1565| 504|Last Date      |$1655531  |0.07808%  |4.18%
# Eval num_timesteps=4698000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1567| 499|update         |$1678533  |0.08474%  |3.84%
# 1567| 504|Last Date      |$1668676  |0.07949%  |3.94%
# Eval num_timesteps=4704000, episode_reward=-0.10 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1569| 499|update         |$1697994  |0.08790%  |3.83%
# 1569| 504|Last Date      |$1688021  |0.08251%  |3.88%
# Eval num_timesteps=4710000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1571| 499|update         |$1758310  |0.09718%  |3.55%
# 1571| 504|Last Date      |$1747952  |0.09143%  |3.57%
# Eval num_timesteps=4716000, episode_reward=-0.04 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1573| 499|update         |$1712098  |0.08882%  |3.39%
# 1573| 504|Last Date      |$1704495  |0.08328%  |3.29%
# Eval num_timesteps=4722000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1575| 499|update         |$1724951  |0.09124%  |3.51%
# 1575| 504|Last Date      |$1715067  |0.08536%  |3.39%
# Eval num_timesteps=4728000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1577| 499|update         |$1728280  |0.09161%  |3.39%
# 1577| 504|Last Date      |$1718064  |0.08603%  |3.44%
# Eval num_timesteps=4734000, episode_reward=-0.10 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1579| 499|update         |$1722034  |0.09063%  |3.41%
# 1579| 504|Last Date      |$1711856  |0.08490%  |3.41%
# Eval num_timesteps=4740000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1581| 499|update         |$1715054  |0.08940%  |3.48%
# 1581| 504|Last Date      |$1704939  |0.08396%  |3.47%
# Eval num_timesteps=4746000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1583| 499|update         |$1718174  |0.09071%  |3.65%
# 1583| 504|Last Date      |$1708063  |0.08530%  |3.72%
# Eval num_timesteps=4752000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1585| 499|update         |$1711411  |0.08821%  |3.31%
# 1585| 504|Last Date      |$1701287  |0.08262%  |3.25%
# Eval num_timesteps=4758000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1587| 499|update         |$1719528  |0.09016%  |3.44%
# 1587| 504|Last Date      |$1709379  |0.08434%  |3.37%
# Eval num_timesteps=4764000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1589| 499|update         |$1726985  |0.09068%  |3.18%
# 1589| 504|Last Date      |$1716762  |0.08488%  |3.17%
# Eval num_timesteps=4770000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1591| 499|update         |$1741332  |0.09348%  |3.31%
# 1591| 504|Last Date      |$1731050  |0.08782%  |3.34%
# Eval num_timesteps=4776000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1593| 499|update         |$1739893  |0.09345%  |3.38%
# 1593| 504|Last Date      |$1729602  |0.08733%  |3.26%
# Eval num_timesteps=4782000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1595| 499|update         |$1742607  |0.09362%  |3.33%
# 1595| 504|Last Date      |$1732306  |0.08806%  |3.35%
# Eval num_timesteps=4788000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1597| 499|update         |$1741329  |0.09352%  |3.32%
# 1597| 504|Last Date      |$1731032  |0.08801%  |3.39%
# Eval num_timesteps=4794000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1599| 499|update         |$1773363  |0.09887%  |3.33%
# 1599| 504|Last Date      |$1762884  |0.09282%  |3.26%
# Eval num_timesteps=4800000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1601| 499|update         |$1765613  |0.09714%  |3.15%
# 1601| 504|Last Date      |$1755153  |0.09116%  |3.15%
# Eval num_timesteps=4806000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1603| 499|update         |$1746268  |0.09389%  |3.26%
# 1603| 504|Last Date      |$1735938  |0.08828%  |3.24%
# Eval num_timesteps=4812000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1605| 499|update         |$1742266  |0.09373%  |3.35%
# 1605| 504|Last Date      |$1731973  |0.08789%  |3.31%
# Eval num_timesteps=4818000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1607| 499|update         |$1773283  |0.09898%  |3.38%
# 1607| 504|Last Date      |$1762806  |0.09285%  |3.27%
# Eval num_timesteps=4824000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1609| 499|update         |$1771318  |0.09891%  |3.44%
# 1609| 504|Last Date      |$1760861  |0.09277%  |3.34%
# Eval num_timesteps=4830000, episode_reward=-0.05 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1611| 499|update         |$1740796  |0.09276%  |3.10%
# 1611| 504|Last Date      |$1730470  |0.08747%  |3.26%
# Eval num_timesteps=4836000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1613| 499|update         |$1745603  |0.09404%  |3.27%
# 1613| 504|Last Date      |$1735290  |0.08844%  |3.31%
# Eval num_timesteps=4842000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1615| 499|update         |$1729455  |0.09159%  |3.39%
# 1615| 504|Last Date      |$1719234  |0.08581%  |3.32%
# Eval num_timesteps=4848000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1617| 499|update         |$1742082  |0.09496%  |3.72%
# 1617| 504|Last Date      |$1731834  |0.08933%  |3.74%
# Eval num_timesteps=4854000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1619| 499|update         |$1723203  |0.09062%  |3.37%
# 1619| 504|Last Date      |$1713025  |0.08491%  |3.36%
# Eval num_timesteps=4860000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1621| 499|update         |$1723203  |0.09062%  |3.37%
# 1621| 504|Last Date      |$1713025  |0.08491%  |3.36%
# Eval num_timesteps=4866000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1623| 499|update         |$1694579  |0.08556%  |3.37%
# 1623| 504|Last Date      |$1684571  |0.08006%  |3.31%
# Eval num_timesteps=4872000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1625| 499|update         |$1705163  |0.08858%  |3.74%
# 1625| 504|Last Date      |$1695123  |0.08281%  |3.61%
# Eval num_timesteps=4878000, episode_reward=-0.09 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1627| 499|update         |$1707574  |0.08826%  |3.45%
# 1627| 504|Last Date      |$1697506  |0.08280%  |3.49%
# Eval num_timesteps=4884000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1629| 499|update         |$1719588  |0.09029%  |3.47%
# 1629| 504|Last Date      |$1709440  |0.08457%  |3.43%
# Eval num_timesteps=4890000, episode_reward=-0.02 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1631| 499|update         |$1741418  |0.09310%  |3.24%
# 1631| 504|Last Date      |$1731120  |0.08731%  |3.19%
# Eval num_timesteps=4896000, episode_reward=-0.04 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1633| 499|update         |$1745334  |0.09516%  |3.66%
# 1633| 504|Last Date      |$1735050  |0.08950%  |3.63%
# Eval num_timesteps=4902000, episode_reward=-0.00 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1635| 499|update         |$1770654  |0.09931%  |3.63%
# 1635| 504|Last Date      |$1760208  |0.09328%  |3.52%
# Eval num_timesteps=4908000, episode_reward=0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1637| 499|update         |$1753789  |0.09635%  |3.64%
# 1637| 504|Last Date      |$1743447  |0.09059%  |3.55%
# Eval num_timesteps=4914000, episode_reward=-0.01 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1639| 499|update         |$1741009  |0.09459%  |3.65%
# 1639| 504|Last Date      |$1730760  |0.08877%  |3.63%
# Eval num_timesteps=4920000, episode_reward=-0.03 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1641| 499|update         |$1733599  |0.09272%  |3.53%
# 1641| 504|Last Date      |$1723379  |0.08709%  |3.49%
# Eval num_timesteps=4926000, episode_reward=-0.04 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1643| 499|update         |$1704867  |0.08844%  |3.54%
# 1643| 504|Last Date      |$1698603  |0.08352%  |3.65%
# Eval num_timesteps=4932000, episode_reward=-0.07 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1645| 499|update         |$1717402  |0.08998%  |3.53%
# 1645| 504|Last Date      |$1711268  |0.08549%  |3.61%
# Eval num_timesteps=4938000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1647| 499|update         |$1733105  |0.09183%  |3.34%
# 1647| 504|Last Date      |$1726734  |0.08688%  |3.27%
# Eval num_timesteps=4944000, episode_reward=-0.06 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1649| 499|update         |$1744513  |0.09453%  |3.51%
# 1649| 504|Last Date      |$1737063  |0.08955%  |3.55%
# Eval num_timesteps=4950000, episode_reward=-0.05 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1651| 499|update         |$1746522  |0.09478%  |3.54%
# 1651| 504|Last Date      |$1738996  |0.08968%  |3.50%
# Eval num_timesteps=4956000, episode_reward=-0.08 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1653| 499|update         |$1737425  |0.09356%  |3.40%
# 1653| 504|Last Date      |$1730231  |0.08819%  |3.48%
# Eval num_timesteps=4962000, episode_reward=-0.11 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1655| 499|update         |$1712920  |0.08784%  |3.16%
# 1655| 504|Last Date      |$1708571  |0.08310%  |3.04%
# Eval num_timesteps=4968000, episode_reward=-0.13 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1657| 499|update         |$1675124  |0.07862%  |2.45%
# 1657| 504|Last Date      |$1679392  |0.07598%  |2.35%
# Eval num_timesteps=4974000, episode_reward=-0.15 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1659| 499|update         |$1710873  |0.08619%  |2.76%
# 1659| 504|Last Date      |$1707089  |0.08190%  |2.76%
# Eval num_timesteps=4980000, episode_reward=-0.15 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1661| 499|update         |$1679394  |0.08041%  |2.66%
# 1661| 504|Last Date      |$1682044  |0.07737%  |2.63%
# Eval num_timesteps=4986000, episode_reward=-0.15 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1663| 499|update         |$1703476  |0.08563%  |3.03%
# 1663| 504|Last Date      |$1701504  |0.08141%  |2.89%
# Eval num_timesteps=4992000, episode_reward=-0.12 +/- 0.00
# Episode length: 505.00 +/- 0.00
# 1665| 499|update         |$1704999  |0.08585%  |2.97%
# 1665| 504|Last Date      |$1702922  |0.08175%  |2.92%
# Eval num_timesteps=4998000, episode_reward=-0.13 +/- 0.00
# Episode length: 505.00 +/- 0.00

# %%
model.save("different.model")

# %%
data_turbulence = processed[(processed.date<'2019-01-01') & (processed.date>='2009-01-01')]
insample_turbulence = data_turbulence.drop_duplicates(subset=['date'])

# %%
insample_turbulence.turbulence.describe()
# Out:
# count    2516.000000
# mean       33.277068
# std        33.989003
# min         0.000000
# 25%        15.233736
# 50%        25.180862
# 75%        39.290075
# max       332.062852
# Name: turbulence, dtype: float64

# %%
turbulence_threshold = np.quantile(insample_turbulence.turbulence.values,1)

# %%
turbulence_threshold
# Out:
# 332.0628518086291

# %% [markdown]
# ### Trade
#
# DRL model needs to update periodically in order to take full advantage of the data, ideally we need to retrain our model yearly, quarterly, or monthly. We also need to tune the parameters along the way, in this notebook I only use the in-sample data from 2009-01 to 2018-12 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
trade.head()
# Out:
#          date        open        high         low       close       volume  \
# 0  2019-01-02   38.722500   39.712502   38.557499   38.562561  148158800.0
# 0  2019-01-02   93.910004   96.269997   93.769997   92.319603    4175400.0
# 0  2019-01-02  316.190002  323.950012  313.709991  314.645142    3292200.0
# 0  2019-01-02  124.029999  127.879997  123.000000  119.302582    4783200.0
# 0  2019-01-02   42.279999   43.200001   42.209999   40.057236   23833500.0
#
#     tic  day      macd     rsi_30     cci_30      dx_30  turbulence  \
# 0  AAPL    2 -2.019903  37.867349 -91.567852  42.250808    51.36772
# 0   AXP    2 -3.414037  41.205002 -97.751316  26.709417    51.36772
# 0    BA    2 -5.550592  47.010000 -21.712382  13.611972    51.36772
# 0   CAT    2 -0.686759  48.229089  -5.091209   0.873482    51.36772
# 0  CSCO    2 -0.952338  44.872557 -87.518839  29.529377    51.36772
#
#    log_volume    change  daily_variance
# 0   22.466077 -0.004148        0.029951
# 0   19.769977 -0.017227        0.027080
# 0   20.758512 -0.004910        0.032545
# 0   20.162283 -0.039625        0.040904
# 0   20.676912 -0.055490        0.024715

# %%
e_trade_gym.hmax = 2500

# %%
print(len(e_trade_gym.dates))
# Out:
# 505

# %%
df_account_value, df_actions = DRLAgent.DRL_prediction(model=model,environment = e_trade_gym)
# Out:
# EPISODE|STEPS|TERMINAL_REASON|TOT_ASSETS|TERMINAL_REWARD_unsc|CASH_PCT
#    3| 499|update         |$1471341  |0.04955%  |3.18%
#    3| 504|Last Date      |$1474510  |0.04556%  |3.39%
# hit end!

# %%
df_account_value.shape
# Out:
# (504, 5)

# %%
df_account_value.head(50)
# Out:
#               cash    asset_value  total_assets        reward        date
# 0   1000000.000000       0.000000  1.000000e+06  0.000000e+00  2019-01-03
# 1    967092.496508   31938.739890  9.990312e+05  0.000000e+00  2019-01-04
# 2    957266.787393   43168.736474  1.000436e+06 -4.843818e-04  2019-01-07
# 3    937043.515568   63555.038933  1.000599e+06  1.451746e-04  2019-01-08
# 4    924940.667714   76189.916315  1.001131e+06  1.496386e-04  2019-01-09
# 5    930036.309931   71252.257559  1.001289e+06  2.261168e-04  2019-01-10
# 6    923969.060812   77196.709566  1.001166e+06  2.147612e-04  2019-01-11
# 7    906611.271416   94248.962876  1.000860e+06  1.665386e-04  2019-01-14
# 8    886081.527514  113920.111477  1.000002e+06  1.075293e-04  2019-01-15
# 9    896116.538026  105019.636591  1.001136e+06  1.821100e-07  2019-01-16
# 10   881429.998697  119652.955822  1.001083e+06  1.136175e-04  2019-01-17
# 11   884550.789876  117545.757788  1.002097e+06  9.845041e-05  2019-01-18
# 12   869620.580817  133807.651245  1.003428e+06  1.747123e-04  2019-01-22
# 13   864971.331687  137260.244036  1.002232e+06  2.637102e-04  2019-01-23
# 14   887487.099093  114750.923301  1.002238e+06  1.593983e-04  2019-01-24
# 15   890321.453628  110883.953660  1.001205e+06  1.492015e-04  2019-01-25
# 16   877390.328292  124290.250311  1.001681e+06  7.533796e-05  2019-01-28
# 17   871677.036106  129156.421813  1.000833e+06  9.885756e-05  2019-01-29
# 18   855414.946815  145513.972941  1.000929e+06  4.630322e-05  2019-01-30
# 19   851089.339147  151914.403102  1.003004e+06  4.889051e-05  2019-01-31
# 20   846093.507349  157918.736745  1.004012e+06  1.501871e-04  2019-02-01
# 21   856050.009606  148320.021933  1.004370e+06  1.910592e-04  2019-02-04
# 22   859192.301643  146215.116617  1.005407e+06  1.986378e-04  2019-02-05
# 23   853801.361786  152653.035426  1.006454e+06  2.351051e-04  2019-02-06
# 24   843737.688762  162421.833622  1.006160e+06  2.689332e-04  2019-02-07
# 25   849986.433701  154937.646540  1.004924e+06  2.463809e-04  2019-02-08
# 26   833546.629039  171445.175242  1.004992e+06  1.893877e-04  2019-02-11
# 27   813551.501041  190933.964398  1.004485e+06  1.848816e-04  2019-02-12
# 28   806768.102342  200232.970997  1.007001e+06  1.601952e-04  2019-02-13
# 29   785641.003191  222247.322924  1.007888e+06  2.414163e-04  2019-02-14
# 30   787427.220371  219680.023035  1.007107e+06  2.629442e-04  2019-02-15
# 31   795034.290727  214350.127243  1.009384e+06  2.292659e-04  2019-02-19
# 32   782604.705177  225949.639367  1.008554e+06  2.932631e-04  2019-02-20
# 33   776728.577867  231980.984222  1.008710e+06  2.592226e-04  2019-02-21
# 34   773190.699516  235051.624998  1.008242e+06  2.561636e-04  2019-02-22
# 35   758335.776615  252069.326700  1.010405e+06  2.354950e-04  2019-02-25
# 36   748187.799309  262668.371394  1.010856e+06  2.890306e-04  2019-02-26
# 37   727651.980327  283633.595211  1.011286e+06  2.934100e-04  2019-02-27
# 38   740872.601616  269872.388655  1.010745e+06  2.969888e-04  2019-02-28
# 39   726445.437377  283459.304478  1.009905e+06  2.755126e-04  2019-03-01
# 40   725601.172645  286938.881190  1.012540e+06  2.476185e-04  2019-03-04
# 41   707612.032190  301801.879838  1.009414e+06  3.058550e-04  2019-03-05
# 42   705208.890995  304257.254660  1.009466e+06  2.241408e-04  2019-03-06
# 43   694364.629907  313368.228645  1.007733e+06  2.201429e-04  2019-03-07
# 44   677532.319056  328234.220025  1.005767e+06  1.757468e-04  2019-03-08
# 45   670622.330127  334018.103484  1.004640e+06  1.281453e-04  2019-03-11
# 46   664642.472370  344772.360001  1.009415e+06  1.008790e-04  2019-03-12
# 47   657295.354798  352595.927975  1.009891e+06  2.003156e-04  2019-03-13
# 48   666103.749009  345954.327512  1.012058e+06  2.060684e-04  2019-03-14
# 49   668847.110144  344741.732229  1.013589e+06  2.460832e-04  2019-03-15

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
perf_stats_all = backtest_stats(account_value=df_account_value, value_col_name = 'total_assets')
# Out:
# ==============Get Backtest Results===========
# Annual return          0.214294
# Cumulative returns     0.474511
# Annual volatility      0.261075
# Sharpe ratio           0.876483
# Calmar ratio           0.628917
# Stability              0.600815
# Max drawdown          -0.340736
# Omega ratio            1.218089
# Sortino ratio          1.250326
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             0.942993
# Daily value at risk   -0.031984
# dtype: float64

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
             baseline_ticker = '^DJI', 
             baseline_start = '2019-01-01',
             baseline_end = '2021-01-01', value_col_name = 'total_assets')
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (505, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2019-01-03</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2020-12-31</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>24</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>21.429%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>47.451%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>26.108%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>0.88</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>0.63</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.60</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-34.074%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.22</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>1.25</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>0.94</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-3.198%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.32</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>-0.24</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>34.07</td>
#       <td>2020-01-21</td>
#       <td>2020-03-24</td>
#       <td>2020-06-09</td>
#       <td>101</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>9.19</td>
#       <td>2020-06-09</td>
#       <td>2020-06-29</td>
#       <td>2020-08-11</td>
#       <td>46</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>7.72</td>
#       <td>2020-10-12</td>
#       <td>2020-11-02</td>
#       <td>2020-11-06</td>
#       <td>20</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>6.13</td>
#       <td>2019-07-16</td>
#       <td>2019-08-16</td>
#       <td>2019-10-01</td>
#       <td>56</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.21</td>
#       <td>2019-04-29</td>
#       <td>2019-06-04</td>
#       <td>2019-06-19</td>
#       <td>38</td>
#     </tr>
#   </tbody>
# </table>
# /opt/conda/lib/python3.6/site-packages/pyfolio/tears.py:907: UserWarning: Passed returns do not overlap with anyinteresting times.
#   'interesting times.', UserWarning)
