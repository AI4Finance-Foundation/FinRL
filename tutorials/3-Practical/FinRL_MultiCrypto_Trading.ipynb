# %% [markdown]
# # Multiple Cryptocurrencies Trading Demo

# %% [markdown]
# ## Installation

# %%
# %cd /
# !git clone https://github.com/AI4Finance-Foundation/FinRL-Meta
# %cd /FinRL-Meta/
# !pip install git+https://github.com/AI4Finance-LLC/ElegantRL.git
# !pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git
# !pip install yfinance stockstats
# !pip install alpaca_trade_api
# !pip install ray[default]
# !pip install lz4
# !pip install ray[tune]
# !pip install tensorboardX
# !pip install gputil
# !pip install trading_calendars
# !pip install wrds
# !pip install rqdatac
# !pip install sqlalchemy==1.2.19
# !pip install tushare
#install talib
# !wget http://prdownloads.sourceforge.net/ta-lib/ta-lib-0.4.0-src.tar.gz 
# !tar xvzf ta-lib-0.4.0-src.tar.gz
import os
os.chdir('ta-lib') 
# !./configure --prefix=/usr
# !make
# !make install
os.chdir('../')
# !pip install TA-Lib
# !pip install baostock
# !pip install quandl
# Out:
# Collecting git+https://github.com/AI4Finance-LLC/ElegantRL.git
#   Cloning https://github.com/AI4Finance-LLC/ElegantRL.git to /tmp/pip-req-build-dgj58_ab
#   Running command git clone -q https://github.com/AI4Finance-LLC/ElegantRL.git /tmp/pip-req-build-dgj58_ab
#   Resolved https://github.com/AI4Finance-LLC/ElegantRL.git to commit 9e44c3487b7fd71c160e144f8caac31d6a724465
# Requirement already satisfied: gym in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from elegantrl==0.3.3) (0.21.0)
# Requirement already satisfied: matplotlib in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from elegantrl==0.3.3) (3.4.3)
# Requirement already satisfied: numpy in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from elegantrl==0.3.3) (1.21.6)
# Requirement already satisfied: pybullet in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from elegantrl==0.3.3) (3.2.5)
# Requirement already satisfied: torch in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from elegantrl==0.3.3) (1.11.0.dev20211118+cu113)
# Requirement already satisfied: opencv-python in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from elegantrl==0.3.3) (3.4.15.55)
# Requirement already satisfied: box2d-py in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from elegantrl==0.3.3) (2.3.8)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from gym->elegantrl==0.3.3) (1.6.0)
# Requirement already satisfied: importlib-metadata>=4.8.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from gym->elegantrl==0.3.3) (4.11.4)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from importlib-metadata>=4.8.1->gym->elegantrl==0.3.3) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from importlib-metadata>=4.8.1->gym->elegantrl==0.3.3) (3.5.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from matplotlib->elegantrl==0.3.3) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from matplotlib->elegantrl==0.3.3) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from matplotlib->elegantrl==0.3.3) (7.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from matplotlib->elegantrl==0.3.3) (2.8.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from matplotlib->elegantrl==0.3.3) (2.4.7)
# Requirement already satisfied: six>=1.5 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from python-dateutil>=2.7->matplotlib->elegantrl==0.3.3) (1.16.0)
# Collecting git+https://github.com/AI4Finance-LLC/FinRL-Library.git
#   Cloning https://github.com/AI4Finance-LLC/FinRL-Library.git to /tmp/pip-req-build-hed26ceb
#   Running command git clone -q https://github.com/AI4Finance-LLC/FinRL-Library.git /tmp/pip-req-build-hed26ceb
#   Resolved https://github.com/AI4Finance-LLC/FinRL-Library.git to commit 656b713f3efa4ddd469851defce4b2d4a62c5429
# Collecting pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2
#   Cloning https://github.com/quantopian/pyfolio.git to /tmp/pip-install-i_boi1rr/pyfolio_87b6f9d019ef405e8f326ccc3abb6a9d
#   Running command git clone -q https://github.com/quantopian/pyfolio.git /tmp/pip-install-i_boi1rr/pyfolio_87b6f9d019ef405e8f326ccc3abb6a9d
#   Resolved https://github.com/quantopian/pyfolio.git to commit 4b901f6d73aa02ceb6d04b7d83502e5c6f2e81aa
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /tmp/pip-install-i_boi1rr/elegantrl_44c14860f0c84c8cbe95bc8f492f7e2e
#   Running command git clone -q https://github.com/AI4Finance-Foundation/ElegantRL.git /tmp/pip-install-i_boi1rr/elegantrl_44c14860f0c84c8cbe95bc8f492f7e2e
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 9e44c3487b7fd71c160e144f8caac31d6a724465
# Requirement already satisfied: numpy>=1.17.3 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (1.21.6)
# Requirement already satisfied: pandas>=1.1.5 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (1.1.5)
# Requirement already satisfied: stockstats>=0.4.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (0.4.1)
# Requirement already satisfied: yfinance in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (0.1.70)
# Requirement already satisfied: elegantrl in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (0.3.3)
# Requirement already satisfied: matplotlib in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (3.4.3)
# Requirement already satisfied: scikit-learn>=0.21.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (1.0.2)
# Requirement already satisfied: gym>=0.17 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (0.21.0)
# Requirement already satisfied: stable-baselines3[extra] in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (1.5.0)
# Requirement already satisfied: ray[default] in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (1.12.1)
# Requirement already satisfied: lz4 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (4.0.1)
# Requirement already satisfied: tensorboardX in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (2.5)
# Requirement already satisfied: gputil in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (1.4.0)
# Requirement already satisfied: exchange_calendars in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (3.6.2)
# Requirement already satisfied: alpaca_trade_api>=2.1.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (2.1.0)
# Requirement already satisfied: ccxt==1.66.32 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (1.66.32)
# Requirement already satisfied: jqdatasdk in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (1.8.10)
# Requirement already satisfied: wrds in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (3.1.1)
# Requirement already satisfied: pytest in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (7.1.2)
# Requirement already satisfied: setuptools==59.5.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (59.5.0)
# Requirement already satisfied: wheel>=0.33.6 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (0.37.1)
# Requirement already satisfied: pre-commit in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from finrl==0.3.5) (2.19.0)
# Requirement already satisfied: aiohttp>=3.8 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ccxt==1.66.32->finrl==0.3.5) (3.8.1)
# Requirement already satisfied: requests>=2.18.4 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ccxt==1.66.32->finrl==0.3.5) (2.27.1)
# Requirement already satisfied: yarl==1.7.2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ccxt==1.66.32->finrl==0.3.5) (1.7.2)
# Requirement already satisfied: cryptography>=2.6.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ccxt==1.66.32->finrl==0.3.5) (37.0.2)
# Requirement already satisfied: certifi>=2018.1.18 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ccxt==1.66.32->finrl==0.3.5) (2022.6.15)
# Requirement already satisfied: aiodns>=1.1.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ccxt==1.66.32->finrl==0.3.5) (3.0.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from yarl==1.7.2->ccxt==1.66.32->finrl==0.3.5) (4.1.1)
# Requirement already satisfied: multidict>=4.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from yarl==1.7.2->ccxt==1.66.32->finrl==0.3.5) (6.0.2)
# Requirement already satisfied: idna>=2.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from yarl==1.7.2->ccxt==1.66.32->finrl==0.3.5) (3.3)
# Requirement already satisfied: pycares>=4.0.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiodns>=1.1.1->ccxt==1.66.32->finrl==0.3.5) (4.1.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp>=3.8->ccxt==1.66.32->finrl==0.3.5) (1.2.0)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp>=3.8->ccxt==1.66.32->finrl==0.3.5) (2.0.4)
# Requirement already satisfied: attrs>=17.3.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp>=3.8->ccxt==1.66.32->finrl==0.3.5) (21.2.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp>=3.8->ccxt==1.66.32->finrl==0.3.5) (4.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp>=3.8->ccxt==1.66.32->finrl==0.3.5) (0.13.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp>=3.8->ccxt==1.66.32->finrl==0.3.5) (1.3.0)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (0.57.0)
# Requirement already satisfied: msgpack==1.0.3 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.0.3)
# Requirement already satisfied: websockets<11,>=9.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (10.3)
# Requirement already satisfied: PyYAML==6.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (6.0)
# Requirement already satisfied: urllib3<2,>1.24 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (1.26.9)
# Requirement already satisfied: deprecation==2.1.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from alpaca_trade_api>=2.1.0->finrl==0.3.5) (2.1.0)
# Requirement already satisfied: packaging in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from deprecation==2.1.0->alpaca_trade_api>=2.1.0->finrl==0.3.5) (21.2)
# Requirement already satisfied: cffi>=1.12 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from cryptography>=2.6.1->ccxt==1.66.32->finrl==0.3.5) (1.15.0)
# Requirement already satisfied: pycparser in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt==1.66.32->finrl==0.3.5) (2.21)
# Requirement already satisfied: cloudpickle>=1.2.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from gym>=0.17->finrl==0.3.5) (1.6.0)
# Requirement already satisfied: importlib-metadata>=4.8.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from gym>=0.17->finrl==0.3.5) (4.11.4)
# Requirement already satisfied: zipp>=0.5 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from importlib-metadata>=4.8.1->gym>=0.17->finrl==0.3.5) (3.5.0)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pandas>=1.1.5->finrl==0.3.5) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pandas>=1.1.5->finrl==0.3.5) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=1.1.5->finrl==0.3.5) (1.16.0)
# Requirement already satisfied: scipy>=1.1.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from scikit-learn>=0.21.0->finrl==0.3.5) (1.5.4)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from scikit-learn>=0.21.0->finrl==0.3.5) (3.1.0)
# Requirement already satisfied: joblib>=0.11 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from scikit-learn>=0.21.0->finrl==0.3.5) (0.14.1)
# Requirement already satisfied: pybullet in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.5) (3.2.5)
# Requirement already satisfied: torch in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.5) (1.11.0.dev20211118+cu113)
# Requirement already satisfied: opencv-python in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.5) (3.4.15.55)
# Requirement already satisfied: box2d-py in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.5) (2.3.8)
# Requirement already satisfied: toolz in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from exchange_calendars->finrl==0.3.5) (0.11.2)
# Requirement already satisfied: pyluach in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from exchange_calendars->finrl==0.3.5) (2.0.0)
# Requirement already satisfied: korean-lunar-calendar in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from exchange_calendars->finrl==0.3.5) (0.2.1)
# Requirement already satisfied: thriftpy2>=0.3.9 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from jqdatasdk->finrl==0.3.5) (0.4.14)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from jqdatasdk->finrl==0.3.5) (1.2.19)
# Requirement already satisfied: pymysql>=0.7.6 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from jqdatasdk->finrl==0.3.5) (1.0.2)
# Requirement already satisfied: ply<4.0,>=3.4 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from thriftpy2>=0.3.9->jqdatasdk->finrl==0.3.5) (3.11)
# Requirement already satisfied: cycler>=0.10 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from matplotlib->finrl==0.3.5) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from matplotlib->finrl==0.3.5) (7.2.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from matplotlib->finrl==0.3.5) (1.3.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from matplotlib->finrl==0.3.5) (2.4.7)
# Requirement already satisfied: toml in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pre-commit->finrl==0.3.5) (0.10.2)
# Requirement already satisfied: cfgv>=2.0.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pre-commit->finrl==0.3.5) (3.3.1)
# Requirement already satisfied: virtualenv>=20.0.8 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pre-commit->finrl==0.3.5) (20.14.1)
# Requirement already satisfied: nodeenv>=0.11.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pre-commit->finrl==0.3.5) (1.6.0)
# Requirement already satisfied: identify>=1.0.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pre-commit->finrl==0.3.5) (2.5.1)
# Requirement already satisfied: distlib<1,>=0.3.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from virtualenv>=20.0.8->pre-commit->finrl==0.3.5) (0.3.4)
# Requirement already satisfied: filelock<4,>=3.2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from virtualenv>=20.0.8->pre-commit->finrl==0.3.5) (3.7.1)
# Requirement already satisfied: platformdirs<3,>=2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from virtualenv>=20.0.8->pre-commit->finrl==0.3.5) (2.5.1)
# Requirement already satisfied: ipython>=3.2.3 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (7.29.0)
# Requirement already satisfied: seaborn>=0.7.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.11.2)
# Requirement already satisfied: empyrical>=0.5.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.5.5)
# Requirement already satisfied: pandas-datareader>=0.2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from empyrical>=0.5.0->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.10.0)
# Requirement already satisfied: pickleshare in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (3.0.21)
# Requirement already satisfied: traitlets>=4.2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (5.1.1)
# Requirement already satisfied: matplotlib-inline in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.1.3)
# Requirement already satisfied: backcall in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.18.0)
# Requirement already satisfied: pygments in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (2.10.0)
# Requirement already satisfied: decorator in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (5.1.0)
# Requirement already satisfied: pexpect>4.3 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (4.8.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.8.2)
# Requirement already satisfied: lxml in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (4.9.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.7.0)
# Requirement already satisfied: wcwidth in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.2.5)
# Requirement already satisfied: tomli>=1.0.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pytest->finrl==0.3.5) (2.0.1)
# Requirement already satisfied: py>=1.8.2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pytest->finrl==0.3.5) (1.11.0)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pytest->finrl==0.3.5) (1.0.0)
# Requirement already satisfied: iniconfig in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pytest->finrl==0.3.5) (1.1.1)
# Requirement already satisfied: grpcio<=1.43.0,>=1.28.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (1.39.0)
# Requirement already satisfied: click>=7.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (8.1.3)
# Requirement already satisfied: jsonschema in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (4.1.2)
# Requirement already satisfied: protobuf>=3.15.3 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (3.17.3)
# Requirement already satisfied: colorful in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (0.5.4)
# Requirement already satisfied: aiohttp-cors in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (0.7.0)
# Requirement already satisfied: prometheus-client<0.14.0,>=0.7.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (0.12.0)
# Requirement already satisfied: smart-open in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (6.0.0)
# Requirement already satisfied: gpustat>=1.0.0b1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (1.0.0b1)
# Requirement already satisfied: py-spy>=0.2.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (0.3.12)
# Requirement already satisfied: opencensus in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (0.9.0)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from gpustat>=1.0.0b1->ray[default]->finrl==0.3.5) (7.352.0)
# Requirement already satisfied: blessed>=1.17.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from gpustat>=1.0.0b1->ray[default]->finrl==0.3.5) (1.19.1)
# Requirement already satisfied: psutil in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from gpustat>=1.0.0b1->ray[default]->finrl==0.3.5) (5.9.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from jsonschema->ray[default]->finrl==0.3.5) (0.18.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from opencensus->ray[default]->finrl==0.3.5) (2.8.1)
# Requirement already satisfied: opencensus-context>=0.1.2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from opencensus->ray[default]->finrl==0.3.5) (0.1.2)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]->finrl==0.3.5) (1.35.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]->finrl==0.3.5) (1.56.2)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]->finrl==0.3.5) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]->finrl==0.3.5) (4.2.2)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]->finrl==0.3.5) (4.7.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]->finrl==0.3.5) (0.4.8)
# Requirement already satisfied: tabulate in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (0.8.9)
# Requirement already satisfied: tensorboard>=2.2.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from stable-baselines3[extra]->finrl==0.3.5) (2.9.0)
# Requirement already satisfied: autorom[accept-rom-license]~=0.4.2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from stable-baselines3[extra]->finrl==0.3.5) (0.4.2)
# Requirement already satisfied: ale-py~=0.7.4 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from stable-baselines3[extra]->finrl==0.3.5) (0.7.5)
# Requirement already satisfied: importlib-resources in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ale-py~=0.7.4->stable-baselines3[extra]->finrl==0.3.5) (5.7.1)
# Requirement already satisfied: tqdm in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]->finrl==0.3.5) (4.62.1)
# Requirement already satisfied: AutoROM.accept-rom-license in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from autorom[accept-rom-license]~=0.4.2->stable-baselines3[extra]->finrl==0.3.5) (0.4.2)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]->finrl==0.3.5) (0.4.5)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]->finrl==0.3.5) (0.6.1)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]->finrl==0.3.5) (1.8.0)
# Requirement already satisfied: markdown>=2.6.8 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]->finrl==0.3.5) (3.3.4)
# Requirement already satisfied: absl-py>=0.4 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]->finrl==0.3.5) (1.1.0)
# Requirement already satisfied: werkzeug>=1.0.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]->finrl==0.3.5) (2.0.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]->finrl==0.3.5) (1.3.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]->finrl==0.3.5) (3.1.1)
# Requirement already satisfied: mock in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from wrds->finrl==0.3.5) (4.0.3)
# Requirement already satisfied: psycopg2-binary in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from wrds->finrl==0.3.5) (2.9.3)
# Requirement already satisfied: multitasking>=0.0.7 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from yfinance->finrl==0.3.5) (0.0.10)
# Requirement already satisfied: yfinance in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (0.1.70)
# Requirement already satisfied: stockstats in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (0.4.1)
# Requirement already satisfied: requests>=2.26 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from yfinance) (2.27.1)
# Requirement already satisfied: multitasking>=0.0.7 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from yfinance) (0.0.10)
# Requirement already satisfied: pandas>=0.24.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from yfinance) (1.1.5)
# Requirement already satisfied: lxml>=4.5.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from yfinance) (4.9.0)
# Requirement already satisfied: numpy>=1.15 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from yfinance) (1.21.6)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pandas>=0.24.0->yfinance) (2.8.2)
# Requirement already satisfied: pytz>=2017.2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pandas>=0.24.0->yfinance) (2021.3)
# Requirement already satisfied: six>=1.5 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.24.0->yfinance) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from requests>=2.26->yfinance) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from requests>=2.26->yfinance) (2.0.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from requests>=2.26->yfinance) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from requests>=2.26->yfinance) (3.3)
# Requirement already satisfied: alpaca_trade_api in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (2.1.0)
# Requirement already satisfied: websockets<11,>=9.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from alpaca_trade_api) (10.3)
# Requirement already satisfied: pandas>=0.18.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from alpaca_trade_api) (1.1.5)
# Requirement already satisfied: numpy>=1.11.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from alpaca_trade_api) (1.21.6)
# Requirement already satisfied: msgpack==1.0.3 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from alpaca_trade_api) (1.0.3)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from alpaca_trade_api) (0.57.0)
# Requirement already satisfied: PyYAML==6.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from alpaca_trade_api) (6.0)
# Requirement already satisfied: deprecation==2.1.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from alpaca_trade_api) (2.1.0)
# Requirement already satisfied: urllib3<2,>1.24 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from alpaca_trade_api) (1.26.9)
# Requirement already satisfied: aiohttp==3.8.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from alpaca_trade_api) (3.8.1)
# Requirement already satisfied: requests<3,>2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from alpaca_trade_api) (2.27.1)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (2.0.4)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (1.3.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (4.1.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (1.2.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (6.0.2)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (1.7.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (21.2.0)
# Requirement already satisfied: asynctest==0.13.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp==3.8.1->alpaca_trade_api) (0.13.0)
# Requirement already satisfied: packaging in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from deprecation==2.1.0->alpaca_trade_api) (21.2)
# Requirement already satisfied: pytz>=2017.2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pandas>=0.18.1->alpaca_trade_api) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pandas>=0.18.1->alpaca_trade_api) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.18.1->alpaca_trade_api) (1.16.0)
# Requirement already satisfied: idna<4,>=2.5 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from requests<3,>2->alpaca_trade_api) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from requests<3,>2->alpaca_trade_api) (2022.6.15)
# Requirement already satisfied: pyparsing<3,>=2.0.2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from packaging->deprecation==2.1.0->alpaca_trade_api) (2.4.7)
# Requirement already satisfied: ray[default] in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (1.12.1)
# Requirement already satisfied: grpcio<=1.43.0,>=1.28.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (1.39.0)
# Requirement already satisfied: frozenlist in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (1.3.0)
# Requirement already satisfied: protobuf>=3.15.3 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (3.17.3)
# Requirement already satisfied: attrs in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (21.2.0)
# Requirement already satisfied: numpy>=1.16 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (1.21.6)
# Requirement already satisfied: aiosignal in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (1.2.0)
# Requirement already satisfied: virtualenv in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (20.14.1)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (1.0.3)
# Requirement already satisfied: pyyaml in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (6.0)
# Requirement already satisfied: requests in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (2.27.1)
# Requirement already satisfied: click>=7.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (8.1.3)
# Requirement already satisfied: filelock in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (3.7.1)
# Requirement already satisfied: jsonschema in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (4.1.2)
# Requirement already satisfied: py-spy>=0.2.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (0.3.12)
# Requirement already satisfied: colorful in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (0.5.4)
# Requirement already satisfied: prometheus-client<0.14.0,>=0.7.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (0.12.0)
# Requirement already satisfied: gpustat>=1.0.0b1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (1.0.0b1)
# Requirement already satisfied: smart-open in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (6.0.0)
# Requirement already satisfied: opencensus in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (0.9.0)
# Requirement already satisfied: aiohttp>=3.7 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (3.8.1)
# Requirement already satisfied: aiohttp-cors in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[default]) (0.7.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp>=3.7->ray[default]) (6.0.2)
# Requirement already satisfied: asynctest==0.13.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp>=3.7->ray[default]) (0.13.0)
# Requirement already satisfied: typing-extensions>=3.7.4 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp>=3.7->ray[default]) (4.1.1)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp>=3.7->ray[default]) (1.7.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp>=3.7->ray[default]) (2.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from aiohttp>=3.7->ray[default]) (4.0.2)
# Requirement already satisfied: importlib-metadata in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from click>=7.0->ray[default]) (4.11.4)
# Requirement already satisfied: six>=1.7 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from gpustat>=1.0.0b1->ray[default]) (1.16.0)
# Requirement already satisfied: psutil in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from gpustat>=1.0.0b1->ray[default]) (5.9.1)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from gpustat>=1.0.0b1->ray[default]) (7.352.0)
# Requirement already satisfied: blessed>=1.17.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from gpustat>=1.0.0b1->ray[default]) (1.19.1)
# Requirement already satisfied: wcwidth>=0.1.4 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from blessed>=1.17.1->gpustat>=1.0.0b1->ray[default]) (0.2.5)
# Requirement already satisfied: idna>=2.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from yarl<2.0,>=1.0->aiohttp>=3.7->ray[default]) (3.3)
# Requirement already satisfied: zipp>=0.5 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from importlib-metadata->click>=7.0->ray[default]) (3.5.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from jsonschema->ray[default]) (0.18.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from opencensus->ray[default]) (2.8.1)
# Requirement already satisfied: opencensus-context>=0.1.2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from opencensus->ray[default]) (0.1.2)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (1.35.0)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.56.2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (1.56.2)
# Requirement already satisfied: setuptools>=40.3.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (59.5.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (4.7.2)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (4.2.2)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]) (0.4.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from requests->ray[default]) (1.26.9)
# Requirement already satisfied: certifi>=2017.4.17 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from requests->ray[default]) (2022.6.15)
# Requirement already satisfied: distlib<1,>=0.3.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from virtualenv->ray[default]) (0.3.4)
# Requirement already satisfied: platformdirs<3,>=2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from virtualenv->ray[default]) (2.5.1)
# Requirement already satisfied: lz4 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (4.0.1)
# Requirement already satisfied: ray[tune] in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (1.12.1)
# Requirement already satisfied: filelock in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[tune]) (3.7.1)
# Requirement already satisfied: grpcio<=1.43.0,>=1.28.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[tune]) (1.39.0)
# Requirement already satisfied: pyyaml in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[tune]) (6.0)
# Requirement already satisfied: virtualenv in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[tune]) (20.14.1)
# Requirement already satisfied: jsonschema in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[tune]) (4.1.2)
# Requirement already satisfied: protobuf>=3.15.3 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[tune]) (3.17.3)
# Requirement already satisfied: numpy>=1.16 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[tune]) (1.21.6)
# Requirement already satisfied: frozenlist in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[tune]) (1.3.0)
# Requirement already satisfied: aiosignal in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[tune]) (1.2.0)
# Requirement already satisfied: attrs in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[tune]) (21.2.0)
# Requirement already satisfied: click>=7.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[tune]) (8.1.3)
# Requirement already satisfied: msgpack<2.0.0,>=1.0.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[tune]) (1.0.3)
# Requirement already satisfied: requests in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[tune]) (2.27.1)
# Requirement already satisfied: pandas in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[tune]) (1.1.5)
# Requirement already satisfied: tabulate in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[tune]) (0.8.9)
# Requirement already satisfied: tensorboardX>=1.9 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from ray[tune]) (2.5)
# Requirement already satisfied: importlib-metadata in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from click>=7.0->ray[tune]) (4.11.4)
# Requirement already satisfied: six>=1.5.2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from grpcio<=1.43.0,>=1.28.1->ray[tune]) (1.16.0)
# Requirement already satisfied: zipp>=0.5 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from importlib-metadata->click>=7.0->ray[tune]) (3.5.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from importlib-metadata->click>=7.0->ray[tune]) (4.1.1)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from jsonschema->ray[tune]) (0.18.0)
# Requirement already satisfied: pytz>=2017.2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pandas->ray[tune]) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pandas->ray[tune]) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from requests->ray[tune]) (2022.6.15)
# Requirement already satisfied: idna<4,>=2.5 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from requests->ray[tune]) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from requests->ray[tune]) (1.26.9)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from requests->ray[tune]) (2.0.4)
# ...
# ta-lib/src/ta_abstract/ta_java_defs.h
# ta-lib/src/Makefile.am
# ta-lib/src/tools/
# ta-lib/src/tools/ta_regtest/
# ta-lib/src/tools/ta_regtest/test_util.c
# ta-lib/src/tools/ta_regtest/ta_test_func.h
# ta-lib/src/tools/ta_regtest/test_data.c
# ta-lib/src/tools/ta_regtest/ta_gDataHigh.c
# ta-lib/src/tools/ta_regtest/Makefile.in
# ta-lib/src/tools/ta_regtest/test_internals.c
# ta-lib/src/tools/ta_regtest/Makefile.am
# ta-lib/src/tools/ta_regtest/ta_regtest.c
# ta-lib/src/tools/ta_regtest/ta_gDataOpen.c
# ta-lib/src/tools/ta_regtest/ta_gDataClose.c
# ta-lib/src/tools/ta_regtest/test_abstract.c
# ta-lib/src/tools/ta_regtest/ta_test_func/
# ta-lib/src/tools/ta_regtest/ta_test_func/test_bbands.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_stddev.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_1in_2out.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_sar.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_1in_1out.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_trange.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_macd.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_po.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_per_hlc.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_mom.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_per_ohlc.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_adx.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_candlestick.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_rsi.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_per_ema.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_minmax.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_per_hlcv.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_per_hl.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_stoch.c
# ta-lib/src/tools/ta_regtest/ta_test_func/test_ma.c
# ta-lib/src/tools/ta_regtest/ta_error_number.h
# ta-lib/src/tools/ta_regtest/ta_test_priv.h
# ta-lib/src/tools/ta_regtest/ReadMe.txt
# ta-lib/src/tools/ta_regtest/ta_gDataLow.c
# ta-lib/src/tools/Makefile.in
# ta-lib/src/tools/Makefile.am
# ta-lib/src/tools/gen_code/
# ta-lib/src/tools/gen_code/java/
# ta-lib/src/tools/gen_code/java/PrettyCode.java
# ta-lib/src/tools/gen_code/java/Main.java
# ta-lib/src/tools/gen_code/gen_code.c
# ta-lib/src/tools/gen_code/Makefile.in
# ta-lib/src/tools/gen_code/Makefile.am
# ta-lib/src/tools/gen_code/mcpp.exe
# checking for a BSD-compatible install... /usr/bin/install -c
# checking whether build environment is sane... yes
# checking for a thread-safe mkdir -p... /usr/bin/mkdir -p
# checking for gawk... no
# checking for mawk... mawk
# checking whether make sets $(MAKE)... yes
# checking for gcc... gcc
# checking for C compiler default output file name... a.out
# checking whether the C compiler works... yes
# checking whether we are cross compiling... no
# checking for suffix of executables...
# checking for suffix of object files... o
# checking whether we are using the GNU C compiler... yes
# checking whether gcc accepts -g... yes
# checking for gcc option to accept ISO C89... none needed
# checking for style of include used by make... GNU
# checking dependency style of gcc... gcc3
# checking build system type... x86_64-unknown-linux-gnu
# checking host system type... x86_64-unknown-linux-gnu
# checking for a sed that does not truncate output... /usr/bin/sed
# checking for grep that handles long lines and -e... /usr/bin/grep
# checking for egrep... /usr/bin/grep -E
# checking for ld used by gcc... /usr/bin/ld
# checking if the linker (/usr/bin/ld) is GNU ld... yes
# checking for /usr/bin/ld option to reload object files... -r
# checking for BSD-compatible nm... /usr/bin/nm -B
# checking whether ln -s works... yes
# checking how to recognise dependent libraries... pass_all
# checking how to run the C preprocessor... gcc -E
# checking for ANSI C header files... yes
# checking for sys/types.h... yes
# checking for sys/stat.h... yes
# checking for stdlib.h... yes
# checking for string.h... yes
# checking for memory.h... yes
# checking for strings.h... yes
# checking for inttypes.h... yes
# checking for stdint.h... yes
# checking for unistd.h... yes
# checking dlfcn.h usability... yes
# checking dlfcn.h presence... yes
# checking for dlfcn.h... yes
# checking for g++... g++
# checking whether we are using the GNU C++ compiler... yes
# checking whether g++ accepts -g... yes
# checking dependency style of g++... gcc3
# checking how to run the C++ preprocessor... g++ -E
# checking for g77... no
# checking for xlf... no
# checking for f77... no
# checking for frt... no
# checking for pgf77... no
# checking for cf77... no
# checking for fort77... no
# checking for fl32... no
# checking for af77... no
# checking for xlf90... no
# checking for f90... no
# checking for pgf90... no
# checking for pghpf... no
# checking for epcf90... no
# checking for gfortran... no
# checking for g95... no
# checking for xlf95... no
# checking for f95... no
# checking for fort... no
# checking for ifort... no
# checking for ifc... no
# checking for efc... no
# checking for pgf95... no
# checking for lf95... no
# checking for ftn... no
# checking whether we are using the GNU Fortran 77 compiler... no
# checking whether  accepts -g... no
# checking the maximum length of command line arguments... 32768
# checking command to parse /usr/bin/nm -B output from gcc object... ok
# checking for objdir... .libs
# checking for ar... ar
# checking for ranlib... ranlib
# checking for strip... strip
# checking if gcc supports -fno-rtti -fno-exceptions... no
# checking for gcc option to produce PIC... -fPIC
# checking if gcc PIC flag -fPIC works... yes
# checking if gcc static flag -static works... yes
# checking if gcc supports -c -o file.o... yes
# checking whether the gcc linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking whether -lc should be explicitly linked in... no
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# checking whether stripping libraries is possible... yes
# checking if libtool supports shared libraries... yes
# checking whether to build shared libraries... yes
# checking whether to build static libraries... yes
# configure: creating libtool
# appending configuration tag "CXX" to libtool
# checking for ld used by g++... /usr/bin/ld -m elf_x86_64
# checking if the linker (/usr/bin/ld -m elf_x86_64) is GNU ld... yes
# checking whether the g++ linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking for g++ option to produce PIC... -fPIC
# checking if g++ PIC flag -fPIC works... yes
# checking if g++ static flag -static works... yes
# checking if g++ supports -c -o file.o... yes
# checking whether the g++ linker (/usr/bin/ld -m elf_x86_64) supports shared libraries... yes
# checking dynamic linker characteristics... GNU/Linux ld.so
# checking how to hardcode library paths into programs... immediate
# appending configuration tag "F77" to libtool
# checking for dlopen in -ldl... yes
# checking for pthread_create in -lpthread... yes
# checking for ANSI C header files... (cached) yes
# checking float.h usability... yes
# checking float.h presence... yes
# checking for float.h... yes
# checking for inttypes.h... (cached) yes
# checking limits.h usability... yes
# checking limits.h presence... yes
# checking for limits.h... yes
# checking locale.h usability... yes
# checking locale.h presence... yes
# checking for locale.h... yes
# checking stddef.h usability... yes
# checking stddef.h presence... yes
# checking for stddef.h... yes
# checking for stdint.h... (cached) yes
# checking for stdlib.h... (cached) yes
# checking for string.h... (cached) yes
# checking for unistd.h... (cached) yes
# checking wchar.h usability... yes
# checking wchar.h presence... yes
# checking for wchar.h... yes
# checking wctype.h usability... yes
# checking wctype.h presence... yes
# checking for wctype.h... yes
# checking for an ANSI C-conforming const... yes
# checking for size_t... yes
# checking whether struct tm is in sys/time.h or time.h... time.h
# checking for working volatile... yes
# checking for ptrdiff_t... yes
# checking return type of signal handlers... void
# checking for working strcoll... yes
# checking for strftime... yes
# checking for working strtod... yes
# checking for vprintf... yes
# checking for _doprnt... no
# checking for floor... no
# checking for isascii... yes
# checking for localeconv... yes
# checking for mblen... yes
# checking for memmove... yes
# checking for memset... yes
# checking for modf... yes
# checking for pow... no
# checking for sqrt... no
# checking for strcasecmp... yes
# checking for strchr... yes
# checking for strerror... yes
# checking for strncasecmp... yes
# checking for strrchr... yes
# checking for strstr... yes
# checking for strtol... yes
# checking for strtoul... yes
# configure: creating ./config.status
# config.status: creating Makefile
# config.status: creating src/Makefile
# config.status: creating src/ta_abstract/Makefile
# config.status: creating src/ta_common/Makefile
# config.status: creating src/ta_func/Makefile
# config.status: creating src/tools/Makefile
# config.status: creating src/tools/gen_code/Makefile
# config.status: creating src/tools/ta_regtest/Makefile
# config.status: creating ta-lib-config
# config.status: creating ta-lib.spec
# config.status: creating ta-lib.dpkg
# config.status: creating include/ta_config.h
# config.status: include/ta_config.h is unchanged
# config.status: executing depfiles commands
# Making all in src
# make[1]: Entering directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src'
# Making all in ta_abstract
# make[2]: Entering directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src/ta_abstract'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src/ta_abstract'
# Making all in ta_common
# make[2]: Entering directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src/ta_common'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src/ta_common'
# Making all in ta_func
# make[2]: Entering directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src/ta_func'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src/ta_func'
# make[2]: Entering directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src'
# make[2]: Nothing to be done for 'all-am'.
# make[2]: Leaving directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src'
# make[1]: Leaving directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src'
# Making all in src/tools
# make[1]: Entering directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src/tools'
# Making all in gen_code
# make[2]: Entering directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src/tools/gen_code'
# make  gen_code
# make[3]: Entering directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src/tools/gen_code'
# make[3]: 'gen_code' is up to date.
# make[3]: Leaving directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src/tools/gen_code'
# cp gen_code ../../../bin
# make[2]: Leaving directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src/tools/gen_code'
# Making all in ta_regtest
# make[2]: Entering directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src/tools/ta_regtest'
# make[2]: Nothing to be done for 'all'.
# make[2]: Leaving directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src/tools/ta_regtest'
# make[2]: Entering directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src/tools'
# make[2]: Nothing to be done for 'all-am'.
# make[2]: Leaving directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src/tools'
# make[1]: Leaving directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src/tools'
# make[1]: Entering directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib'
# make[1]: Nothing to be done for 'all-am'.
# make[1]: Leaving directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib'
# Making install in src
# make[1]: Entering directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src'
# Making install in ta_abstract
# make[2]: Entering directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src/ta_abstract'
# make[3]: Entering directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src/ta_abstract'
# make[3]: Nothing to be done for 'install-exec-am'.
# test -z "/usr/include/ta-lib/" || /usr/bin/mkdir -p "/usr/include/ta-lib/"
# /usr/bin/mkdir: cannot create directory ‘/usr/include/ta-lib/’: Permission denied
# make[3]: *** [Makefile:863: install-libta_abstractHEADERS] Error 1
# make[3]: Leaving directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src/ta_abstract'
# make[2]: *** [Makefile:966: install-am] Error 2
# make[2]: Leaving directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src/ta_abstract'
# make[1]: *** [Makefile:283: install-recursive] Error 1
# make[1]: Leaving directory '/home/quantumiracle/research/FinRL/tutorials/3-Practical/ta-lib/src'
# make: *** [Makefile:283: install-recursive] Error 1
# Requirement already satisfied: TA-Lib in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (0.4.19)
# Requirement already satisfied: numpy in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from TA-Lib) (1.21.6)
# Requirement already satisfied: baostock in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (0.8.8)
# Requirement already satisfied: pandas>=0.18.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from baostock) (1.1.5)
# Requirement already satisfied: pytz>=2017.2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pandas>=0.18.0->baostock) (2021.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pandas>=0.18.0->baostock) (2.8.2)
# Requirement already satisfied: numpy>=1.15.4 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pandas>=0.18.0->baostock) (1.21.6)
# Requirement already satisfied: six>=1.5 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=0.18.0->baostock) (1.16.0)
# Requirement already satisfied: quandl in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (3.7.0)
# Requirement already satisfied: requests>=2.7.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from quandl) (2.27.1)
# Requirement already satisfied: python-dateutil in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from quandl) (2.8.2)
# Requirement already satisfied: pandas>=0.14 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from quandl) (1.1.5)
# Requirement already satisfied: inflection>=0.3.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from quandl) (0.5.1)
# Requirement already satisfied: six in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from quandl) (1.16.0)
# Requirement already satisfied: more-itertools in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from quandl) (8.13.0)
# Requirement already satisfied: numpy>=1.8 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from quandl) (1.21.6)
# Requirement already satisfied: pytz>=2017.2 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from pandas>=0.14->quandl) (2021.3)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from requests>=2.7.0->quandl) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from requests>=2.7.0->quandl) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from requests>=2.7.0->quandl) (2022.6.15)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/quantumiracle/anaconda3/envs/x/lib/python3.7/site-packages (from requests>=2.7.0->quandl) (1.26.9)

# %% [markdown]
# ## Import Related Packages

# %%
# %cd /home/quantumiracle/research/FinRL-Meta/  
from finrl_meta.env_crypto_trading.env_multiple_crypto import CryptoEnv
# Out:
# /home/quantumiracle/research/FinRL-Meta

# %% [markdown]
# ## Functions for Training and Testing

# %%
from agents.elegantrl_models import DRLAgent as DRLAgent_erl
from agents.rllib_models import DRLAgent as DRLAgent_rllib
from agents.stablebaselines3_models import DRLAgent as DRLAgent_sb3
from finrl_meta.data_processor import DataProcessor

def train(start_date, end_date, ticker_list, data_source, time_interval, 
          technical_indicator_list, drl_lib, env, model_name, if_vix=True,
          **kwargs):
    
    #process data using unified data processor
    DP = DataProcessor(data_source, start_date, end_date, time_interval, **kwargs)
    price_array, tech_array, turbulence_array = DP.run(ticker_list,
                                                        technical_indicator_list, 
                                                        if_vix, cache=True)

    data_config = {'price_array': price_array,
                   'tech_array': tech_array,
                   'turbulence_array': turbulence_array}

    #build environment using processed data
    env_instance = env(config=data_config)

    #read parameters and load agents
    current_working_dir = kwargs.get('current_working_dir','./'+str(model_name))

    if drl_lib == 'elegantrl':
        break_step = kwargs.get('break_step', 1e6)
        erl_params = kwargs.get('erl_params')

        agent = DRLAgent_erl(env = env,
                             price_array = price_array,
                             tech_array=tech_array,
                             turbulence_array=turbulence_array)

        model = agent.get_model(model_name, model_kwargs = erl_params)

        trained_model = agent.train_model(model=model, 
                                          cwd=current_working_dir,
                                          total_timesteps=break_step)
        
      
    elif drl_lib == 'rllib':
        total_episodes = kwargs.get('total_episodes', 100)
        rllib_params = kwargs.get('rllib_params')

        agent_rllib = DRLAgent_rllib(env = env,
                       price_array=price_array,
                       tech_array=tech_array,
                       turbulence_array=turbulence_array)

        model,model_config = agent_rllib.get_model(model_name)

        model_config['lr'] = rllib_params['lr']
        model_config['train_batch_size'] = rllib_params['train_batch_size']
        model_config['gamma'] = rllib_params['gamma']

        trained_model = agent_rllib.train_model(model=model, 
                                          model_name=model_name,
                                          model_config=model_config,
                                          total_episodes=total_episodes)
        trained_model.save(current_working_dir)
        
            
    elif drl_lib == 'stable_baselines3':
        total_timesteps = kwargs.get('total_timesteps', 1e6)
        agent_params = kwargs.get('agent_params')

        agent = DRLAgent_sb3(env = env_instance)

        model = agent.get_model(model_name, model_kwargs = agent_params)
        trained_model = agent.train_model(model=model, 
                                tb_log_name=model_name,
                                total_timesteps=total_timesteps)
        print('Training finished!')
        trained_model.save(current_working_dir)
        print('Trained model saved in ' + str(current_working_dir))
    else:
        raise ValueError('DRL library input is NOT supported. Please check.')

# %%
# import DRL agents
from agents.stablebaselines3_models import DRLAgent as DRLAgent_sb3
from agents.rllib_models import DRLAgent as DRLAgent_rllib
from agents.elegantrl_models import DRLAgent as DRLAgent_erl

# import data processor
from finrl_meta.data_processor import DataProcessor

def test(start_date, end_date, ticker_list, data_source, time_interval,
            technical_indicator_list, drl_lib, env, model_name, if_vix=True,
            **kwargs):
  
    #process data using unified data processor
    DP = DataProcessor(data_source, start_date, end_date, time_interval, **kwargs)
    price_array, tech_array, turbulence_array = DP.run(ticker_list,
                                                        technical_indicator_list, 
                                                        if_vix, cache=True)
    
    
    np.save('./price_array.npy', price_array)
    data_config = {'price_array':price_array,
                   'tech_array':tech_array,
                   'turbulence_array':turbulence_array}
    #build environment using processed data
    env_instance = env(config=data_config)

    env_config = {
        "price_array": price_array,
        "tech_array": tech_array,
        "turbulence_array": turbulence_array,
        "if_train": False,
    }
    env_instance = env(config=env_config)

    # load elegantrl needs state dim, action dim and net dim
    net_dimension = kwargs.get("net_dimension", 2 ** 7)
    current_working_dir = kwargs.get("current_working_dir", "./" + str(model_name))
    print("price_array: ", len(price_array))

    if drl_lib == "elegantrl":
        episode_total_assets = DRLAgent_erl.DRL_prediction(
            model_name=model_name,
            cwd=current_working_dir,
            net_dimension=net_dimension,
            environment=env_instance,
        )

        return episode_total_assets

    elif drl_lib == "rllib":
        # load agent
        episode_total_assets = DRLAgent_rllib.DRL_prediction(
            model_name=model_name,
            env=env,
            price_array=price_array,
            tech_array=tech_array,
            turbulence_array=turbulence_array,
            agent_path=current_working_dir,
        )

        return episode_total_assets

    elif drl_lib == "stable_baselines3":
        episode_total_assets = DRLAgent_sb3.DRL_prediction_load_from_file(
            model_name=model_name, environment=env_instance, cwd=current_working_dir
        )

        return episode_total_assets
    else:
        raise ValueError("DRL library input is NOT supported. Please check.")

# %% [markdown]
# ## Multiple Cryptocurrencies Trading Env

# %%
import numpy as np
import math

class CryptoEnv:  # custom env
    def __init__(self, config, lookback=1, initial_capital=1e6, 
                 buy_cost_pct=1e-3, sell_cost_pct=1e-3, gamma=0.99):
        self.lookback = lookback
        self.initial_total_asset = initial_capital
        self.initial_cash = initial_capital
        self.buy_cost_pct = buy_cost_pct
        self.sell_cost_pct = sell_cost_pct
        self.max_stock = 1
        self.gamma = gamma
        self.price_array = config['price_array']
        self.tech_array = config['tech_array']
        self._generate_action_normalizer()
        self.crypto_num = self.price_array.shape[1]
        self.max_step = self.price_array.shape[0] - lookback - 1
        
        # reset
        self.time = lookback-1
        self.cash = self.initial_cash
        self.current_price = self.price_array[self.time]
        self.current_tech = self.tech_array[self.time]
        self.stocks = np.zeros(self.crypto_num, dtype=np.float32)

        self.total_asset = self.cash + (self.stocks * self.price_array[self.time]).sum()
        self.episode_return = 0.0  
        self.gamma_return = 0.0
        

        '''env information'''
        self.env_name = 'MulticryptoEnv'
        self.state_dim = 1 + (self.price_array.shape[1] + self.tech_array.shape[1])*lookback
        self.action_dim = self.price_array.shape[1]
        self.if_discrete = False
        self.target_return = 10


    def reset(self) -> np.ndarray:
        self.time = self.lookback-1
        self.current_price = self.price_array[self.time]
        self.current_tech = self.tech_array[self.time]
        self.cash = self.initial_cash  # reset()
        self.stocks = np.zeros(self.crypto_num, dtype=np.float32)
        self.total_asset = self.cash + (self.stocks * self.price_array[self.time]).sum()
        
        state = self.get_state()
        return state

    def step(self, actions) -> (np.ndarray, float, bool, None):
        self.time += 1
        
        price = self.price_array[self.time]
        for i in range(self.action_dim):
            norm_vector_i = self.action_norm_vector[i]
            actions[i] = actions[i] * norm_vector_i
            
        for index in np.where(actions < 0)[0]:  # sell_index:
            if price[index] > 0:  # Sell only if current asset is > 0
                sell_num_shares = min(self.stocks[index], -actions[index])
                self.stocks[index] -= sell_num_shares
                self.cash += price[index] * sell_num_shares * (1 - self.sell_cost_pct)
                
        for index in np.where(actions > 0)[0]:  # buy_index:
            if price[index] > 0:  # Buy only if the price is > 0 (no missing data in this particular date)
                buy_num_shares = min(self.cash // price[index], actions[index])
                self.stocks[index] += buy_num_shares
                self.cash -= price[index] * buy_num_shares * (1 + self.buy_cost_pct)

        """update time"""
        done = self.time == self.max_step
        state = self.get_state()
        next_total_asset = self.cash + (self.stocks * self.price_array[self.time]).sum()
        reward = (next_total_asset - self.total_asset) * 2 ** -16  
        self.total_asset = next_total_asset
        self.gamma_return = self.gamma_return * self.gamma + reward 
        self.cumu_return = self.total_asset / self.initial_cash
        if done:
            reward = self.gamma_return
            self.episode_return = self.total_asset / self.initial_cash
        return state, reward, done, None

    def get_state(self):
        state =  np.hstack((self.cash * 2 ** -18, self.stocks * 2 ** -3))
        for i in range(self.lookback):
            tech_i = self.tech_array[self.time-i]
            normalized_tech_i = tech_i * 2 ** -15
            state = np.hstack((state, normalized_tech_i)).astype(np.float32)
        return state
    
    def close(self):
        pass

    def _generate_action_normalizer(self):
        action_norm_vector = []
        price_0 = self.price_array[0]
        for price in price_0:
            x = math.floor(math.log(price, 10)) #the order of magnitude 
            action_norm_vector.append(1/((10)**x)) 
            
        action_norm_vector = np.asarray(action_norm_vector) * 10000
        self.action_norm_vector = np.asarray(action_norm_vector)

# %% [markdown]
# ## Set Parameters

# %%
TICKER_LIST = ['BTCUSDT','ETHUSDT','ADAUSDT','BNBUSDT','XRPUSDT',
                'SOLUSDT','DOTUSDT', 'DOGEUSDT','AVAXUSDT','UNIUSDT']
env = CryptoEnv
TRAIN_START_DATE = '2021-09-01'
TRAIN_END_DATE = '2021-09-02'

TEST_START_DATE = '2021-09-21'
TEST_END_DATE = '2021-09-30'

INDICATORS = ['macd', 'rsi', 'cci', 'dx'] #self-defined technical indicator list is NOT supported yet

ERL_PARAMS = {"learning_rate": 2**-15,"batch_size": 2**11,
                "gamma": 0.99, "seed":312,"net_dimension": 2**9, 
                "target_step": 5000, "eval_gap": 30, "eval_times": 1}

# %% [markdown]
# ## Training

# %%
train(start_date=TRAIN_START_DATE, 
      end_date=TRAIN_END_DATE,
      ticker_list=TICKER_LIST, 
      data_source='binance',
      time_interval='5m', 
      technical_indicator_list=INDICATORS,
      drl_lib='elegantrl', 
      env=env, 
      model_name='ppo', 
      current_working_dir='./test_ppo',
      erl_params=ERL_PARAMS,
      break_step=5e4,
      if_vix=False
      )
# Out:
# binance successfully connected
# Using cached file ./cache/BTCUSDT_ETHUSDT_ADAUSDT_BNBUSDT_XRPUSDT_SOLUSDT_DOTUSDT_DOGEUSDT_AVAXUSDT_UNIUSDT_binance_2021-09-01_2021-09-02_5m.pickle
# tech_indicator_list:  ['macd', 'rsi', 'cci', 'dx']
# indicator:  macd
# indicator:  rsi
# indicator:  cci
# indicator:  dx
# Succesfully add technical indicators
# Successfully transformed into array
# | Arguments Remove cwd: ./test_ppo

# %% [markdown]
# ## Testing

# %%
account_value_erl = test(start_date = TEST_START_DATE, 
                        end_date = TEST_END_DATE,
                        ticker_list = TICKER_LIST, 
                        data_source = 'binance',
                        time_interval= '5m', 
                        technical_indicator_list= INDICATORS,
                        drl_lib='elegantrl', 
                        env=env, 
                        model_name='ppo', 
                        current_working_dir='./test_ppo', 
                        net_dimension = 2**9, 
                        if_vix=False
                        )
# Out:
# Error: Session cannot generate requests
# at w.executeCodeCell (/home/quantumiracle/.vscode/extensions/ms-toolsai.jupyter-2021.9.1101343141/out/client/extension.js:52:301180)
# at w.execute (/home/quantumiracle/.vscode/extensions/ms-toolsai.jupyter-2021.9.1101343141/out/client/extension.js:52:300551)
# at w.start (/home/quantumiracle/.vscode/extensions/ms-toolsai.jupyter-2021.9.1101343141/out/client/extension.js:52:296215)
# at runMicrotasks (<anonymous>)
# at processTicksAndRejections (internal/process/task_queues.js:93:5)
# at async t.CellExecutionQueue.executeQueuedCells (/home/quantumiracle/.vscode/extensions/ms-toolsai.jupyter-2021.9.1101343141/out/client/extension.js:52:310950)
# at async t.CellExecutionQueue.start (/home/quantumiracle/.vscode/extensions/ms-toolsai.jupyter-2021.9.1101343141/out/client/extension.js:52:310490)

# %% [markdown]
# ## Plotting

# %%
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker
import matplotlib.dates as mdates
# %matplotlib inline
#calculate agent returns
account_value_erl = np.array(account_value_erl)
agent_returns = account_value_erl/account_value_erl[0]
#calculate buy-and-hold btc returns
price_array = np.load('./price_array.npy')
btc_prices = price_array[:,0]
buy_hold_btc_returns = btc_prices/btc_prices[0]
#calculate equal weight portfolio returns
price_array = np.load('./price_array.npy')
initial_prices = price_array[0,:]
equal_weight = np.array([1e5/initial_prices[i] for i in range(len(TICKER_LIST))])
equal_weight_values = []
for i in range(0, price_array.shape[0]):
    equal_weight_values.append(np.sum(equal_weight * price_array[i]))
equal_weight_values = np.array(equal_weight_values)
equal_returns = equal_weight_values/equal_weight_values[0]
#plot 
plt.figure(dpi=200)
plt.grid()
plt.grid(which='minor', axis='y')
plt.title('Cryptocurrency Trading ', fontsize=20)
plt.plot(agent_returns, label='ElegantRL Agent', color = 'red')
plt.plot(buy_hold_btc_returns, label='Buy-and-Hold BTC', color='blue')
plt.plot(equal_returns, label='Equal Weight Portfolio', color='green')
plt.ylabel('Return', fontsize=16)
plt.xlabel('Times (5min)', fontsize=16)
plt.xticks(size=14)
plt.yticks(size=14)
'''ax = plt.gca()
ax.xaxis.set_major_locator(ticker.MultipleLocator(210))
ax.xaxis.set_minor_locator(ticker.MultipleLocator(21))
ax.yaxis.set_minor_locator(ticker.MultipleLocator(0.005))
ax.yaxis.set_major_formatter(ticker.PercentFormatter(xmax=1, decimals=2))
ax.xaxis.set_major_formatter(ticker.FixedFormatter([]))'''
plt.legend(fontsize=10.5)
# Out:
# Error: Session cannot generate requests
# at w.executeCodeCell (/home/quantumiracle/.vscode/extensions/ms-toolsai.jupyter-2021.9.1101343141/out/client/extension.js:52:301180)
# at w.execute (/home/quantumiracle/.vscode/extensions/ms-toolsai.jupyter-2021.9.1101343141/out/client/extension.js:52:300551)
# at w.start (/home/quantumiracle/.vscode/extensions/ms-toolsai.jupyter-2021.9.1101343141/out/client/extension.js:52:296215)
# at runMicrotasks (<anonymous>)
# at processTicksAndRejections (internal/process/task_queues.js:93:5)
# at async t.CellExecutionQueue.executeQueuedCells (/home/quantumiracle/.vscode/extensions/ms-toolsai.jupyter-2021.9.1101343141/out/client/extension.js:52:310950)
# at async t.CellExecutionQueue.start (/home/quantumiracle/.vscode/extensions/ms-toolsai.jupyter-2021.9.1101343141/out/client/extension.js:52:310490)
