# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL/blob/master/Stock_NeurIPS2018.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading
#
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Task Description](#0)
# * [2. Install Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. A List of Python Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download and Preprocess Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5. Build Market Environment in OpenAI Gym-style](#4)
#     * [5.1. Data Split](#4.1)
#     * [5.3. Environment for Training](#4.2)
# * [6. Train DRL Agents](#5)
# * [7. Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Task Discription

# %% [markdown]
# We train a DRL agent for stock trading. This task is modeled as a Markov Decision Process (MDP), and the objective function is maximizing (expected) cumulative return.
#
# We specify the state-action-reward as follows:
#
# * **State s**: The state space represents an agent's perception of the market environment. Just like a human trader analyzing various information, here our agent passively observes many features and learns by interacting with the market environment (usually by replaying historical data).
#
# * **Action a**: The action space includes allowed actions that an agent can take at each state. For example, a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying. When an action operates multiple shares, a ∈{−k, ..., −1, 0, 1, ..., k}, e.g.. "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * **Reward function r(s, a, s′)**: Reward is an incentive for an agent to learn a better policy. For example, it can be the change of the portfolio value when taking a at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio values at state s′ and s, respectively
#
#
# **Market environment**: 30 consituent stocks of Dow Jones Industrial Average (DJIA) index. Accessed at the starting date of the testing period.
#
#
# The data for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Install Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install packages

# %%
## install finrl library
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. A list of Python packages
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.meta.data_processor import DataProcessor

from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from pprint import pprint

import sys
sys.path.append("../FinRL")

import itertools

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %%
from finrl import config
from finrl import config_tickers
import os
from finrl.main import check_and_make_directories
from finrl.config import (
    DATA_SAVE_DIR,
    TRAINED_MODEL_DIR,
    TENSORBOARD_LOG_DIR,
    RESULTS_DIR,
    INDICATORS,
    TRAIN_START_DATE,
    TRAIN_END_DATE,
    TEST_START_DATE,
    TEST_END_DATE,
    TRADE_START_DATE,
    TRADE_END_DATE,
)
check_and_make_directories([DATA_SAVE_DIR, TRAINED_MODEL_DIR, TENSORBOARD_LOG_DIR, RESULTS_DIR])

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance provides stock data, financial news, financial reports, etc. Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** in FinRL-Meta to fetch data via Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()

# %%
# from config.py, TRAIN_START_DATE is a string
TRAIN_START_DATE
# from config.py, TRAIN_END_DATE is a string
TRAIN_END_DATE
# Out:
# '2014-01-01'

# %%
TRAIN_START_DATE = '2009-01-01'
TRAIN_END_DATE = '2020-07-01'
TRADE_START_DATE = '2020-07-01'
TRADE_END_DATE = '2021-10-31'
# Out:
# '2020-07-31'

# %%
df = YahooDownloader(start_date = TRAIN_START_DATE,
                     end_date = TRADE_END_DATE,
                     ticker_list = config_tickers.DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (94331, 8)

# %%
print(config_tickers.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
df.shape
# Out:
# (94331, 8)

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2009-01-02   3.067143   3.251429   3.041429   2.771174  746015200  AAPL
# 1  2009-01-02  58.590000  59.080002  57.750000  44.867603    6547900  AMGN
# 2  2009-01-02  18.570000  19.520000  18.400000  15.535339   10955700   AXP
# 3  2009-01-02  42.799999  45.560001  42.779999  33.941097    7010200    BA
# 4  2009-01-02  44.910000  46.980000  44.709999  32.164722    7117200   CAT
#
#    day
# 0    4
# 1    4
# 2    4
# 3    4
# 4    4

# %% [markdown]
# # Part 4: Preprocess Data
# We need to check for missing data and do feature engineering to convert the data point into a state.
# * **Adding technical indicators**. In practical trading, various information needs to be taken into account, such as historical prices, current holding shares, technical indicators, etc. Here, we demonstrate two trend-following technical indicators: MACD and RSI.
# * **Adding turbulence index**. Risk-aversion reflects whether an investor prefers to protect the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the turbulence index that measures extreme fluctuation of asset price.

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = INDICATORS,
                    use_vix=True,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (3229, 8)
# Successfully added vix
# Successfully added turbulence index

# %%
list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed_full.fillna(0)

# %%
processed_full.sort_values(['date','tic'],ignore_index=True).head(10)
# Out:
#          date   tic       open       high        low      close       volume  \
# 0  2009-01-02  AAPL   3.067143   3.251429   3.041429   2.771174  746015200.0
# 1  2009-01-02  AMGN  58.590000  59.080002  57.750000  44.867603    6547900.0
# 2  2009-01-02   AXP  18.570000  19.520000  18.400000  15.535339   10955700.0
# 3  2009-01-02    BA  42.799999  45.560001  42.779999  33.941097    7010200.0
# 4  2009-01-02   CAT  44.910000  46.980000  44.709999  32.164722    7117200.0
# 5  2009-01-02   CRM   8.025000   8.550000   7.912500   8.505000    4069200.0
# 6  2009-01-02  CSCO  16.410000  17.000000  16.250000  12.265081   40980600.0
# 7  2009-01-02   CVX  74.230003  77.300003  73.580002  44.807625   13695900.0
# 8  2009-01-02   DIS  22.760000  24.030001  22.500000  20.597496    9796600.0
# 9  2009-01-02    GS  84.019997  87.620003  82.190002  70.735085   14088500.0
#
#    day  macd  boll_ub   boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0  4.0   0.0  2.99505  2.664252   100.0  66.666667  100.0      2.771174
# 1  4.0   0.0  2.99505  2.664252   100.0  66.666667  100.0     44.867603
# 2  4.0   0.0  2.99505  2.664252   100.0  66.666667  100.0     15.535339
# 3  4.0   0.0  2.99505  2.664252   100.0  66.666667  100.0     33.941097
# 4  4.0   0.0  2.99505  2.664252   100.0  66.666667  100.0     32.164722
# 5  4.0   0.0  2.99505  2.664252   100.0  66.666667  100.0      8.505000
# 6  4.0   0.0  2.99505  2.664252   100.0  66.666667  100.0     12.265081
# 7  4.0   0.0  2.99505  2.664252   100.0  66.666667  100.0     44.807625
# 8  4.0   0.0  2.99505  2.664252   100.0  66.666667  100.0     20.597496
# 9  4.0   0.0  2.99505  2.664252   100.0  66.666667  100.0     70.735085
#
#    close_60_sma        vix  turbulence
# 0      2.771174  39.189999         0.0
# 1     44.867603  39.189999         0.0
# 2     15.535339  39.189999         0.0
# 3     33.941097  39.189999         0.0
# 4     32.164722  39.189999         0.0
# 5      8.505000  39.189999         0.0
# 6     12.265081  39.189999         0.0
# 7     44.807625  39.189999         0.0
# 8     20.597496  39.189999         0.0
# 9     70.735085  39.189999         0.0

# %% [markdown]
# <a id='4'></a>
# # Part 5. Build A Market Environment in OpenAI Gym-style
# The training process involves observing stock price change, taking an action and reward's calculation. By interacting with the market environment, the agent will eventually derive a trading strategy that may maximize (expected) rewards.
#
# Our market environment, based on OpenAI Gym, simulates stock markets with historical market data.

# %% [markdown]
# ## Data Split
# We split the data into training set and testing set as follows:
#
# Training data period: 2009-01-01 to 2020-07-01
#
# Trading data period: 2020-07-01 to 2021-10-31

# %%
train = data_split(processed_full, TRAIN_START_DATE,TRAIN_END_DATE)
trade = data_split(processed_full, TRADE_START_DATE,TRADE_END_DATE)
print(len(train))
print(len(trade))
# Out:
# 83897
# 9744

# %%
train.tail()
# Out:
#             date  tic        open        high         low       close  \
# 2892  2020-06-30  UNH  288.570007  296.450012  287.660004  286.754120
# 2892  2020-06-30    V  191.490005  193.750000  190.160004  190.737228
# 2892  2020-06-30   VZ   54.919998   55.290001   54.360001   50.376740
# 2892  2020-06-30  WBA   42.119999   42.580002   41.759998   39.035740
# 2892  2020-06-30  WMT  119.220001  120.129997  118.540001  116.121780
#
#           volume  day      macd     boll_ub     boll_lb     rsi_30     cci_30  \
# 2892   2932900.0  1.0 -0.019414  302.845863  270.287352  52.413031 -25.866470
# 2892   9040100.0  1.0  1.048786  198.750525  185.041392  53.021032 -51.550900
# 2892  17414800.0  1.0 -0.437111   53.918425   48.729322  48.097035 -51.018335
# 2892   4782100.0  1.0 -0.083986   42.609306   36.487096  48.830195 -14.508002
# 2892   6836400.0  1.0 -0.886569  119.473763  113.510452  48.159685 -69.938644
#
#          dx_30  close_30_sma  close_60_sma    vix  turbulence
# 2892  1.846804    286.997200    280.002896  30.43   12.918775
# 2892  2.013358    191.485034    181.677681  30.43   12.918775
# 2892  8.508886     51.012122     51.464678  30.43   12.918775
# 2892  1.500723     39.135190     38.935129  30.43   12.918775
# 2892  3.847271    117.787628    119.723274  30.43   12.918775

# %%
trade.head()
# Out:
#          date   tic        open        high         low       close  \
# 0  2020-07-01  AAPL   91.279999   91.839996   90.977501   89.904617
# 0  2020-07-01  AMGN  235.520004  256.230011  232.580002  240.153961
# 0  2020-07-01   AXP   95.250000   96.959999   93.639999   92.086380
# 0  2020-07-01    BA  185.880005  190.610001  180.039993  180.320007
# 0  2020-07-01   CAT  129.380005  129.399994  125.879997  120.651634
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  110737200.0  2.0  3.014606   92.699321   80.179950  62.807170  107.491949
# 0    6575800.0  2.0  3.636392  232.397419  200.212942  61.279641  271.386208
# 0    3301000.0  2.0 -0.389162  110.423944   87.759333  48.504818  -66.328704
# 0   49036700.0  2.0  5.443193  220.721139  160.932863  50.925771   24.220608
# 0    2807800.0  2.0  1.272630  130.624272  113.353134  52.865419   35.597297
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  29.730532     83.933767     77.717542  28.620001   53.068073
# 0  46.806139    214.858661    215.931666  28.620001   53.068073
# 0   3.142448     97.244637     90.695525  28.620001   53.068073
# 0  15.932920    176.472335    155.614168  28.620001   53.068073
# 0  14.457404    119.412837    113.646674  28.620001   53.068073

# %%
INDICATORS
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %% [markdown]
# ## Environment for Training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# <a id='5'></a>
# # Part 6: Train DRL Agents
# * The DRL algorithms are from **Stable Baselines 3**. Users are also encouraged to try **ElegantRL** and **Ray RLlib**.
# * FinRL includes fine-tuned standard DRL algorithms, such as DQN, DDPG, Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
agent = DRLAgent(env = env_train)

# %% [markdown]
# ### Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# ### Agent 1: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cpu device

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                             tb_log_name='a2c',
                             total_timesteps=50000)
# Out:
# ---------------------------------------
# | time/                 |             |
# |    fps                | 85          |
# |    iterations         | 100         |
# |    time_elapsed       | 5           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | 0.225       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -3.3        |
# |    reward             | -0.38245595 |
# |    std                | 0.997       |
# |    value_loss         | 0.81        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 200        |
# |    time_elapsed       | 11         |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -0.00998   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | -16.6      |
# |    reward             | -2.0795436 |
# |    std                | 0.998      |
# |    value_loss         | 0.521      |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 86       |
# |    iterations         | 300      |
# |    time_elapsed       | 17       |
# |    total_timesteps    | 1500     |
# | train/                |          |
# |    entropy_loss       | -41      |
# |    explained_variance | -0.307   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 299      |
# |    policy_loss        | -185     |
# |    reward             | 3.66972  |
# |    std                | 0.997    |
# |    value_loss         | 23.4     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 86        |
# |    iterations         | 400       |
# |    time_elapsed       | 22        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -0.0719   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | 64.3      |
# |    reward             | 1.3105918 |
# |    std                | 0.998     |
# |    value_loss         | 4.65      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 500       |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 2500      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | -0.0128   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 499       |
# |    policy_loss        | 562       |
# |    reward             | -13.59298 |
# |    std                | 0.996     |
# |    value_loss         | 235       |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 87          |
# |    iterations         | 600         |
# |    time_elapsed       | 34          |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -41         |
# |    explained_variance | -0.612      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | 157         |
# |    reward             | -0.20955521 |
# |    std                | 0.995       |
# |    value_loss         | 16.5        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 700       |
# |    time_elapsed       | 40        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | -0.00822  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -150      |
# |    reward             | -4.177808 |
# |    std                | 0.995     |
# |    value_loss         | 13.7      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 800        |
# |    time_elapsed       | 46         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | -18.7      |
# |    reward             | -2.8758662 |
# |    std                | 0.996      |
# |    value_loss         | 8.18       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 86          |
# |    iterations         | 900         |
# |    time_elapsed       | 52          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -41         |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | 278         |
# |    reward             | -0.08112537 |
# |    std                | 0.997       |
# |    value_loss         | 51.8        |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 86       |
# |    iterations         | 1000     |
# |    time_elapsed       | 57       |
# |    total_timesteps    | 5000     |
# | train/                |          |
# |    entropy_loss       | -41      |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 999      |
# |    policy_loss        | -6.5     |
# |    reward             | -8.42856 |
# |    std                | 0.996    |
# |    value_loss         | 2.46     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 86        |
# |    iterations         | 1100      |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -784      |
# |    reward             | 5.4715543 |
# |    std                | 0.996     |
# |    value_loss         | 442       |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 86          |
# |    iterations         | 1200        |
# |    time_elapsed       | 69          |
# |    total_timesteps    | 6000        |
# | train/                |             |
# |    entropy_loss       | -41         |
# |    explained_variance | 0.0212      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1199        |
# |    policy_loss        | -173        |
# |    reward             | 0.077639945 |
# |    std                | 0.995       |
# |    value_loss         | 19.8        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 1300       |
# |    time_elapsed       | 74         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | -62        |
# |    reward             | -4.6043253 |
# |    std                | 0.994      |
# |    value_loss         | 7.45       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 86        |
# |    iterations         | 1400      |
# |    time_elapsed       | 80        |
# |    total_timesteps    | 7000      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1399      |
# |    policy_loss        | 145       |
# |    reward             | 1.2491926 |
# |    std                | 0.995     |
# |    value_loss         | 19.3      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 86        |
# |    iterations         | 1500      |
# |    time_elapsed       | 86        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41       |
# |    explained_variance | 0.000278  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | 290       |
# |    reward             | 5.5308213 |
# |    std                | 0.995     |
# |    value_loss         | 70.4      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 1600       |
# |    time_elapsed       | 91         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | -261       |
# |    reward             | 0.46437263 |
# |    std                | 0.997      |
# |    value_loss         | 45.7       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 1700      |
# |    time_elapsed       | 97        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 169       |
# |    reward             | 4.5881724 |
# |    std                | 0.998     |
# |    value_loss         | 87.3      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 1800      |
# |    time_elapsed       | 103       |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -13.6     |
# |    reward             | 1.2186269 |
# |    std                | 0.998     |
# |    value_loss         | 0.621     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 1900       |
# |    time_elapsed       | 108        |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | -23.2      |
# |    reward             | 0.86510557 |
# |    std                | 0.999      |
# |    value_loss         | 1.49       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 2000       |
# |    time_elapsed       | 114        |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | -62.9      |
# |    reward             | -3.6844032 |
# |    std                | 1          |
# |    value_loss         | 34.7       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 2100      |
# |    time_elapsed       | 119       |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | 592       |
# |    reward             | 0.5913914 |
# |    std                | 0.999     |
# |    value_loss         | 210       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 2200      |
# |    time_elapsed       | 125       |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | -197      |
# |    reward             | -18.43632 |
# |    std                | 1         |
# |    value_loss         | 28.6      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 2300       |
# |    time_elapsed       | 131        |
# |    total_timesteps    | 11500      |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2299       |
# |    policy_loss        | -2.89e+03  |
# |    reward             | -15.708329 |
# |    std                | 1          |
# |    value_loss         | 5.45e+03   |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 2400      |
# |    time_elapsed       | 136       |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | 101       |
# |    reward             | 1.3252198 |
# |    std                | 1         |
# |    value_loss         | 12.9      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 2500      |
# |    time_elapsed       | 142       |
# |    total_timesteps    | 12500     |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2499      |
# |    policy_loss        | -154      |
# |    reward             | 1.1985308 |
# |    std                | 1         |
# |    value_loss         | 16.8      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 2600       |
# |    time_elapsed       | 148        |
# |    total_timesteps    | 13000      |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2599       |
# |    policy_loss        | 297        |
# |    reward             | -0.3930558 |
# |    std                | 0.999      |
# |    value_loss         | 72.5       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 2700       |
# |    time_elapsed       | 154        |
# |    total_timesteps    | 13500      |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2699       |
# |    policy_loss        | 39.9       |
# |    reward             | -2.0099065 |
# |    std                | 1          |
# |    value_loss         | 3.71       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 2800       |
# |    time_elapsed       | 160        |
# |    total_timesteps    | 14000      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.000893   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2799       |
# |    policy_loss        | 390        |
# |    reward             | 0.57461935 |
# |    std                | 1          |
# |    value_loss         | 91.2       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 2900      |
# |    time_elapsed       | 165       |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.0166   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -159      |
# |    reward             | 5.5083456 |
# |    std                | 1         |
# |    value_loss         | 16.2      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 87          |
# |    iterations         | 3000        |
# |    time_elapsed       | 171         |
# |    total_timesteps    | 15000       |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0.0163      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2999        |
# |    policy_loss        | 35.1        |
# |    reward             | -0.57458067 |
# |    std                | 1           |
# |    value_loss         | 0.858       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 3100       |
# |    time_elapsed       | 177        |
# |    total_timesteps    | 15500      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3099       |
# |    policy_loss        | 66.7       |
# |    reward             | 0.51296186 |
# |    std                | 1.01       |
# |    value_loss         | 3.13       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 3200      |
# |    time_elapsed       | 183       |
# |    total_timesteps    | 16000     |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3199      |
# |    policy_loss        | -332      |
# |    reward             | -2.820065 |
# |    std                | 1.01      |
# |    value_loss         | 107       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 3300      |
# |    time_elapsed       | 189       |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 6.74e-05  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | -13.8     |
# |    reward             | 1.1075561 |
# |    std                | 1.01      |
# |    value_loss         | 3.38      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 3400       |
# |    time_elapsed       | 194        |
# |    total_timesteps    | 17000      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3399       |
# |    policy_loss        | 117        |
# |    reward             | -12.577578 |
# |    std                | 1.01       |
# |    value_loss         | 28         |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 87         |
# |    iterations         | 3500       |
# |    time_elapsed       | 200        |
# |    total_timesteps    | 17500      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3499       |
# |    policy_loss        | 139        |
# |    reward             | 0.79640126 |
# |    std                | 1.01       |
# |    value_loss         | 14.7       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 3600      |
# |    time_elapsed       | 206       |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.00612  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -110      |
# |    reward             | 1.3899982 |
# |    std                | 1.01      |
# |    value_loss         | 8.92      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 3700      |
# |    time_elapsed       | 211       |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | 233       |
# |    reward             | -0.111542 |
# |    std                | 1.01      |
# |    value_loss         | 41.5      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 3800      |
# |    time_elapsed       | 217       |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | 133       |
# |    reward             | 4.2435246 |
# |    std                | 1.01      |
# |    value_loss         | 10.8      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 3900      |
# |    time_elapsed       | 223       |
# |    total_timesteps    | 19500     |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3899      |
# |    policy_loss        | -110      |
# |    reward             | 1.5189852 |
# |    std                | 1.01      |
# |    value_loss         | 15.4      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 87       |
# |    iterations         | 4000     |
# |    time_elapsed       | 229      |
# |    total_timesteps    | 20000    |
# | train/                |          |
# |    entropy_loss       | -41.4    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 3999     |
# |    policy_loss        | -162     |
# |    reward             | 6.805601 |
# |    std                | 1.01     |
# |    value_loss         | 29       |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 87          |
# |    iterations         | 4100        |
# |    time_elapsed       | 235         |
# |    total_timesteps    | 20500       |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4099        |
# |    policy_loss        | 14.3        |
# |    reward             | -0.06070591 |
# |    std                | 1.01        |
# |    value_loss         | 1.95        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 4200      |
# |    time_elapsed       | 241       |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -155      |
# |    reward             | 2.1403897 |
# |    std                | 1.01      |
# |    value_loss         | 20.2      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 87       |
# |    iterations         | 4300     |
# |    time_elapsed       | 247      |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -41.4    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -73.2    |
# |    reward             | 4.132366 |
# |    std                | 1.01     |
# |    value_loss         | 7.15     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 87        |
# |    iterations         | 4400      |
# |    time_elapsed       | 252       |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | -41.7     |
# |    reward             | 4.682027  |
# |    std                | 1.01      |
# |    value_loss         | 29.2      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 86        |
# |    iterations         | 4500      |
# |    time_elapsed       | 258       |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | 706       |
# |    reward             | -0.782581 |
# |    std                | 1.01      |
# |    value_loss         | 299       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 86        |
# |    iterations         | 4600      |
# |    time_elapsed       | 264       |
# |    total_timesteps    | 23000     |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4599      |
# |    policy_loss        | 471       |
# |    reward             | 1.6243507 |
# |    std                | 1.01      |
# |    value_loss         | 140       |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 86          |
# |    iterations         | 4700        |
# |    time_elapsed       | 270         |
# |    total_timesteps    | 23500       |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4699        |
# |    policy_loss        | -135        |
# |    reward             | -0.09023765 |
# |    std                | 1.01        |
# |    value_loss         | 16.8        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 4800       |
# |    time_elapsed       | 275        |
# |    total_timesteps    | 24000      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4799       |
# |    policy_loss        | -278       |
# |    reward             | -1.1204126 |
# |    std                | 1.01       |
# |    value_loss         | 50.1       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 4900       |
# |    time_elapsed       | 283        |
# |    total_timesteps    | 24500      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4899       |
# |    policy_loss        | -16.2      |
# |    reward             | 0.57891697 |
# |    std                | 1          |
# |    value_loss         | 2.09       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 5000       |
# |    time_elapsed       | 289        |
# |    total_timesteps    | 25000      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4999       |
# |    policy_loss        | -77.8      |
# |    reward             | -0.8018503 |
# |    std                | 1.01       |
# |    value_loss         | 10.8       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 86       |
# |    iterations         | 5100     |
# |    time_elapsed       | 294      |
# |    total_timesteps    | 25500    |
# | train/                |          |
# |    entropy_loss       | -41.3    |
# |    explained_variance | 1.19e-07 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5099     |
# |    policy_loss        | 204      |
# |    reward             | 3.961386 |
# |    std                | 1.01     |
# |    value_loss         | 37.9     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 86        |
# |    iterations         | 5200      |
# |    time_elapsed       | 300       |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | -365      |
# |    reward             | 13.346269 |
# |    std                | 1         |
# |    value_loss         | 166       |
# -------------------------------------
# day: 2892, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 7613512.38
# total_reward: 6613512.38
# total_cost: 6267.13
# total_trades: 41022
# Sharpe: 0.963
# =================================
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 5300       |
# |    time_elapsed       | 306        |
# |    total_timesteps    | 26500      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5299       |
# |    policy_loss        | -76.9      |
# |    reward             | 0.22087732 |
# |    std                | 1          |
# |    value_loss         | 3.92       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 5400       |
# |    time_elapsed       | 312        |
# |    total_timesteps    | 27000      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5399       |
# |    policy_loss        | -42.2      |
# |    reward             | -0.7331574 |
# |    std                | 1          |
# |    value_loss         | 4.88       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 86       |
# |    iterations         | 5500     |
# |    time_elapsed       | 318      |
# |    total_timesteps    | 27500    |
# | train/                |          |
# |    entropy_loss       | -41.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5499     |
# |    policy_loss        | 98       |
# |    reward             | 1.317904 |
# |    std                | 1        |
# |    value_loss         | 24.7     |
# ------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 5600       |
# |    time_elapsed       | 324        |
# |    total_timesteps    | 28000      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5599       |
# |    policy_loss        | -259       |
# |    reward             | -2.1360464 |
# |    std                | 1          |
# |    value_loss         | 51.1       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 5700       |
# |    time_elapsed       | 330        |
# |    total_timesteps    | 28500      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5699       |
# |    policy_loss        | -276       |
# |    reward             | -4.0962267 |
# |    std                | 1          |
# |    value_loss         | 75.3       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 86       |
# |    iterations         | 5800     |
# |    time_elapsed       | 336      |
# |    total_timesteps    | 29000    |
# | train/                |          |
# |    entropy_loss       | -41.2    |
# |    explained_variance | 0.0146   |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5799     |
# |    policy_loss        | -27.5    |
# |    reward             | 1.270464 |
# |    std                | 1        |
# |    value_loss         | 3.49     |
# ------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 86           |
# |    iterations         | 5900         |
# |    time_elapsed       | 341          |
# |    total_timesteps    | 29500        |
# | train/                |              |
# |    entropy_loss       | -41.2        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 5899         |
# |    policy_loss        | -1.33        |
# |    reward             | 0.0148807345 |
# |    std                | 1            |
# |    value_loss         | 0.381        |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 6000       |
# |    time_elapsed       | 347        |
# |    total_timesteps    | 30000      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5999       |
# |    policy_loss        | 174        |
# |    reward             | -1.4712937 |
# |    std                | 1          |
# |    value_loss         | 20         |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 86        |
# |    iterations         | 6100      |
# |    time_elapsed       | 353       |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | -141      |
# |    reward             | -5.030463 |
# |    std                | 1         |
# |    value_loss         | 14.9      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 86          |
# |    iterations         | 6200        |
# |    time_elapsed       | 359         |
# |    total_timesteps    | 31000       |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6199        |
# |    policy_loss        | -262        |
# |    reward             | -0.94790137 |
# |    std                | 1           |
# |    value_loss         | 41.7        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 86        |
# |    iterations         | 6300      |
# |    time_elapsed       | 365       |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | -375      |
# |    reward             | 3.6837375 |
# |    std                | 1         |
# |    value_loss         | 129       |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 86        |
# |    iterations         | 6400      |
# |    time_elapsed       | 371       |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | 97.1      |
# |    reward             | 1.8584676 |
# |    std                | 1         |
# |    value_loss         | 5.02      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 6500       |
# |    time_elapsed       | 377        |
# |    total_timesteps    | 32500      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6499       |
# |    policy_loss        | 1.77       |
# |    reward             | -3.7367923 |
# |    std                | 1          |
# |    value_loss         | 4.41       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 6600       |
# |    time_elapsed       | 383        |
# |    total_timesteps    | 33000      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6599       |
# |    policy_loss        | -46.6      |
# |    reward             | -1.8607585 |
# |    std                | 1          |
# |    value_loss         | 8.77       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 86        |
# |    iterations         | 6700      |
# |    time_elapsed       | 388       |
# |    total_timesteps    | 33500     |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6699      |
# |    policy_loss        | -1.09e+03 |
# |    reward             | -8.768982 |
# |    std                | 1         |
# |    value_loss         | 916       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 6800       |
# |    time_elapsed       | 394        |
# |    total_timesteps    | 34000      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6799       |
# |    policy_loss        | -403       |
# |    reward             | 0.51975477 |
# |    std                | 1          |
# |    value_loss         | 107        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 86          |
# |    iterations         | 6900        |
# |    time_elapsed       | 400         |
# |    total_timesteps    | 34500       |
# | train/                |             |
# |    entropy_loss       | -41.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6899        |
# |    policy_loss        | -119        |
# |    reward             | -0.71556073 |
# |    std                | 1           |
# |    value_loss         | 109         |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 86         |
# |    iterations         | 7000       |
# |    time_elapsed       | 406        |
# |    total_timesteps    | 35000      |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6999       |
# |    policy_loss        | 6.97       |
# |    reward             | 0.07734101 |
# |    std                | 1          |
# |    value_loss         | 0.193      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 86        |
# |    iterations         | 7100      |
# |    time_elapsed       | 412       |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | -6.05     |
# |    reward             | 1.7844425 |
# |    std                | 1         |
# |    value_loss         | 0.513     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 86        |
# |    iterations         | 7200      |
# |    time_elapsed       | 418       |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -343      |
# |    reward             | 2.7030456 |
# |    std                | 1         |
# |    value_loss         | 65.9      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 7300       |
# |    time_elapsed       | 424        |
# |    total_timesteps    | 36500      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7299       |
# |    policy_loss        | -445       |
# |    reward             | -1.2324498 |
# |    std                | 1          |
# |    value_loss         | 127        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 7400       |
# |    time_elapsed       | 430        |
# |    total_timesteps    | 37000      |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7399       |
# |    policy_loss        | 380        |
# |    reward             | -17.135262 |
# |    std                | 1          |
# |    value_loss         | 132        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 7500       |
# |    time_elapsed       | 436        |
# |    total_timesteps    | 37500      |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7499       |
# |    policy_loss        | 217        |
# |    reward             | -11.758028 |
# |    std                | 1          |
# |    value_loss         | 42         |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 85          |
# |    iterations         | 7600        |
# |    time_elapsed       | 442         |
# |    total_timesteps    | 38000       |
# | train/                |             |
# |    entropy_loss       | -41.1       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 7599        |
# |    policy_loss        | -87.6       |
# |    reward             | 0.032885257 |
# |    std                | 1           |
# |    value_loss         | 4.97        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 85        |
# |    iterations         | 7700      |
# |    time_elapsed       | 447       |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -41.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -42.8     |
# |    reward             | 2.4885812 |
# |    std                | 1         |
# |    value_loss         | 2.28      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 7800       |
# |    time_elapsed       | 453        |
# |    total_timesteps    | 39000      |
# | train/                |            |
# |    entropy_loss       | -41.1      |
# |    explained_variance | -2.38e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7799       |
# |    policy_loss        | -86.3      |
# |    reward             | -2.6571417 |
# |    std                | 1          |
# |    value_loss         | 9.24       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 85        |
# |    iterations         | 7900      |
# |    time_elapsed       | 459       |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | -0.000151 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7899      |
# |    policy_loss        | 335       |
# |    reward             | 8.218592  |
# |    std                | 1         |
# |    value_loss         | 113       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 8000       |
# |    time_elapsed       | 466        |
# |    total_timesteps    | 40000      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | 0.0108     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7999       |
# |    policy_loss        | -180       |
# |    reward             | 0.58800954 |
# |    std                | 1          |
# |    value_loss         | 25.8       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 85        |
# |    iterations         | 8100      |
# |    time_elapsed       | 472       |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -41.2     |
# |    explained_variance | 1.79e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8099      |
# |    policy_loss        | 259       |
# |    reward             | 1.3651996 |
# |    std                | 1         |
# |    value_loss         | 147       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 8200       |
# |    time_elapsed       | 477        |
# |    total_timesteps    | 41000      |
# | train/                |            |
# |    entropy_loss       | -41.2      |
# |    explained_variance | -0.000263  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8199       |
# |    policy_loss        | 94         |
# |    reward             | -0.5384578 |
# |    std                | 1          |
# |    value_loss         | 7.34       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 8300       |
# |    time_elapsed       | 483        |
# |    total_timesteps    | 41500      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8299       |
# |    policy_loss        | 84.1       |
# |    reward             | -1.9264724 |
# |    std                | 1.01       |
# |    value_loss         | 6.88       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 85        |
# |    iterations         | 8400      |
# |    time_elapsed       | 489       |
# |    total_timesteps    | 42000     |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8399      |
# |    policy_loss        | 150       |
# |    reward             | -6.429836 |
# |    std                | 1.01      |
# |    value_loss         | 19.9      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 85          |
# |    iterations         | 8500        |
# |    time_elapsed       | 495         |
# |    total_timesteps    | 42500       |
# | train/                |             |
# |    entropy_loss       | -41.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8499        |
# |    policy_loss        | -139        |
# |    reward             | -0.73073864 |
# |    std                | 1.01        |
# |    value_loss         | 14.4        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 8600       |
# |    time_elapsed       | 501        |
# |    total_timesteps    | 43000      |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8599       |
# |    policy_loss        | 207        |
# |    reward             | -16.898623 |
# |    std                | 1.01       |
# |    value_loss         | 47.9       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 85       |
# |    iterations         | 8700     |
# |    time_elapsed       | 507      |
# |    total_timesteps    | 43500    |
# | train/                |          |
# |    entropy_loss       | -41.3    |
# |    explained_variance | 2.32e-05 |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 8699     |
# |    policy_loss        | 16.6     |
# |    reward             | 1.095771 |
# |    std                | 1.01     |
# |    value_loss         | 1.45     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 85        |
# |    iterations         | 8800      |
# |    time_elapsed       | 512       |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0.0328    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | -68       |
# |    reward             | 0.8716334 |
# |    std                | 1.01      |
# |    value_loss         | 2.92      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 8900       |
# |    time_elapsed       | 518        |
# |    total_timesteps    | 44500      |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8899       |
# |    policy_loss        | -26.3      |
# |    reward             | 0.13365027 |
# |    std                | 1.01       |
# |    value_loss         | 2.09       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 85          |
# |    iterations         | 9000        |
# |    time_elapsed       | 524         |
# |    total_timesteps    | 45000       |
# | train/                |             |
# |    entropy_loss       | -41.5       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8999        |
# |    policy_loss        | 7.9         |
# |    reward             | 0.061435416 |
# |    std                | 1.01        |
# |    value_loss         | 6.97        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 85        |
# |    iterations         | 9100      |
# |    time_elapsed       | 530       |
# |    total_timesteps    | 45500     |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | -0.00365  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9099      |
# |    policy_loss        | 15.7      |
# |    reward             | 2.2866766 |
# |    std                | 1.02      |
# |    value_loss         | 6.09      |
# -------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 85            |
# |    iterations         | 9200          |
# |    time_elapsed       | 536           |
# |    total_timesteps    | 46000         |
# | train/                |               |
# |    entropy_loss       | -41.6         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 9199          |
# |    policy_loss        | -273          |
# |    reward             | -0.0070014545 |
# |    std                | 1.02          |
# |    value_loss         | 91.8          |
# -----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 85         |
# |    iterations         | 9300       |
# |    time_elapsed       | 542        |
# |    total_timesteps    | 46500      |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | -0.0327    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9299       |
# |    policy_loss        | -204       |
# |    reward             | 0.07887427 |
# |    std                | 1.01       |
# |    value_loss         | 29.3       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 85          |
# |    iterations         | 9400        |
# |    time_elapsed       | 547         |
# |    total_timesteps    | 47000       |
# | train/                |             |
# |    entropy_loss       | -41.6       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9399        |
# |    policy_loss        | 234         |
# |    reward             | -0.45618594 |
# |    std                | 1.02        |
# |    value_loss         | 33.7        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 85        |
# |    iterations         | 9500      |
# |    time_elapsed       | 553       |
# |    total_timesteps    | 47500     |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9499      |
# |    policy_loss        | 157       |
# |    reward             | 0.6259964 |
# |    std                | 1.02      |
# |    value_loss         | 18.6      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 85        |
# |    iterations         | 9600      |
# |    time_elapsed       | 559       |
# |    total_timesteps    | 48000     |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9599      |
# |    policy_loss        | -124      |
# |    reward             | 1.2416445 |
# |    std                | 1.02      |
# |    value_loss         | 13.5      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 85        |
# |    iterations         | 9700      |
# |    time_elapsed       | 565       |
# |    total_timesteps    | 48500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9699      |
# |    policy_loss        | 18        |
# |    reward             | 2.1162922 |
# |    std                | 1.02      |
# |    value_loss         | 3.82      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 85       |
# |    iterations         | 9800     |
# |    time_elapsed       | 571      |
# |    total_timesteps    | 49000    |
# | train/                |          |
# |    entropy_loss       | -41.7    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9799     |
# |    policy_loss        | -140     |
# |    reward             | 8.202153 |
# |    std                | 1.02     |
# |    value_loss         | 89.4     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 85          |
# |    iterations         | 9900        |
# |    time_elapsed       | 577         |
# |    total_timesteps    | 49500       |
# | train/                |             |
# |    entropy_loss       | -41.7       |
# |    explained_variance | 5.96e-08    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9899        |
# |    policy_loss        | -11.6       |
# |    reward             | -0.64417005 |
# |    std                | 1.02        |
# |    value_loss         | 0.478       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 85          |
# |    iterations         | 10000       |
# |    time_elapsed       | 583         |
# |    total_timesteps    | 50000       |
# | train/                |             |
# |    entropy_loss       | -41.9       |
# |    explained_variance | -0.0549     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9999        |
# |    policy_loss        | 26          |
# |    reward             | -0.55169517 |
# |    std                | 1.03        |
# |    value_loss         | 1.77        |
# ---------------------------------------

# %% [markdown]
# ### Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
model_ddpg = agent.get_model("ddpg")
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000)
# Out:
# day: 2892, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 4817633.79
# total_reward: 3817633.79
# total_cost: 6109.81
# total_trades: 54806
# Sharpe: 0.927
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 29        |
# |    time_elapsed    | 394       |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | -41.3     |
# |    critic_loss     | 101       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8679      |
# |    reward          | 1.4751048 |
# ----------------------------------

# %% [markdown]
# ### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cpu device

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=50000)
# Out:
# -----------------------------------
# | time/              |            |
# |    fps             | 96         |
# |    iterations      | 1          |
# |    time_elapsed    | 21         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.30886105 |
# -----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 94          |
# |    iterations           | 2           |
# |    time_elapsed         | 43          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015826263 |
# |    clip_fraction        | 0.205       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0394     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.77        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0202     |
# |    reward               | 0.71778566  |
# |    std                  | 1           |
# |    value_loss           | 13.9        |
# -----------------------------------------
# day: 2892, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 3441481.08
# total_reward: 2441481.08
# total_cost: 353770.58
# total_trades: 80749
# Sharpe: 0.741
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 94         |
# |    iterations           | 3          |
# |    time_elapsed         | 65         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01884521 |
# |    clip_fraction        | 0.247      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.2      |
# |    explained_variance   | -0.00243   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 30.3       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0181    |
# |    reward               | -1.3031422 |
# |    std                  | 1          |
# |    value_loss           | 67.9       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 92         |
# |    iterations           | 4          |
# |    time_elapsed         | 88         |
# |    total_timesteps      | 8192       |
# | train/                  |            |
# |    approx_kl            | 0.01728037 |
# |    clip_fraction        | 0.193      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.3      |
# |    explained_variance   | -0.00394   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 24.1       |
# |    n_updates            | 30         |
# |    policy_gradient_loss | -0.0192    |
# |    reward               | 2.4198737  |
# |    std                  | 1          |
# |    value_loss           | 43         |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 5           |
# |    time_elapsed         | 110         |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.020282106 |
# |    clip_fraction        | 0.24        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.00879    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 6.86        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0247     |
# |    reward               | 2.4776623   |
# |    std                  | 1.01        |
# |    value_loss           | 15.8        |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 92         |
# |    iterations           | 6          |
# |    time_elapsed         | 132        |
# |    total_timesteps      | 12288      |
# | train/                  |            |
# |    approx_kl            | 0.01991706 |
# |    clip_fraction        | 0.248      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.3      |
# |    explained_variance   | 0.000112   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 30.8       |
# |    n_updates            | 50         |
# |    policy_gradient_loss | -0.0173    |
# |    reward               | 1.5963827  |
# |    std                  | 1.01       |
# |    value_loss           | 33.7       |
# ----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 92         |
# |    iterations           | 7          |
# |    time_elapsed         | 154        |
# |    total_timesteps      | 14336      |
# | train/                  |            |
# |    approx_kl            | 0.02312897 |
# |    clip_fraction        | 0.197      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.4      |
# |    explained_variance   | -0.00486   |
# |    learning_rate        | 0.00025    |
# |    loss                 | 16.6       |
# |    n_updates            | 60         |
# |    policy_gradient_loss | -0.0161    |
# |    reward               | 1.1714903  |
# |    std                  | 1.01       |
# |    value_loss           | 38.8       |
# ----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 92           |
# |    iterations           | 8            |
# |    time_elapsed         | 177          |
# |    total_timesteps      | 16384        |
# | train/                  |              |
# |    approx_kl            | 0.018019047  |
# |    clip_fraction        | 0.156        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.4        |
# |    explained_variance   | 0.0234       |
# |    learning_rate        | 0.00025      |
# |    loss                 | 3.73         |
# |    n_updates            | 70           |
# |    policy_gradient_loss | -0.0139      |
# |    reward               | 0.0071891127 |
# |    std                  | 1.01         |
# |    value_loss           | 11.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 92          |
# |    iterations           | 9           |
# |    time_elapsed         | 200         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.022401342 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | 0.00658     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 14          |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0161     |
# |    reward               | -0.16097178 |
# |    std                  | 1.01        |
# |    value_loss           | 25.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 10          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.024039125 |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | -0.000831   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 20.2        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0172     |
# |    reward               | 0.48095208  |
# |    std                  | 1.01        |
# |    value_loss           | 43.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 91          |
# |    iterations           | 11          |
# |    time_elapsed         | 247         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.021172967 |
# |    clip_fraction        | 0.232       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | -8.09e-05   |
# |    learning_rate        | 0.00025     |
# |    loss                 | 23.7        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0184     |
# |    reward               | 2.8099735   |
# |    std                  | 1.02        |
# |    value_loss           | 53.6        |
# -----------------------------------------
# --------------------------------------------
# | time/                   |                |
# |    fps                  | 90             |
# |    iterations           | 12             |
# |    time_elapsed         | 270            |
# |    total_timesteps      | 24576          |
# | train/                  |                |
# |    approx_kl            | 0.016935166    |
# |    clip_fraction        | 0.174          |
# |    clip_range           | 0.2            |
# |    entropy_loss         | -41.6          |
# |    explained_variance   | -0.0446        |
# |    learning_rate        | 0.00025        |
# |    loss                 | 9.64           |
# |    n_updates            | 110            |
# |    policy_gradient_loss | -0.0148        |
# |    reward               | -0.00097534724 |
# |    std                  | 1.02           |
# |    value_loss           | 23             |
# --------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 13          |
# |    time_elapsed         | 293         |
# |    total_timesteps      | 26624       |
# | train/                  |             |
# |    approx_kl            | 0.021523612 |
# |    clip_fraction        | 0.202       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | -0.0117     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 31.9        |
# |    n_updates            | 120         |
# |    policy_gradient_loss | -0.0181     |
# |    reward               | -0.15636031 |
# |    std                  | 1.02        |
# |    value_loss           | 84.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 14          |
# |    time_elapsed         | 316         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.021340657 |
# |    clip_fraction        | 0.237       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | -0.00332    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 20.1        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0115     |
# |    reward               | 0.24301007  |
# |    std                  | 1.02        |
# |    value_loss           | 58.2        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 15          |
# |    time_elapsed         | 338         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.018273095 |
# |    clip_fraction        | 0.183       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0.0126      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 21.1        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0128     |
# |    reward               | 4.9345737   |
# |    std                  | 1.02        |
# |    value_loss           | 40.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 16          |
# |    time_elapsed         | 361         |
# |    total_timesteps      | 32768       |
# | train/                  |             |
# |    approx_kl            | 0.018592542 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | -0.00808    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 20.1        |
# |    n_updates            | 150         |
# |    policy_gradient_loss | -0.0226     |
# |    reward               | -0.36810476 |
# |    std                  | 1.02        |
# |    value_loss           | 59.5        |
# -----------------------------------------
# day: 2892, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 4017317.43
# total_reward: 3017317.43
# total_cost: 321478.58
# total_trades: 77582
# Sharpe: 0.720
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 17          |
# |    time_elapsed         | 385         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.022970995 |
# |    clip_fraction        | 0.235       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | -0.00651    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 49.3        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0122     |
# |    reward               | 0.37088677  |
# |    std                  | 1.02        |
# |    value_loss           | 116         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 90          |
# |    iterations           | 18          |
# |    time_elapsed         | 408         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.014596333 |
# |    clip_fraction        | 0.145       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0.024       |
# |    learning_rate        | 0.00025     |
# |    loss                 | 33.2        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.00831    |
# |    reward               | -0.32497942 |
# |    std                  | 1.02        |
# |    value_loss           | 78.7        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 19          |
# |    time_elapsed         | 432         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.026338592 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | -0.008      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 5.47        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.02       |
# |    reward               | -0.13824873 |
# |    std                  | 1.03        |
# |    value_loss           | 11.6        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 89           |
# |    iterations           | 20           |
# |    time_elapsed         | 455          |
# |    total_timesteps      | 40960        |
# | train/                  |              |
# |    approx_kl            | 0.024078036  |
# |    clip_fraction        | 0.255        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.9        |
# |    explained_variance   | 0.00203      |
# |    learning_rate        | 0.00025      |
# |    loss                 | 28.4         |
# |    n_updates            | 190          |
# |    policy_gradient_loss | -0.0176      |
# |    reward               | -0.077695966 |
# |    std                  | 1.03         |
# |    value_loss           | 52.8         |
# ------------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 21          |
# |    time_elapsed         | 478         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.031172728 |
# |    clip_fraction        | 0.329       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | 0.00693     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 27.1        |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.00453    |
# |    reward               | -8.163727   |
# |    std                  | 1.03        |
# |    value_loss           | 76.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 22          |
# |    time_elapsed         | 500         |
# |    total_timesteps      | 45056       |
# | train/                  |             |
# |    approx_kl            | 0.018378198 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | -0.022      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 16.3        |
# |    n_updates            | 210         |
# |    policy_gradient_loss | -0.0145     |
# |    reward               | 3.1000922   |
# |    std                  | 1.03        |
# |    value_loss           | 25.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 23          |
# |    time_elapsed         | 523         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.017813593 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | 0.00422     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 15.6        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.011      |
# |    reward               | 0.88160783  |
# |    std                  | 1.03        |
# |    value_loss           | 61          |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 24          |
# |    time_elapsed         | 546         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.025783975 |
# |    clip_fraction        | 0.135       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | 0.00921     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 30.7        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.0105     |
# |    reward               | 5.9369354   |
# |    std                  | 1.03        |
# |    value_loss           | 81.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 89          |
# |    iterations           | 25          |
# |    time_elapsed         | 570         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.038430214 |
# |    clip_fraction        | 0.323       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | 0.00663     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 35.5        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0147     |
# |    reward               | -0.13486888 |
# |    std                  | 1.04        |
# |    value_loss           | 73.8        |
# -----------------------------------------

# %% [markdown]
# ### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cpu device

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=30000)
# Out:
# day: 2892, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 3941856.98
# total_reward: 2941856.98
# total_cost: 999.00
# total_trades: 49164
# Sharpe: 0.718
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 31        |
# |    time_elapsed    | 370       |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | 55.7      |
# |    critic_loss     | 3.7e+03   |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8679      |
# |    reward          | 1.2822058 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 27        |
# |    time_elapsed    | 844       |
# |    total_timesteps | 23144     |
# | train/             |           |
# |    actor_loss      | 21.4      |
# |    critic_loss     | 932       |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20251     |
# |    reward          | 1.2822058 |
# ----------------------------------

# %% [markdown]
# ### Agent 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 1000000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cpu device

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=60000)
# Out:
# day: 2892, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 5483466.70
# total_reward: 4483466.70
# total_cost: 162323.27
# total_trades: 50926
# Sharpe: 0.929
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 24        |
# |    time_elapsed    | 467       |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | 246       |
# |    critic_loss     | 639       |
# |    ent_coef        | 0.115     |
# |    ent_coef_loss   | -96.9     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 11471     |
# |    reward          | 7.5468073 |
# ----------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 24       |
# |    time_elapsed    | 945      |
# |    total_timesteps | 23144    |
# | train/             |          |
# |    actor_loss      | 97.3     |
# |    critic_loss     | 61.2     |
# |    ent_coef        | 0.0362   |
# |    ent_coef_loss   | -144     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 23043    |
# |    reward          | 10.76891 |
# ---------------------------------
# day: 2892, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 8867966.41
# total_reward: 7867966.41
# total_cost: 8154.17
# total_trades: 47568
# Sharpe: 1.037
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 24        |
# |    time_elapsed    | 1423      |
# |    total_timesteps | 34716     |
# | train/             |           |
# |    actor_loss      | 34.3      |
# |    critic_loss     | 64.6      |
# |    ent_coef        | 0.0117    |
# |    ent_coef_loss   | -142      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 34615     |
# |    reward          | 13.044359 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 24        |
# |    time_elapsed    | 1904      |
# |    total_timesteps | 46288     |
# | train/             |           |
# |    actor_loss      | 17.4      |
# |    critic_loss     | 22.7      |
# |    ent_coef        | 0.00413   |
# |    ent_coef_loss   | -49.7     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 46187     |
# |    reward          | 10.832052 |
# ----------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 24       |
# |    time_elapsed    | 2390     |
# |    total_timesteps | 57860    |
# | train/             |          |
# |    actor_loss      | 11.2     |
# |    critic_loss     | 11.8     |
# |    ent_coef        | 0.00281  |
# |    ent_coef_loss   | -9.17    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 57759    |
# |    reward          | 8.068603 |
# ---------------------------------

# %% [markdown]
# ## In-sample Performance
#
# Assume that the initial capital is $1,000,000.

# %% [markdown]
# ### Set turbulence threshold
# Set the turbulence threshold to be greater than the maximum of insample turbulence data. If current turbulence index is greater than the threshold, then we assume that the current market is volatile

# %%
data_risk_indicator = processed_full[(processed_full.date<TRAIN_END_DATE) & (processed_full.date>=TRAIN_START_DATE)]
insample_risk_indicator = data_risk_indicator.drop_duplicates(subset=['date'])

# %%
insample_risk_indicator.vix.describe()
# Out:
# count    2893.000000
# mean       18.824245
# std         8.489311
# min         9.140000
# 25%        13.330000
# 50%        16.139999
# 75%        21.309999
# max        82.690002
# Name: vix, dtype: float64

# %%
insample_risk_indicator.vix.quantile(0.996)
# Out:
# 57.40400183105453

# %%
insample_risk_indicator.turbulence.describe()
# Out:
# count    2893.000000
# mean       34.567957
# std        43.790802
# min         0.000000
# 25%        14.962679
# 50%        24.124183
# 75%        39.162269
# max       652.502726
# Name: turbulence, dtype: float64

# %%
insample_risk_indicator.turbulence.quantile(0.996)
# Out:
# 276.4542576252012

# %% [markdown]
# ### Trading (Out-of-sample Performance)
#
# We update periodically in order to take full advantage of the data, e.g., retrain quarterly, monthly or weekly. We also tune the parameters along the way, in this notebook we use the in-sample data from 2009-01 to 2020-07 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
trade.head()
# Out:
#          date   tic        open        high         low       close  \
# 0  2020-07-01  AAPL   91.279999   91.839996   90.977501   89.904617
# 0  2020-07-01  AMGN  235.520004  256.230011  232.580002  240.153961
# 0  2020-07-01   AXP   95.250000   96.959999   93.639999   92.086380
# 0  2020-07-01    BA  185.880005  190.610001  180.039993  180.320007
# 0  2020-07-01   CAT  129.380005  129.399994  125.879997  120.651634
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  110737200.0  2.0  3.014606   92.699321   80.179950  62.807170  107.491949
# 0    6575800.0  2.0  3.636392  232.397419  200.212942  61.279641  271.386208
# 0    3301000.0  2.0 -0.389162  110.423944   87.759333  48.504818  -66.328704
# 0   49036700.0  2.0  5.443193  220.721139  160.932863  50.925771   24.220608
# 0    2807800.0  2.0  1.272630  130.624272  113.353134  52.865419   35.597297
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  29.730532     83.933767     77.717542  28.620001   53.068073
# 0  46.806139    214.858661    215.931666  28.620001   53.068073
# 0   3.142448     97.244637     90.695525  28.620001   53.068073
# 0  15.932920    176.472335    155.614168  28.620001   53.068073
# 0  14.457404    119.412837    113.646674  28.620001   53.068073

# %%
df_account_value, df_actions = DRLAgent.DRL_prediction(
    model=trained_sac, 
    environment = e_trade_gym)
# Out:
# hit end!

# %%
df_account_value.shape
# Out:
# (336, 2)

# %%
df_account_value.tail()
# Out:
#            date  account_value
# 331  2021-10-22   1.400329e+06
# 332  2021-10-25   1.399896e+06
# 333  2021-10-26   1.404413e+06
# 334  2021-10-27   1.402845e+06
# 335  2021-10-28   1.417062e+06

# %%
df_actions.head()
# Out:
#             AAPL  AMGN  AXP  BA  CAT  CRM  CSCO  CVX  DIS  GS  ...  MRK  MSFT  \
# date                                                           ...
# 2020-07-01    86    66    0  18    0   19    89   32    5  87  ...    0     0
# 2020-07-02    88    74    0  36    0   35    90    9   26  88  ...    0     0
# 2020-07-06    90    80    0  53    0   51    92  -16   45  88  ...    0     0
# 2020-07-07    92    85    0  67    0   64    93  -25   61  89  ...    0     0
# 2020-07-08    94    90    0  79    0   76    94    0   75  90  ...    0    29
#
#             NKE  PG  TRV  UNH   V  VZ  WBA  WMT
# date
# 2020-07-01    0   0    0   93  93   0    0    0
# 2020-07-02    0   0    0   93  94   0    0    0
# 2020-07-06    0   0    0   94  94   0    0    0
# 2020-07-07    0   0    0   95  95   0    0    0
# 2020-07-08    0   0    0   96  96   0    0    0
#
# [5 rows x 29 columns]

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtesting Results
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
perf_stats_all.to_csv("./"+RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return          0.298798
# Cumulative returns     0.417062
# Annual volatility      0.170675
# Sharpe ratio           1.622374
# Calmar ratio           2.599563
# Stability              0.917383
# Max drawdown          -0.114942
# Omega ratio            1.313801
# Sortino ratio          2.377919
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.035998
# Daily value at risk   -0.020404
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (335, 8)
# Annual return          0.273520
# Cumulative returns     0.379084
# Annual volatility      0.139248
# Sharpe ratio           1.811893
# Calmar ratio           3.062662
# Stability              0.918651
# Max drawdown          -0.089308
# Omega ratio            1.351851
# Sortino ratio          2.684720
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.051856
# Daily value at risk   -0.016542
# dtype: float64

# %%
df_account_value.loc[0,'date']
# Out:
# '2020-07-01'

# %%
df_account_value.loc[len(df_account_value)-1,'date']
# Out:
# '2021-10-28'

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
             baseline_ticker = '^DJI', 
             baseline_start = df_account_value.loc[0,'date'],
             baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (335, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-07-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-28</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>16</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>29.88%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>41.706%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>17.067%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.62</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>2.60</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.92</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-11.494%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.31</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>2.38</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.04</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-2.04%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.00</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>1.09</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>11.49</td>
#       <td>2020-09-02</td>
#       <td>2020-10-30</td>
#       <td>2020-11-11</td>
#       <td>51</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6.69</td>
#       <td>2021-09-02</td>
#       <td>2021-10-04</td>
#       <td>NaT</td>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>4.95</td>
#       <td>2021-04-16</td>
#       <td>2021-05-12</td>
#       <td>2021-06-24</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.44</td>
#       <td>2020-07-15</td>
#       <td>2020-07-30</td>
#       <td>2020-08-06</td>
#       <td>17</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>4.44</td>
#       <td>2021-01-25</td>
#       <td>2021-01-29</td>
#       <td>2021-02-09</td>
#       <td>12</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.11%</td>
#       <td>-4.00%</td>
#       <td>3.73%</td>
#     </tr>
#   </tbody>
# </table>
