# %% [markdown]
# # Stock NeurIPS2018 Part 2. Train
# This series is a reproduction of *the process in the paper Practical Deep Reinforcement Learning Approach for Stock Trading*.
#
# This is the second part of the NeurIPS2018 series, introducing how to use FinRL to make data into the gym form environment, and train DRL agents on it.
#
# Other demos can be found at the repo of [FinRL-Tutorials]((https://github.com/AI4Finance-Foundation/FinRL-Tutorials)).

# %% [markdown]
# # Part 1. Install Packages

# %%
## install finrl library
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %%
import pandas as pd
from stable_baselines3.common.logger import configure

from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.config import INDICATORS, TRAINED_MODEL_DIR, RESULTS_DIR
from finrl.main import check_and_make_directories
from finrl.meta.env_stock_trading.env_stocktrading import StockTradingEnv

check_and_make_directories([TRAINED_MODEL_DIR])

# %% [markdown]
# # Part 2. Build A Market Environment in OpenAI Gym-style

# %% [markdown]
# ![rl_diagram_transparent_bg.png](data:image/png;base64,...)

# %% [markdown]
# The core element in reinforcement learning are **agent** and **environment**. You can understand RL as the following process:
#
# The agent is active in a world, which is the environment. It observe its current condition as a **state**, and is allowed to do certain **actions**. After the agent execute an action, it will arrive at a new state. At the same time, the environment will have feedback to the agent called **reward**, a numerical signal that tells how good or bad the new state is. As the figure above, agent and environment will keep doing this interaction.
#
# The goal of agent is to get as much cumulative reward as possible. Reinforcement learning is the method that agent learns to improve its behavior and achieve that goal.

# %% [markdown]
# To achieve this in Python, we follow the OpenAI gym style to build the stock data into environment.
#
# state-action-reward are specified as follows:
#
# * **State s**: The state space represents an agent's perception of the market environment. Just like a human trader analyzing various information, here our agent passively observes the price data and technical indicators based on the past data. It will learn by interacting with the market environment (usually by replaying historical data).
#
# * **Action a**: The action space includes allowed actions that an agent can take at each state. For example, a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying. When an action operates multiple shares, a ∈{−k, ..., −1, 0, 1, ..., k}, e.g.. "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * **Reward function r(s, a, s′)**: Reward is an incentive for an agent to learn a better policy. For example, it can be the change of the portfolio value when taking a at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio values at state s′ and s, respectively
#
#
# **Market environment**: 30 constituent stocks of Dow Jones Industrial Average (DJIA) index. Accessed at the starting date of the testing period.

# %% [markdown]
# ## Read data
#
# We first read the .csv file of our training data into dataframe.

# %%
train.columns[0]
# Out:
# 'Unnamed: 0'

# %%
train = pd.read_csv('train_data.csv')
# If you are not using the data generated from part 1 of this tutorial, make sure 
# it has the columns and index in the form that could be make into the environment. 
# Then you can comment and skip the following two lines.
train = train.set_index(train.columns[0])
train.index.names = ['']
train
# Out:
#             date   tic       close        high         low        open  \
#
# 0     2009-01-02  AAPL    2.724325    2.733032    2.556513    2.578127
# 0     2009-01-02  AMGN   40.463203   40.524938   39.612645   40.188829
# 0     2009-01-02  AMZN    2.718000    2.726500    2.553500    2.567500
# 0     2009-01-02   AXP   14.854059   15.000064   14.139404   14.270040
# 0     2009-01-02    BA   33.941101   34.173627   32.088404   32.103406
# ...          ...   ...         ...         ...         ...         ...
# 2892  2020-06-30   TRV  102.140358  102.534406  100.393982  100.725347
# 2892  2020-06-30   UNH  271.594116  272.975337  264.881374  265.719318
# 2892  2020-06-30     V  186.097656  186.656423  183.197864  184.479171
# 2892  2020-06-30    VZ   39.978680   40.094707   39.420298   39.826392
# 2892  2020-06-30   WMT   37.091057   37.199436   36.707078   36.917649
#
#            volume  day      macd     boll_ub     boll_lb      rsi_30  \
#
# 0     746015200.0  4.0  0.000000    2.944416    2.619211  100.000000
# 0       6547900.0  4.0  0.000000    2.944416    2.619211  100.000000
# 0     145928000.0  4.0  0.000000    2.944416    2.619211  100.000000
# 0      10955700.0  4.0  0.000000    2.944416    2.619211  100.000000
# 0       7010200.0  4.0  0.000000    2.944416    2.619211  100.000000
# ...           ...  ...       ...         ...         ...         ...
# 2892    1464500.0  1.0  1.686138  112.348430   96.156778   52.925504
# 2892    2932900.0  1.0 -0.018384  286.835072  255.997832   52.413050
# 2892    9040100.0  1.0  1.023277  193.916000  180.540350   53.021039
# 2892   17414800.0  1.0 -0.346889   42.789332   38.671291   48.097065
# 2892   20509200.0  1.0 -0.283183   38.161733   36.256963   48.159672
#
#          cci_30       dx_30  close_30_sma  close_60_sma        vix  turbulence
#
# 0     66.666667  100.000000      2.724325      2.724325  39.189999    0.000000
# 0     66.666667  100.000000     40.463203     40.463203  39.189999    0.000000
# 0     66.666667  100.000000      2.718000      2.718000  39.189999    0.000000
# 0     66.666667  100.000000     14.854059     14.854059  39.189999    0.000000
# 0     66.666667  100.000000     33.941101     33.941101  39.189999    0.000000
# ...         ...         ...           ...           ...        ...         ...
# 2892  20.975645    1.225720    100.134005     94.375528  30.430000   14.149375
# 2892 -20.026227    0.598698    271.824281    265.199754  30.430000   14.149375
# 2892 -51.427758    2.103860    186.827245    177.258451  30.430000   14.149375
# 2892 -50.670924    8.321286     40.482909     40.842054  30.430000   14.149375
# 2892 -69.838659    3.558082     37.623156     38.241431  30.430000   14.149375
#
# [86790 rows x 18 columns]

# %% [markdown]
# ## Construct the environment

# %% [markdown]
# Calculate and specify the parameters we need for constructing the environment.

# %%
train.head()
# Out:
#          date   tic      close       high        low       open       volume  \
#
# 0  2009-01-02  AAPL   2.724325   2.733032   2.556513   2.578127  746015200.0
# 0  2009-01-02  AMGN  40.463203  40.524938  39.612645  40.188829    6547900.0
# 0  2009-01-02  AMZN   2.718000   2.726500   2.553500   2.567500  145928000.0
# 0  2009-01-02   AXP  14.854059  15.000064  14.139404  14.270040   10955700.0
# 0  2009-01-02    BA  33.941101  34.173627  32.088404  32.103406    7010200.0
#
#    day  macd   boll_ub   boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
#
# 0  4.0   0.0  2.944416  2.619211   100.0  66.666667  100.0      2.724325
# 0  4.0   0.0  2.944416  2.619211   100.0  66.666667  100.0     40.463203
# 0  4.0   0.0  2.944416  2.619211   100.0  66.666667  100.0      2.718000
# 0  4.0   0.0  2.944416  2.619211   100.0  66.666667  100.0     14.854059
# 0  4.0   0.0  2.944416  2.619211   100.0  66.666667  100.0     33.941101
#
#    close_60_sma        vix  turbulence
#
# 0      2.724325  39.189999         0.0
# 0     40.463203  39.189999         0.0
# 0      2.718000  39.189999         0.0
# 0     14.854059  39.189999         0.0
# 0     33.941101  39.189999         0.0

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 30, State Space: 301

# %%
buy_cost_list = sell_cost_list = [0.001] * stock_dimension
num_stock_shares = [0] * stock_dimension

env_kwargs = {
    "hmax": 100,
    "initial_amount": 1000000,
    "num_stock_shares": num_stock_shares,
    "buy_cost_pct": buy_cost_list,
    "sell_cost_pct": sell_cost_list,
    "state_space": state_space,
    "stock_dim": stock_dimension,
    "tech_indicator_list": INDICATORS,
    "action_space": stock_dimension,
    "reward_scaling": 1e-4
}


e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %% [markdown]
# ## Environment for training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# # Part 3: Train DRL Agents
# * Here, the DRL algorithms are from **[Stable Baselines 3](https://stable-baselines3.readthedocs.io/en/master/)**. It's a library that implemented popular DRL algorithms using pytorch, succeeding to its old version: Stable Baselines.
# * Users are also encouraged to try **[ElegantRL](https://github.com/AI4Finance-Foundation/ElegantRL)** and **[Ray RLlib](https://github.com/ray-project/ray)**.

# %%
agent = DRLAgent(env = env_train)

# Set the corresponding values to 'True' for the algorithms that you want to use
if_using_a2c = True
if_using_ddpg = True
if_using_ppo = True
if_using_td3 = True
if_using_sac = True

# %% [markdown]
# ## Agent Training: 5 algorithms (A2C, DDPG, PPO, TD3, SAC)

# %% [markdown]
# ### Agent 1: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")

if if_using_a2c:
  # set up logger
  tmp_path = RESULTS_DIR + '/a2c'
  new_logger_a2c = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_a2c.set_logger(new_logger_a2c)
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cpu device
# Logging to results/a2c

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                             tb_log_name='a2c',
                             total_timesteps=50000) if if_using_a2c else None
# Out:
# ---------------------------------------
# | time/                 |             |
# |    fps                | 210         |
# |    iterations         | 100         |
# |    time_elapsed       | 2           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -39.8       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | -122        |
# |    reward             | -0.17196977 |
# |    reward_max         | 0.73133135  |
# |    reward_mean        | 0.024463132 |
# |    reward_min         | -0.75204647 |
# |    std                | 1           |
# |    value_loss         | 11.9        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 211        |
# |    iterations         | 200        |
# |    time_elapsed       | 4          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -39.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | -46.4      |
# |    reward             | -1.3898851 |
# |    reward_max         | 2.5768158  |
# |    reward_mean        | 0.51089776 |
# |    reward_min         | -2.0573418 |
# |    std                | 1.01       |
# |    value_loss         | 3.01       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 300        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 1500       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | -0.201     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 299        |
# |    policy_loss        | -232       |
# |    reward             | 6.824099   |
# |    reward_max         | 6.824099   |
# |    reward_mean        | 0.3552628  |
# |    reward_min         | -3.7637582 |
# |    std                | 1          |
# |    value_loss         | 32.2       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 212         |
# |    iterations         | 400         |
# |    time_elapsed       | 9           |
# |    total_timesteps    | 2000        |
# | train/                |             |
# |    entropy_loss       | -39.8       |
# |    explained_variance | 0.00274     |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 399         |
# |    policy_loss        | -32.7       |
# |    reward             | -0.12307093 |
# |    reward_max         | 6.1454124   |
# |    reward_mean        | 1.4415286   |
# |    reward_min         | -0.733101   |
# |    std                | 1           |
# |    value_loss         | 28.5        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 500        |
# |    time_elapsed       | 11         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 1.36e+03   |
# |    reward             | -20.475613 |
# |    reward_max         | 12.268119  |
# |    reward_mean        | -6.609636  |
# |    reward_min         | -21.190979 |
# |    std                | 1          |
# |    value_loss         | 1.6e+03    |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 212         |
# |    iterations         | 600         |
# |    time_elapsed       | 14          |
# |    total_timesteps    | 3000        |
# | train/                |             |
# |    entropy_loss       | -39.8       |
# |    explained_variance | -0.358      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 599         |
# |    policy_loss        | 127         |
# |    reward             | -1.0136317  |
# |    reward_max         | 1.7358392   |
# |    reward_mean        | 0.030921802 |
# |    reward_min         | -1.0136317  |
# |    std                | 1           |
# |    value_loss         | 14.1        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 700        |
# |    time_elapsed       | 16         |
# |    total_timesteps    | 3500       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | -0.131     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 699        |
# |    policy_loss        | -145       |
# |    reward             | -2.491889  |
# |    reward_max         | 1.3943051  |
# |    reward_mean        | -0.1422259 |
# |    reward_min         | -2.491889  |
# |    std                | 1          |
# |    value_loss         | 13.1       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 800        |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 4000       |
# | train/                |            |
# |    entropy_loss       | -39.7      |
# |    explained_variance | -0.11      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 799        |
# |    policy_loss        | 59.9       |
# |    reward             | -2.810285  |
# |    reward_max         | 3.5432122  |
# |    reward_mean        | -0.5724525 |
# |    reward_min         | -2.810285  |
# |    std                | 1          |
# |    value_loss         | 2.85       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 900        |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 4500       |
# | train/                |            |
# |    entropy_loss       | -39.7      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 899        |
# |    policy_loss        | 301        |
# |    reward             | -2.3684213 |
# |    reward_max         | 4.717784   |
# |    reward_mean        | 0.3313706  |
# |    reward_min         | -2.749857  |
# |    std                | 0.998      |
# |    value_loss         | 71.9       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 1000       |
# |    time_elapsed       | 23         |
# |    total_timesteps    | 5000       |
# | train/                |            |
# |    entropy_loss       | -39.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 999        |
# |    policy_loss        | -20.9      |
# |    reward             | 1.1612239  |
# |    reward_max         | 1.1612239  |
# |    reward_mean        | -2.1339645 |
# |    reward_min         | -8.274199  |
# |    std                | 0.998      |
# |    value_loss         | 4.88       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 1100       |
# |    time_elapsed       | 25         |
# |    total_timesteps    | 5500       |
# | train/                |            |
# |    entropy_loss       | -39.6      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1099       |
# |    policy_loss        | 460        |
# |    reward             | -9.321192  |
# |    reward_max         | 9.32902    |
# |    reward_mean        | -0.9595052 |
# |    reward_min         | -9.321192  |
# |    std                | 0.997      |
# |    value_loss         | 230        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 1200       |
# |    time_elapsed       | 28         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -39.7      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -108       |
# |    reward             | 0.23488215 |
# |    reward_max         | 2.8133888  |
# |    reward_mean        | 1.0443282  |
# |    reward_min         | 0.23488215 |
# |    std                | 0.998      |
# |    value_loss         | 8.29       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 213        |
# |    iterations         | 1300       |
# |    time_elapsed       | 30         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -39.7      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | 77.4       |
# |    reward             | -4.496841  |
# |    reward_max         | 2.875926   |
# |    reward_mean        | -0.8207246 |
# |    reward_min         | -4.496841  |
# |    std                | 0.998      |
# |    value_loss         | 11.1       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 213         |
# |    iterations         | 1400        |
# |    time_elapsed       | 32          |
# |    total_timesteps    | 7000        |
# | train/                |             |
# |    entropy_loss       | -39.7       |
# |    explained_variance | 0.000825    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1399        |
# |    policy_loss        | -159        |
# |    reward             | 2.1880684   |
# |    reward_max         | 2.1880684   |
# |    reward_mean        | 0.087859735 |
# |    reward_min         | -2.6441088  |
# |    std                | 1           |
# |    value_loss         | 42          |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 213        |
# |    iterations         | 1500       |
# |    time_elapsed       | 35         |
# |    total_timesteps    | 7500       |
# | train/                |            |
# |    entropy_loss       | -39.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1499       |
# |    policy_loss        | -106       |
# |    reward             | 9.905907   |
# |    reward_max         | 9.905907   |
# |    reward_mean        | 0.15462847 |
# |    reward_min         | -4.472451  |
# |    std                | 1          |
# |    value_loss         | 21.3       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 212       |
# |    iterations         | 1600      |
# |    time_elapsed       | 37        |
# |    total_timesteps    | 8000      |
# | train/                |           |
# |    entropy_loss       | -39.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1599      |
# |    policy_loss        | -38.6     |
# |    reward             | 2.5313327 |
# |    reward_max         | 20.979277 |
# |    reward_mean        | 3.762871  |
# |    reward_min         | -4.428367 |
# |    std                | 1         |
# |    value_loss         | 8.27      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 1700       |
# |    time_elapsed       | 39         |
# |    total_timesteps    | 8500       |
# | train/                |            |
# |    entropy_loss       | -39.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1699       |
# |    policy_loss        | 128        |
# |    reward             | 26.85874   |
# |    reward_max         | 26.85874   |
# |    reward_mean        | 8.2268505  |
# |    reward_min         | -0.7670226 |
# |    std                | 1          |
# |    value_loss         | 65         |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 1800       |
# |    time_elapsed       | 42         |
# |    total_timesteps    | 9000       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | -2.38e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1799       |
# |    policy_loss        | -27.9      |
# |    reward             | 1.4038812  |
# |    reward_max         | 1.4038812  |
# |    reward_mean        | 0.72574645 |
# |    reward_min         | 0.21261933 |
# |    std                | 1          |
# |    value_loss         | 0.77       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 1900       |
# |    time_elapsed       | 44         |
# |    total_timesteps    | 9500       |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1899       |
# |    policy_loss        | 137        |
# |    reward             | 0.9349257  |
# |    reward_max         | 1.3911427  |
# |    reward_mean        | 0.11960177 |
# |    reward_min         | -2.0890872 |
# |    std                | 1          |
# |    value_loss         | 13.4       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 211         |
# |    iterations         | 2000        |
# |    time_elapsed       | 47          |
# |    total_timesteps    | 10000       |
# | train/                |             |
# |    entropy_loss       | -39.7       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 1999        |
# |    policy_loss        | -94.1       |
# |    reward             | 0.81860566  |
# |    reward_max         | 1.8139998   |
# |    reward_mean        | 1.0977011   |
# |    reward_min         | -0.21300365 |
# |    std                | 1           |
# |    value_loss         | 6.02        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 211        |
# |    iterations         | 2100       |
# |    time_elapsed       | 49         |
# |    total_timesteps    | 10500      |
# | train/                |            |
# |    entropy_loss       | -39.7      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2099       |
# |    policy_loss        | 137        |
# |    reward             | 1.7020984  |
# |    reward_max         | 2.0803754  |
# |    reward_mean        | 1.0208895  |
# |    reward_min         | -1.0898404 |
# |    std                | 1          |
# |    value_loss         | 14.2       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 211        |
# |    iterations         | 2200       |
# |    time_elapsed       | 51         |
# |    total_timesteps    | 11000      |
# | train/                |            |
# |    entropy_loss       | -39.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2199       |
# |    policy_loss        | 253        |
# |    reward             | -7.995455  |
# |    reward_max         | 3.5285313  |
# |    reward_mean        | -6.8832717 |
# |    reward_min         | -14.226249 |
# |    std                | 1          |
# |    value_loss         | 63.9       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 211        |
# |    iterations         | 2300       |
# |    time_elapsed       | 54         |
# |    total_timesteps    | 11500      |
# | train/                |            |
# |    entropy_loss       | -39.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2299       |
# |    policy_loss        | -3.38e+03  |
# |    reward             | 24.819086  |
# |    reward_max         | 44.267384  |
# |    reward_mean        | -11.683236 |
# |    reward_min         | -108.12331 |
# |    std                | 1          |
# |    value_loss         | 7.65e+03   |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 211        |
# |    iterations         | 2400       |
# |    time_elapsed       | 56         |
# |    total_timesteps    | 12000      |
# | train/                |            |
# |    entropy_loss       | -39.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2399       |
# |    policy_loss        | 46.9       |
# |    reward             | 0.84996796 |
# |    reward_max         | 1.068863   |
# |    reward_mean        | 0.2341828  |
# |    reward_min         | -0.919899  |
# |    std                | 1          |
# |    value_loss         | 4.6        |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 211         |
# |    iterations         | 2500        |
# |    time_elapsed       | 59          |
# |    total_timesteps    | 12500       |
# | train/                |             |
# |    entropy_loss       | -39.7       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2499        |
# |    policy_loss        | -27.4       |
# |    reward             | -0.07010171 |
# |    reward_max         | 3.4682512   |
# |    reward_mean        | 0.95260453  |
# |    reward_min         | -0.4701773  |
# |    std                | 1           |
# |    value_loss         | 1.02        |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 211          |
# |    iterations         | 2600         |
# |    time_elapsed       | 61           |
# |    total_timesteps    | 13000        |
# | train/                |              |
# |    entropy_loss       | -39.7        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2599         |
# |    policy_loss        | 12.9         |
# |    reward             | 0.70515215   |
# |    reward_max         | 0.8292378    |
# |    reward_mean        | -0.051594764 |
# |    reward_min         | -1.1831967   |
# |    std                | 1            |
# |    value_loss         | 0.201        |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 211         |
# |    iterations         | 2700        |
# |    time_elapsed       | 63          |
# |    total_timesteps    | 13500       |
# | train/                |             |
# |    entropy_loss       | -39.8       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2699        |
# |    policy_loss        | -101        |
# |    reward             | 0.6884253   |
# |    reward_max         | 1.8265394   |
# |    reward_mean        | -0.13418938 |
# |    reward_min         | -1.4423007  |
# |    std                | 1           |
# |    value_loss         | 8.83        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 210        |
# |    iterations         | 2800       |
# |    time_elapsed       | 66         |
# |    total_timesteps    | 14000      |
# | train/                |            |
# |    entropy_loss       | -39.7      |
# |    explained_variance | -0.016     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2799       |
# |    policy_loss        | 274        |
# |    reward             | 1.3663267  |
# |    reward_max         | 1.3663267  |
# |    reward_mean        | -0.5172333 |
# |    reward_min         | -1.9849836 |
# |    std                | 1          |
# |    value_loss         | 69         |
# --------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 210          |
# |    iterations         | 2900         |
# |    time_elapsed       | 68           |
# |    total_timesteps    | 14500        |
# | train/                |              |
# |    entropy_loss       | -39.7        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2899         |
# |    policy_loss        | -49          |
# |    reward             | 0.97508264   |
# |    reward_max         | 0.97508264   |
# |    reward_mean        | -0.110280484 |
# |    reward_min         | -1.1440415   |
# |    std                | 1            |
# |    value_loss         | 1.69         |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 210         |
# |    iterations         | 3000        |
# |    time_elapsed       | 71          |
# |    total_timesteps    | 15000       |
# | train/                |             |
# |    entropy_loss       | -39.7       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 2999        |
# |    policy_loss        | 38.2        |
# |    reward             | 0.82539374  |
# |    reward_max         | 0.82539374  |
# |    reward_mean        | -0.09444947 |
# |    reward_min         | -1.1150815  |
# |    std                | 1           |
# |    value_loss         | 1.38        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 210         |
# |    iterations         | 3100        |
# |    time_elapsed       | 73          |
# |    total_timesteps    | 15500       |
# | train/                |             |
# |    entropy_loss       | -39.7       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3099        |
# |    policy_loss        | 105         |
# |    reward             | -0.38745904 |
# |    reward_max         | 1.8480022   |
# |    reward_mean        | 0.24195434  |
# |    reward_min         | -0.38745904 |
# |    std                | 1           |
# |    value_loss         | 8.38        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 210        |
# |    iterations         | 3200       |
# |    time_elapsed       | 76         |
# |    total_timesteps    | 16000      |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3199       |
# |    policy_loss        | -120       |
# |    reward             | -1.9552583 |
# |    reward_max         | 2.9242876  |
# |    reward_mean        | 0.6722391  |
# |    reward_min         | -1.9552583 |
# |    std                | 1          |
# |    value_loss         | 26.2       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 210         |
# |    iterations         | 3300        |
# |    time_elapsed       | 78          |
# |    total_timesteps    | 16500       |
# | train/                |             |
# |    entropy_loss       | -39.8       |
# |    explained_variance | 0.333       |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3299        |
# |    policy_loss        | 0.0459      |
# |    reward             | 0.35136873  |
# |    reward_max         | 0.80197155  |
# |    reward_mean        | -0.40701464 |
# |    reward_min         | -1.7342511  |
# |    std                | 1           |
# |    value_loss         | 1.64        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 209        |
# |    iterations         | 3400       |
# |    time_elapsed       | 80         |
# |    total_timesteps    | 17000      |
# | train/                |            |
# |    entropy_loss       | -39.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3399       |
# |    policy_loss        | 80.7       |
# |    reward             | 3.0791962  |
# |    reward_max         | 3.0791962  |
# |    reward_mean        | 0.39055005 |
# |    reward_min         | -2.3319383 |
# |    std                | 1          |
# |    value_loss         | 9.25       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 209         |
# |    iterations         | 3500        |
# |    time_elapsed       | 83          |
# |    total_timesteps    | 17500       |
# | train/                |             |
# |    entropy_loss       | -39.9       |
# |    explained_variance | -0.112      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3499        |
# |    policy_loss        | 166         |
# |    reward             | -0.180285   |
# |    reward_max         | 2.2912798   |
# |    reward_mean        | 0.35458097  |
# |    reward_min         | -0.57206213 |
# |    std                | 1.01        |
# |    value_loss         | 23.8        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 210        |
# |    iterations         | 3600       |
# |    time_elapsed       | 85         |
# |    total_timesteps    | 18000      |
# | train/                |            |
# |    entropy_loss       | -39.9      |
# |    explained_variance | 5.07e-06   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3599       |
# |    policy_loss        | -109       |
# |    reward             | 1.4540046  |
# |    reward_max         | 5.132913   |
# |    reward_mean        | 1.2313554  |
# |    reward_min         | -0.8934591 |
# |    std                | 1.01       |
# |    value_loss         | 11         |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 210         |
# |    iterations         | 3700        |
# |    time_elapsed       | 88          |
# |    total_timesteps    | 18500       |
# | train/                |             |
# |    entropy_loss       | -39.8       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3699        |
# |    policy_loss        | 58.9        |
# |    reward             | -1.8325825  |
# |    reward_max         | 0.91079634  |
# |    reward_mean        | -0.22361441 |
# |    reward_min         | -1.8325825  |
# |    std                | 1.01        |
# |    value_loss         | 3.29        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 210         |
# |    iterations         | 3800        |
# |    time_elapsed       | 90          |
# |    total_timesteps    | 19000       |
# | train/                |             |
# |    entropy_loss       | -39.9       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3799        |
# |    policy_loss        | 5.36        |
# |    reward             | 0.026439056 |
# |    reward_max         | 3.6819558   |
# |    reward_mean        | 0.63657475  |
# |    reward_min         | -3.5311477  |
# |    std                | 1.01        |
# |    value_loss         | 0.539       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 210        |
# |    iterations         | 3900       |
# |    time_elapsed       | 92         |
# |    total_timesteps    | 19500      |
# | train/                |            |
# |    entropy_loss       | -39.9      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3899       |
# |    policy_loss        | -30.2      |
# |    reward             | 1.3911195  |
# |    reward_max         | 1.3911195  |
# |    reward_mean        | 0.17165773 |
# |    reward_min         | -2.8349938 |
# |    std                | 1.01       |
# |    value_loss         | 1.55       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 210         |
# |    iterations         | 4000        |
# |    time_elapsed       | 95          |
# |    total_timesteps    | 20000       |
# | train/                |             |
# |    entropy_loss       | -39.8       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3999        |
# |    policy_loss        | -23.9       |
# |    reward             | 2.9131663   |
# |    reward_max         | 3.4725795   |
# |    reward_mean        | 1.3637797   |
# |    reward_min         | -0.37990165 |
# |    std                | 1           |
# |    value_loss         | 3.45        |
# ---------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 210          |
# |    iterations         | 4100         |
# |    time_elapsed       | 97           |
# |    total_timesteps    | 20500        |
# | train/                |              |
# |    entropy_loss       | -39.8        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 4099         |
# |    policy_loss        | -1.54        |
# |    reward             | -0.122421816 |
# |    reward_max         | 1.0013278    |
# |    reward_mean        | 0.45306027   |
# |    reward_min         | -0.122421816 |
# |    std                | 1.01         |
# |    value_loss         | 1.55         |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 210         |
# |    iterations         | 4200        |
# |    time_elapsed       | 99          |
# |    total_timesteps    | 21000       |
# | train/                |             |
# |    entropy_loss       | -39.9       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4199        |
# |    policy_loss        | -227        |
# |    reward             | -2.5581522  |
# |    reward_max         | 5.7752237   |
# |    reward_mean        | 0.105261266 |
# |    reward_min         | -2.5581522  |
# |    std                | 1.01        |
# |    value_loss         | 39.2        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 210        |
# |    iterations         | 4300       |
# |    time_elapsed       | 102        |
# |    total_timesteps    | 21500      |
# | train/                |            |
# |    entropy_loss       | -39.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4299       |
# |    policy_loss        | -119       |
# |    reward             | 3.6675613  |
# |    reward_max         | 3.6675613  |
# |    reward_mean        | 0.5381829  |
# |    reward_min         | -1.9119574 |
# |    std                | 1.01       |
# |    value_loss         | 10.5       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 210        |
# |    iterations         | 4400       |
# |    time_elapsed       | 104        |
# |    total_timesteps    | 22000      |
# | train/                |            |
# |    entropy_loss       | -39.9      |
# |    explained_variance | -0.229     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4399       |
# |    policy_loss        | -26.5      |
# |    reward             | 2.9099233  |
# |    reward_max         | 2.9099233  |
# |    reward_mean        | -1.0362066 |
# |    reward_min         | -4.5106053 |
# |    std                | 1.01       |
# |    value_loss         | 5.08       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 210        |
# |    iterations         | 4500       |
# |    time_elapsed       | 106        |
# |    total_timesteps    | 22500      |
# | train/                |            |
# |    entropy_loss       | -40        |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4499       |
# |    policy_loss        | 167        |
# |    reward             | 0.5350023  |
# |    reward_max         | 1.6112012  |
# |    reward_mean        | -0.7559196 |
# |    reward_min         | -5.0904355 |
# |    std                | 1.01       |
# |    value_loss         | 20.3       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 210        |
# |    iterations         | 4600       |
# |    time_elapsed       | 109        |
# |    total_timesteps    | 23000      |
# | train/                |            |
# |    entropy_loss       | -40        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4599       |
# |    policy_loss        | 257        |
# |    reward             | 1.1060466  |
# |    reward_max         | 1.1060466  |
# |    reward_mean        | -2.6818027 |
# |    reward_min         | -6.4146366 |
# |    std                | 1.01       |
# |    value_loss         | 48.3       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 210        |
# |    iterations         | 4700       |
# |    time_elapsed       | 111        |
# |    total_timesteps    | 23500      |
# | train/                |            |
# |    entropy_loss       | -40.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4699       |
# |    policy_loss        | -156       |
# |    reward             | 0.5701354  |
# |    reward_max         | 4.7345185  |
# |    reward_mean        | 1.2486053  |
# |    reward_min         | -1.5951393 |
# |    std                | 1.01       |
# |    value_loss         | 21.5       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 210        |
# |    iterations         | 4800       |
# |    time_elapsed       | 113        |
# |    total_timesteps    | 24000      |
# | train/                |            |
# |    entropy_loss       | -40.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4799       |
# |    policy_loss        | -241       |
# |    reward             | -1.5879732 |
# |    reward_max         | 2.9889493  |
# |    reward_mean        | -0.1774262 |
# |    reward_min         | -1.5879732 |
# |    std                | 1.01       |
# |    value_loss         | 44.9       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 211        |
# |    iterations         | 4900       |
# |    time_elapsed       | 116        |
# |    total_timesteps    | 24500      |
# | train/                |            |
# |    entropy_loss       | -40.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4899       |
# |    policy_loss        | -73.7      |
# |    reward             | 0.81141865 |
# |    reward_max         | 2.5609503  |
# |    reward_mean        | -0.0748981 |
# |    reward_min         | -3.071764  |
# |    std                | 1.01       |
# |    value_loss         | 8.19       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 211         |
# |    iterations         | 5000        |
# |    time_elapsed       | 118         |
# |    total_timesteps    | 25000       |
# | train/                |             |
# |    entropy_loss       | -40.1       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4999        |
# |    policy_loss        | 78.1        |
# |    reward             | -0.46043465 |
# |    reward_max         | 2.9854786   |
# |    reward_mean        | -0.4989139  |
# |    reward_min         | -2.910944   |
# |    std                | 1.02        |
# |    value_loss         | 5.95        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 211        |
# |    iterations         | 5100       |
# |    time_elapsed       | 120        |
# |    total_timesteps    | 25500      |
# | train/                |            |
# |    entropy_loss       | -40.2      |
# |    explained_variance | 0.0397     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5099       |
# |    policy_loss        | 416        |
# |    reward             | 1.3290982  |
# |    reward_max         | 6.5861177  |
# |    reward_mean        | 2.2043571  |
# |    reward_min         | -1.0098363 |
# |    std                | 1.02       |
# |    value_loss         | 129        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 211       |
# |    iterations         | 5200      |
# |    time_elapsed       | 123       |
# |    total_timesteps    | 26000     |
# | train/                |           |
# |    entropy_loss       | -40.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5199      |
# |    policy_loss        | -440      |
# |    reward             | 10.828471 |
# |    reward_max         | 10.828471 |
# |    reward_mean        | 3.6778708 |
# |    reward_min         | 0.1366765 |
# |    std                | 1.02      |
# |    value_loss         | 180       |
# -------------------------------------
# day: 2892, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 5863171.59
# total_reward: 4863171.59
# total_cost: 56809.19
# total_trades: 50437
# Sharpe: 0.855
# =================================
# ---------------------------------------
# | time/                 |             |
# |    fps                | 211         |
# |    iterations         | 5300        |
# |    time_elapsed       | 125         |
# |    total_timesteps    | 26500       |
# | train/                |             |
# |    entropy_loss       | -40.3       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5299        |
# |    policy_loss        | 33.2        |
# |    reward             | 0.074376486 |
# |    reward_max         | 1.8187782   |
# |    reward_mean        | 0.7641589   |
# |    reward_min         | 0.074376486 |
# |    std                | 1.02        |
# |    value_loss         | 0.854       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 211         |
# |    iterations         | 5400        |
# |    time_elapsed       | 127         |
# |    total_timesteps    | 27000       |
# | train/                |             |
# |    entropy_loss       | -40.3       |
# |    explained_variance | -0.798      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5399        |
# |    policy_loss        | -7.19       |
# |    reward             | 0.057475522 |
# |    reward_max         | 0.6103431   |
# |    reward_mean        | -0.6852358  |
# |    reward_min         | -3.6604285  |
# |    std                | 1.02        |
# |    value_loss         | 11.6        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 211       |
# |    iterations         | 5500      |
# |    time_elapsed       | 130       |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -40.2     |
# |    explained_variance | 0.00833   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | 22.5      |
# |    reward             | 3.890022  |
# |    reward_max         | 5.990702  |
# |    reward_mean        | 2.409021  |
# |    reward_min         | -3.618661 |
# |    std                | 1.02      |
# |    value_loss         | 12.7      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 211        |
# |    iterations         | 5600       |
# |    time_elapsed       | 132        |
# |    total_timesteps    | 28000      |
# | train/                |            |
# |    entropy_loss       | -40.2      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5599       |
# |    policy_loss        | -79.6      |
# |    reward             | 1.9353576  |
# |    reward_max         | 2.460068   |
# |    reward_mean        | 0.5943072  |
# |    reward_min         | -2.1216695 |
# |    std                | 1.02       |
# |    value_loss         | 5.7        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 211        |
# |    iterations         | 5700       |
# |    time_elapsed       | 134        |
# |    total_timesteps    | 28500      |
# | train/                |            |
# |    entropy_loss       | -40.2      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5699       |
# |    policy_loss        | -271       |
# |    reward             | -3.3507483 |
# |    reward_max         | 5.8154135  |
# |    reward_mean        | -6.8837137 |
# |    reward_min         | -23.6559   |
# |    std                | 1.02       |
# |    value_loss         | 52.7       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 211        |
# |    iterations         | 5800       |
# |    time_elapsed       | 137        |
# |    total_timesteps    | 29000      |
# | train/                |            |
# |    entropy_loss       | -40.1      |
# |    explained_variance | -0.0572    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5799       |
# |    policy_loss        | -23.1      |
# |    reward             | 1.7528014  |
# |    reward_max         | 4.5585523  |
# |    reward_mean        | 0.85927635 |
# |    reward_min         | -4.2637634 |
# |    std                | 1.02       |
# |    value_loss         | 4.89       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 211         |
# |    iterations         | 5900        |
# |    time_elapsed       | 139         |
# |    total_timesteps    | 29500       |
# | train/                |             |
# |    entropy_loss       | -40.1       |
# |    explained_variance | -0.155      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5899        |
# |    policy_loss        | 19.6        |
# |    reward             | -0.09368234 |
# |    reward_max         | 1.6069655   |
# |    reward_mean        | 0.42017403  |
# |    reward_min         | -0.5428796  |
# |    std                | 1.02        |
# |    value_loss         | 1.02        |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 211         |
# |    iterations         | 6000        |
# |    time_elapsed       | 141         |
# |    total_timesteps    | 30000       |
# | train/                |             |
# |    entropy_loss       | -40.2       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5999        |
# |    policy_loss        | -2.44       |
# |    reward             | 0.26742217  |
# |    reward_max         | 1.0923198   |
# |    reward_mean        | -0.27679598 |
# |    reward_min         | -2.7447557  |
# |    std                | 1.02        |
# |    value_loss         | 0.18        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 211        |
# |    iterations         | 6100       |
# |    time_elapsed       | 144        |
# |    total_timesteps    | 30500      |
# | train/                |            |
# |    entropy_loss       | -40.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6099       |
# |    policy_loss        | -1.31      |
# |    reward             | -2.847189  |
# |    reward_max         | 2.5778098  |
# |    reward_mean        | -1.2672192 |
# |    reward_min         | -5.095934  |
# |    std                | 1.02       |
# |    value_loss         | 3.19       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 211        |
# |    iterations         | 6200       |
# |    time_elapsed       | 146        |
# |    total_timesteps    | 31000      |
# | train/                |            |
# |    entropy_loss       | -40.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6199       |
# |    policy_loss        | -71        |
# |    reward             | -1.4011556 |
# |    reward_max         | 0.49479178 |
# |    reward_mean        | -1.62351   |
# |    reward_min         | -7.383935  |
# |    std                | 1.02       |
# |    value_loss         | 3.52       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 211       |
# |    iterations         | 6300      |
# |    time_elapsed       | 148       |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -40.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | 253       |
# |    reward             | 5.112186  |
# |    reward_max         | 5.112186  |
# |    reward_mean        | 1.4800072 |
# |    reward_min         | -4.409808 |
# |    std                | 1.02      |
# |    value_loss         | 51.6      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 211         |
# |    iterations         | 6400        |
# |    time_elapsed       | 151         |
# |    total_timesteps    | 32000       |
# | train/                |             |
# |    entropy_loss       | -40.2       |
# |    explained_variance | 0.0699      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6399        |
# |    policy_loss        | 163         |
# |    reward             | 2.2396727   |
# |    reward_max         | 2.3892977   |
# |    reward_mean        | 1.2622211   |
# |    reward_min         | -0.28390217 |
# |    std                | 1.02        |
# ...
# |    policy_loss        | 310       |
# |    reward             | 4.411916  |
# |    reward_max         | 4.411916  |
# |    reward_mean        | 1.4275756 |
# |    reward_min         | -2.473925 |
# |    std                | 1.02      |
# |    value_loss         | 67.8      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 8000       |
# |    time_elapsed       | 188        |
# |    total_timesteps    | 40000      |
# | train/                |            |
# |    entropy_loss       | -40.3      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7999       |
# |    policy_loss        | -90.9      |
# |    reward             | -3.2558072 |
# |    reward_max         | 8.067989   |
# |    reward_mean        | 2.097044   |
# |    reward_min         | -3.2558072 |
# |    std                | 1.02       |
# |    value_loss         | 8.39       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 8100       |
# |    time_elapsed       | 190        |
# |    total_timesteps    | 40500      |
# | train/                |            |
# |    entropy_loss       | -40.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8099       |
# |    policy_loss        | -127       |
# |    reward             | 13.65351   |
# |    reward_max         | 13.65351   |
# |    reward_mean        | -2.742957  |
# |    reward_min         | -19.019634 |
# |    std                | 1.02       |
# |    value_loss         | 34         |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 212         |
# |    iterations         | 8200        |
# |    time_elapsed       | 193         |
# |    total_timesteps    | 41000       |
# | train/                |             |
# |    entropy_loss       | -40.3       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8199        |
# |    policy_loss        | 45.2        |
# |    reward             | -0.32576305 |
# |    reward_max         | 1.9622748   |
# |    reward_mean        | 0.46118078  |
# |    reward_min         | -0.58787394 |
# |    std                | 1.02        |
# |    value_loss         | 3.31        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 8300       |
# |    time_elapsed       | 195        |
# |    total_timesteps    | 41500      |
# | train/                |            |
# |    entropy_loss       | -40.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8299       |
# |    policy_loss        | 86.8       |
# |    reward             | -1.8405111 |
# |    reward_max         | 0.831896   |
# |    reward_mean        | -0.5288443 |
# |    reward_min         | -1.8405111 |
# |    std                | 1.02       |
# |    value_loss         | 4.65       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 8400       |
# |    time_elapsed       | 197        |
# |    total_timesteps    | 42000      |
# | train/                |            |
# |    entropy_loss       | -40.3      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8399       |
# |    policy_loss        | -52        |
# |    reward             | -1.5292188 |
# |    reward_max         | 1.5929388  |
# |    reward_mean        | -3.1606894 |
# |    reward_min         | -8.391672  |
# |    std                | 1.02       |
# |    value_loss         | 4.52       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 212         |
# |    iterations         | 8500        |
# |    time_elapsed       | 200         |
# |    total_timesteps    | 42500       |
# | train/                |             |
# |    entropy_loss       | -40.3       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8499        |
# |    policy_loss        | -143        |
# |    reward             | 0.56617826  |
# |    reward_max         | 6.7374372   |
# |    reward_mean        | 2.1741009   |
# |    reward_min         | -0.75766426 |
# |    std                | 1.02        |
# |    value_loss         | 18.8        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 212       |
# |    iterations         | 8600      |
# |    time_elapsed       | 202       |
# |    total_timesteps    | 43000     |
# | train/                |           |
# |    entropy_loss       | -40.2     |
# |    explained_variance | 5.96e-08  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8599      |
# |    policy_loss        | 219       |
# |    reward             | -4.930422 |
# |    reward_max         | 3.5707738 |
# |    reward_mean        | -2.211969 |
# |    reward_min         | -8.09258  |
# |    std                | 1.02      |
# |    value_loss         | 61.7      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 8700       |
# |    time_elapsed       | 204        |
# |    total_timesteps    | 43500      |
# | train/                |            |
# |    entropy_loss       | -40.2      |
# |    explained_variance | -0.0975    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8699       |
# |    policy_loss        | 80.1       |
# |    reward             | 3.6910856  |
# |    reward_max         | 3.6910856  |
# |    reward_mean        | 0.82319844 |
# |    reward_min         | -1.1407422 |
# |    std                | 1.02       |
# |    value_loss         | 6.65       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 212       |
# |    iterations         | 8800      |
# |    time_elapsed       | 207       |
# |    total_timesteps    | 44000     |
# | train/                |           |
# |    entropy_loss       | -40.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8799      |
# |    policy_loss        | -151      |
# |    reward             | 1.6190509 |
# |    reward_max         | 1.6190509 |
# |    reward_mean        | 0.269361  |
# |    reward_min         | -0.960472 |
# |    std                | 1.02      |
# |    value_loss         | 15        |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 212         |
# |    iterations         | 8900        |
# |    time_elapsed       | 209         |
# |    total_timesteps    | 44500       |
# | train/                |             |
# |    entropy_loss       | -40.2       |
# |    explained_variance | -0.000481   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8899        |
# |    policy_loss        | 183         |
# |    reward             | 0.4409976   |
# |    reward_max         | 0.6081297   |
# |    reward_mean        | -0.43078658 |
# |    reward_min         | -2.0034628  |
# |    std                | 1.02        |
# |    value_loss         | 22.4        |
# ---------------------------------------
# -----------------------------------------
# | time/                 |               |
# |    fps                | 212           |
# |    iterations         | 9000          |
# |    time_elapsed       | 211           |
# |    total_timesteps    | 45000         |
# | train/                |               |
# |    entropy_loss       | -40.3         |
# |    explained_variance | 0             |
# |    learning_rate      | 0.0007        |
# |    n_updates          | 8999          |
# |    policy_loss        | 56.2          |
# |    reward             | -0.0110330945 |
# |    reward_max         | 2.5803063     |
# |    reward_mean        | 0.83720005    |
# |    reward_min         | -0.04290434   |
# |    std                | 1.02          |
# |    value_loss         | 5.61          |
# -----------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 212          |
# |    iterations         | 9100         |
# |    time_elapsed       | 214          |
# |    total_timesteps    | 45500        |
# | train/                |              |
# |    entropy_loss       | -40.2        |
# |    explained_variance | 0            |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 9099         |
# |    policy_loss        | -104         |
# |    reward             | 1.9796028    |
# |    reward_max         | 1.9796028    |
# |    reward_mean        | -0.103085496 |
# |    reward_min         | -1.1940894   |
# |    std                | 1.02         |
# |    value_loss         | 7.41         |
# ----------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 9200       |
# |    time_elapsed       | 216        |
# |    total_timesteps    | 46000      |
# | train/                |            |
# |    entropy_loss       | -40.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9199       |
# |    policy_loss        | 5.86       |
# |    reward             | 3.5413098  |
# |    reward_max         | 3.5413098  |
# |    reward_mean        | -2.2133255 |
# |    reward_min         | -9.331242  |
# |    std                | 1.02       |
# |    value_loss         | 21.2       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 9300       |
# |    time_elapsed       | 218        |
# |    total_timesteps    | 46500      |
# | train/                |            |
# |    entropy_loss       | -40.2      |
# |    explained_variance | 0.0847     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9299       |
# |    policy_loss        | -101       |
# |    reward             | 1.3161314  |
# |    reward_max         | 2.990518   |
# |    reward_mean        | 0.26940578 |
# |    reward_min         | -3.776991  |
# |    std                | 1.02       |
# |    value_loss         | 7          |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 212         |
# |    iterations         | 9400        |
# |    time_elapsed       | 221         |
# |    total_timesteps    | 47000       |
# | train/                |             |
# |    entropy_loss       | -40.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9399        |
# |    policy_loss        | 117         |
# |    reward             | -0.46246913 |
# |    reward_max         | 4.988729    |
# |    reward_mean        | 0.89180255  |
# |    reward_min         | -2.9453065  |
# |    std                | 1.02        |
# |    value_loss         | 11.3        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 9500       |
# |    time_elapsed       | 223        |
# |    total_timesteps    | 47500      |
# | train/                |            |
# |    entropy_loss       | -40.2      |
# |    explained_variance | -0.0619    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9499       |
# |    policy_loss        | 109        |
# |    reward             | 5.8030844  |
# |    reward_max         | 5.8030844  |
# |    reward_mean        | 0.80890906 |
# |    reward_min         | -1.1266294 |
# |    std                | 1.02       |
# |    value_loss         | 10.7       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 9600       |
# |    time_elapsed       | 225        |
# |    total_timesteps    | 48000      |
# | train/                |            |
# |    entropy_loss       | -40.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9599       |
# |    policy_loss        | -209       |
# |    reward             | -1.8449672 |
# |    reward_max         | 3.3539016  |
# |    reward_mean        | 0.80964005 |
# |    reward_min         | -1.8449672 |
# |    std                | 1.02       |
# |    value_loss         | 27.7       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 212       |
# |    iterations         | 9700      |
# |    time_elapsed       | 228       |
# |    total_timesteps    | 48500     |
# | train/                |           |
# |    entropy_loss       | -40.2     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9699      |
# |    policy_loss        | 169       |
# |    reward             | 1.669741  |
# |    reward_max         | 3.2845478 |
# |    reward_mean        | 1.9220241 |
# |    reward_min         | 1.1741982 |
# |    std                | 1.02      |
# |    value_loss         | 25.4      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 212       |
# |    iterations         | 9800      |
# |    time_elapsed       | 230       |
# |    total_timesteps    | 49000     |
# | train/                |           |
# |    entropy_loss       | -40.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9799      |
# |    policy_loss        | 120       |
# |    reward             | 5.256874  |
# |    reward_max         | 11.88031  |
# |    reward_mean        | 1.8494081 |
# |    reward_min         | -8.048    |
# |    std                | 1.02      |
# |    value_loss         | 106       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 212        |
# |    iterations         | 9900       |
# |    time_elapsed       | 232        |
# |    total_timesteps    | 49500      |
# | train/                |            |
# |    entropy_loss       | -40.2      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9899       |
# |    policy_loss        | -2.23      |
# |    reward             | 0.2165327  |
# |    reward_max         | 1.1545278  |
# |    reward_mean        | 0.24217086 |
# |    reward_min         | -0.9076557 |
# |    std                | 1.02       |
# |    value_loss         | 0.249      |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 212         |
# |    iterations         | 10000       |
# |    time_elapsed       | 235         |
# |    total_timesteps    | 50000       |
# | train/                |             |
# |    entropy_loss       | -40.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9999        |
# |    policy_loss        | 17.3        |
# |    reward             | -2.1703837  |
# |    reward_max         | 0.97956556  |
# |    reward_mean        | -0.40000036 |
# |    reward_min         | -2.1703837  |
# |    std                | 1.02        |
# |    value_loss         | 0.981       |
# ---------------------------------------

# %%
trained_a2c.save(TRAINED_MODEL_DIR + "/agent_a2c") if if_using_a2c else None

# %% [markdown]
# ### Agent 2: DDPG

# %%
agent = DRLAgent(env = env_train)
model_ddpg = agent.get_model("ddpg")

if if_using_ddpg:
  # set up logger
  tmp_path = RESULTS_DIR + '/ddpg'
  new_logger_ddpg = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ddpg.set_logger(new_logger_ddpg)

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000) if if_using_ddpg else None

# %%
trained_ddpg.save(TRAINED_MODEL_DIR + "/agent_ddpg") if if_using_ddpg else None

# %% [markdown]
# ### Agent 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)

if if_using_ppo:
  # set up logger
  tmp_path = RESULTS_DIR + '/ppo'
  new_logger_ppo = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_ppo.set_logger(new_logger_ppo)

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=200000) if if_using_ppo else None

# %%
trained_ppo.save(TRAINED_MODEL_DIR + "/agent_ppo") if if_using_ppo else None

# %% [markdown]
# ### Agent 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)

if if_using_td3:
  # set up logger
  tmp_path = RESULTS_DIR + '/td3'
  new_logger_td3 = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_td3.set_logger(new_logger_td3)

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=50000) if if_using_td3 else None

# %%
trained_td3.save(TRAINED_MODEL_DIR + "/agent_td3") if if_using_td3 else None

# %% [markdown]
# ### Agent 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 100000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)

if if_using_sac:
  # set up logger
  tmp_path = RESULTS_DIR + '/sac'
  new_logger_sac = configure(tmp_path, ["stdout", "csv", "tensorboard"])
  # Set new logger
  model_sac.set_logger(new_logger_sac)

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=70000) if if_using_sac else None

# %%
trained_sac.save(TRAINED_MODEL_DIR + "/agent_sac") if if_using_sac else None

# %% [markdown]
# ## Save the trained agent
# Trained agents should have already been saved in the "trained_models" drectory after you run the code blocks above.
#
# For Colab users, the zip files should be at "./trained_models" or "/content/trained_models".
#
# For users running on your local environment, the zip files should be at "./trained_models".
