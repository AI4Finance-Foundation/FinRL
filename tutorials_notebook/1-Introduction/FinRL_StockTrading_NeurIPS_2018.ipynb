# %% [markdown]
# <a href="https://colab.research.google.com/github/AI4Finance-Foundation/FinRL/blob/master/FinRL_StockTrading_NeurIPS_2018.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Deep Reinforcement Learning for Stock Trading from Scratch: Multiple Stock Trading
#
# * **Pytorch Version**

# %% [markdown]
# # Content

# %% [markdown]
# * [1. Problem Definition](#0)
# * [2. Getting Started - Load Python packages](#1)
#     * [2.1. Install Packages](#1.1)
#     * [2.2. Check Additional Packages](#1.2)
#     * [2.3. Import Packages](#1.3)
#     * [2.4. Create Folders](#1.4)
# * [3. Download Data](#2)
# * [4. Preprocess Data](#3)
#     * [4.1. Technical Indicators](#3.1)
#     * [4.2. Perform Feature Engineering](#3.2)
# * [5.Build Environment](#4)
#     * [5.1. Training & Trade Data Split](#4.1)
#     * [5.2. User-defined Environment](#4.2)
#     * [5.3. Initialize Environment](#4.3)
# * [6.Implement DRL Algorithms](#5)
# * [7.Backtesting Performance](#6)
#     * [7.1. BackTestStats](#6.1)
#     * [7.2. BackTestPlot](#6.2)
#     * [7.3. Baseline Stats](#6.3)
#     * [7.3. Compare to Stock Market Index](#6.4)
# * [RLlib Section](#7)

# %% [markdown]
# <a id='0'></a>
# # Part 1. Problem Definition

# %% [markdown]
# This problem is to design an automated trading solution for single stock trading. We model the stock trading process as a Markov Decision Process (MDP). We then formulate our trading goal as a maximization problem.
#
# The algorithm is trained using Deep Reinforcement Learning (DRL) algorithms and the components of the reinforcement learning environment are:
#
#
# * Action: The action space describes the allowed actions that the agent interacts with the
# environment. Normally, a ∈ A includes three actions: a ∈ {−1, 0, 1}, where −1, 0, 1 represent
# selling, holding, and buying one stock. Also, an action can be carried upon multiple shares. We use
# an action space {−k, ..., −1, 0, 1, ..., k}, where k denotes the number of shares. For example, "Buy
# 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or −10, respectively
#
# * Reward function: r(s, a, s′) is the incentive mechanism for an agent to learn a better action. The change of the portfolio value when action a is taken at state s and arriving at new state s',  i.e., r(s, a, s′) = v′ − v, where v′ and v represent the portfolio
# values at state s′ and s, respectively
#
# * State: The state space describes the observations that the agent receives from the environment. Just as a human trader needs to analyze various information before executing a trade, so
# our trading agent observes many different features to better learn in an interactive environment.
#
# * Environment: Dow 30 consituents
#
#
# The data of the single stock that we will be using for this case study is obtained from Yahoo Finance API. The data contains Open-High-Low-Close price and volume.

# %% [markdown]
# <a id='1'></a>
# # Part 2. Getting Started- Load Python Packages

# %% [markdown]
# <a id='1.1'></a>
# ## 2.1. Install all the packages through FinRL library

# %%
## install finrl library
# %pip install git+https://github.com/AI4Finance-LLC/FinRL-Library.git
# Out:
# Looking in indexes: https://mirror.sjtu.edu.cn/pypi/web/simple
# Collecting git+https://github.com/AI4Finance-LLC/FinRL-Library.git
#   Cloning https://github.com/AI4Finance-LLC/FinRL-Library.git to /tmp/pip-req-build-vzh_g44r
#   Running command git clone -q https://github.com/AI4Finance-LLC/FinRL-Library.git /tmp/pip-req-build-vzh_g44r
#   Resolved https://github.com/AI4Finance-LLC/FinRL-Library.git to commit ba39188a3ae6f9032a3402d050e32f6dd8846c5c
# Collecting pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2
#   Cloning https://github.com/quantopian/pyfolio.git to /tmp/pip-install-lraysq3w/pyfolio_c4f3da290a6c4b998be6849a33d3b81e
#   Running command git clone -q https://github.com/quantopian/pyfolio.git /tmp/pip-install-lraysq3w/pyfolio_c4f3da290a6c4b998be6849a33d3b81e
#   Resolved https://github.com/quantopian/pyfolio.git to commit 4b901f6d73aa02ceb6d04b7d83502e5c6f2e81aa
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to /tmp/pip-install-lraysq3w/elegantrl_e559c5561584485f8733318d0b084cfc
#   Running command git clone -q https://github.com/AI4Finance-Foundation/ElegantRL.git /tmp/pip-install-lraysq3w/elegantrl_e559c5561584485f8733318d0b084cfc
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit 4275ac8b71335593cc5513ca4c5cf62068dcbf87
# Requirement already satisfied: numpy>=1.17.3 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (1.21.2)
# Requirement already satisfied: pandas>=1.1.5 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (1.3.5)
# Requirement already satisfied: stockstats>=0.4.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (0.4.1)
# Requirement already satisfied: yfinance in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (0.1.70)
# Requirement already satisfied: elegantrl in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (0.3.3)
# Requirement already satisfied: matplotlib in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (3.5.1)
# Requirement already satisfied: scikit-learn>=0.21.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (1.0.2)
# Requirement already satisfied: gym>=0.17 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (0.19.0)
# Requirement already satisfied: stable-baselines3[extra] in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (1.4.0)
# Requirement already satisfied: ray[default] in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (1.11.0)
# Requirement already satisfied: lz4 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (4.0.0)
# Requirement already satisfied: tensorboardX in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (2.5)
# Requirement already satisfied: gputil in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (1.4.0)
# Requirement already satisfied: exchange_calendars in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (3.6.1)
# Requirement already satisfied: alpaca_trade_api in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (1.2.3)
# Requirement already satisfied: ccxt>=1.66.32 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (1.72.98)
# Requirement already satisfied: jqdatasdk in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (1.8.10)
# Requirement already satisfied: wrds in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (3.1.1)
# Requirement already satisfied: pytest in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (7.1.1)
# Requirement already satisfied: setuptools==59.5.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (59.5.0)
# Requirement already satisfied: wheel>=0.33.6 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (0.37.1)
# Requirement already satisfied: pre-commit in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from finrl==0.3.5) (2.17.0)
# Requirement already satisfied: aiohttp>=3.8 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ccxt>=1.66.32->finrl==0.3.5) (3.8.1)
# Requirement already satisfied: cryptography>=2.6.1 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ccxt>=1.66.32->finrl==0.3.5) (36.0.2)
# Requirement already satisfied: yarl==1.7.2 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ccxt>=1.66.32->finrl==0.3.5) (1.7.2)
# Requirement already satisfied: requests>=2.18.4 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ccxt>=1.66.32->finrl==0.3.5) (2.27.1)
# Requirement already satisfied: certifi>=2018.1.18 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ccxt>=1.66.32->finrl==0.3.5) (2021.10.8)
# Requirement already satisfied: aiodns>=1.1.1 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ccxt>=1.66.32->finrl==0.3.5) (3.0.0)
# Requirement already satisfied: multidict>=4.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from yarl==1.7.2->ccxt>=1.66.32->finrl==0.3.5) (6.0.2)
# Requirement already satisfied: typing-extensions>=3.7.4 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from yarl==1.7.2->ccxt>=1.66.32->finrl==0.3.5) (3.10.0.2)
# Requirement already satisfied: idna>=2.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from yarl==1.7.2->ccxt>=1.66.32->finrl==0.3.5) (3.3)
# Requirement already satisfied: pycares>=4.0.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from aiodns>=1.1.1->ccxt>=1.66.32->finrl==0.3.5) (4.1.2)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from aiohttp>=3.8->ccxt>=1.66.32->finrl==0.3.5) (2.0.12)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from aiohttp>=3.8->ccxt>=1.66.32->finrl==0.3.5) (1.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from aiohttp>=3.8->ccxt>=1.66.32->finrl==0.3.5) (1.3.0)
# Requirement already satisfied: asynctest==0.13.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from aiohttp>=3.8->ccxt>=1.66.32->finrl==0.3.5) (0.13.0)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from aiohttp>=3.8->ccxt>=1.66.32->finrl==0.3.5) (4.0.2)
# Requirement already satisfied: attrs>=17.3.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from aiohttp>=3.8->ccxt>=1.66.32->finrl==0.3.5) (21.4.0)
# Requirement already satisfied: cffi>=1.12 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from cryptography>=2.6.1->ccxt>=1.66.32->finrl==0.3.5) (1.15.0)
# Requirement already satisfied: pycparser in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from cffi>=1.12->cryptography>=2.6.1->ccxt>=1.66.32->finrl==0.3.5) (2.21)
# Requirement already satisfied: cloudpickle<1.7.0,>=1.2.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from gym>=0.17->finrl==0.3.5) (1.6.0)
# Requirement already satisfied: pytz>=2017.3 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from pandas>=1.1.5->finrl==0.3.5) (2022.1)
# Requirement already satisfied: python-dateutil>=2.7.3 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from pandas>=1.1.5->finrl==0.3.5) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from python-dateutil>=2.7.3->pandas>=1.1.5->finrl==0.3.5) (1.16.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from requests>=2.18.4->ccxt>=1.66.32->finrl==0.3.5) (1.26.9)
# Requirement already satisfied: scipy>=1.1.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from scikit-learn>=0.21.0->finrl==0.3.5) (1.7.3)
# Requirement already satisfied: joblib>=0.11 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from scikit-learn>=0.21.0->finrl==0.3.5) (1.1.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from scikit-learn>=0.21.0->finrl==0.3.5) (3.1.0)
# Requirement already satisfied: msgpack==1.0.2 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from alpaca_trade_api->finrl==0.3.5) (1.0.2)
# Requirement already satisfied: websocket-client<2,>=0.56.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from alpaca_trade_api->finrl==0.3.5) (1.3.1)
# Requirement already satisfied: websockets<10,>=8.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from alpaca_trade_api->finrl==0.3.5) (9.1)
# Requirement already satisfied: pybullet in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.5) (3.2.1)
# Requirement already satisfied: torch in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.5) (1.10.2)
# Requirement already satisfied: opencv-python in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.5) (4.5.5.64)
# Requirement already satisfied: box2d-py in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl->finrl==0.3.5) (2.3.8)
# Requirement already satisfied: toolz in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from exchange_calendars->finrl==0.3.5) (0.11.2)
# Requirement already satisfied: pyluach in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from exchange_calendars->finrl==0.3.5) (1.4.0)
# Requirement already satisfied: korean-lunar-calendar in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from exchange_calendars->finrl==0.3.5) (0.2.1)
# Requirement already satisfied: SQLAlchemy>=1.2.8 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from jqdatasdk->finrl==0.3.5) (1.4.32)
# Requirement already satisfied: pymysql>=0.7.6 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from jqdatasdk->finrl==0.3.5) (1.0.2)
# Requirement already satisfied: thriftpy2>=0.3.9 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from jqdatasdk->finrl==0.3.5) (0.4.14)
# Requirement already satisfied: importlib-metadata in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from SQLAlchemy>=1.2.8->jqdatasdk->finrl==0.3.5) (4.11.3)
# Requirement already satisfied: greenlet!=0.4.17 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from SQLAlchemy>=1.2.8->jqdatasdk->finrl==0.3.5) (1.1.2)
# Requirement already satisfied: ply<4.0,>=3.4 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from thriftpy2>=0.3.9->jqdatasdk->finrl==0.3.5) (3.11)
# Requirement already satisfied: zipp>=0.5 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from importlib-metadata->SQLAlchemy>=1.2.8->jqdatasdk->finrl==0.3.5) (3.7.0)
# Requirement already satisfied: pillow>=6.2.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from matplotlib->finrl==0.3.5) (9.0.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from matplotlib->finrl==0.3.5) (3.0.7)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from matplotlib->finrl==0.3.5) (1.4.0)
# Requirement already satisfied: cycler>=0.10 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from matplotlib->finrl==0.3.5) (0.11.0)
# Requirement already satisfied: packaging>=20.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from matplotlib->finrl==0.3.5) (21.3)
# Requirement already satisfied: fonttools>=4.22.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from matplotlib->finrl==0.3.5) (4.31.1)
# Requirement already satisfied: nodeenv>=0.11.1 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from pre-commit->finrl==0.3.5) (1.6.0)
# Requirement already satisfied: toml in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from pre-commit->finrl==0.3.5) (0.10.2)
# Requirement already satisfied: cfgv>=2.0.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from pre-commit->finrl==0.3.5) (3.3.1)
# Requirement already satisfied: pyyaml>=5.1 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from pre-commit->finrl==0.3.5) (6.0)
# Requirement already satisfied: identify>=1.0.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from pre-commit->finrl==0.3.5) (2.4.12)
# Requirement already satisfied: virtualenv>=20.0.8 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from pre-commit->finrl==0.3.5) (20.13.4)
# Requirement already satisfied: platformdirs<3,>=2 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from virtualenv>=20.0.8->pre-commit->finrl==0.3.5) (2.5.1)
# Requirement already satisfied: filelock<4,>=3.2 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from virtualenv>=20.0.8->pre-commit->finrl==0.3.5) (3.6.0)
# Requirement already satisfied: distlib<1,>=0.3.1 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from virtualenv>=20.0.8->pre-commit->finrl==0.3.5) (0.3.4)
# Requirement already satisfied: ipython>=3.2.3 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (7.32.0)
# Requirement already satisfied: seaborn>=0.7.1 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.11.2)
# Requirement already satisfied: empyrical>=0.5.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.5.5)
# Requirement already satisfied: pandas-datareader>=0.2 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from empyrical>=0.5.0->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.10.0)
# Requirement already satisfied: pexpect>4.3 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (4.8.0)
# Requirement already satisfied: matplotlib-inline in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.1.3)
# Requirement already satisfied: pygments in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (2.11.2)
# Requirement already satisfied: traitlets>=4.2 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (5.1.1)
# Requirement already satisfied: pickleshare in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.7.5)
# Requirement already satisfied: decorator in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.18.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (3.0.28)
# Requirement already satisfied: backcall in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.2.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from jedi>=0.16->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.8.3)
# Requirement already satisfied: lxml in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from pandas-datareader>=0.2->empyrical>=0.5.0->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (4.8.0)
# Requirement already satisfied: ptyprocess>=0.5 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from pexpect>4.3->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.7.0)
# Requirement already satisfied: wcwidth in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=3.2.3->pyfolio@ git+https://github.com/quantopian/pyfolio.git#egg=pyfolio-0.9.2->finrl==0.3.5) (0.2.5)
# Requirement already satisfied: tomli>=1.0.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from pytest->finrl==0.3.5) (2.0.1)
# Requirement already satisfied: pluggy<2.0,>=0.12 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from pytest->finrl==0.3.5) (1.0.0)
# Requirement already satisfied: iniconfig in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from pytest->finrl==0.3.5) (1.1.1)
# Requirement already satisfied: py>=1.8.2 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from pytest->finrl==0.3.5) (1.11.0)
# Requirement already satisfied: redis>=3.5.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (4.1.4)
# Requirement already satisfied: click>=7.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (8.0.4)
# Requirement already satisfied: grpcio<=1.43.0,>=1.28.1 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (1.43.0)
# Requirement already satisfied: protobuf>=3.15.3 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (3.19.4)
# Requirement already satisfied: jsonschema in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (4.4.0)
# Requirement already satisfied: opencensus in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (0.8.0)
# Requirement already satisfied: aioredis<2 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (1.3.1)
# Requirement already satisfied: smart-open in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (5.2.1)
# Requirement already satisfied: colorful in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (0.5.4)
# Requirement already satisfied: prometheus-client>=0.7.1 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (0.13.1)
# Requirement already satisfied: gpustat>=1.0.0b1 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (1.0.0b1)
# Requirement already satisfied: py-spy>=0.2.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (0.3.11)
# Requirement already satisfied: aiohttp-cors in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (0.7.0)
# Requirement already satisfied: hiredis in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from aioredis<2->ray[default]->finrl==0.3.5) (2.0.0)
# Requirement already satisfied: blessed>=1.17.1 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from gpustat>=1.0.0b1->ray[default]->finrl==0.3.5) (1.19.1)
# Requirement already satisfied: psutil in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from gpustat>=1.0.0b1->ray[default]->finrl==0.3.5) (5.9.0)
# Requirement already satisfied: nvidia-ml-py3>=7.352.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from gpustat>=1.0.0b1->ray[default]->finrl==0.3.5) (7.352.0)
# Requirement already satisfied: deprecated>=1.2.3 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from redis>=3.5.0->ray[default]->finrl==0.3.5) (1.2.13)
# Requirement already satisfied: wrapt<2,>=1.10 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from deprecated>=1.2.3->redis>=3.5.0->ray[default]->finrl==0.3.5) (1.14.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from jsonschema->ray[default]->finrl==0.3.5) (0.18.1)
# Requirement already satisfied: importlib-resources>=1.4.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from jsonschema->ray[default]->finrl==0.3.5) (5.4.0)
# Requirement already satisfied: google-api-core<3.0.0,>=1.0.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from opencensus->ray[default]->finrl==0.3.5) (2.7.1)
# Requirement already satisfied: opencensus-context==0.1.2 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from opencensus->ray[default]->finrl==0.3.5) (0.1.2)
# Requirement already satisfied: google-auth<3.0dev,>=1.25.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]->finrl==0.3.5) (2.6.2)
# Requirement already satisfied: googleapis-common-protos<2.0dev,>=1.52.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]->finrl==0.3.5) (1.56.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]->finrl==0.3.5) (0.2.8)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]->finrl==0.3.5) (5.0.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]->finrl==0.3.5) (4.8)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from pyasn1-modules>=0.2.1->google-auth<3.0dev,>=1.25.0->google-api-core<3.0.0,>=1.0.0->opencensus->ray[default]->finrl==0.3.5) (0.4.8)
# Requirement already satisfied: tabulate in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from ray[default]->finrl==0.3.5) (0.8.9)
# Requirement already satisfied: atari-py==0.2.6 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from stable-baselines3[extra]->finrl==0.3.5) (0.2.6)
# Requirement already satisfied: tensorboard>=2.2.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from stable-baselines3[extra]->finrl==0.3.5) (2.8.0)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]->finrl==0.3.5) (0.4.6)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]->finrl==0.3.5) (1.8.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]->finrl==0.3.5) (2.0.3)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]->finrl==0.3.5) (0.6.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]->finrl==0.3.5) (3.3.6)
# Requirement already satisfied: absl-py>=0.4 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from tensorboard>=2.2.0->stable-baselines3[extra]->finrl==0.3.5) (1.0.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]->finrl==0.3.5) (1.3.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->stable-baselines3[extra]->finrl==0.3.5) (3.2.0)
# Requirement already satisfied: psycopg2-binary in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from wrds->finrl==0.3.5) (2.9.3)
# Requirement already satisfied: mock in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from wrds->finrl==0.3.5) (4.0.3)
# Requirement already satisfied: multitasking>=0.0.7 in /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages (from yfinance->finrl==0.3.5) (0.0.10)

# %%
from finrl import config
from finrl import config_tickers
import os
if not os.path.exists("./" + config.DATA_SAVE_DIR):
    os.makedirs("./" + config.DATA_SAVE_DIR)
if not os.path.exists("./" + config.TRAINED_MODEL_DIR):
    os.makedirs("./" + config.TRAINED_MODEL_DIR)
if not os.path.exists("./" + config.TENSORBOARD_LOG_DIR):
    os.makedirs("./" + config.TENSORBOARD_LOG_DIR)
if not os.path.exists("./" + config.RESULTS_DIR):
    os.makedirs("./" + config.RESULTS_DIR)

# %% [markdown]
# <a id='1.2'></a>
# ## 2.2. Check if the additional packages needed are present, if not install them.
# * Yahoo Finance API
# * pandas
# * numpy
# * matplotlib
# * stockstats
# * OpenAI gym
# * stable-baselines
# * tensorflow
# * pyfolio

# %% [markdown]
# <a id='1.3'></a>
# ## 2.3. Import Packages

# %%
import pandas as pd
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
# matplotlib.use('Agg')
import datetime

# %matplotlib inline
from finrl.finrl_meta.preprocessor.yahoodownloader import YahooDownloader
from finrl.finrl_meta.preprocessor.preprocessors import FeatureEngineer, data_split
from finrl.finrl_meta.env_stock_trading.env_stocktrading import StockTradingEnv
from finrl.agents.stablebaselines3.models import DRLAgent
from finrl.finrl_meta.data_processor import DataProcessor

from finrl.plot import backtest_stats, backtest_plot, get_daily_return, get_baseline
from pprint import pprint

import sys
sys.path.append("../FinRL-Library")

import itertools
# Out:
# /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages/pyfolio/pos.py:27: UserWarning: Module "zipline.assets" not found; multipliers will not be applied to position notionals.
#   'Module "zipline.assets" not found; multipliers will not be applied'

# %% [markdown]
# <a id='1.4'></a>
# ## 2.4. Create Folders

# %% [markdown]
# <a id='2'></a>
# # Part 3. Download Data
# Yahoo Finance is a website that provides stock data, financial news, financial reports, etc. All the data provided by Yahoo Finance is free.
# * FinRL uses a class **YahooDownloader** to fetch data from Yahoo Finance API
# * Call Limit: Using the Public API (without authentication), you are limited to 2,000 requests per hour per IP (or up to a total of 48,000 requests a day).

# %% [markdown]
# -----
# class YahooDownloader:
#     Provides methods for retrieving daily stock data from
#     Yahoo Finance API
#
#     Attributes
#     ----------
#         start_date : str
#             start date of the data (modified from config.py)
#         end_date : str
#             end date of the data (modified from config.py)
#         ticker_list : list
#             a list of stock tickers (modified from config.py)
#
#     Methods
#     -------
#     fetch_data()
#         Fetches data from yahoo API

# %%
# from config.py start_date is a string, not provided now
# config.START_DATE

# %%
# from config.py end_date is a string, not provided now
# config.END_DATE

# %%
df = YahooDownloader(start_date = '2009-01-01',
                     end_date = '2021-10-31',
                     ticker_list = config_tickers.DOW_30_TICKER).fetch_data()
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (94360, 8)

# %%
print(config_tickers.DOW_30_TICKER)
# Out:
# ['AXP', 'AMGN', 'AAPL', 'BA', 'CAT', 'CSCO', 'CVX', 'GS', 'HD', 'HON', 'IBM', 'INTC', 'JNJ', 'KO', 'JPM', 'MCD', 'MMM', 'MRK', 'MSFT', 'NKE', 'PG', 'TRV', 'UNH', 'CRM', 'VZ', 'V', 'WBA', 'WMT', 'DIS', 'DOW']

# %%
df.shape
# Out:
# (94360, 8)

# %%
df.sort_values(['date','tic'],ignore_index=True).head()
# Out:
#          date       open       high        low      close     volume   tic  \
# 0  2008-12-31   3.070357   3.133571   3.047857   2.610108  607541200  AAPL
# 1  2008-12-31  57.110001  58.220001  57.060001  44.277363    6287200  AMGN
# 2  2008-12-31  17.969999  18.750000  17.910000  14.950783    9625600   AXP
# 3  2008-12-31  41.590000  43.049999  41.500000  32.005878    5443100    BA
# 4  2008-12-31  43.700001  45.099998  43.700001  30.775715    6277400   CAT
#
#    day
# 0    2
# 1    2
# 2    2
# 3    2
# 4    2

# %% [markdown]
# # Part 4: Preprocess Data
# Data preprocessing is a crucial step for training a high quality machine learning model. We need to check for missing data and do feature engineering in order to convert the data into a model-ready state.
# * Add technical indicators. In practical trading, various information needs to be taken into account, for example the historical stock prices, current holding shares, technical indicators, etc. In this article, we demonstrate two trend-following technical indicators: MACD and RSI.
# * Add turbulence index. Risk-aversion reflects whether an investor will choose to preserve the capital. It also influences one's trading strategy when facing different market volatility level. To control the risk in a worst-case scenario, such as financial crisis of 2007–2008, FinRL employs the financial turbulence index that measures extreme asset price fluctuation.

# %%
fe = FeatureEngineer(
                    use_technical_indicator=True,
                    tech_indicator_list = config.INDICATORS,
                    use_vix=True,
                    use_turbulence=True,
                    user_defined_feature = False)

processed = fe.preprocess_data(df)
# Out:
# Successfully added technical indicators
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (3231, 8)
# Successfully added vix
# Successfully added turbulence index

# %%
list_ticker = processed["tic"].unique().tolist()
list_date = list(pd.date_range(processed['date'].min(),processed['date'].max()).astype(str))
combination = list(itertools.product(list_date,list_ticker))

processed_full = pd.DataFrame(combination,columns=["date","tic"]).merge(processed,on=["date","tic"],how="left")
processed_full = processed_full[processed_full['date'].isin(processed['date'])]
processed_full = processed_full.sort_values(['date','tic'])

processed_full = processed_full.fillna(0)

# %%
processed_full.sort_values(['date','tic'],ignore_index=True).head(10)
# Out:
#          date   tic       open       high        low      close       volume  \
# 0  2008-12-31  AAPL   3.070357   3.133571   3.047857   2.610108  607541200.0
# 1  2008-12-31  AMGN  57.110001  58.220001  57.060001  44.277363    6287200.0
# 2  2008-12-31   AXP  17.969999  18.750000  17.910000  14.950783    9625600.0
# 3  2008-12-31    BA  41.590000  43.049999  41.500000  32.005878    5443100.0
# 4  2008-12-31   CAT  43.700001  45.099998  43.700001  30.775715    6277400.0
# 5  2008-12-31   CRM   7.712500   8.130000   7.707500   8.002500    5367600.0
# 6  2008-12-31  CSCO  16.180000  16.549999  16.120001  11.868505   37513700.0
# 7  2008-12-31   CVX  72.900002  74.629997  72.900002  43.670765    9964300.0
# 8  2008-12-31   DIS  22.570000  22.950001  22.520000  19.538342    9012100.0
# 9  2008-12-31    GS  82.239998  86.150002  81.120003  69.224457   14894100.0
#
#    day  macd   boll_ub   boll_lb  rsi_30     cci_30  dx_30  close_30_sma  \
# 0  2.0   0.0  2.926216  2.459137   100.0  66.666667  100.0      2.610108
# 1  2.0   0.0  2.926216  2.459137   100.0  66.666667  100.0     44.277363
# 2  2.0   0.0  2.926216  2.459137   100.0  66.666667  100.0     14.950783
# 3  2.0   0.0  2.926216  2.459137   100.0  66.666667  100.0     32.005878
# 4  2.0   0.0  2.926216  2.459137   100.0  66.666667  100.0     30.775715
# 5  2.0   0.0  2.926216  2.459137   100.0  66.666667  100.0      8.002500
# 6  2.0   0.0  2.926216  2.459137   100.0  66.666667  100.0     11.868505
# 7  2.0   0.0  2.926216  2.459137   100.0  66.666667  100.0     43.670765
# 8  2.0   0.0  2.926216  2.459137   100.0  66.666667  100.0     19.538342
# 9  2.0   0.0  2.926216  2.459137   100.0  66.666667  100.0     69.224457
#
#    close_60_sma   vix  turbulence
# 0      2.610108  40.0         0.0
# 1     44.277363  40.0         0.0
# 2     14.950783  40.0         0.0
# 3     32.005878  40.0         0.0
# 4     30.775715  40.0         0.0
# 5      8.002500  40.0         0.0
# 6     11.868505  40.0         0.0
# 7     43.670765  40.0         0.0
# 8     19.538342  40.0         0.0
# 9     69.224457  40.0         0.0

# %% [markdown]
# <a id='4'></a>
# # Part 5. Design Environment
# Considering the stochastic and interactive nature of the automated stock trading tasks, a financial task is modeled as a **Markov Decision Process (MDP)** problem. The training process involves observing stock price change, taking an action and reward's calculation to have the agent adjusting its strategy accordingly. By interacting with the environment, the trading agent will derive a trading strategy with the maximized rewards as time proceeds.
#
# Our trading environments, based on OpenAI Gym framework, simulate live stock markets with real market data according to the principle of time-driven simulation.
#
# The action space describes the allowed actions that the agent interacts with the environment. Normally, action a includes three actions: {-1, 0, 1}, where -1, 0, 1 represent selling, holding, and buying one share. Also, an action can be carried upon multiple shares. We use an action space {-k,…,-1, 0, 1, …, k}, where k denotes the number of shares to buy and -k denotes the number of shares to sell. For example, "Buy 10 shares of AAPL" or "Sell 10 shares of AAPL" are 10 or -10, respectively. The continuous action space needs to be normalized to [-1, 1], since the policy is defined on a Gaussian distribution, which needs to be normalized and symmetric.

# %% [markdown]
# ## Training data split: 2009-01-01 to 2020-07-01
# ## Trade data split: 2020-07-01 to 2021-10-31

# %%
train = data_split(processed_full, '2009-01-01','2020-07-01')
trade = data_split(processed_full, '2020-07-01','2021-10-31')
print(len(train))
print(len(trade))
# Out:
# 83897
# 9744

# %%
train.tail()
# Out:
#             date  tic        open        high         low       close  \
# 2892  2020-06-30  UNH  288.570007  296.450012  287.660004  287.776764
# 2892  2020-06-30    V  191.490005  193.750000  190.160004  191.101532
# 2892  2020-06-30   VZ   54.919998   55.290001   54.360001   50.991920
# 2892  2020-06-30  WBA   42.119999   42.580002   41.759998   39.497250
# 2892  2020-06-30  WMT  119.220001  120.129997  118.540001  116.543854
#
#           volume  day      macd     boll_ub     boll_lb     rsi_30     cci_30  \
# 2892   2932900.0  1.0 -0.019480  303.925875  271.251243  52.413038 -25.838509
# 2892   9040100.0  1.0  1.050788  199.130134  185.394798  53.021036 -51.532362
# 2892  17414800.0  1.0 -0.442448   54.576847   49.324378  48.097056 -50.972077
# 2892   4782100.0  1.0 -0.085024   43.113070   36.918483  48.829875 -14.474123
# 2892   6836400.0  1.0 -0.889793  119.908039  113.923055  48.159657 -69.927206
#
#          dx_30  close_30_sma  close_60_sma    vix  turbulence
# 2892  1.846804    288.020683    281.001435  30.43   12.918493
# 2892  2.013358    191.850756    182.024669  30.43   12.918493
# 2892  8.508886     51.635054     52.093137  30.43   12.918493
# 2892  1.500723     39.597882     39.395699  30.43   12.918493
# 2892  3.847271    118.215776    120.158460  30.43   12.918493

# %%
trade.head()
# Out:
#          date   tic        open        high         low       close  \
# 0  2020-07-01  AAPL   91.279999   91.839996   90.977501   90.036713
# 0  2020-07-01  AMGN  235.520004  256.230011  232.580002  242.083466
# 0  2020-07-01   AXP   95.250000   96.959999   93.639999   92.347778
# 0  2020-07-01    BA  185.880005  190.610001  180.039993  180.320007
# 0  2020-07-01   CAT  129.380005  129.399994  125.879997  121.230247
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  110737200.0  2.0  3.019034   92.835525   80.297754  62.807141  107.489641
# 0    6575800.0  2.0  3.665608  234.264599  201.821546  61.279638  271.571281
# 0    3301000.0  2.0 -0.390267  110.737387   88.008448  48.504819  -66.334510
# 0   49036700.0  2.0  5.443193  220.721139  160.932863  50.925771   24.220608
# 0    2807800.0  2.0  1.278733  131.250712  113.896730  52.865423   35.572311
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  29.730532     84.057089     77.831731  28.620001   53.070842
# 0  46.806139    216.584928    217.666551  28.620001   53.070842
# 0   3.142448     97.520674     90.952973  28.620001   53.070842
# 0  15.932920    176.472335    155.614168  28.620001   53.070842
# 0  14.457404    119.985501    114.191686  28.620001   53.070842

# %%
config.INDICATORS
# Out:
# ['macd',
#  'boll_ub',
#  'boll_lb',
#  'rsi_30',
#  'cci_30',
#  'dx_30',
#  'close_30_sma',
#  'close_60_sma']

# %%
stock_dimension = len(train.tic.unique())
state_space = 1 + 2*stock_dimension + len(config.INDICATORS)*stock_dimension
print(f"Stock Dimension: {stock_dimension}, State Space: {state_space}")
# Out:
# Stock Dimension: 29, State Space: 291

# %%
env_kwargs = {
    "hmax": 100, 
    # initial_amount = 1000000, and hold no shares at beginning.
    "initial_list": [1000000] + [0 for i in range(stock_dimension)],
    # buy and sell cost for each stock
    "buy_cost_pct": [0.001] * stock_dimension,
    "sell_cost_pct": [0.001] * stock_dimension,
    "state_space": state_space, 
    "stock_dim": stock_dimension, 
    "tech_indicator_list": config.INDICATORS, 
    "action_space": stock_dimension, 
    "reward_scaling": 1e-4
    
}

e_train_gym = StockTradingEnv(df = train, **env_kwargs)

# %% [markdown]
# ## Environment for Training

# %%
env_train, _ = e_train_gym.get_sb_env()
print(type(env_train))
# Out:
# <class 'stable_baselines3.common.vec_env.dummy_vec_env.DummyVecEnv'>

# %% [markdown]
# <a id='5'></a>
# # Part 6: Implement DRL Algorithms
# * The implementation of the DRL algorithms are based on **OpenAI Baselines** and **Stable Baselines**. Stable Baselines is a fork of OpenAI Baselines, with a major structural refactoring, and code cleanups.
# * FinRL library includes fine-tuned standard DRL algorithms, such as DQN, DDPG,
# Multi-Agent DDPG, PPO, SAC, A2C and TD3. We also allow users to
# design their own DRL algorithms by adapting these DRL algorithms.

# %%
agent = DRLAgent(env = env_train)

# %% [markdown]
# ### Model Training: 5 models, A2C DDPG, PPO, TD3, SAC

# %% [markdown]
# ### Model 1: A2C

# %%
agent = DRLAgent(env = env_train)
model_a2c = agent.get_model("a2c")
# Out:
# {'n_steps': 5, 'ent_coef': 0.01, 'learning_rate': 0.0007}
# Using cuda device

# %%
trained_a2c = agent.train_model(model=model_a2c, 
                             tb_log_name='a2c',
                             total_timesteps=50000)
# Out:
# ---------------------------------------
# | time/                 |             |
# |    fps                | 113         |
# |    iterations         | 100         |
# |    time_elapsed       | 4           |
# |    total_timesteps    | 500         |
# | train/                |             |
# |    entropy_loss       | -41.4       |
# |    explained_variance | -0.889      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 99          |
# |    policy_loss        | 9.93        |
# |    reward             | -0.28941807 |
# |    std                | 1.01        |
# |    value_loss         | 0.37        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 126        |
# |    iterations         | 200        |
# |    time_elapsed       | 7          |
# |    total_timesteps    | 1000       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 199        |
# |    policy_loss        | 15.4       |
# |    reward             | -1.7484787 |
# |    std                | 1.01       |
# |    value_loss         | 0.675      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 132       |
# |    iterations         | 300       |
# |    time_elapsed       | 11        |
# |    total_timesteps    | 1500      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.0961   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 299       |
# |    policy_loss        | -292      |
# |    reward             | 3.1992984 |
# |    std                | 1.01      |
# |    value_loss         | 61.2      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 134       |
# |    iterations         | 400       |
# |    time_elapsed       | 14        |
# |    total_timesteps    | 2000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 399       |
# |    policy_loss        | -8.03     |
# |    reward             | 1.6250848 |
# |    std                | 1.01      |
# |    value_loss         | 0.942     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 135        |
# |    iterations         | 500        |
# |    time_elapsed       | 18         |
# |    total_timesteps    | 2500       |
# | train/                |            |
# |    entropy_loss       | -41.3      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 499        |
# |    policy_loss        | 519        |
# |    reward             | -13.256469 |
# |    std                | 1.01       |
# |    value_loss         | 184        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 137        |
# |    iterations         | 600        |
# |    time_elapsed       | 21         |
# |    total_timesteps    | 3000       |
# | train/                |            |
# |    entropy_loss       | -41.4      |
# |    explained_variance | 0.0622     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 599        |
# |    policy_loss        | 155        |
# |    reward             | 0.46254045 |
# |    std                | 1.01       |
# |    value_loss         | 17.2       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 138       |
# |    iterations         | 700       |
# |    time_elapsed       | 25        |
# |    total_timesteps    | 3500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 699       |
# |    policy_loss        | -74       |
# |    reward             | -2.339627 |
# |    std                | 1.01      |
# |    value_loss         | 3.35      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 138       |
# |    iterations         | 800       |
# |    time_elapsed       | 28        |
# |    total_timesteps    | 4000      |
# | train/                |           |
# |    entropy_loss       | -41.3     |
# |    explained_variance | -0.0498   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 799       |
# |    policy_loss        | -51.4     |
# |    reward             | -3.928559 |
# |    std                | 1.01      |
# |    value_loss         | 6.25      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 139         |
# |    iterations         | 900         |
# |    time_elapsed       | 32          |
# |    total_timesteps    | 4500        |
# | train/                |             |
# |    entropy_loss       | -41.4       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 899         |
# |    policy_loss        | 129         |
# |    reward             | -0.98333204 |
# |    std                | 1.01        |
# |    value_loss         | 13.5        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 139       |
# |    iterations         | 1000      |
# |    time_elapsed       | 35        |
# |    total_timesteps    | 5000      |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | -0.312    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 999       |
# |    policy_loss        | -99       |
# |    reward             | -4.010672 |
# |    std                | 1.01      |
# |    value_loss         | 6.24      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 139       |
# |    iterations         | 1100      |
# |    time_elapsed       | 39        |
# |    total_timesteps    | 5500      |
# | train/                |           |
# |    entropy_loss       | -41.4     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1099      |
# |    policy_loss        | -212      |
# |    reward             | 1.2367517 |
# |    std                | 1.01      |
# |    value_loss         | 35.2      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 139        |
# |    iterations         | 1200       |
# |    time_elapsed       | 42         |
# |    total_timesteps    | 6000       |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1199       |
# |    policy_loss        | -113       |
# |    reward             | 0.32160327 |
# |    std                | 1.01       |
# |    value_loss         | 9.65       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 139        |
# |    iterations         | 1300       |
# |    time_elapsed       | 46         |
# |    total_timesteps    | 6500       |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1299       |
# |    policy_loss        | -73.7      |
# |    reward             | -3.4776604 |
# |    std                | 1.01       |
# |    value_loss         | 5.15       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 140        |
# |    iterations         | 1400       |
# |    time_elapsed       | 49         |
# |    total_timesteps    | 7000       |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1399       |
# |    policy_loss        | 155        |
# |    reward             | 0.35829556 |
# |    std                | 1.01       |
# |    value_loss         | 18.2       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 140       |
# |    iterations         | 1500      |
# |    time_elapsed       | 53        |
# |    total_timesteps    | 7500      |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1499      |
# |    policy_loss        | -208      |
# |    reward             | 2.7483172 |
# |    std                | 1.01      |
# |    value_loss         | 59.4      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 140        |
# |    iterations         | 1600       |
# |    time_elapsed       | 56         |
# |    total_timesteps    | 8000       |
# | train/                |            |
# |    entropy_loss       | -41.5      |
# |    explained_variance | 0.0523     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1599       |
# |    policy_loss        | 233        |
# |    reward             | 0.34545362 |
# |    std                | 1.01       |
# |    value_loss         | 40.9       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 140       |
# |    iterations         | 1700      |
# |    time_elapsed       | 60        |
# |    total_timesteps    | 8500      |
# | train/                |           |
# |    entropy_loss       | -41.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1699      |
# |    policy_loss        | 51        |
# |    reward             | 3.3337283 |
# |    std                | 1.01      |
# |    value_loss         | 14.8      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 140       |
# |    iterations         | 1800      |
# |    time_elapsed       | 63        |
# |    total_timesteps    | 9000      |
# | train/                |           |
# |    entropy_loss       | -41.6     |
# |    explained_variance | -0.0734   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1799      |
# |    policy_loss        | -5.96     |
# |    reward             | 1.6243345 |
# |    std                | 1.02      |
# |    value_loss         | 0.378     |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 140       |
# |    iterations         | 1900      |
# |    time_elapsed       | 67        |
# |    total_timesteps    | 9500      |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0.000715  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 1899      |
# |    policy_loss        | 2.59      |
# |    reward             | 0.9994049 |
# |    std                | 1.02      |
# |    value_loss         | 1.85      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 141        |
# |    iterations         | 2000       |
# |    time_elapsed       | 70         |
# |    total_timesteps    | 10000      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 1999       |
# |    policy_loss        | 29.5       |
# |    reward             | -1.3883934 |
# |    std                | 1.02       |
# |    value_loss         | 1.22       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 141       |
# |    iterations         | 2100      |
# |    time_elapsed       | 74        |
# |    total_timesteps    | 10500     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2099      |
# |    policy_loss        | 123       |
# |    reward             | 1.4562865 |
# |    std                | 1.02      |
# |    value_loss         | 9.67      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 141       |
# |    iterations         | 2200      |
# |    time_elapsed       | 77        |
# |    total_timesteps    | 11000     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2199      |
# |    policy_loss        | -66.3     |
# |    reward             | -9.806904 |
# |    std                | 1.02      |
# |    value_loss         | 7.3       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 141        |
# |    iterations         | 2300       |
# |    time_elapsed       | 81         |
# |    total_timesteps    | 11500      |
# | train/                |            |
# |    entropy_loss       | -41.7      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2299       |
# |    policy_loss        | -2.65e+03  |
# |    reward             | -20.535526 |
# |    std                | 1.02       |
# |    value_loss         | 4.65e+03   |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 141       |
# |    iterations         | 2400      |
# |    time_elapsed       | 84        |
# |    total_timesteps    | 12000     |
# | train/                |           |
# |    entropy_loss       | -41.7     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2399      |
# |    policy_loss        | 24        |
# |    reward             | 1.0629094 |
# |    std                | 1.02      |
# |    value_loss         | 2.5       |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 141        |
# |    iterations         | 2500       |
# |    time_elapsed       | 88         |
# |    total_timesteps    | 12500      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2499       |
# |    policy_loss        | -49.6      |
# |    reward             | 0.37323892 |
# |    std                | 1.02       |
# |    value_loss         | 1.59       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 2600      |
# |    time_elapsed       | 91        |
# |    total_timesteps    | 13000     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2599      |
# |    policy_loss        | -27       |
# |    reward             | 1.3083143 |
# |    std                | 1.02      |
# |    value_loss         | 0.534     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 142        |
# |    iterations         | 2700       |
# |    time_elapsed       | 94         |
# |    total_timesteps    | 13500      |
# | train/                |            |
# |    entropy_loss       | -41.8      |
# |    explained_variance | 0.0195     |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 2699       |
# |    policy_loss        | -41.8      |
# |    reward             | -1.0799911 |
# |    std                | 1.02       |
# |    value_loss         | 2.44       |
# --------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 142      |
# |    iterations         | 2800     |
# |    time_elapsed       | 98       |
# |    total_timesteps    | 14000    |
# | train/                |          |
# |    entropy_loss       | -41.8    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 2799     |
# |    policy_loss        | 337      |
# |    reward             | 2.208143 |
# |    std                | 1.02     |
# |    value_loss         | 69.6     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 2900      |
# |    time_elapsed       | 102       |
# |    total_timesteps    | 14500     |
# | train/                |           |
# |    entropy_loss       | -41.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 2899      |
# |    policy_loss        | -90.9     |
# |    reward             | 1.3153307 |
# |    std                | 1.02      |
# |    value_loss         | 4.66      |
# -------------------------------------
# ----------------------------------------
# | time/                 |              |
# |    fps                | 141          |
# |    iterations         | 3000         |
# |    time_elapsed       | 105          |
# |    total_timesteps    | 15000        |
# | train/                |              |
# |    entropy_loss       | -41.8        |
# |    explained_variance | -1.19e-07    |
# |    learning_rate      | 0.0007       |
# |    n_updates          | 2999         |
# |    policy_loss        | -9.25        |
# |    reward             | -0.020414623 |
# |    std                | 1.02         |
# |    value_loss         | 0.132        |
# ----------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 141         |
# |    iterations         | 3100        |
# |    time_elapsed       | 109         |
# |    total_timesteps    | 15500       |
# | train/                |             |
# |    entropy_loss       | -41.9       |
# |    explained_variance | -1.19e-07   |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3099        |
# |    policy_loss        | 89.8        |
# |    reward             | -0.21376915 |
# |    std                | 1.03        |
# |    value_loss         | 4.66        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 141        |
# |    iterations         | 3200       |
# |    time_elapsed       | 112        |
# |    total_timesteps    | 16000      |
# | train/                |            |
# |    entropy_loss       | -41.9      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 3199       |
# |    policy_loss        | -38.1      |
# |    reward             | -2.3477583 |
# |    std                | 1.03       |
# |    value_loss         | 4.12       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 141       |
# |    iterations         | 3300      |
# |    time_elapsed       | 116       |
# |    total_timesteps    | 16500     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3299      |
# |    policy_loss        | -52.3     |
# |    reward             | 0.5293865 |
# |    std                | 1.03      |
# |    value_loss         | 3.67      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 3400      |
# |    time_elapsed       | 119       |
# |    total_timesteps    | 17000     |
# | train/                |           |
# |    entropy_loss       | -41.9     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3399      |
# |    policy_loss        | -30.1     |
# |    reward             | 7.1667824 |
# |    std                | 1.03      |
# |    value_loss         | 9.39      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 142         |
# |    iterations         | 3500        |
# |    time_elapsed       | 123         |
# |    total_timesteps    | 17500       |
# | train/                |             |
# |    entropy_loss       | -42         |
# |    explained_variance | -0.00858    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3499        |
# |    policy_loss        | 96.3        |
# |    reward             | -0.22258572 |
# |    std                | 1.03        |
# |    value_loss         | 9           |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 3600      |
# |    time_elapsed       | 126       |
# |    total_timesteps    | 18000     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3599      |
# |    policy_loss        | -96       |
# |    reward             | 1.7647082 |
# |    std                | 1.03      |
# |    value_loss         | 8.22      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 3700      |
# |    time_elapsed       | 129       |
# |    total_timesteps    | 18500     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3699      |
# |    policy_loss        | 142       |
# |    reward             | 1.9066213 |
# |    std                | 1.03      |
# |    value_loss         | 13.5      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 3800      |
# |    time_elapsed       | 133       |
# |    total_timesteps    | 19000     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | -0.478    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3799      |
# |    policy_loss        | 71.4      |
# |    reward             | 1.0005893 |
# |    std                | 1.03      |
# |    value_loss         | 3.71      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 142         |
# |    iterations         | 3900        |
# |    time_elapsed       | 136         |
# |    total_timesteps    | 19500       |
# | train/                |             |
# |    entropy_loss       | -42         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 3899        |
# |    policy_loss        | -113        |
# |    reward             | -0.08188314 |
# |    std                | 1.03        |
# |    value_loss         | 8.5         |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 4000      |
# |    time_elapsed       | 140       |
# |    total_timesteps    | 20000     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 3999      |
# |    policy_loss        | 6.69      |
# |    reward             | 1.8166423 |
# |    std                | 1.03      |
# |    value_loss         | 3.21      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 142         |
# |    iterations         | 4100        |
# |    time_elapsed       | 143         |
# |    total_timesteps    | 20500       |
# | train/                |             |
# |    entropy_loss       | -42         |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4099        |
# |    policy_loss        | 3.97        |
# |    reward             | 0.020475978 |
# |    std                | 1.03        |
# |    value_loss         | 1.09        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 4200      |
# |    time_elapsed       | 147       |
# |    total_timesteps    | 21000     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4199      |
# |    policy_loss        | -219      |
# |    reward             | 1.5841429 |
# |    std                | 1.03      |
# |    value_loss         | 29.2      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 142      |
# |    iterations         | 4300     |
# |    time_elapsed       | 150      |
# |    total_timesteps    | 21500    |
# | train/                |          |
# |    entropy_loss       | -42      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4299     |
# |    policy_loss        | -35      |
# |    reward             | 4.286633 |
# |    std                | 1.03     |
# |    value_loss         | 2.26     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 142       |
# |    iterations         | 4400      |
# |    time_elapsed       | 153       |
# |    total_timesteps    | 22000     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 0.0501    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4399      |
# |    policy_loss        | -205      |
# |    reward             | 3.0652566 |
# |    std                | 1.03      |
# |    value_loss         | 29.1      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 4500      |
# |    time_elapsed       | 157       |
# |    total_timesteps    | 22500     |
# | train/                |           |
# |    entropy_loss       | -42       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 4499      |
# |    policy_loss        | 286       |
# |    reward             | 0.9811628 |
# |    std                | 1.03      |
# |    value_loss         | 46.8      |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 143      |
# |    iterations         | 4600     |
# |    time_elapsed       | 160      |
# |    total_timesteps    | 23000    |
# | train/                |          |
# |    entropy_loss       | -42      |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 4599     |
# |    policy_loss        | 32.1     |
# |    reward             | 2.527636 |
# |    std                | 1.03     |
# |    value_loss         | 2.12     |
# ------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 143         |
# |    iterations         | 4700        |
# |    time_elapsed       | 164         |
# |    total_timesteps    | 23500       |
# | train/                |             |
# |    entropy_loss       | -42         |
# |    explained_variance | 0.0282      |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 4699        |
# |    policy_loss        | -57.1       |
# |    reward             | 0.036566436 |
# |    std                | 1.03        |
# |    value_loss         | 5.12        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 4800       |
# |    time_elapsed       | 167        |
# |    total_timesteps    | 24000      |
# | train/                |            |
# |    entropy_loss       | -42.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4799       |
# |    policy_loss        | -200       |
# |    reward             | -1.1245095 |
# |    std                | 1.03       |
# |    value_loss         | 26.7       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 4900       |
# |    time_elapsed       | 171        |
# |    total_timesteps    | 24500      |
# | train/                |            |
# |    entropy_loss       | -42.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4899       |
# |    policy_loss        | -128       |
# |    reward             | 0.81897354 |
# |    std                | 1.03       |
# |    value_loss         | 12         |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 5000       |
# |    time_elapsed       | 174        |
# |    total_timesteps    | 25000      |
# | train/                |            |
# |    entropy_loss       | -42.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 4999       |
# |    policy_loss        | -60.7      |
# |    reward             | 0.13401902 |
# |    std                | 1.03       |
# |    value_loss         | 4.01       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 5100      |
# |    time_elapsed       | 177       |
# |    total_timesteps    | 25500     |
# | train/                |           |
# |    entropy_loss       | -42.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5099      |
# |    policy_loss        | 261       |
# |    reward             | 1.9537575 |
# |    std                | 1.03      |
# |    value_loss         | 45        |
# -------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 143      |
# |    iterations         | 5200     |
# |    time_elapsed       | 181      |
# |    total_timesteps    | 26000    |
# | train/                |          |
# |    entropy_loss       | -42.1    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 5199     |
# |    policy_loss        | -222     |
# |    reward             | 7.490017 |
# |    std                | 1.03     |
# |    value_loss         | 82.3     |
# ------------------------------------
# day: 2892, episode: 10
# begin_total_asset: 1000000.00
# end_total_asset: 3187761.53
# total_reward: 2187761.53
# total_cost: 7742.76
# total_trades: 47121
# Sharpe: 0.546
# =================================
# ---------------------------------------
# | time/                 |             |
# |    fps                | 143         |
# |    iterations         | 5300        |
# |    time_elapsed       | 184         |
# |    total_timesteps    | 26500       |
# | train/                |             |
# |    entropy_loss       | -42.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5299        |
# |    policy_loss        | 15.2        |
# |    reward             | 0.050645974 |
# |    std                | 1.04        |
# |    value_loss         | 0.305       |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 5400      |
# |    time_elapsed       | 188       |
# |    total_timesteps    | 27000     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | -2.38e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5399      |
# |    policy_loss        | -74.7     |
# |    reward             | 0.019676  |
# |    std                | 1.04      |
# |    value_loss         | 5.91      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 5500      |
# |    time_elapsed       | 191       |
# |    total_timesteps    | 27500     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | -0.0482   |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 5499      |
# |    policy_loss        | 30.9      |
# |    reward             | 1.8178662 |
# |    std                | 1.04      |
# |    value_loss         | 9.95      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 5600       |
# |    time_elapsed       | 195        |
# |    total_timesteps    | 28000      |
# | train/                |            |
# |    entropy_loss       | -42.4      |
# |    explained_variance | 1.19e-07   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5599       |
# |    policy_loss        | -93.3      |
# |    reward             | -0.4410713 |
# |    std                | 1.04       |
# |    value_loss         | 6.25       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 143         |
# |    iterations         | 5700        |
# |    time_elapsed       | 198         |
# |    total_timesteps    | 28500       |
# | train/                |             |
# |    entropy_loss       | -42.3       |
# |    explained_variance | -0.00365    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5699        |
# |    policy_loss        | -96.1       |
# |    reward             | -0.80104846 |
# |    std                | 1.04        |
# |    value_loss         | 10.4        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 5800       |
# |    time_elapsed       | 202        |
# |    total_timesteps    | 29000      |
# | train/                |            |
# |    entropy_loss       | -42.3      |
# |    explained_variance | -0.0636    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 5799       |
# |    policy_loss        | -17.7      |
# |    reward             | 0.89140505 |
# |    std                | 1.04       |
# |    value_loss         | 3.32       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 143         |
# |    iterations         | 5900        |
# |    time_elapsed       | 205         |
# |    total_timesteps    | 29500       |
# | train/                |             |
# |    entropy_loss       | -42.4       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5899        |
# |    policy_loss        | -5.51       |
# |    reward             | 0.122499965 |
# |    std                | 1.04        |
# |    value_loss         | 0.182       |
# ---------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 143         |
# |    iterations         | 6000        |
# |    time_elapsed       | 209         |
# |    total_timesteps    | 30000       |
# | train/                |             |
# |    entropy_loss       | -42.4       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 5999        |
# |    policy_loss        | 80.8        |
# |    reward             | -0.91107553 |
# |    std                | 1.04        |
# |    value_loss         | 5.17        |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 6100      |
# |    time_elapsed       | 212       |
# |    total_timesteps    | 30500     |
# | train/                |           |
# |    entropy_loss       | -42.3     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6099      |
# |    policy_loss        | -60.7     |
# |    reward             | -4.065117 |
# |    std                | 1.04      |
# |    value_loss         | 5.84      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 6200       |
# |    time_elapsed       | 215        |
# |    total_timesteps    | 31000      |
# | train/                |            |
# |    entropy_loss       | -42.4      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6199       |
# |    policy_loss        | -119       |
# |    reward             | -1.5543652 |
# |    std                | 1.05       |
# |    value_loss         | 8.3        |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 6300      |
# |    time_elapsed       | 219       |
# |    total_timesteps    | 31500     |
# | train/                |           |
# |    entropy_loss       | -42.5     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6299      |
# |    policy_loss        | 107       |
# |    reward             | 2.7353306 |
# |    std                | 1.05      |
# |    value_loss         | 12.8      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 6400      |
# |    time_elapsed       | 222       |
# |    total_timesteps    | 32000     |
# | train/                |           |
# |    entropy_loss       | -42.6     |
# |    explained_variance | -0.00547  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6399      |
# |    policy_loss        | 96        |
# |    reward             | 1.3822479 |
# |    std                | 1.05      |
# |    value_loss         | 5.43      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 6500       |
# |    time_elapsed       | 226        |
# |    total_timesteps    | 32500      |
# | train/                |            |
# |    entropy_loss       | -42.6      |
# |    explained_variance | 0.00316    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6499       |
# |    policy_loss        | -17.5      |
# |    reward             | -3.4931877 |
# |    std                | 1.05       |
# |    value_loss         | 2.77       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 6600       |
# |    time_elapsed       | 229        |
# |    total_timesteps    | 33000      |
# | train/                |            |
# |    entropy_loss       | -42.7      |
# |    explained_variance | 5.96e-08   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6599       |
# |    policy_loss        | -78.1      |
# |    reward             | 0.21184576 |
# |    std                | 1.05       |
# |    value_loss         | 6.18       |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 6700       |
# |    time_elapsed       | 233        |
# |    total_timesteps    | 33500      |
# | train/                |            |
# |    entropy_loss       | -42.7      |
# |    explained_variance | -0.00238   |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6699       |
# |    policy_loss        | -631       |
# |    reward             | -6.6879826 |
# |    std                | 1.05       |
# |    value_loss         | 301        |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 6800       |
# |    time_elapsed       | 236        |
# |    total_timesteps    | 34000      |
# | train/                |            |
# |    entropy_loss       | -42.7      |
# |    explained_variance | 0.128      |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 6799       |
# |    policy_loss        | -130       |
# |    reward             | 0.22453934 |
# |    std                | 1.06       |
# |    value_loss         | 13.7       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 6900      |
# |    time_elapsed       | 239       |
# |    total_timesteps    | 34500     |
# | train/                |           |
# |    entropy_loss       | -42.7     |
# |    explained_variance | -0.00844  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 6899      |
# |    policy_loss        | -336      |
# |    reward             | 0.5393575 |
# |    std                | 1.06      |
# |    value_loss         | 83.5      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 143         |
# |    iterations         | 7000        |
# |    time_elapsed       | 243         |
# |    total_timesteps    | 35000       |
# | train/                |             |
# |    entropy_loss       | -42.7       |
# |    explained_variance | -0.00732    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 6999        |
# |    policy_loss        | 31.5        |
# |    reward             | -0.11265607 |
# |    std                | 1.06        |
# |    value_loss         | 0.895       |
# ---------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 7100      |
# |    time_elapsed       | 246       |
# |    total_timesteps    | 35500     |
# | train/                |           |
# |    entropy_loss       | -42.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7099      |
# |    policy_loss        | 38.9      |
# |    reward             | 0.7133105 |
# |    std                | 1.06      |
# |    value_loss         | 1.58      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 7200      |
# |    time_elapsed       | 250       |
# |    total_timesteps    | 36000     |
# | train/                |           |
# |    entropy_loss       | -42.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7199      |
# |    policy_loss        | -286      |
# |    reward             | 1.7799962 |
# |    std                | 1.06      |
# |    value_loss         | 46.3      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 7300      |
# |    time_elapsed       | 253       |
# |    total_timesteps    | 36500     |
# | train/                |           |
# |    entropy_loss       | -42.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7299      |
# |    policy_loss        | 161       |
# |    reward             | 0.7170681 |
# |    std                | 1.06      |
# |    value_loss         | 23.9      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 7400       |
# |    time_elapsed       | 257        |
# |    total_timesteps    | 37000      |
# | train/                |            |
# |    entropy_loss       | -42.8      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7399       |
# |    policy_loss        | -300       |
# |    reward             | -3.5129883 |
# |    std                | 1.06       |
# |    value_loss         | 44.1       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 7500      |
# |    time_elapsed       | 260       |
# |    total_timesteps    | 37500     |
# | train/                |           |
# |    entropy_loss       | -42.7     |
# |    explained_variance | 1.19e-07  |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7499      |
# |    policy_loss        | 208       |
# |    reward             | -3.552659 |
# |    std                | 1.06      |
# |    value_loss         | 32.1      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 7600      |
# |    time_elapsed       | 264       |
# |    total_timesteps    | 38000     |
# | train/                |           |
# |    entropy_loss       | -42.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7599      |
# |    policy_loss        | -101      |
# |    reward             | 1.1801535 |
# |    std                | 1.06      |
# |    value_loss         | 5.78      |
# -------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 7700      |
# |    time_elapsed       | 267       |
# |    total_timesteps    | 38500     |
# | train/                |           |
# |    entropy_loss       | -42.8     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7699      |
# |    policy_loss        | -53       |
# |    reward             | 0.9275206 |
# |    std                | 1.06      |
# |    value_loss         | 2.66      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 7800       |
# |    time_elapsed       | 271        |
# |    total_timesteps    | 39000      |
# | train/                |            |
# |    entropy_loss       | -42.8      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7799       |
# |    policy_loss        | -68.2      |
# |    reward             | -1.7279409 |
# |    std                | 1.06       |
# |    value_loss         | 2.85       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 7900      |
# |    time_elapsed       | 275       |
# |    total_timesteps    | 39500     |
# | train/                |           |
# |    entropy_loss       | -42.7     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 7899      |
# |    policy_loss        | 283       |
# |    reward             | 2.32455   |
# |    std                | 1.06      |
# |    value_loss         | 61.6      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 8000       |
# |    time_elapsed       | 278        |
# |    total_timesteps    | 40000      |
# | train/                |            |
# |    entropy_loss       | -42.8      |
# |    explained_variance | 0.00847    |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 7999       |
# |    policy_loss        | -91.8      |
# |    reward             | 0.65985394 |
# |    std                | 1.06       |
# |    value_loss         | 6.04       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 8100      |
# |    time_elapsed       | 282       |
# |    total_timesteps    | 40500     |
# | train/                |           |
# |    entropy_loss       | -42.8     |
# |    explained_variance | -1.19e-07 |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8099      |
# |    policy_loss        | -110      |
# |    reward             | 3.1460335 |
# |    std                | 1.06      |
# |    value_loss         | 13.7      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 8200       |
# |    time_elapsed       | 285        |
# |    total_timesteps    | 41000      |
# | train/                |            |
# |    entropy_loss       | -42.8      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8199       |
# |    policy_loss        | -37.3      |
# |    reward             | 0.04887711 |
# |    std                | 1.06       |
# |    value_loss         | 1          |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 143         |
# |    iterations         | 8300        |
# |    time_elapsed       | 289         |
# |    total_timesteps    | 41500       |
# | train/                |             |
# |    entropy_loss       | -42.9       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8299        |
# |    policy_loss        | 27.7        |
# |    reward             | -0.84631824 |
# |    std                | 1.06        |
# |    value_loss         | 0.783       |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 8400       |
# |    time_elapsed       | 292        |
# |    total_timesteps    | 42000      |
# | train/                |            |
# |    entropy_loss       | -43        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8399       |
# |    policy_loss        | 2.78       |
# |    reward             | -1.6576338 |
# |    std                | 1.07       |
# |    value_loss         | 0.483      |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 8500      |
# |    time_elapsed       | 296       |
# |    total_timesteps    | 42500     |
# | train/                |           |
# |    entropy_loss       | -43       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8499      |
# |    policy_loss        | 50.4      |
# |    reward             | 1.4188771 |
# |    std                | 1.07      |
# |    value_loss         | 2.06      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 8600       |
# |    time_elapsed       | 299        |
# |    total_timesteps    | 43000      |
# | train/                |            |
# |    entropy_loss       | -43        |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8599       |
# |    policy_loss        | 16.3       |
# |    reward             | -7.3555183 |
# |    std                | 1.07       |
# |    value_loss         | 22.5       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 8700      |
# |    time_elapsed       | 303       |
# |    total_timesteps    | 43500     |
# | train/                |           |
# |    entropy_loss       | -43       |
# |    explained_variance | 0.0222    |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8699      |
# |    policy_loss        | 20.4      |
# |    reward             | 1.5501578 |
# |    std                | 1.07      |
# |    value_loss         | 1.15      |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 8800       |
# |    time_elapsed       | 306        |
# |    total_timesteps    | 44000      |
# | train/                |            |
# |    entropy_loss       | -43        |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 8799       |
# |    policy_loss        | -46.9      |
# |    reward             | 0.64812475 |
# |    std                | 1.07       |
# |    value_loss         | 1.66       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 8900      |
# |    time_elapsed       | 310       |
# |    total_timesteps    | 44500     |
# | train/                |           |
# |    entropy_loss       | -43       |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 8899      |
# |    policy_loss        | 80.6      |
# |    reward             | 0.8562285 |
# |    std                | 1.07      |
# |    value_loss         | 4.46      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 143         |
# |    iterations         | 9000        |
# |    time_elapsed       | 313         |
# |    total_timesteps    | 45000       |
# | train/                |             |
# |    entropy_loss       | -43.1       |
# |    explained_variance | 1.19e-07    |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 8999        |
# |    policy_loss        | 37.2        |
# |    reward             | -0.47763506 |
# |    std                | 1.07        |
# |    value_loss         | 5.75        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 9100       |
# |    time_elapsed       | 317        |
# |    total_timesteps    | 45500      |
# | train/                |            |
# |    entropy_loss       | -43.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9099       |
# |    policy_loss        | 187        |
# |    reward             | 0.79475695 |
# |    std                | 1.07       |
# |    value_loss         | 18         |
# --------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 9200       |
# |    time_elapsed       | 320        |
# |    total_timesteps    | 46000      |
# | train/                |            |
# |    entropy_loss       | -43.1      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9199       |
# |    policy_loss        | 239        |
# |    reward             | -1.0064074 |
# |    std                | 1.07       |
# |    value_loss         | 29.3       |
# --------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 143         |
# |    iterations         | 9300        |
# |    time_elapsed       | 324         |
# |    total_timesteps    | 46500       |
# | train/                |             |
# |    entropy_loss       | -43.1       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9299        |
# |    policy_loss        | -157        |
# |    reward             | -0.15295859 |
# |    std                | 1.07        |
# |    value_loss         | 17.4        |
# ---------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 9400       |
# |    time_elapsed       | 327        |
# |    total_timesteps    | 47000      |
# | train/                |            |
# |    entropy_loss       | -43.1      |
# |    explained_variance | -1.19e-07  |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9399       |
# |    policy_loss        | 99.8       |
# |    reward             | 0.08487628 |
# |    std                | 1.07       |
# |    value_loss         | 6.98       |
# --------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 9500      |
# |    time_elapsed       | 331       |
# |    total_timesteps    | 47500     |
# | train/                |           |
# |    entropy_loss       | -43.1     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9499      |
# |    policy_loss        | 167       |
# |    reward             | 1.4760301 |
# |    std                | 1.07      |
# |    value_loss         | 19.8      |
# -------------------------------------
# ---------------------------------------
# | time/                 |             |
# |    fps                | 143         |
# |    iterations         | 9600        |
# |    time_elapsed       | 334         |
# |    total_timesteps    | 48000       |
# | train/                |             |
# |    entropy_loss       | -43.2       |
# |    explained_variance | 0           |
# |    learning_rate      | 0.0007      |
# |    n_updates          | 9599        |
# |    policy_loss        | -182        |
# |    reward             | -0.50290424 |
# |    std                | 1.08        |
# |    value_loss         | 18          |
# ---------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 143      |
# |    iterations         | 9700     |
# |    time_elapsed       | 338      |
# |    total_timesteps    | 48500    |
# | train/                |          |
# |    entropy_loss       | -43.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9699     |
# |    policy_loss        | 62.7     |
# |    reward             | 3.175349 |
# |    std                | 1.08     |
# |    value_loss         | 5.37     |
# ------------------------------------
# ------------------------------------
# | time/                 |          |
# |    fps                | 143      |
# |    iterations         | 9800     |
# |    time_elapsed       | 341      |
# |    total_timesteps    | 49000    |
# | train/                |          |
# |    entropy_loss       | -43.2    |
# |    explained_variance | 0        |
# |    learning_rate      | 0.0007   |
# |    n_updates          | 9799     |
# |    policy_loss        | 146      |
# |    reward             | 9.872848 |
# |    std                | 1.08     |
# |    value_loss         | 63.9     |
# ------------------------------------
# -------------------------------------
# | time/                 |           |
# |    fps                | 143       |
# |    iterations         | 9900      |
# |    time_elapsed       | 345       |
# |    total_timesteps    | 49500     |
# | train/                |           |
# |    entropy_loss       | -43.2     |
# |    explained_variance | 0         |
# |    learning_rate      | 0.0007    |
# |    n_updates          | 9899      |
# |    policy_loss        | 32.4      |
# |    reward             | 0.1524109 |
# |    std                | 1.08      |
# |    value_loss         | 0.648     |
# -------------------------------------
# --------------------------------------
# | time/                 |            |
# |    fps                | 143        |
# |    iterations         | 10000      |
# |    time_elapsed       | 348        |
# |    total_timesteps    | 50000      |
# | train/                |            |
# |    entropy_loss       | -43.3      |
# |    explained_variance | 0          |
# |    learning_rate      | 0.0007     |
# |    n_updates          | 9999       |
# |    policy_loss        | 40.1       |
# |    reward             | 0.04456331 |
# |    std                | 1.08       |
# |    value_loss         | 1.94       |
# --------------------------------------

# %% [markdown]
# ### Model 2: DDPG

# %%
agent = DRLAgent(env = env_train)
model_ddpg = agent.get_model("ddpg")
# Out:
# {'batch_size': 128, 'buffer_size': 50000, 'learning_rate': 0.001}
# Using cuda device

# %%
trained_ddpg = agent.train_model(model=model_ddpg, 
                             tb_log_name='ddpg',
                             total_timesteps=50000)
# Out:
# day: 2892, episode: 20
# begin_total_asset: 1000000.00
# end_total_asset: 3592519.15
# total_reward: 2592519.15
# total_cost: 4687.48
# total_trades: 39390
# Sharpe: 0.739
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 110       |
# |    time_elapsed    | 104       |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | -14.9     |
# |    critic_loss     | 42.6      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 8679      |
# |    reward          | 5.7052374 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 103       |
# |    time_elapsed    | 224       |
# |    total_timesteps | 23144     |
# | train/             |           |
# |    actor_loss      | -11.4     |
# |    critic_loss     | 2.59      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 20251     |
# |    reward          | 5.7052374 |
# ----------------------------------
# day: 2892, episode: 30
# begin_total_asset: 1000000.00
# end_total_asset: 3957386.73
# total_reward: 2957386.73
# total_cost: 999.00
# total_trades: 37596
# Sharpe: 0.736
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 12        |
# |    fps             | 100       |
# |    time_elapsed    | 344       |
# |    total_timesteps | 34716     |
# | train/             |           |
# |    actor_loss      | -10.4     |
# |    critic_loss     | 1.61      |
# |    learning_rate   | 0.001     |
# |    n_updates       | 31823     |
# |    reward          | 5.7052374 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 99        |
# |    time_elapsed    | 465       |
# |    total_timesteps | 46288     |
# | train/             |           |
# |    actor_loss      | -10.5     |
# |    critic_loss     | 0.903     |
# |    learning_rate   | 0.001     |
# |    n_updates       | 43395     |
# |    reward          | 5.7052374 |
# ----------------------------------

# %% [markdown]
# ### Model 3: PPO

# %%
agent = DRLAgent(env = env_train)
PPO_PARAMS = {
    "n_steps": 2048,
    "ent_coef": 0.01,
    "learning_rate": 0.00025,
    "batch_size": 128,
}
model_ppo = agent.get_model("ppo",model_kwargs = PPO_PARAMS)
# Out:
# {'n_steps': 2048, 'ent_coef': 0.01, 'learning_rate': 0.00025, 'batch_size': 128}
# Using cuda device

# %%
trained_ppo = agent.train_model(model=model_ppo, 
                             tb_log_name='ppo',
                             total_timesteps=50000)
# Out:
# -----------------------------------
# | time/              |            |
# |    fps             | 165        |
# |    iterations      | 1          |
# |    time_elapsed    | 12         |
# |    total_timesteps | 2048       |
# | train/             |            |
# |    reward          | 0.27658287 |
# -----------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 160         |
# |    iterations           | 2           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.015207985 |
# |    clip_fraction        | 0.223       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.2       |
# |    explained_variance   | -0.0126     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 3.37        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0259     |
# |    reward               | 0.65249425  |
# |    std                  | 1           |
# |    value_loss           | 10.5        |
# -----------------------------------------
# day: 2892, episode: 40
# begin_total_asset: 1000000.00
# end_total_asset: 2692613.41
# total_reward: 1692613.41
# total_cost: 345081.12
# total_trades: 80236
# Sharpe: 0.562
# =================================
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 159        |
# |    iterations           | 3          |
# |    time_elapsed         | 38         |
# |    total_timesteps      | 6144       |
# | train/                  |            |
# |    approx_kl            | 0.01633561 |
# |    clip_fraction        | 0.205      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.3      |
# |    explained_variance   | 0.00105    |
# |    learning_rate        | 0.00025    |
# |    loss                 | 35.5       |
# |    n_updates            | 20         |
# |    policy_gradient_loss | -0.0155    |
# |    reward               | -1.6211109 |
# |    std                  | 1.01       |
# |    value_loss           | 44.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 158         |
# |    iterations           | 4           |
# |    time_elapsed         | 51          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.013639852 |
# |    clip_fraction        | 0.126       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0153     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 48.6        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0155     |
# |    reward               | 4.460654    |
# |    std                  | 1.01        |
# |    value_loss           | 76.4        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 157         |
# |    iterations           | 5           |
# |    time_elapsed         | 64          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013265347 |
# |    clip_fraction        | 0.117       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.3       |
# |    explained_variance   | -0.0169     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 13.6        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0188     |
# |    reward               | 2.6711717   |
# |    std                  | 1.01        |
# |    value_loss           | 30.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 157         |
# |    iterations           | 6           |
# |    time_elapsed         | 77          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.013743095 |
# |    clip_fraction        | 0.131       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | -0.00163    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 24.4        |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0214     |
# |    reward               | 2.4510612   |
# |    std                  | 1.01        |
# |    value_loss           | 62.6        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 157         |
# |    iterations           | 7           |
# |    time_elapsed         | 91          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.016789166 |
# |    clip_fraction        | 0.179       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.4       |
# |    explained_variance   | 0.0151      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 41.3        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0242     |
# |    reward               | 1.3114874   |
# |    std                  | 1.01        |
# |    value_loss           | 58.1        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 157         |
# |    iterations           | 8           |
# |    time_elapsed         | 104         |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.019948123 |
# |    clip_fraction        | 0.206       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | -0.00549    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.1        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0214     |
# |    reward               | 0.5546479   |
# |    std                  | 1.01        |
# |    value_loss           | 23.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 9           |
# |    time_elapsed         | 117         |
# |    total_timesteps      | 18432       |
# | train/                  |             |
# |    approx_kl            | 0.017302716 |
# |    clip_fraction        | 0.177       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.5       |
# |    explained_variance   | -0.028      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 13.1        |
# |    n_updates            | 80          |
# |    policy_gradient_loss | -0.0141     |
# |    reward               | 0.36263618  |
# |    std                  | 1.01        |
# |    value_loss           | 46.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 10          |
# |    time_elapsed         | 130         |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.017772019 |
# |    clip_fraction        | 0.151       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | 0.0201      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 37.9        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.0219     |
# |    reward               | 1.3380458   |
# |    std                  | 1.02        |
# |    value_loss           | 64.8        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 11          |
# |    time_elapsed         | 143         |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.020979047 |
# |    clip_fraction        | 0.219       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.6       |
# |    explained_variance   | -0.0252     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 27.7        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0157     |
# |    reward               | 3.7232587   |
# |    std                  | 1.02        |
# |    value_loss           | 55.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 12          |
# |    time_elapsed         | 157         |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.029937552 |
# |    clip_fraction        | 0.28        |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.7       |
# |    explained_variance   | -0.00433    |
# |    learning_rate        | 0.00025     |
# |    loss                 | 11.6        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.0151     |
# |    reward               | -0.21071689 |
# |    std                  | 1.02        |
# |    value_loss           | 23          |
# -----------------------------------------
# ----------------------------------------
# | time/                   |            |
# |    fps                  | 156        |
# |    iterations           | 13         |
# |    time_elapsed         | 170        |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.02125568 |
# |    clip_fraction        | 0.244      |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -41.7      |
# |    explained_variance   | -0.000474  |
# |    learning_rate        | 0.00025    |
# |    loss                 | 33.9       |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.0174    |
# |    reward               | 0.3046624  |
# |    std                  | 1.02       |
# |    value_loss           | 85.1       |
# ----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 14          |
# |    time_elapsed         | 183         |
# |    total_timesteps      | 28672       |
# | train/                  |             |
# |    approx_kl            | 0.021271437 |
# |    clip_fraction        | 0.255       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.8       |
# |    explained_variance   | 0.00129     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 18.9        |
# |    n_updates            | 130         |
# |    policy_gradient_loss | -0.0103     |
# |    reward               | 1.2507067   |
# |    std                  | 1.02        |
# |    value_loss           | 42.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 15          |
# |    time_elapsed         | 196         |
# |    total_timesteps      | 30720       |
# | train/                  |             |
# |    approx_kl            | 0.023480592 |
# |    clip_fraction        | 0.196       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.9       |
# |    explained_variance   | -0.0199     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.6        |
# |    n_updates            | 140         |
# |    policy_gradient_loss | -0.0131     |
# |    reward               | 2.5811338   |
# |    std                  | 1.03        |
# |    value_loss           | 21.8        |
# -----------------------------------------
# ------------------------------------------
# | time/                   |              |
# |    fps                  | 156          |
# |    iterations           | 16           |
# |    time_elapsed         | 209          |
# |    total_timesteps      | 32768        |
# | train/                  |              |
# |    approx_kl            | 0.0191725    |
# |    clip_fraction        | 0.213        |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -41.9        |
# |    explained_variance   | -0.00333     |
# |    learning_rate        | 0.00025      |
# |    loss                 | 17.1         |
# |    n_updates            | 150          |
# |    policy_gradient_loss | -0.0188      |
# |    reward               | -0.024714569 |
# |    std                  | 1.03         |
# |    value_loss           | 38.1         |
# ------------------------------------------
# day: 2892, episode: 50
# begin_total_asset: 1000000.00
# end_total_asset: 3367791.87
# total_reward: 2367791.87
# total_cost: 309555.56
# total_trades: 76926
# Sharpe: 0.661
# =================================
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 156         |
# |    iterations           | 17          |
# |    time_elapsed         | 223         |
# |    total_timesteps      | 34816       |
# | train/                  |             |
# |    approx_kl            | 0.027460776 |
# |    clip_fraction        | 0.209       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -41.9       |
# |    explained_variance   | -0.006      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 17.7        |
# |    n_updates            | 160         |
# |    policy_gradient_loss | -0.0107     |
# |    reward               | 0.7888741   |
# |    std                  | 1.03        |
# |    value_loss           | 32.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 18          |
# |    time_elapsed         | 236         |
# |    total_timesteps      | 36864       |
# | train/                  |             |
# |    approx_kl            | 0.023554265 |
# |    clip_fraction        | 0.328       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42         |
# |    explained_variance   | 0.00461     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 34.5        |
# |    n_updates            | 170         |
# |    policy_gradient_loss | -0.0128     |
# |    reward               | 0.21230395  |
# |    std                  | 1.03        |
# |    value_loss           | 76.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 19          |
# |    time_elapsed         | 249         |
# |    total_timesteps      | 38912       |
# | train/                  |             |
# |    approx_kl            | 0.019302616 |
# |    clip_fraction        | 0.208       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | 0.00138     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 7.59        |
# |    n_updates            | 180         |
# |    policy_gradient_loss | -0.0228     |
# |    reward               | -0.20436543 |
# |    std                  | 1.03        |
# |    value_loss           | 13.5        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 20          |
# |    time_elapsed         | 263         |
# |    total_timesteps      | 40960       |
# | train/                  |             |
# |    approx_kl            | 0.02037433  |
# |    clip_fraction        | 0.233       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.1       |
# |    explained_variance   | 0.0186      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 10.8        |
# |    n_updates            | 190         |
# |    policy_gradient_loss | -0.0215     |
# |    reward               | -0.42412946 |
# |    std                  | 1.04        |
# |    value_loss           | 42.3        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 21          |
# |    time_elapsed         | 276         |
# |    total_timesteps      | 43008       |
# | train/                  |             |
# |    approx_kl            | 0.018008176 |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | 0.00507     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 14          |
# |    n_updates            | 200         |
# |    policy_gradient_loss | -0.0175     |
# |    reward               | -9.7877445  |
# |    std                  | 1.04        |
# |    value_loss           | 38          |
# -----------------------------------------
# ---------------------------------------
# | time/                   |           |
# |    fps                  | 155       |
# |    iterations           | 22        |
# |    time_elapsed         | 289       |
# |    total_timesteps      | 45056     |
# | train/                  |           |
# |    approx_kl            | 0.0212068 |
# |    clip_fraction        | 0.149     |
# |    clip_range           | 0.2       |
# |    entropy_loss         | -42.2     |
# |    explained_variance   | -0.00978  |
# |    learning_rate        | 0.00025   |
# |    loss                 | 18.9      |
# |    n_updates            | 210       |
# |    policy_gradient_loss | -0.0101   |
# |    reward               | 3.525863  |
# |    std                  | 1.04      |
# |    value_loss           | 34.8      |
# ---------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 23          |
# |    time_elapsed         | 302         |
# |    total_timesteps      | 47104       |
# | train/                  |             |
# |    approx_kl            | 0.018262116 |
# |    clip_fraction        | 0.197       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.2       |
# |    explained_variance   | 0.0143      |
# |    learning_rate        | 0.00025     |
# |    loss                 | 46.7        |
# |    n_updates            | 220         |
# |    policy_gradient_loss | -0.0154     |
# |    reward               | -0.14553371 |
# |    std                  | 1.04        |
# |    value_loss           | 85.9        |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 24          |
# |    time_elapsed         | 315         |
# |    total_timesteps      | 49152       |
# | train/                  |             |
# |    approx_kl            | 0.030582216 |
# |    clip_fraction        | 0.234       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.3       |
# |    explained_variance   | -0.0068     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 62.8        |
# |    n_updates            | 230         |
# |    policy_gradient_loss | -0.00983    |
# |    reward               | 1.7929913   |
# |    std                  | 1.04        |
# |    value_loss           | 162         |
# -----------------------------------------
# -----------------------------------------
# | time/                   |             |
# |    fps                  | 155         |
# |    iterations           | 25          |
# |    time_elapsed         | 329         |
# |    total_timesteps      | 51200       |
# | train/                  |             |
# |    approx_kl            | 0.01968589  |
# |    clip_fraction        | 0.195       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -42.3       |
# |    explained_variance   | 0.00447     |
# |    learning_rate        | 0.00025     |
# |    loss                 | 43.1        |
# |    n_updates            | 240         |
# |    policy_gradient_loss | -0.0131     |
# |    reward               | -0.92996037 |
# |    std                  | 1.04        |
# |    value_loss           | 157         |
# -----------------------------------------

# %% [markdown]
# ### Model 4: TD3

# %%
agent = DRLAgent(env = env_train)
TD3_PARAMS = {"batch_size": 100, 
              "buffer_size": 1000000, 
              "learning_rate": 0.001}

model_td3 = agent.get_model("td3",model_kwargs = TD3_PARAMS)
# Out:
# {'batch_size': 100, 'buffer_size': 1000000, 'learning_rate': 0.001}
# Using cuda device

# %%
trained_td3 = agent.train_model(model=model_td3, 
                             tb_log_name='td3',
                             total_timesteps=30000)
# Out:
# day: 2892, episode: 60
# begin_total_asset: 1000000.00
# end_total_asset: 4367128.67
# total_reward: 3367128.67
# total_cost: 1083.95
# total_trades: 46312
# Sharpe: 0.783
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 4        |
# |    fps             | 113      |
# |    time_elapsed    | 101      |
# |    total_timesteps | 11572    |
# | train/             |          |
# |    actor_loss      | 39.2     |
# |    critic_loss     | 97.5     |
# |    learning_rate   | 0.001    |
# |    n_updates       | 8679     |
# |    reward          | 6.283589 |
# ---------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 8        |
# |    fps             | 106      |
# |    time_elapsed    | 218      |
# |    total_timesteps | 23144    |
# | train/             |          |
# |    actor_loss      | 24.2     |
# |    critic_loss     | 63       |
# |    learning_rate   | 0.001    |
# |    n_updates       | 20251    |
# |    reward          | 6.283589 |
# ---------------------------------

# %% [markdown]
# ### Model 5: SAC

# %%
agent = DRLAgent(env = env_train)
SAC_PARAMS = {
    "batch_size": 128,
    "buffer_size": 1000000,
    "learning_rate": 0.0001,
    "learning_starts": 100,
    "ent_coef": "auto_0.1",
}

model_sac = agent.get_model("sac",model_kwargs = SAC_PARAMS)
# Out:
# {'batch_size': 128, 'buffer_size': 1000000, 'learning_rate': 0.0001, 'learning_starts': 100, 'ent_coef': 'auto_0.1'}
# Using cuda device
# /home/henry/miniconda3/envs/finrl/lib/python3.7/site-packages/stable_baselines3/common/buffers.py:221: UserWarning: This system does not have apparently enough memory to store the complete replay buffer 2.45GB > 2.31GB
#   "This system does not have apparently enough memory to store the complete "

# %%
trained_sac = agent.train_model(model=model_sac, 
                             tb_log_name='sac',
                             total_timesteps=60000)
# Out:
# day: 2892, episode: 70
# begin_total_asset: 1000000.00
# end_total_asset: 4427374.52
# total_reward: 3427374.52
# total_cost: 214877.29
# total_trades: 58009
# Sharpe: 0.818
# =================================
# ----------------------------------
# | time/              |           |
# |    episodes        | 4         |
# |    fps             | 56        |
# |    time_elapsed    | 203       |
# |    total_timesteps | 11572     |
# | train/             |           |
# |    actor_loss      | 505       |
# |    critic_loss     | 168       |
# |    ent_coef        | 0.129     |
# |    ent_coef_loss   | -98.2     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 11471     |
# |    reward          | 3.2633708 |
# ----------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 8         |
# |    fps             | 56        |
# |    time_elapsed    | 406       |
# |    total_timesteps | 23144     |
# | train/             |           |
# |    actor_loss      | 208       |
# |    critic_loss     | 63.1      |
# |    ent_coef        | 0.0411    |
# |    ent_coef_loss   | -132      |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 23043     |
# |    reward          | 7.4360914 |
# ----------------------------------
# day: 2892, episode: 80
# begin_total_asset: 1000000.00
# end_total_asset: 6840257.37
# total_reward: 5840257.37
# total_cost: 6757.89
# total_trades: 49937
# Sharpe: 0.892
# =================================
# ---------------------------------
# | time/              |          |
# |    episodes        | 12       |
# |    fps             | 56       |
# |    time_elapsed    | 610      |
# |    total_timesteps | 34716    |
# | train/             |          |
# |    actor_loss      | 92.1     |
# |    critic_loss     | 46.1     |
# |    ent_coef        | 0.0134   |
# |    ent_coef_loss   | -126     |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 34615    |
# |    reward          | 8.880091 |
# ---------------------------------
# ----------------------------------
# | time/              |           |
# |    episodes        | 16        |
# |    fps             | 56        |
# |    time_elapsed    | 815       |
# |    total_timesteps | 46288     |
# | train/             |           |
# |    actor_loss      | 46        |
# |    critic_loss     | 9.88      |
# |    ent_coef        | 0.00459   |
# |    ent_coef_loss   | -60.9     |
# |    learning_rate   | 0.0001    |
# |    n_updates       | 46187     |
# |    reward          | 2.1676805 |
# ----------------------------------
# ---------------------------------
# | time/              |          |
# |    episodes        | 20       |
# |    fps             | 56       |
# |    time_elapsed    | 1019     |
# |    total_timesteps | 57860    |
# | train/             |          |
# |    actor_loss      | 34.4     |
# |    critic_loss     | 234      |
# |    ent_coef        | 0.00267  |
# |    ent_coef_loss   | -1.51    |
# |    learning_rate   | 0.0001   |
# |    n_updates       | 57759    |
# |    reward          | 1.756596 |
# ---------------------------------

# %% [markdown]
# ## Trading
# Assume that we have $1,000,000 initial capital at 2020-07-01. We use the DDPG model to trade Dow jones 30 stocks.

# %% [markdown]
# ### Set turbulence threshold
# Set the turbulence threshold to be greater than the maximum of insample turbulence data, if current turbulence index is greater than the threshold, then we assume that the current market is volatile

# %%
data_risk_indicator = processed_full[(processed_full.date<'2020-07-01') & (processed_full.date>='2009-01-01')]
insample_risk_indicator = data_risk_indicator.drop_duplicates(subset=['date'])

# %%
insample_risk_indicator.vix.describe()
# Out:
# count    2893.000000
# mean       18.824245
# std         8.489311
# min         9.140000
# 25%        13.330000
# 50%        16.139999
# 75%        21.309999
# max        82.690002
# Name: vix, dtype: float64

# %%
insample_risk_indicator.vix.quantile(0.996)
# Out:
# 57.40400183105453

# %%
insample_risk_indicator.turbulence.describe()
# Out:
# count    2893.000000
# mean       34.573957
# std        43.781720
# min         0.000000
# 25%        14.963723
# 50%        24.122105
# 75%        39.166693
# max       652.444611
# Name: turbulence, dtype: float64

# %%
insample_risk_indicator.turbulence.quantile(0.996)
# Out:
# 276.4593474871079

# %% [markdown]
# ### Trade
#
# DRL model needs to update periodically in order to take full advantage of the data, ideally we need to retrain our model yearly, quarterly, or monthly. We also need to tune the parameters along the way, in this notebook I only use the in-sample data from 2009-01 to 2020-07 to tune the parameters once, so there is some alpha decay here as the length of trade date extends.
#
# Numerous hyperparameters – e.g. the learning rate, the total number of samples to train on – influence the learning process and are usually determined by testing some variations.

# %%
#trade = data_split(processed_full, '2020-07-01','2021-10-31')
e_trade_gym = StockTradingEnv(df = trade, turbulence_threshold = 70,risk_indicator_col='vix', **env_kwargs)
# env_trade, obs_trade = e_trade_gym.get_sb_env()

# %%
trade.head()
# Out:
#          date   tic        open        high         low       close  \
# 0  2020-07-01  AAPL   91.279999   91.839996   90.977501   90.036713
# 0  2020-07-01  AMGN  235.520004  256.230011  232.580002  242.083466
# 0  2020-07-01   AXP   95.250000   96.959999   93.639999   92.347778
# 0  2020-07-01    BA  185.880005  190.610001  180.039993  180.320007
# 0  2020-07-01   CAT  129.380005  129.399994  125.879997  121.230247
#
#         volume  day      macd     boll_ub     boll_lb     rsi_30      cci_30  \
# 0  110737200.0  2.0  3.019034   92.835525   80.297754  62.807141  107.489641
# 0    6575800.0  2.0  3.665608  234.264599  201.821546  61.279638  271.571281
# 0    3301000.0  2.0 -0.390267  110.737387   88.008448  48.504819  -66.334510
# 0   49036700.0  2.0  5.443193  220.721139  160.932863  50.925771   24.220608
# 0    2807800.0  2.0  1.278733  131.250712  113.896730  52.865423   35.572311
#
#        dx_30  close_30_sma  close_60_sma        vix  turbulence
# 0  29.730532     84.057089     77.831731  28.620001   53.070842
# 0  46.806139    216.584928    217.666551  28.620001   53.070842
# 0   3.142448     97.520674     90.952973  28.620001   53.070842
# 0  15.932920    176.472335    155.614168  28.620001   53.070842
# 0  14.457404    119.985501    114.191686  28.620001   53.070842

# %%
df_account_value, df_actions = DRLAgent.DRL_prediction(
    model=trained_sac, 
    environment = e_trade_gym)
# Out:
# hit end!

# %%
df_account_value.shape
# Out:
# (336, 2)

# %%
df_account_value.tail()
# Out:
#            date  account_value
# 331  2021-10-22   1.440544e+06
# 332  2021-10-25   1.443741e+06
# 333  2021-10-26   1.445598e+06
# 334  2021-10-27   1.430793e+06
# 335  2021-10-28   1.445795e+06

# %%
df_actions.head()
# Out:
#             AAPL  AMGN  AXP  BA  CAT  CRM  CSCO  CVX  DIS  GS  ...  MRK  MSFT  \
# date                                                           ...
# 2020-07-01    96    73    0  95   91    0    90   97    0  94  ...   52     0
# 2020-07-02    96    73    0  95   91    0    90   97    0  94  ...   52     0
# 2020-07-06    96    73    0  95   91    0    90   97    0  94  ...   52     0
# 2020-07-07    96    73    0  95   91    0    90   97    0  94  ...   52     0
# 2020-07-08    96    73    0  95   91    0    90   97    0  94  ...   52     0
#
#             NKE  PG  TRV  UNH  V  VZ  WBA  WMT
# date
# 2020-07-01    0   0   96   96  0   0   70   94
# 2020-07-02    0   0   96   96  0   0   70   94
# 2020-07-06    0   0   96   96  0   0   70   94
# 2020-07-07    0   0   96   96  0   0   70   94
# 2020-07-08    0   0   96   96  0   0   70   94
#
# [5 rows x 29 columns]

# %% [markdown]
# <a id='6'></a>
# # Part 7: Backtest Our Strategy
# Backtesting plays a key role in evaluating the performance of a trading strategy. Automated backtesting tool is preferred because it reduces the human error. We usually use the Quantopian pyfolio package to backtest our trading strategies. It is easy to use and consists of various individual plots that provide a comprehensive image of the performance of a trading strategy.

# %% [markdown]
# <a id='6.1'></a>
# ## 7.1 BackTestStats
# pass in df_account_value, this information is stored in env class

# %%
print("==============Get Backtest Results===========")
now = datetime.datetime.now().strftime('%Y%m%d-%Hh%M')

perf_stats_all = backtest_stats(account_value=df_account_value)
perf_stats_all = pd.DataFrame(perf_stats_all)
perf_stats_all.to_csv("./"+config.RESULTS_DIR+"/perf_stats_all_"+now+'.csv')
# Out:
# ==============Get Backtest Results===========
# Annual return          0.318499
# Cumulative returns     0.445795
# Annual volatility      0.154591
# Sharpe ratio           1.871926
# Calmar ratio           3.556966
# Stability              0.888863
# Max drawdown          -0.089542
# Omega ratio            1.358515
# Sortino ratio          2.858117
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.109459
# Daily value at risk   -0.018328
# dtype: float64

# %%
#baseline stats
print("==============Get Baseline Stats===========")
baseline_df = get_baseline(
        ticker="^DJI", 
        start = df_account_value.loc[0,'date'],
        end = df_account_value.loc[len(df_account_value)-1,'date'])

stats = backtest_stats(baseline_df, value_col_name = 'close')
# Out:
# ==============Get Baseline Stats===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (336, 8)
# Annual return          0.269722
# Cumulative returns     0.374922
# Annual volatility      0.139083
# Sharpe ratio           1.792302
# Calmar ratio           3.020136
# Stability              0.919220
# Max drawdown          -0.089308
# Omega ratio            1.347571
# Sortino ratio          2.655481
# Skew                        NaN
# Kurtosis                    NaN
# Tail ratio             1.052781
# Daily value at risk   -0.016534
# dtype: float64

# %%
df_account_value.loc[0,'date']
# Out:
# '2020-07-01'

# %%
df_account_value.loc[len(df_account_value)-1,'date']
# Out:
# '2021-10-28'

# %% [markdown]
# <a id='6.2'></a>
# ## 7.2 BackTestPlot

# %%
print("==============Compare to DJIA===========")
# %matplotlib inline
# S&P 500: ^GSPC
# Dow Jones Index: ^DJI
# NASDAQ 100: ^NDX
backtest_plot(df_account_value, 
             baseline_ticker = '^DJI', 
             baseline_start = df_account_value.loc[0,'date'],
             baseline_end = df_account_value.loc[len(df_account_value)-1,'date'])
# Out:
# ==============Compare to DJIA===========
# [*********************100%***********************]  1 of 1 completed
# Shape of DataFrame:  (336, 8)
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;"><th>Start date</th><td colspan=2>2020-07-01</td></tr>
#     <tr style="text-align: right;"><th>End date</th><td colspan=2>2021-10-28</td></tr>
#     <tr style="text-align: right;"><th>Total months</th><td colspan=2>16</td></tr>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>Backtest</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>Annual return</th>
#       <td>31.85%</td>
#     </tr>
#     <tr>
#       <th>Cumulative returns</th>
#       <td>44.579%</td>
#     </tr>
#     <tr>
#       <th>Annual volatility</th>
#       <td>15.459%</td>
#     </tr>
#     <tr>
#       <th>Sharpe ratio</th>
#       <td>1.87</td>
#     </tr>
#     <tr>
#       <th>Calmar ratio</th>
#       <td>3.56</td>
#     </tr>
#     <tr>
#       <th>Stability</th>
#       <td>0.89</td>
#     </tr>
#     <tr>
#       <th>Max drawdown</th>
#       <td>-8.954%</td>
#     </tr>
#     <tr>
#       <th>Omega ratio</th>
#       <td>1.36</td>
#     </tr>
#     <tr>
#       <th>Sortino ratio</th>
#       <td>2.86</td>
#     </tr>
#     <tr>
#       <th>Skew</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Kurtosis</th>
#       <td>NaN</td>
#     </tr>
#     <tr>
#       <th>Tail ratio</th>
#       <td>1.11</td>
#     </tr>
#     <tr>
#       <th>Daily value at risk</th>
#       <td>-1.833%</td>
#     </tr>
#     <tr>
#       <th>Alpha</th>
#       <td>0.02</td>
#     </tr>
#     <tr>
#       <th>Beta</th>
#       <td>1.06</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Worst drawdown periods</th>
#       <th>Net drawdown in %</th>
#       <th>Peak date</th>
#       <th>Valley date</th>
#       <th>Recovery date</th>
#       <th>Duration</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>8.95</td>
#       <td>2020-09-02</td>
#       <td>2020-09-23</td>
#       <td>2020-11-09</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>6.02</td>
#       <td>2021-06-04</td>
#       <td>2021-06-18</td>
#       <td>2021-08-11</td>
#       <td>49</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>5.85</td>
#       <td>2021-08-16</td>
#       <td>2021-09-30</td>
#       <td>2021-10-22</td>
#       <td>50</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>4.54</td>
#       <td>2021-01-14</td>
#       <td>2021-01-29</td>
#       <td>2021-02-16</td>
#       <td>24</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>3.49</td>
#       <td>2021-05-10</td>
#       <td>2021-05-12</td>
#       <td>2021-06-04</td>
#       <td>20</td>
#     </tr>
#   </tbody>
# </table>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th>Stress Events</th>
#       <th>mean</th>
#       <th>min</th>
#       <th>max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>New Normal</th>
#       <td>0.11%</td>
#       <td>-3.07%</td>
#       <td>3.77%</td>
#     </tr>
#   </tbody>
# </table>
